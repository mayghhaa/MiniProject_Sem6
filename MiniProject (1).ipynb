# %% [markdown]
# Inspecting the contents of the .npz file

# %%
import numpy as np

# Load the .npz file
data = np.load("/content/test_predictions_full_300.npz")

# List all arrays stored in the .npz file
print("Keys in the .npz file:", data.files)
# Extract and process time values
time_key = "times"  # Make sure this key exists
if time_key in data:
    time_values = np.array(data[time_key])  # Convert to NumPy array if needed

    # Find max and min time values
    max_time = np.max(time_values)
    min_time = np.min(time_values)

    print(f"Max Time: {max_time}")
    print(f"Min Time: {min_time}")
else:
    print(f"Key '{time_key}' not found in the dataset.")
# Out:
# Keys in the .npz file: ['true', 'predicted', 'times', 'vehicle_ids']
# Max Time: 4081.0
# Min Time: 99.0

# %%
import numpy as np

def print_vehicle_ids_info():
    data = np.load("test_predictions_full_300.npz")


    # Print overall data file information
    print("Data file contents:")
    for key in data.files:
        print(f"Array Name: {key}")
        print(f"Shape: {data[key].shape}")
        print(f"Data Type: {data[key].dtype}")
        print(f"First few elements: {data[key]}")
        print()

    # Get vehicle IDs
    vehicle_ids = data["vehicle_ids"]

    # Count unique vehicle IDs
    unique_ids = np.unique(vehicle_ids)
    print(f"Total rows in data: {len(vehicle_ids)}")
    print(f"Number of unique vehicle IDs: {len(unique_ids)}")

    # Print frequency of each vehicle ID
    print("\nVehicle ID frequencies:")
    unique_counts = {}
    for id in vehicle_ids:
        if id in unique_counts:
            unique_counts[id] += 1
        else:
            unique_counts[id] = 1

    # Print first 10 vehicle IDs and their frequencies
    for i, (vid, count) in enumerate(unique_counts.items()):
        print(f"Vehicle ID {vid}: appears {count} times")
        if i >= 9:  # Print only first 10
            remaining = len(unique_counts) - 10
            print(f"... and {remaining} more vehicle IDs")
            break

    # Print example of one vehicle's multiple entries
    if len(unique_ids) > 0:
        sample_id = unique_ids[0]
        print(f"\nExample: Entries for vehicle ID {sample_id}:")
        indices = np.where(vehicle_ids == sample_id)[0]
        for i, idx in enumerate(indices):  # Show first 5 positions for this vehicle
            print(f"Position {i+1}: {data['predicted'][idx]}")
            print(f"Time: {data['times'][idx]}")

        if len(indices) > 5:
            print(f"... and {len(indices)-5} more positions")

if __name__ == "__main__":
    print_vehicle_ids_info()
# Out:
# Data file contents:
# Array Name: true
# Shape: (7749, 4)
# Data Type: float64
# First few elements: [[0.33987706 0.32164875 0.62537523 0.36172222]
#  [0.36651336 0.29936155 0.71723034 0.38916667]
#  [0.67414753 0.28413575 0.79347609 0.52175   ]
#  ...
#  [0.78090765 0.24385047 0.66619972 0.34325   ]
#  [0.31691248 0.35017705 0.65099059 0.32830556]
#  [0.22130184 0.49190074 0.38343006 0.4595    ]]
#
# Array Name: predicted
# Shape: (7749, 4)
# Data Type: float32
# First few elements: [[0.34083343 0.3204603  0.6288214  0.35854965]
#  [0.36779606 0.3010285  0.7236053  0.38662297]
#  [0.67191696 0.2848128  0.77416193 0.5185673 ]
#  ...
#  [0.7837848  0.24354845 0.6516647  0.3376571 ]
#  [0.31812245 0.34774077 0.6830598  0.3240996 ]
#  [0.21209985 0.48948732 0.3804854  0.45059562]]
#
# Array Name: times
# Shape: (7749, 10)
# Data Type: float64
# First few elements: [[ 357.  358.  359. ...  364.  365.  366.]
#  [3426. 3427. 3428. ... 3433. 3434. 3435.]
#  [2728. 2729. 2730. ... 2735. 2736. 2737.]
#  ...
#  [2488. 2489. 2490. ... 2495. 2496. 2497.]
#  [1165. 1166. 1167. ... 1172. 1173. 1174.]
#  [2005. 2006. 2007. ... 2012. 2013. 2014.]]
#
# Array Name: vehicle_ids
# Shape: (7749,)
# Data Type: float64
# First few elements: [ 0. 27. 16. ... 55.  2. 76.]
#
# Total rows in data: 7749
# Number of unique vehicle IDs: 100
#
# Vehicle ID frequencies:
# Vehicle ID 0.0: appears 118 times
# Vehicle ID 27.0: appears 102 times
# Vehicle ID 16.0: appears 92 times
# Vehicle ID 19.0: appears 92 times
# Vehicle ID 17.0: appears 128 times
# Vehicle ID 48.0: appears 66 times
# Vehicle ID 54.0: appears 59 times
# Vehicle ID 69.0: appears 70 times
# Vehicle ID 8.0: appears 128 times
# Vehicle ID 44.0: appears 57 times
# ... and 90 more vehicle IDs
#
# Example: Entries for vehicle ID 0.0:
# Position 1: [0.34083343 0.3204603  0.6288214  0.35854965]
# Time: [357. 358. 359. 360. 361. 362. 363. 364. 365. 366.]
# Position 2: [0.75948364 0.81247544 0.63704103 0.10926113]
# Time: [696. 697. 698. 699. 700. 701. 702. 703. 704. 705.]
# Position 3: [0.29918578 0.39441136 0.62748003 0.28581563]
# Time: [392. 393. 394. 395. 396. 397. 398. 399. 400. 401.]
# Position 4: [0.7251797  0.2897267  0.64173406 0.45570967]
# Time: [210. 211. 212. 213. 214. 215. 216. 217. 218. 219.]
# Position 5: [0.533532   0.73878616 0.679775   0.0152543 ]
# Time: [610. 611. 612. 613. 614. 616. 617. 618. 620. 621.]
# Position 6: [0.41192442 0.72267246 0.64720833 0.09172126]
# Time: [569. 570. 571. 572. 573. 574. 575. 576. 577. 578.]
# Position 7: [0.46812904 0.7436179  0.6404297  0.05218914]
# Time: [587. 588. 589. 590. 591. 592. 593. 594. 595. 596.]
# Position 8: [0.29110554 0.42603272 0.64981985 0.2803191 ]
# Time: [403. 404. 405. 406. 407. 408. 409. 410. 411. 412.]
# Position 9: [0.2847262  0.45049292 0.63762873 0.28046393]
# Time: [413. 414. 415. 416. 417. 418. 419. 420. 421. 422.]
# Position 10: [0.38196516 0.29393017 0.6440302  0.40499046]
# Time: [338. 339. 340. 341. 342. 343. 344. 345. 346. 347.]
# Position 11: [0.54590553 0.7302872  0.6705158  0.01439595]
# Time: [611. 612. 613. 614. 616. 617. 618. 620. 621. 622.]
# Position 12: [0.6370267  0.79077566 0.6408151  0.10465661]
# Time: [647. 648. 649. 650. 651. 652. 653. 654. 655. 656.]
# Position 13: [0.65661305 0.7954378  0.6387775  0.10733482]
# Time: [651. 652. 653. 654. 655. 656. 657. 658. 659. 660.]
# Position 14: [0.2538631  0.5569509  0.64406043 0.2649785 ]
# Time: [462. 463. 464. 465. 466. 467. 468. 469. 470. 471.]
# Position 15: [0.7236414  0.8042929  0.63493955 0.10053809]
# Time: [678. 679. 680. 681. 682. 683. 684. 685. 686. 687.]
# Position 16: [0.28222394 0.45655787 0.6461829  0.28578216]
# Time: [418. 419. 420. 421. 422. 423. 424. 425. 426. 427.]
# Position 17: [0.31414974 0.6641642  0.6384571  0.10150487]
# Time: [514. 515. 516. 517. 518. 519. 520. 521. 522. 523.]
# Position 18: [0.56520647 0.2677458  0.6425995  0.52975273]
# Time: [268. 269. 270. 271. 272. 273. 274. 275. 276. 277.]
# Position 19: [0.3732108  0.69776344 0.6457594  0.10277595]
# Time: [536. 537. 538. 539. 540. 541. 542. 543. 544. 545.]
# Position 20: [0.571462   0.76370454 0.6635156  0.02275866]
# Time: [616. 617. 618. 620. 621. 622. 623. 624. 625. 626.]
# Position 21: [0.81123173 0.15535307 0.6258522  0.24620698]
# Time: [144. 145. 146. 147. 148. 149. 150. 151. 152. 153.]
# Position 22: [0.80399704 0.19238727 0.6356852  0.2842968 ]
# Time: [153. 154. 155. 156. 157. 158. 159. 160. 161. 162.]
# Position 23: [0.24581508 0.547047   0.6552508  0.26344365]
# Time: [463. 464. 465. 466. 467. 468. 469. 470. 471. 472.]
# Position 24: [0.28005615 0.460293   0.6643697  0.2866814 ]
# Time: [417. 418. 419. 420. 421. 422. 423. 424. 425. 426.]
# Position 25: [0.29281145 0.4142949  0.63618886 0.28158164]
# Time: [401. 402. 403. 404. 405. 406. 407. 408. 409. 410.]
# Position 26: [0.8479504  0.8303869  0.63731176 0.11373129]
# Time: [732. 733. 734. 735. 736. 737. 738. 739. 740. 741.]
# Position 27: [0.5564769  0.76268625 0.63437915 0.09866979]
# Time: [605. 606. 607. 608. 609. 610. 611. 612. 613. 614.]
# Position 28: [0.4453519  0.73481005 0.6510968  0.08378076]
# Time: [581. 582. 583. 584. 585. 586. 587. 588. 589. 590.]
# Position 29: [0.571965   0.76998514 0.62367386 0.10470834]
# Time: [633. 634. 635. 636. 637. 638. 639. 640. 641. 642.]
# Position 30: [0.28877407 0.4225537  0.6587925  0.27858615]
# Time: [402. 403. 404. 405. 406. 407. 408. 409. 410. 411.]
# Position 31: [0.28437287 0.4406456  0.65750295 0.2796845 ]
# Time: [408. 409. 410. 411. 412. 413. 414. 415. 416. 417.]
# Position 32: [0.6167035 0.7857779 0.6422857 0.0937704]
# Time: [643. 644. 645. 646. 647. 648. 649. 650. 651. 652.]
# Position 33: [0.26089504 0.59667194 0.6553761  0.19978145]
# Time: [483. 484. 485. 486. 487. 488. 489. 490. 491. 492.]
# Position 34: [0.61887145 0.27631682 0.63771033 0.5318681 ]
# Time: [249. 250. 251. 252. 253. 254. 255. 256. 257. 258.]
# Position 35: [0.84934515 0.82967746 0.6268303  0.11883876]
# Time: [733. 734. 735. 736. 737. 738. 739. 740. 741. 742.]
# Position 36: [0.82030463 0.82237506 0.630682   0.09758648]
# Time: [721. 722. 723. 724. 725. 726. 727. 728. 729. 730.]
# Position 37: [0.40887296 0.7220049  0.64328    0.10248829]
# Time: [568. 569. 570. 571. 572. 573. 574. 575. 576. 577.]
# Position 38: [0.5232906 0.2649194 0.6508616 0.5138307]
# Time: [284. 285. 286. 287. 288. 289. 290. 291. 292. 293.]
# Position 39: [0.71133566 0.28973252 0.63264203 0.48709273]
# Time: [215. 216. 217. 218. 219. 220. 221. 222. 223. 224.]
# Position 40: [0.74505126 0.28101546 0.6308219  0.40873998]
# Time: [201. 202. 203. 204. 205. 206. 207. 208. 209. 210.]
# Position 41: [0.30011094 0.38947988 0.63613904 0.2907345 ]
# Time: [391. 392. 393. 394. 395. 396. 397. 398. 399. 400.]
# Position 42: [0.67587894 0.28864563 0.62443554 0.5290356 ]
# Time: [226. 227. 228. 229. 230. 231. 232. 233. 234. 235.]
# Position 43: [0.26188427 0.49422842 0.65348953 0.29594517]
# Time: [444. 445. 446. 447. 448. 449. 450. 451. 452. 453.]
# Position 44: [0.68788743 0.28757685 0.6412333  0.519586  ]
# Time: [223. 224. 225. 226. 227. 228. 229. 230. 231. 232.]
# Position 45: [0.25426129 0.56803954 0.65382975 0.23782699]
# Time: [470. 471. 472. 473. 474. 475. 476. 477. 478. 479.]
# Position 46: [0.25943452 0.5924294  0.6433674  0.20379667]
# Time: [481. 482. 483. 484. 485. 486. 487. 488. 489. 490.]
# Position 47: [0.67791617 0.8247968  0.60929036 1.0283517 ]
# Time: [658. 659. 660. 661. 662. 663. 664. 665. 667. 668.]
# Position 48: [0.37641388 0.7026485  0.629619   0.10388297]
# Time: [539. 540. 541. 542. 543. 544. 545. 546. 547. 548.]
# Position 49: [0.3006112 0.3814387 0.6531373 0.2943412]
# Time: [388. 389. 390. 391. 392. 393. 394. 395. 396. 397.]
# Position 50: [0.32498387 0.66896296 0.65388834 0.09694148]
# Time: [517. 518. 519. 520. 521. 522. 523. 524. 525. 526.]
# Position 51: [0.35330546 0.31073266 0.63729423 0.37178767]
# Time: [350. 351. 352. 353. 354. 355. 356. 357. 358. 359.]
# Position 52: [0.26141095 0.5967382  0.63839316 0.19744128]
# Time: [482. 483. 484. 485. 486. 487. 488. 489. 490. 491.]
# Position 53: [0.25721693 0.5120338  0.6612576  0.29287642]
# Time: [452. 453. 454. 455. 456. 457. 458. 459. 460. 461.]
# Position 54: [0.81020707 0.81744397 0.65019137 0.01872407]
# Time: [713. 714. 715. 716. 717. 718. 720. 721. 722. 723.]
# Position 55: [0.2532458  0.52187085 0.6605142  0.28584397]
# Time: [454. 455. 456. 457. 458. 459. 460. 461. 462. 463.]
# Position 56: [0.76504827 0.26293588 0.64365363 0.37388626]
# Time: [192. 193. 194. 195. 196. 197. 198. 199. 200. 201.]
# Position 57: [0.26081258 0.5034559  0.6399083  0.29229927]
# Time: [448. 449. 450. 451. 452. 453. 454. 455. 456. 457.]
# Position 58: [0.6428483  0.28056893 0.6466011  0.5367861 ]
# Time: [238. 239. 240. 241. 242. 243. 244. 245. 246. 247.]
# Position 59: [0.64637387 0.28198424 0.62511444 0.5307398 ]
# Time: [236. 237. 238. 239. 240. 241. 242. 243. 244. 245.]
# Position 60: [0.7848872  0.24338129 0.62236524 0.3362024 ]
# Time: [180. 181. 182. 183. 184. 185. 186. 187. 188. 189.]
# Position 61: [0.39130545 0.7108811  0.65418935 0.10610802]
# Time: [556. 557. 558. 559. 560. 561. 562. 563. 564. 565.]
# Position 62: [0.7270609  0.28936675 0.6504159  0.453702  ]
# Time: [209. 210. 211. 212. 213. 214. 215. 216. 217. 218.]
# Position 63: [0.30998087 0.36782214 0.6506598  0.30779704]
# Time: [382. 383. 384. 385. 386. 387. 388. 389. 390. 391.]
# Position 64: [0.4052707  0.27635142 0.6501757  0.43409547]
# Time: [326. 327. 328. 329. 330. 331. 332. 333. 334. 335.]
# Position 65: [0.57439905 0.7645911  0.6191572  0.12567306]
# Time: [622. 623. 624. 625. 626. 627. 628. 629. 630. 631.]
# Position 66: [0.46282965 0.26433882 0.6408726  0.47377783]
# Time: [305. 306. 307. 308. 309. 310. 311. 312. 313. 314.]
# Position 67: [0.5185863  0.7560491  0.64080346 0.07026114]
# Time: [597. 598. 599. 600. 601. 602. 603. 604. 605. 606.]
# Position 68: [0.605256   0.7832686  0.62153554 0.09159518]
# Time: [641. 642. 643. 644. 645. 646. 647. 648. 649. 650.]
# Position 69: [0.32244477 0.66883004 0.6414474  0.09939639]
# Time: [516. 517. 518. 519. 520. 521. 522. 523. 524. 525.]
# Position 70: [0.2583518  0.51307976 0.6532347  0.29066774]
# Time: [451. 452. 453. 454. 455. 456. 457. 458. 459. 460.]
# Position 71: [0.603135   0.27413255 0.64495397 0.52889884]
# Time: [256. 257. 258. 259. 260. 261. 262. 263. 264. 265.]
# Position 72: [0.7902184  0.23108742 0.62211084 0.32361448]
# Time: [174. 175. 176. 177. 178. 179. 180. 181. 182. 183.]
# Position 73: [0.37426513 0.2968489  0.6384822  0.395664  ]
# Time: [340. 341. 342. 343. 344. 345. 346. 347. 348. 349.]
# Position 74: [0.29772902 0.6498321  0.63617367 0.11811457]
# Time: [509. 510. 511. 512. 513. 514. 515. 516. 517. 518.]
# Position 75: [0.6596256  0.8126967  0.62186027 1.0499378 ]
# Time: [659. 660. 661. 662. 663. 664. 665. 667. 668. 669.]
# Position 76: [0.28024426 0.46129298 0.64232635 0.2840128 ]
# Time: [419. 420. 421. 422. 423. 424. 425. 426. 427. 428.]
# Position 77: [0.29097795 0.4243831  0.65022933 0.28343198]
# Time: [404. 405. 406. 407. 408. 409. 410. 411. 412. 413.]
# Position 78: [0.38384277 0.2893622  0.63584554 0.40642622]
# Time: [336. 337. 338. 339. 340. 341. 342. 343. 344. 345.]
# Position 79: [0.8541812 0.8298286 0.641214  0.1124354]
# Time: [734. 735. 736. 737. 738. 739. 740. 741. 742. 743.]
# Position 80: [0.2622857  0.5988624  0.63636386 0.19643302]
# Time: [484. 485. 486. 487. 488. 489. 490. 491. 492. 493.]
# Position 81: [0.539212  0.266635  0.6448965 0.5137686]
# Time: [279. 280. 281. 282. 283. 284. 285. 286. 287. 288.]
# Position 82: [0.5937356  0.27283588 0.64539343 0.52892077]
# Time: [259. 260. 261. 262. 263. 264. 265. 266. 267. 268.]
# Position 83: [0.6711811  0.8007955  0.62879217 0.11022563]
# Time: [654. 655. 656. 657. 658. 659. 660. 661. 662. 663.]
# Position 84: [0.3083458  0.36611325 0.6608515  0.30720288]
# Time: [381. 382. 383. 384. 385. 386. 387. 388. 389. 390.]
# Position 85: [0.736144   0.8062413  0.6310114  0.10177215]
# Time: [684. 685. 686. 687. 688. 689. 690. 691. 692. 693.]
# Position 86: [0.31069976 0.6625398  0.62725294 0.09604643]
# Time: [513. 514. 515. 516. 517. 518. 519. 520. 521. 522.]
# Position 87: [0.2885537  0.43192825 0.6407603  0.27900854]
# Time: [406. 407. 408. 409. 410. 411. 412. 413. 414. 415.]
# Position 88: [0.27971658 0.6321112  0.6575915  0.1462261 ]
# Time: [501. 502. 503. 504. 505. 506. 507. 508. 509. 510.]
# Position 89: [0.52901536 0.7544931  0.63737357 0.09276431]
# Time: [600. 601. 602. 603. 604. 605. 606. 607. 608. 609.]
# Position 90: [0.66041094 0.28682306 0.62753487 0.5279059 ]
# Time: [232. 233. 234. 235. 236. 237. 238. 239. 240. 241.]
# Position 91: [0.6706584 0.2855994 0.639449  0.5197229]
# Time: [229. 230. 231. 232. 233. 234. 235. 236. 237. 238.]
# Position 92: [0.7624056  0.26994804 0.6352588  0.38174003]
# Time: [193. 194. 195. 196. 197. 198. 199. 200. 201. 202.]
# Position 93: [0.25499487 0.5118674  0.6632326  0.29210734]
# Time: [450. 451. 452. 453. 454. 455. 456. 457. 458. 459.]
# Position 94: [0.40521154 0.2814646  0.65367854 0.4268315 ]
# Time: [327. 328. 329. 330. 331. 332. 333. 334. 335. 336.]
# Position 95: [0.667903   0.28748184 0.6401742  0.52959085]
# Time: [230. 231. 232. 233. 234. 235. 236. 237. 238. 239.]
# Position 96: [0.2568893  0.57720506 0.6378987  0.2253485 ]
# Time: [474. 475. 476. 477. 478. 479. 480. 481. 482. 483.]
# Position 97: [0.33940107 0.31622428 0.6453288  0.36269814]
# Time: [356. 357. 358. 359. 360. 361. 362. 363. 364. 365.]
# Position 98: [0.56329495 0.26938725 0.6433174  0.52483904]
# Time: [270. 271. 272. 273. 274. 275. 276. 277. 278. 279.]
# Position 99: [0.83182603 0.82438874 0.6316782  0.10628433]
# Time: [726. 727. 728. 729. 730. 731. 732. 733. 734. 735.]
# Position 100: [0.5531245  0.76135105 0.6384773  0.1062541 ]
# Time: [604. 605. 606. 607. 608. 609. 610. 611. 612. 613.]
# Position 101: [0.5791365  0.76883924 0.6165933  0.12040054]
# Time: [621. 622. 623. 624. 625. 626. 627. 628. 629. 630.]
# Position 102: [0.60207987 0.78264284 0.6414599  0.09936788]
# Time: [640. 641. 642. 643. 644. 645. 646. 647. 648. 649.]
# Position 103: [0.67860883 0.28720447 0.6268052  0.5211337 ]
# Time: [225. 226. 227. 228. 229. 230. 231. 232. 233. 234.]
# Position 104: [0.83431846 0.82414985 0.63012576 0.11001336]
# Time: [727. 728. 729. 730. 731. 732. 733. 734. 735. 736.]
# Position 105: [0.2686627  0.48352668 0.6662835  0.29771176]
# Time: [438. 439. 440. 441. 442. 443. 444. 445. 446. 447.]
# Position 106: [0.35644215 0.68769896 0.6498816  0.10132692]
# Time: [527. 528. 529. 530. 531. 532. 533. 534. 535. 536.]
# Position 107: [0.52649796 0.75608957 0.6296675  0.08268145]
# Time: [599. 600. 601. 602. 603. 604. 605. 606. 607. 608.]
# Position 108: [0.80665    0.19370456 0.61794025 0.28160736]
# Time: [147. 148. 149. 150. 151. 152. 153. 154. 155. 156.]
# Position 109: [0.43587154 0.73347056 0.65354633 0.07537789]
# Time: [578. 579. 580. 581. 582. 583. 584. 585. 586. 587.]
# Position 110: [0.5465406  0.76681185 0.62746465 0.07347139]
# Time: [602. 603. 604. 605. 606. 607. 608. 609. 610. 611.]
# Position 111: [0.6911629  0.7845968  0.64781713 0.05405293]
# Time: [665. 667. 668. 669. 670. 672. 675. 676. 677. 678.]
# Position 112: [0.80812556 0.18327722 0.6273463  0.2751783 ]
# Time: [146. 147. 148. 149. 150. 151. 152. 153. 154. 155.]
# Position 113: [0.8007554  0.2044305  0.63450444 0.29738605]
# Time: [163. 164. 165. 166. 167. 168. 169. 170. 171. 172.]
# Position 114: [0.33453587 0.67532563 0.6261822  0.08905434]
# Time: [520. 521. 522. 523. 524. 525. 526. 527. 528. 529.]
# Position 115: [0.4137239  0.72582734 0.639539   0.08690521]
# Time: [570. 571. 572. 573. 574. 575. 576. 577. 578. 579.]
# Position 116: [0.5719829  0.27143613 0.62551963 0.5233649 ]
# Time: [267. 268. 269. 270. 271. 272. 273. 274. 275. 276.]
# Position 117: [0.38321322 0.70676017 0.627277   0.10221327]
# Time: [548. 549. 550. 551. 552. 553. 554. 555. 556. 557.]
# Position 118: [0.25783443 0.5181096  0.6390116  0.28440416]
# Time: [453. 454. 455. 456. 457. 458. 459. 460. 461. 462.]
# ... and 113 more positions

# %% [markdown]
# **Setting the environment (positions of RSUs)**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Road Parameters
road_length = 2900  # meters
road_width = 22  # meters

# RSU Parameters
rsu_coverage_radius = 500  # meters
rsu_overlap = 50  # meters

# Optimized RSU positions to maximize coverage
rsu_positions = [
    (500,0 ), (1450, 0), (2400, 0),  # RSUs on first road

]

# Generate a grid to visualize coverage
x_vals = np.linspace(0, road_length, 500)  # Fine granularity grid
y_vals = np.linspace(0, road_width, 100)
X, Y = np.meshgrid(x_vals, y_vals)
covered = np.zeros_like(X, dtype=bool)  # Initialize as False (not covered)

# Compute coverage
for rsu_x, rsu_y in rsu_positions:
    distance = np.sqrt((X - rsu_x)**2 + (Y - rsu_y)**2)
    covered |= (distance <= rsu_coverage_radius)

# Plot the road and RSU coverage
plt.figure(figsize=(12, 5))
plt.imshow(covered, extent=[0, road_length, 0, road_width], origin="lower", cmap="Greys", alpha=0.6)
# plt.colorbar(label="Coverage (1 = Covered, 0 = Not Covered)")
plt.scatter(*zip(*rsu_positions), c="red", marker="o", label="RSUs")  # Plot RSUs
plt.xlabel("Road Length (m)")
plt.ylabel("Road Width (m)")
plt.title(" RSU Coverage Map")
plt.legend()
plt.show()

# %% [markdown]
# Simulation Parameters

# %%
import numpy as np
# Simulation parameters
no_of_vehicles=20
W_n = 10e6  # Bandwidth of the transmission (10 MHz)
P_u = 0.1  # Transmission power of TV_n (0.1 W)
h_n = np.random.uniform(10**-8, 10**-7)  # Channel gain (randomized within range)
N_0 = 10**(-7.4)  # Noise power density (-74 dBm/Hz converted to Watts)
D_n = np.random.uniform(0.3e6, 1.0e6)  # Data size of P_n (MB to bits)
C_n = np.random.uniform(0.5, 1.2) * 1e9  # CPU cycles of P_n (Gcycles to cycles)
f_n = 0.3 * 1e9  # Computational capability of TV_n (cycles/s)
f_rsu = np.random.uniform(1.6, 2.4) * 1e9
rho_l, rho_r = 1, 0  # Local execution decision
I_n=0


# Distance of vehicle to RSU (random distance in meters)
d_n = np.random.uniform(10, 200)
#to be replaced by values from the LSTM model

#this is just to check the formulae



#β (Path Loss Exponent)
beta = 1

#beta works for 2, but for 4 its giving rn =0

import numpy as np

def compute_data_transmission_rate(W_n, P_u, d_n, beta, h_n, N_0, I_n):
    return W_n * np.log2(1 + ((P_u * d_n**(-beta) * h_n) / (N_0 + I_n)))

def compute_transmission_delay(D_n, r_n):
    return D_n / r_n

def compute_downlink_delay(D_n, C_n, r_n):
    ratio_lambda = D_n / C_n
    return (ratio_lambda * D_n) / r_n

def compute_communication_latency(t_n_up, t_n_down):
    return t_n_up + t_n_down

def compute_local_computation_delay(C_n, f_n):
    return C_n / f_n

def compute_rsu_computation_delay(C_n, f_rsu):
    f_rsu_allocated = np.random.uniform(0.5, 1.0) * f_rsu
    return C_n / f_rsu_allocated

def make_offloading_decision():
    ρ_l = 1

    ρ_r = 1 - ρ_l
    return ρ_l, ρ_r

def compute_total_computation_delay(ρ_l, ρ_r, t_n_comloc, t_n_comRSU):
    return ρ_l * t_n_comloc + ρ_r * t_n_comRSU

r_n = compute_data_transmission_rate(W_n, P_u, d_n, beta, h_n, N_0, I_n)
t_n_up = compute_transmission_delay(D_n, r_n)
t_n_down = compute_downlink_delay(D_n, C_n, r_n)
t_n_link = compute_communication_latency(t_n_up, t_n_down)
t_n_comloc = compute_local_computation_delay(C_n, f_n)
t_n_comRSU = compute_rsu_computation_delay(C_n, f_rsu)
ρ_l, ρ_r = make_offloading_decision()
t_n_com = compute_total_computation_delay(ρ_l, ρ_r, t_n_comloc, t_n_comRSU)



def transmission_latency(P_u, d_n, beta, h_n, N_0, I_n, W_n, D_n):
  # this formula
    r_n = W_n * np.log2(1 + (P_u * d_n**-beta * h_n**2) / (N_0 + I_n))  # Eq. (4)
    return D_n / r_n  # Eq. (3)

def local_computation_latency(C_n, f_n):

    return C_n / f_n  # Eq. (7)

def rsu_computation_latency(C_n, f_rsu_prime):

    return C_n / f_rsu_prime  # Eq. (8)

def total_computation_latency(t_comloc, t_comRSU, rho_l, rho_r):

    return rho_l * t_comloc + rho_r * t_comRSU  # Eq. (9)



# Compute latencies
t_up = transmission_latency(P_u, d_n, beta, h_n, N_0, I_n, W_n, D_n)
t_comloc = local_computation_latency(C_n, f_n)
t_comRSU = rsu_computation_latency(C_n, f_rsu)
t_com = total_computation_latency(t_comloc, t_comRSU, rho_l, rho_r)

# %%
# Print the results
print(f"Data Transmission Rate (r_n): {r_n:.2f} bps")
print(f"Transmission Delay (t_n^up): {t_n_up:.6f} s")
print(f"Return Delay (t_n^down): {t_n_down:.6f} s")
print(f"Communication Latency (t_n^link): {t_n_link:.6f} s")
print(f"Local Computation Delay (t_n^comloc): {t_n_comloc:.6f} s")
print(f"RSU Computation Delay (t_n^comRSU): {t_n_comRSU:.6f} s")
print(f"Final Computation Latency (t_n^com): {t_n_com:.6f} s (\u03c1_l={ρ_l}, \u03c1_r={ρ_r})")
print(f"Transmission Latency (t^up_n): {t_up:.6f} sec")
print(f"Local Computation Latency (t^comloc_n): {t_comloc:.6f} sec")
print(f"RSU Computation Latency (t^comRSU_n): {t_comRSU:.6f} sec")
print(f"Total Computation Latency (t^com_n): {t_com:.6f} sec")
# Out:
# Data Transmission Rate (r_n): 18611.71 bps
# Transmission Delay (t_n^up): 53.134665 s
# Return Delay (t_n^down): 0.053717 s
# Communication Latency (t_n^link): 53.188382 s
# Local Computation Delay (t_n^comloc): 3.260694 s
# RSU Computation Delay (t_n^comRSU): 0.547980 s
# Final Computation Latency (t_n^com): 3.260694 s (ρ_l=1, ρ_r=0)
# Transmission Latency (t^up_n): 735352523.869979 sec
# Local Computation Latency (t^comloc_n): 3.260694 sec
# RSU Computation Latency (t^comRSU_n): 0.516373 sec
# Total Computation Latency (t^com_n): 3.260694 sec

# %% [markdown]
# DQN MODEL

# %% [markdown]
# only 2 rsus

# %% [markdown]
# (too many errors- due to wrong parameters)

# %%
# Final Deep Q-Network implementation for Vehicular Edge Computing
# with multi-vehicle offloading decisions using predicted trajectories.

import random
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt

# ----------- Constants -----------
m = 10**6
k = 10**3
g = 10**9
W = 10 * m  # 10 MHz
P_u = 0.1   # 0.1W
sigma2 = 10**(-17.4)  # noise power density in W/Hz
I = 1e-10  # interference

# ----------- RSU and Vehicle Models -----------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)  # Gcycles/s
        self.resource_capacity = 100

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g  # 0.3 Gcycles/s

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

# ----------- Replay Memory -----------
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.idx = 0

    def store(self, state, action, next_state, reward, done):
        data = (state, action, next_state, reward, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(data)
        else:
            self.buffer[self.idx] = data
        self.idx = (self.idx + 1) % self.capacity

    def sample(self, batch_size, device):
        batch = random.sample(self.buffer, batch_size)
        states, actions, next_states, rewards, dones = zip(*batch)
        return (
            torch.tensor(states, dtype=torch.float32).to(device),
            torch.tensor(actions, dtype=torch.int64).to(device),
            torch.tensor(next_states, dtype=torch.float32).to(device),
            torch.tensor(rewards, dtype=torch.float32).to(device),
            torch.tensor(dones, dtype=torch.bool).to(device)
        )

    def __len__(self):
        return len(self.buffer)

# ----------- DQN Network -----------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# ----------- DQN Agent -----------
class DQNAgent:
    def __init__(self, state_size, action_size, device):
        self.device = device
        self.epsilon = 0.9
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.discount = 0.99
        self.memory = ReplayMemory(10000)
        self.policy_net = DQNNet(state_size, action_size).to(device)
        self.target_net = DQNNet(state_size, action_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=0.0008)

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, 1)
        state_tensor = torch.tensor([state], dtype=torch.float32).to(self.device)
        with torch.no_grad():
            return torch.argmax(self.policy_net(state_tensor)).item()

    def learn(self, batch_size):
        if len(self.memory) < batch_size:
            return
        states, actions, next_states, rewards, dones = self.memory.sample(batch_size, self.device)
        q_values = self.policy_net(states).gather(1, actions.view(-1, 1))
        max_next_q = self.target_net(next_states).max(1).values
        targets = rewards + self.discount * max_next_q * (~dones)
        loss = F.mse_loss(q_values.view(-1), targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_target_net(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# ----------- Environment Class -----------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450,0), (2400, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

    def rsu_return_delay(self, d_n):
        rate = W * math.log2(1 + (P_u * 1e-7) / (sigma2 + I))
        return d_n / rate

    def step(self, actions):
        rewards = []
        rsu_remaining = self.rsu.resource_capacity
        for i, vid in enumerate(self.vehicle_ids):
            cpu_cycles = random.uniform(0.5, 1.2) * g
            data_size = random.uniform(0.3, 1.0) * m
            task_deadline = 1.2
            x, y, _, _ = self.trajectories[vid][self.current_step]

            if actions[i] == 0:
                delay = self.vehicles[vid].compDelay(cpu_cycles)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 0
            else:
                comp = self.rsu.compDelay(cpu_cycles)
                t_ret = self.rsu_return_delay(data_size)
                delay = comp + t_ret
                stable = any(math.hypot(x - rx, y - ry) <= self.rsu.radius for rx, ry in self.rsu_positions)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 5 if stable else -5
                rsu_remaining -= 1
                self.Salloc[i] = 1

            delay_ratio = delay / max(0.0001, task_deadline)
            rtime = 5 * (1 - min(1, delay_ratio))
            reward = 0.4 * rsuc + 0.4 * rtime + 0.2 * roffsuc
            rewards.append(reward)
            self.Soff[i] = actions[i]
            self.Ssche[i] = 1 if delay <= task_deadline else 0

        self.Srest = [max(0, rsu_remaining)]
        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_state = self.Soff + self.Ssche + self.Salloc + self.Srest
        return next_state, sum(rewards), done



# ----------- Setup and Training Script -----------
if __name__ == '__main__':
    data = np.load("test_predictions_full_300.npz")
    predicted = data['predicted']
    vehicle_ids = data['vehicle_ids']

    df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1,1), predicted]),
                      columns=["vehicle_id", "lat", "lon", "vx", "vy"])
    top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
    trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

    vehicles = {vid: Vehicle() for vid in top_15_ids}
    rsu = RSU()
    env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

    state_size = len(env.reset())
    action_size = 2
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    agent = DQNAgent(state_size, action_size, device)

    episodes = 6000
    reward_log = []
    for ep in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0
        while not done:
            actions = [agent.select_action(state) for _ in range(len(top_15_ids))]
            next_state, reward, done = env.step(actions)
            agent.memory.store(state, actions[0], next_state, reward, done)
            agent.learn(32)
            state = next_state
            total_reward += reward
        agent.update_epsilon()
        agent.update_target_net()
        reward_log.append(total_reward)
        print(f"Episode {ep+1}, Total Reward: {total_reward:.2f}, Epsilon: {agent.epsilon:.3f}")

    torch.save(agent.policy_net.state_dict(), "dqn_multi_vehicle.pth")

    plt.plot(range(1, episodes + 1), reward_log)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("DQN Training: Reward vs Episode")
    plt.grid(True)
    plt.savefig("reward_vs_episode.png")
    plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 1001, Total Reward: 6414.07, Epsilon: 0.010
# Episode 1002, Total Reward: 6992.95, Epsilon: 0.010
# Episode 1003, Total Reward: 6964.14, Epsilon: 0.010
# Episode 1004, Total Reward: 7016.81, Epsilon: 0.010
# Episode 1005, Total Reward: 6970.02, Epsilon: 0.010
# Episode 1006, Total Reward: 6989.14, Epsilon: 0.010
# Episode 1007, Total Reward: 6945.37, Epsilon: 0.010
# Episode 1008, Total Reward: 6495.09, Epsilon: 0.010
# Episode 1009, Total Reward: 6985.50, Epsilon: 0.010
# Episode 1010, Total Reward: 7024.47, Epsilon: 0.010
# Episode 1011, Total Reward: 6975.63, Epsilon: 0.010
# Episode 1012, Total Reward: 6970.14, Epsilon: 0.010
# Episode 1013, Total Reward: 6986.46, Epsilon: 0.010
# Episode 1014, Total Reward: 6975.11, Epsilon: 0.010
# Episode 1015, Total Reward: 7003.48, Epsilon: 0.010
# Episode 1016, Total Reward: 6974.33, Epsilon: 0.010
# Episode 1017, Total Reward: 6972.10, Epsilon: 0.010
# Episode 1018, Total Reward: 6949.40, Epsilon: 0.010
# Episode 1019, Total Reward: 6996.40, Epsilon: 0.010
# Episode 1020, Total Reward: 6000.54, Epsilon: 0.010
# Episode 1021, Total Reward: 6976.74, Epsilon: 0.010
# Episode 1022, Total Reward: 6975.96, Epsilon: 0.010
# Episode 1023, Total Reward: 7023.32, Epsilon: 0.010
# Episode 1024, Total Reward: 7006.05, Epsilon: 0.010
# Episode 1025, Total Reward: 6980.27, Epsilon: 0.010
# Episode 1026, Total Reward: 6964.69, Epsilon: 0.010
# Episode 1027, Total Reward: 6983.12, Epsilon: 0.010
# Episode 1028, Total Reward: 7008.21, Epsilon: 0.010
# Episode 1029, Total Reward: 6992.78, Epsilon: 0.010
# Episode 1030, Total Reward: 7027.17, Epsilon: 0.010
# Episode 1031, Total Reward: 7012.38, Epsilon: 0.010
# Episode 1032, Total Reward: 6976.25, Epsilon: 0.010
# Episode 1033, Total Reward: 6992.92, Epsilon: 0.010
# Episode 1034, Total Reward: 6985.02, Epsilon: 0.010
# Episode 1035, Total Reward: 6993.69, Epsilon: 0.010
# Episode 1036, Total Reward: 6958.21, Epsilon: 0.010
# Episode 1037, Total Reward: 2676.72, Epsilon: 0.010
# Episode 1038, Total Reward: 6983.56, Epsilon: 0.010
# Episode 1039, Total Reward: 6949.25, Epsilon: 0.010
# Episode 1040, Total Reward: 6971.04, Epsilon: 0.010
# Episode 1041, Total Reward: 6968.66, Epsilon: 0.010
# Episode 1042, Total Reward: 6976.42, Epsilon: 0.010
# Episode 1043, Total Reward: 6994.14, Epsilon: 0.010
# Episode 1044, Total Reward: 6942.96, Epsilon: 0.010
# Episode 1045, Total Reward: 6964.13, Epsilon: 0.010
# Episode 1046, Total Reward: 6940.51, Epsilon: 0.010
# Episode 1047, Total Reward: 6950.77, Epsilon: 0.010
# Episode 1048, Total Reward: 6899.97, Epsilon: 0.010
# Episode 1049, Total Reward: 6982.82, Epsilon: 0.010
# Episode 1050, Total Reward: 7010.30, Epsilon: 0.010
# Episode 1051, Total Reward: 7007.82, Epsilon: 0.010
# Episode 1052, Total Reward: 6977.79, Epsilon: 0.010
# Episode 1053, Total Reward: 6968.55, Epsilon: 0.010
# Episode 1054, Total Reward: 7025.68, Epsilon: 0.010
# Episode 1055, Total Reward: 6980.19, Epsilon: 0.010
# Episode 1056, Total Reward: 6990.21, Epsilon: 0.010
# Episode 1057, Total Reward: 6920.08, Epsilon: 0.010
# Episode 1058, Total Reward: 6997.25, Epsilon: 0.010
# Episode 1059, Total Reward: 6970.41, Epsilon: 0.010
# Episode 1060, Total Reward: 6980.58, Epsilon: 0.010
# Episode 1061, Total Reward: 6972.89, Epsilon: 0.010
# Episode 1062, Total Reward: 6989.88, Epsilon: 0.010
# Episode 1063, Total Reward: 6970.88, Epsilon: 0.010
# Episode 1064, Total Reward: 7018.60, Epsilon: 0.010
# Episode 1065, Total Reward: 7010.34, Epsilon: 0.010
# Episode 1066, Total Reward: 7014.35, Epsilon: 0.010
# Episode 1067, Total Reward: 7009.06, Epsilon: 0.010
# Episode 1068, Total Reward: 5143.90, Epsilon: 0.010
# Episode 1069, Total Reward: 6981.88, Epsilon: 0.010
# Episode 1070, Total Reward: 7005.33, Epsilon: 0.010
# Episode 1071, Total Reward: 6720.63, Epsilon: 0.010
# Episode 1072, Total Reward: 6978.77, Epsilon: 0.010
# Episode 1073, Total Reward: 6970.66, Epsilon: 0.010
# Episode 1074, Total Reward: 6984.18, Epsilon: 0.010
# Episode 1075, Total Reward: 7015.31, Epsilon: 0.010
# Episode 1076, Total Reward: 7020.99, Epsilon: 0.010
# Episode 1077, Total Reward: 6979.90, Epsilon: 0.010
# Episode 1078, Total Reward: 6953.43, Epsilon: 0.010
# Episode 1079, Total Reward: 7016.44, Epsilon: 0.010
# Episode 1080, Total Reward: 6999.80, Epsilon: 0.010
# Episode 1081, Total Reward: 6980.19, Epsilon: 0.010
# Episode 1082, Total Reward: 6983.11, Epsilon: 0.010
# Episode 1083, Total Reward: 6994.77, Epsilon: 0.010
# Episode 1084, Total Reward: 7023.59, Epsilon: 0.010
# Episode 1085, Total Reward: 6976.40, Epsilon: 0.010
# Episode 1086, Total Reward: 7018.49, Epsilon: 0.010
# Episode 1087, Total Reward: 6943.46, Epsilon: 0.010
# Episode 1088, Total Reward: 6991.56, Epsilon: 0.010
# Episode 1089, Total Reward: 7002.44, Epsilon: 0.010
# Episode 1090, Total Reward: 6972.97, Epsilon: 0.010
# Episode 1091, Total Reward: 6929.75, Epsilon: 0.010
# Episode 1092, Total Reward: 7014.78, Epsilon: 0.010
# Episode 1093, Total Reward: 6996.23, Epsilon: 0.010
# Episode 1094, Total Reward: 6972.93, Epsilon: 0.010
# Episode 1095, Total Reward: 6984.53, Epsilon: 0.010
# Episode 1096, Total Reward: 6940.46, Epsilon: 0.010
# Episode 1097, Total Reward: 6929.12, Epsilon: 0.010
# Episode 1098, Total Reward: 6963.55, Epsilon: 0.010
# Episode 1099, Total Reward: 7016.23, Epsilon: 0.010
# Episode 1100, Total Reward: 6984.87, Epsilon: 0.010
# Episode 1101, Total Reward: 7013.10, Epsilon: 0.010
# Episode 1102, Total Reward: 7010.51, Epsilon: 0.010
# Episode 1103, Total Reward: 6972.40, Epsilon: 0.010
# Episode 1104, Total Reward: 6971.67, Epsilon: 0.010
# Episode 1105, Total Reward: 6940.13, Epsilon: 0.010
# Episode 1106, Total Reward: 6947.33, Epsilon: 0.010
# Episode 1107, Total Reward: 7015.18, Epsilon: 0.010
# Episode 1108, Total Reward: 7015.46, Epsilon: 0.010
# Episode 1109, Total Reward: 6992.15, Epsilon: 0.010
# Episode 1110, Total Reward: 7010.26, Epsilon: 0.010
# Episode 1111, Total Reward: 6995.60, Epsilon: 0.010
# Episode 1112, Total Reward: 6971.42, Epsilon: 0.010
# Episode 1113, Total Reward: 6975.76, Epsilon: 0.010
# Episode 1114, Total Reward: 6992.36, Epsilon: 0.010
# Episode 1115, Total Reward: 6972.67, Epsilon: 0.010
# Episode 1116, Total Reward: 7004.27, Epsilon: 0.010
# Episode 1117, Total Reward: 6967.54, Epsilon: 0.010
# Episode 1118, Total Reward: 6995.30, Epsilon: 0.010
# Episode 1119, Total Reward: 6947.18, Epsilon: 0.010
# Episode 1120, Total Reward: 6992.21, Epsilon: 0.010
# Episode 1121, Total Reward: 6969.74, Epsilon: 0.010
# Episode 1122, Total Reward: 6973.53, Epsilon: 0.010
# Episode 1123, Total Reward: 6954.95, Epsilon: 0.010
# Episode 1124, Total Reward: 6983.73, Epsilon: 0.010
# Episode 1125, Total Reward: 6975.94, Epsilon: 0.010
# Episode 1126, Total Reward: 6975.50, Epsilon: 0.010
# Episode 1127, Total Reward: 6969.23, Epsilon: 0.010
# Episode 1128, Total Reward: 6997.43, Epsilon: 0.010
# Episode 1129, Total Reward: 6960.75, Epsilon: 0.010
# Episode 1130, Total Reward: 6995.30, Epsilon: 0.010
# Episode 1131, Total Reward: 6970.10, Epsilon: 0.010
# Episode 1132, Total Reward: 7002.85, Epsilon: 0.010
# Episode 1133, Total Reward: 7021.19, Epsilon: 0.010
# Episode 1134, Total Reward: 6954.69, Epsilon: 0.010
# Episode 1135, Total Reward: 6950.98, Epsilon: 0.010
# Episode 1136, Total Reward: 6945.07, Epsilon: 0.010
# Episode 1137, Total Reward: 6995.40, Epsilon: 0.010
# Episode 1138, Total Reward: 6984.40, Epsilon: 0.010
# Episode 1139, Total Reward: 7004.72, Epsilon: 0.010
# Episode 1140, Total Reward: 6970.34, Epsilon: 0.010
# Episode 1141, Total Reward: 6999.29, Epsilon: 0.010
# Episode 1142, Total Reward: 6984.33, Epsilon: 0.010
# Episode 1143, Total Reward: 7015.78, Epsilon: 0.010
# Episode 1144, Total Reward: 6980.68, Epsilon: 0.010
# Episode 1145, Total Reward: 6969.62, Epsilon: 0.010
# Episode 1146, Total Reward: 6984.96, Epsilon: 0.010
# Episode 1147, Total Reward: 6961.99, Epsilon: 0.010
# Episode 1148, Total Reward: 6960.89, Epsilon: 0.010
# Episode 1149, Total Reward: 6994.40, Epsilon: 0.010
# Episode 1150, Total Reward: 7013.25, Epsilon: 0.010
# Episode 1151, Total Reward: 6194.16, Epsilon: 0.010
# Episode 1152, Total Reward: 7016.32, Epsilon: 0.010
# Episode 1153, Total Reward: 6990.20, Epsilon: 0.010
# Episode 1154, Total Reward: 7012.90, Epsilon: 0.010
# Episode 1155, Total Reward: 2678.99, Epsilon: 0.010
# Episode 1156, Total Reward: 6992.68, Epsilon: 0.010
# Episode 1157, Total Reward: 6943.68, Epsilon: 0.010
# Episode 1158, Total Reward: 6979.01, Epsilon: 0.010
# Episode 1159, Total Reward: 7006.53, Epsilon: 0.010
# Episode 1160, Total Reward: 7019.28, Epsilon: 0.010
# Episode 1161, Total Reward: 6985.28, Epsilon: 0.010
# Episode 1162, Total Reward: 7007.78, Epsilon: 0.010
# Episode 1163, Total Reward: 6183.11, Epsilon: 0.010
# Episode 1164, Total Reward: 6915.47, Epsilon: 0.010
# Episode 1165, Total Reward: 6990.55, Epsilon: 0.010
# Episode 1166, Total Reward: 6968.53, Epsilon: 0.010
# Episode 1167, Total Reward: 6983.67, Epsilon: 0.010
# Episode 1168, Total Reward: 5891.36, Epsilon: 0.010
# Episode 1169, Total Reward: 7011.56, Epsilon: 0.010
# Episode 1170, Total Reward: 6992.43, Epsilon: 0.010
# Episode 1171, Total Reward: 6985.21, Epsilon: 0.010
# Episode 1172, Total Reward: 6987.15, Epsilon: 0.010
# Episode 1173, Total Reward: 6981.13, Epsilon: 0.010
# Episode 1174, Total Reward: 6982.77, Epsilon: 0.010
# Episode 1175, Total Reward: 6922.53, Epsilon: 0.010
# Episode 1176, Total Reward: 6960.35, Epsilon: 0.010
# Episode 1177, Total Reward: 7004.70, Epsilon: 0.010
# Episode 1178, Total Reward: 6970.80, Epsilon: 0.010
# Episode 1179, Total Reward: 6943.78, Epsilon: 0.010
# Episode 1180, Total Reward: 5274.81, Epsilon: 0.010
# Episode 1181, Total Reward: 5160.15, Epsilon: 0.010
# Episode 1182, Total Reward: 6992.88, Epsilon: 0.010
# Episode 1183, Total Reward: 6974.93, Epsilon: 0.010
# Episode 1184, Total Reward: 7008.57, Epsilon: 0.010
# Episode 1185, Total Reward: 7021.97, Epsilon: 0.010
# Episode 1186, Total Reward: 6982.36, Epsilon: 0.010
# Episode 1187, Total Reward: 7021.90, Epsilon: 0.010
# Episode 1188, Total Reward: 6960.41, Epsilon: 0.010
# Episode 1189, Total Reward: 6988.10, Epsilon: 0.010
# Episode 1190, Total Reward: 6975.72, Epsilon: 0.010
# Episode 1191, Total Reward: 7007.66, Epsilon: 0.010
# Episode 1192, Total Reward: 7030.69, Epsilon: 0.010
# Episode 1193, Total Reward: 6998.18, Epsilon: 0.010
# Episode 1194, Total Reward: 6983.56, Epsilon: 0.010
# Episode 1195, Total Reward: 6973.31, Epsilon: 0.010
# Episode 1196, Total Reward: 7016.16, Epsilon: 0.010
# Episode 1197, Total Reward: 7021.12, Epsilon: 0.010
# Episode 1198, Total Reward: 6982.12, Epsilon: 0.010
# Episode 1199, Total Reward: 7001.02, Epsilon: 0.010
# Episode 1200, Total Reward: 7003.70, Epsilon: 0.010
# Episode 1201, Total Reward: 6955.29, Epsilon: 0.010
# Episode 1202, Total Reward: 6964.60, Epsilon: 0.010
# Episode 1203, Total Reward: 6980.68, Epsilon: 0.010
# Episode 1204, Total Reward: 7000.78, Epsilon: 0.010
# Episode 1205, Total Reward: 7038.21, Epsilon: 0.010
# Episode 1206, Total Reward: 6950.12, Epsilon: 0.010
# Episode 1207, Total Reward: 6967.68, Epsilon: 0.010
# Episode 1208, Total Reward: 6993.04, Epsilon: 0.010
# Episode 1209, Total Reward: 6968.45, Epsilon: 0.010
# Episode 1210, Total Reward: 7008.64, Epsilon: 0.010
# Episode 1211, Total Reward: 6961.33, Epsilon: 0.010
# Episode 1212, Total Reward: 6989.96, Epsilon: 0.010
# Episode 1213, Total Reward: 6924.98, Epsilon: 0.010
# Episode 1214, Total Reward: 6984.89, Epsilon: 0.010
# Episode 1215, Total Reward: 6959.61, Epsilon: 0.010
# Episode 1216, Total Reward: 6917.17, Epsilon: 0.010
# Episode 1217, Total Reward: 6960.93, Epsilon: 0.010
# Episode 1218, Total Reward: 6933.65, Epsilon: 0.010
# Episode 1219, Total Reward: 6945.61, Epsilon: 0.010
# Episode 1220, Total Reward: 6972.32, Epsilon: 0.010
# Episode 1221, Total Reward: 6972.27, Epsilon: 0.010
# Episode 1222, Total Reward: 6977.09, Epsilon: 0.010
# Episode 1223, Total Reward: 6999.96, Epsilon: 0.010
# Episode 1224, Total Reward: 6961.59, Epsilon: 0.010
# Episode 1225, Total Reward: 6941.77, Epsilon: 0.010
# Episode 1226, Total Reward: 6963.86, Epsilon: 0.010
# Episode 1227, Total Reward: 6981.43, Epsilon: 0.010
# Episode 1228, Total Reward: 6974.32, Epsilon: 0.010
# Episode 1229, Total Reward: 7011.02, Epsilon: 0.010
# Episode 1230, Total Reward: 6949.59, Epsilon: 0.010
# Episode 1231, Total Reward: 7006.04, Epsilon: 0.010
# Episode 1232, Total Reward: 6967.41, Epsilon: 0.010
# Episode 1233, Total Reward: 6977.10, Epsilon: 0.010
# Episode 1234, Total Reward: 6953.24, Epsilon: 0.010
# Episode 1235, Total Reward: 6945.95, Epsilon: 0.010
# Episode 1236, Total Reward: 6953.54, Epsilon: 0.010
# Episode 1237, Total Reward: 6993.20, Epsilon: 0.010
# Episode 1238, Total Reward: 6963.40, Epsilon: 0.010
# Episode 1239, Total Reward: 7008.72, Epsilon: 0.010
# Episode 1240, Total Reward: 6966.62, Epsilon: 0.010
# Episode 1241, Total Reward: 7016.31, Epsilon: 0.010
# Episode 1242, Total Reward: 6978.10, Epsilon: 0.010
# Episode 1243, Total Reward: 6977.65, Epsilon: 0.010
# Episode 1244, Total Reward: 6977.46, Epsilon: 0.010
# Episode 1245, Total Reward: 6987.05, Epsilon: 0.010
# Episode 1246, Total Reward: 6952.27, Epsilon: 0.010
# Episode 1247, Total Reward: 6984.26, Epsilon: 0.010
# Episode 1248, Total Reward: 6979.74, Epsilon: 0.010
# Episode 1249, Total Reward: 6523.25, Epsilon: 0.010
# Episode 1250, Total Reward: 6987.77, Epsilon: 0.010
# Episode 1251, Total Reward: 6969.99, Epsilon: 0.010
# Episode 1252, Total Reward: 6931.15, Epsilon: 0.010
# Episode 1253, Total Reward: 6525.59, Epsilon: 0.010
# Episode 1254, Total Reward: 6974.12, Epsilon: 0.010
# Episode 1255, Total Reward: 6994.75, Epsilon: 0.010
# Episode 1256, Total Reward: 7025.06, Epsilon: 0.010
# Episode 1257, Total Reward: 7002.95, Epsilon: 0.010
# Episode 1258, Total Reward: 6990.03, Epsilon: 0.010
# Episode 1259, Total Reward: 6997.25, Epsilon: 0.010
# Episode 1260, Total Reward: 6933.95, Epsilon: 0.010
# Episode 1261, Total Reward: 6958.50, Epsilon: 0.010
# Episode 1262, Total Reward: 6930.98, Epsilon: 0.010
# Episode 1263, Total Reward: 7029.49, Epsilon: 0.010
# Episode 1264, Total Reward: 6936.06, Epsilon: 0.010
# Episode 1265, Total Reward: 7008.29, Epsilon: 0.010
# Episode 1266, Total Reward: 6974.42, Epsilon: 0.010
# Episode 1267, Total Reward: 6988.15, Epsilon: 0.010
# Episode 1268, Total Reward: 6994.48, Epsilon: 0.010
# Episode 1269, Total Reward: 6952.55, Epsilon: 0.010
# Episode 1270, Total Reward: 6984.03, Epsilon: 0.010
# Episode 1271, Total Reward: 6986.70, Epsilon: 0.010
# Episode 1272, Total Reward: 6980.07, Epsilon: 0.010
# Episode 1273, Total Reward: 7002.94, Epsilon: 0.010
# Episode 1274, Total Reward: 6978.12, Epsilon: 0.010
# Episode 1275, Total Reward: 6981.70, Epsilon: 0.010
# Episode 1276, Total Reward: 7002.99, Epsilon: 0.010
# Episode 1277, Total Reward: 7022.00, Epsilon: 0.010
# Episode 1278, Total Reward: 6974.24, Epsilon: 0.010
# Episode 1279, Total Reward: 5863.47, Epsilon: 0.010
# Episode 1280, Total Reward: 7013.30, Epsilon: 0.010
# Episode 1281, Total Reward: 7004.40, Epsilon: 0.010
# Episode 1282, Total Reward: 6980.45, Epsilon: 0.010
# Episode 1283, Total Reward: 6967.72, Epsilon: 0.010
# Episode 1284, Total Reward: 6993.38, Epsilon: 0.010
# Episode 1285, Total Reward: 6949.37, Epsilon: 0.010
# Episode 1286, Total Reward: 6945.79, Epsilon: 0.010
# Episode 1287, Total Reward: 7014.52, Epsilon: 0.010
# Episode 1288, Total Reward: 7005.93, Epsilon: 0.010
# Episode 1289, Total Reward: 6982.62, Epsilon: 0.010
# Episode 1290, Total Reward: 6979.62, Epsilon: 0.010
# Episode 1291, Total Reward: 7011.15, Epsilon: 0.010
# Episode 1292, Total Reward: 6973.85, Epsilon: 0.010
# Episode 1293, Total Reward: 7010.15, Epsilon: 0.010
# Episode 1294, Total Reward: 7011.04, Epsilon: 0.010
# Episode 1295, Total Reward: 6982.34, Epsilon: 0.010
# Episode 1296, Total Reward: 6989.00, Epsilon: 0.010
# Episode 1297, Total Reward: 6997.57, Epsilon: 0.010
# Episode 1298, Total Reward: 6989.44, Epsilon: 0.010
# Episode 1299, Total Reward: 6980.24, Epsilon: 0.010
# Episode 1300, Total Reward: 6994.66, Epsilon: 0.010
# Episode 1301, Total Reward: 6991.25, Epsilon: 0.010
# Episode 1302, Total Reward: 6992.88, Epsilon: 0.010
# Episode 1303, Total Reward: 6984.49, Epsilon: 0.010
# Episode 1304, Total Reward: 6981.46, Epsilon: 0.010
# Episode 1305, Total Reward: 7055.95, Epsilon: 0.010
# Episode 1306, Total Reward: 6876.08, Epsilon: 0.010
# Episode 1307, Total Reward: 6986.48, Epsilon: 0.010
# Episode 1308, Total Reward: 7004.54, Epsilon: 0.010
# Episode 1309, Total Reward: 6972.63, Epsilon: 0.010
# Episode 1310, Total Reward: 6984.71, Epsilon: 0.010
# Episode 1311, Total Reward: 6971.60, Epsilon: 0.010
# Episode 1312, Total Reward: 7007.41, Epsilon: 0.010
# Episode 1313, Total Reward: 6966.42, Epsilon: 0.010
# Episode 1314, Total Reward: 7015.80, Epsilon: 0.010
# Episode 1315, Total Reward: 6962.80, Epsilon: 0.010
# Episode 1316, Total Reward: 6963.48, Epsilon: 0.010
# Episode 1317, Total Reward: 7007.12, Epsilon: 0.010
# Episode 1318, Total Reward: 6999.50, Epsilon: 0.010
# Episode 1319, Total Reward: 6958.59, Epsilon: 0.010
# Episode 1320, Total Reward: 6962.10, Epsilon: 0.010
# Episode 1321, Total Reward: 6938.31, Epsilon: 0.010
# Episode 1322, Total Reward: 7035.67, Epsilon: 0.010
# Episode 1323, Total Reward: 7009.72, Epsilon: 0.010
# Episode 1324, Total Reward: 6984.43, Epsilon: 0.010
# Episode 1325, Total Reward: 6953.99, Epsilon: 0.010
# Episode 1326, Total Reward: 6982.72, Epsilon: 0.010
# Episode 1327, Total Reward: 7008.42, Epsilon: 0.010
# Episode 1328, Total Reward: 6990.73, Epsilon: 0.010
# Episode 1329, Total Reward: 6976.37, Epsilon: 0.010
# Episode 1330, Total Reward: 6995.71, Epsilon: 0.010
# Episode 1331, Total Reward: 7001.81, Epsilon: 0.010
# Episode 1332, Total Reward: 6985.90, Epsilon: 0.010
# Episode 1333, Total Reward: 6976.28, Epsilon: 0.010
# Episode 1334, Total Reward: 6984.24, Epsilon: 0.010
# Episode 1335, Total Reward: 6963.39, Epsilon: 0.010
# Episode 1336, Total Reward: 6947.17, Epsilon: 0.010
# Episode 1337, Total Reward: 6972.62, Epsilon: 0.010
# Episode 1338, Total Reward: 7021.61, Epsilon: 0.010
# Episode 1339, Total Reward: 6988.63, Epsilon: 0.010
# Episode 1340, Total Reward: 6940.36, Epsilon: 0.010
# Episode 1341, Total Reward: 6990.15, Epsilon: 0.010
# Episode 1342, Total Reward: 6989.65, Epsilon: 0.010
# Episode 1343, Total Reward: 6979.06, Epsilon: 0.010
# Episode 1344, Total Reward: 6969.89, Epsilon: 0.010
# Episode 1345, Total Reward: 6936.90, Epsilon: 0.010
# Episode 1346, Total Reward: 6988.01, Epsilon: 0.010
# Episode 1347, Total Reward: 6937.64, Epsilon: 0.010
# Episode 1348, Total Reward: 6998.56, Epsilon: 0.010
# Episode 1349, Total Reward: 6983.72, Epsilon: 0.010
# Episode 1350, Total Reward: 6930.00, Epsilon: 0.010
# Episode 1351, Total Reward: 7010.29, Epsilon: 0.010
# Episode 1352, Total Reward: 7001.18, Epsilon: 0.010
# Episode 1353, Total Reward: 6973.65, Epsilon: 0.010
# Episode 1354, Total Reward: 5140.07, Epsilon: 0.010
# Episode 1355, Total Reward: 6989.24, Epsilon: 0.010
# Episode 1356, Total Reward: 6971.31, Epsilon: 0.010
# Episode 1357, Total Reward: 6939.36, Epsilon: 0.010
# Episode 1358, Total Reward: 6963.49, Epsilon: 0.010
# Episode 1359, Total Reward: 6968.09, Epsilon: 0.010
# Episode 1360, Total Reward: 7013.51, Epsilon: 0.010
# Episode 1361, Total Reward: 6939.38, Epsilon: 0.010
# Episode 1362, Total Reward: 6981.21, Epsilon: 0.010
# Episode 1363, Total Reward: 5899.86, Epsilon: 0.010
# Episode 1364, Total Reward: 6979.65, Epsilon: 0.010
# Episode 1365, Total Reward: 6982.10, Epsilon: 0.010
# Episode 1366, Total Reward: 6923.61, Epsilon: 0.010
# Episode 1367, Total Reward: 6967.67, Epsilon: 0.010
# Episode 1368, Total Reward: 6989.70, Epsilon: 0.010
# Episode 1369, Total Reward: 6966.92, Epsilon: 0.010
# Episode 1370, Total Reward: 7010.64, Epsilon: 0.010
# Episode 1371, Total Reward: 6980.32, Epsilon: 0.010
# Episode 1372, Total Reward: 4029.60, Epsilon: 0.010
# Episode 1373, Total Reward: 6980.63, Epsilon: 0.010
# Episode 1374, Total Reward: 7009.89, Epsilon: 0.010
# Episode 1375, Total Reward: 6952.78, Epsilon: 0.010
# Episode 1376, Total Reward: 6936.76, Epsilon: 0.010
# Episode 1377, Total Reward: 6970.65, Epsilon: 0.010
# Episode 1378, Total Reward: 6971.77, Epsilon: 0.010
# Episode 1379, Total Reward: 6998.99, Epsilon: 0.010
# Episode 1380, Total Reward: 6982.83, Epsilon: 0.010
# Episode 1381, Total Reward: 7011.93, Epsilon: 0.010
# Episode 1382, Total Reward: 6927.45, Epsilon: 0.010
# Episode 1383, Total Reward: 6994.90, Epsilon: 0.010
# Episode 1384, Total Reward: 5660.50, Epsilon: 0.010
# Episode 1385, Total Reward: 7011.71, Epsilon: 0.010
# Episode 1386, Total Reward: 6989.87, Epsilon: 0.010
# Episode 1387, Total Reward: 6969.17, Epsilon: 0.010
# Episode 1388, Total Reward: 7004.21, Epsilon: 0.010
# Episode 1389, Total Reward: 7007.01, Epsilon: 0.010
# Episode 1390, Total Reward: 6991.31, Epsilon: 0.010
# Episode 1391, Total Reward: 7011.65, Epsilon: 0.010
# Episode 1392, Total Reward: 6941.77, Epsilon: 0.010
# Episode 1393, Total Reward: 6934.89, Epsilon: 0.010
# Episode 1394, Total Reward: 6943.61, Epsilon: 0.010
# Episode 1395, Total Reward: 6981.81, Epsilon: 0.010
# Episode 1396, Total Reward: 7011.40, Epsilon: 0.010
# Episode 1397, Total Reward: 6966.50, Epsilon: 0.010
# Episode 1398, Total Reward: 7002.66, Epsilon: 0.010
# Episode 1399, Total Reward: 6991.57, Epsilon: 0.010
# Episode 1400, Total Reward: 6957.21, Epsilon: 0.010
# Episode 1401, Total Reward: 6964.70, Epsilon: 0.010
# Episode 1402, Total Reward: 7008.34, Epsilon: 0.010
# Episode 1403, Total Reward: 7028.54, Epsilon: 0.010
# Episode 1404, Total Reward: 6966.67, Epsilon: 0.010
# Episode 1405, Total Reward: 7012.38, Epsilon: 0.010
# Episode 1406, Total Reward: 6981.79, Epsilon: 0.010
# Episode 1407, Total Reward: 6961.59, Epsilon: 0.010
# Episode 1408, Total Reward: 6982.50, Epsilon: 0.010
# Episode 1409, Total Reward: 6962.14, Epsilon: 0.010
# Episode 1410, Total Reward: 6964.09, Epsilon: 0.010
# Episode 1411, Total Reward: 7022.26, Epsilon: 0.010
# Episode 1412, Total Reward: 6977.16, Epsilon: 0.010
# Episode 1413, Total Reward: 7019.55, Epsilon: 0.010
# Episode 1414, Total Reward: 7003.70, Epsilon: 0.010
# Episode 1415, Total Reward: 6975.92, Epsilon: 0.010
# Episode 1416, Total Reward: 6985.93, Epsilon: 0.010
# Episode 1417, Total Reward: 7009.87, Epsilon: 0.010
# Episode 1418, Total Reward: 6950.75, Epsilon: 0.010
# Episode 1419, Total Reward: 6984.98, Epsilon: 0.010
# Episode 1420, Total Reward: 6977.04, Epsilon: 0.010
# Episode 1421, Total Reward: 6972.15, Epsilon: 0.010
# Episode 1422, Total Reward: 6956.36, Epsilon: 0.010
# Episode 1423, Total Reward: 6982.79, Epsilon: 0.010
# Episode 1424, Total Reward: 6947.74, Epsilon: 0.010
# Episode 1425, Total Reward: 6999.72, Epsilon: 0.010
# Episode 1426, Total Reward: 6978.07, Epsilon: 0.010
# Episode 1427, Total Reward: 6964.16, Epsilon: 0.010
# Episode 1428, Total Reward: 6997.73, Epsilon: 0.010
# Episode 1429, Total Reward: 6991.77, Epsilon: 0.010
# Episode 1430, Total Reward: 6980.99, Epsilon: 0.010
# Episode 1431, Total Reward: 7018.10, Epsilon: 0.010
# Episode 1432, Total Reward: 6973.03, Epsilon: 0.010
# Episode 1433, Total Reward: 6963.07, Epsilon: 0.010
# Episode 1434, Total Reward: 6962.86, Epsilon: 0.010
# Episode 1435, Total Reward: 6957.36, Epsilon: 0.010
# Episode 1436, Total Reward: 7011.38, Epsilon: 0.010
# Episode 1437, Total Reward: 7006.49, Epsilon: 0.010
# Episode 1438, Total Reward: 6986.30, Epsilon: 0.010
# Episode 1439, Total Reward: 6980.54, Epsilon: 0.010
# Episode 1440, Total Reward: 7008.94, Epsilon: 0.010
# Episode 1441, Total Reward: 6937.98, Epsilon: 0.010
# Episode 1442, Total Reward: 6984.75, Epsilon: 0.010
# Episode 1443, Total Reward: 6961.70, Epsilon: 0.010
# Episode 1444, Total Reward: 7004.88, Epsilon: 0.010
# Episode 1445, Total Reward: 6984.37, Epsilon: 0.010
# Episode 1446, Total Reward: 6979.26, Epsilon: 0.010
# Episode 1447, Total Reward: 6997.97, Epsilon: 0.010
# Episode 1448, Total Reward: 6968.10, Epsilon: 0.010
# Episode 1449, Total Reward: 7013.10, Epsilon: 0.010
# Episode 1450, Total Reward: 7000.00, Epsilon: 0.010
# Episode 1451, Total Reward: 6994.01, Epsilon: 0.010
# Episode 1452, Total Reward: 6962.51, Epsilon: 0.010
# Episode 1453, Total Reward: 7015.16, Epsilon: 0.010
# Episode 1454, Total Reward: 6978.83, Epsilon: 0.010
# Episode 1455, Total Reward: 6971.15, Epsilon: 0.010
# Episode 1456, Total Reward: 6972.32, Epsilon: 0.010
# Episode 1457, Total Reward: 6992.51, Epsilon: 0.010
# Episode 1458, Total Reward: 6993.04, Epsilon: 0.010
# Episode 1459, Total Reward: 6975.66, Epsilon: 0.010
# Episode 1460, Total Reward: 7009.53, Epsilon: 0.010
# Episode 1461, Total Reward: 6996.65, Epsilon: 0.010
# Episode 1462, Total Reward: 6961.97, Epsilon: 0.010
# Episode 1463, Total Reward: 6954.09, Epsilon: 0.010
# Episode 1464, Total Reward: 7000.60, Epsilon: 0.010
# Episode 1465, Total Reward: 7001.93, Epsilon: 0.010
# Episode 1466, Total Reward: 6937.80, Epsilon: 0.010
# Episode 1467, Total Reward: 6981.98, Epsilon: 0.010
# Episode 1468, Total Reward: 6927.34, Epsilon: 0.010
# Episode 1469, Total Reward: 6975.39, Epsilon: 0.010
# Episode 1470, Total Reward: 6966.75, Epsilon: 0.010
# Episode 1471, Total Reward: 7011.45, Epsilon: 0.010
# Episode 1472, Total Reward: 6962.40, Epsilon: 0.010
# Episode 1473, Total Reward: 6984.25, Epsilon: 0.010
# Episode 1474, Total Reward: 6980.64, Epsilon: 0.010
# Episode 1475, Total Reward: 6981.68, Epsilon: 0.010
# Episode 1476, Total Reward: 6971.85, Epsilon: 0.010
# Episode 1477, Total Reward: 6913.07, Epsilon: 0.010
# Episode 1478, Total Reward: 6985.23, Epsilon: 0.010
# Episode 1479, Total Reward: 6966.73, Epsilon: 0.010
# Episode 1480, Total Reward: 7018.21, Epsilon: 0.010
# Episode 1481, Total Reward: 6986.30, Epsilon: 0.010
# Episode 1482, Total Reward: 6984.07, Epsilon: 0.010
# Episode 1483, Total Reward: 6982.96, Epsilon: 0.010
# Episode 1484, Total Reward: 7002.41, Epsilon: 0.010
# Episode 1485, Total Reward: 7021.02, Epsilon: 0.010
# Episode 1486, Total Reward: 6983.97, Epsilon: 0.010
# Episode 1487, Total Reward: 6976.82, Epsilon: 0.010
# Episode 1488, Total Reward: 6932.65, Epsilon: 0.010
# Episode 1489, Total Reward: 6993.21, Epsilon: 0.010
# Episode 1490, Total Reward: 6996.99, Epsilon: 0.010
# Episode 1491, Total Reward: 6940.55, Epsilon: 0.010
# Episode 1492, Total Reward: 6576.43, Epsilon: 0.010
# Episode 1493, Total Reward: 5989.35, Epsilon: 0.010
# Episode 1494, Total Reward: 6937.75, Epsilon: 0.010
# Episode 1495, Total Reward: 6975.11, Epsilon: 0.010
# Episode 1496, Total Reward: 6996.34, Epsilon: 0.010
# Episode 1497, Total Reward: 6993.43, Epsilon: 0.010
# Episode 1498, Total Reward: 6747.63, Epsilon: 0.010
# Episode 1499, Total Reward: 6985.99, Epsilon: 0.010
# Episode 1500, Total Reward: 6963.41, Epsilon: 0.010
# Episode 1501, Total Reward: 6947.87, Epsilon: 0.010
# Episode 1502, Total Reward: 6964.75, Epsilon: 0.010
# Episode 1503, Total Reward: 6981.10, Epsilon: 0.010
# Episode 1504, Total Reward: 6963.05, Epsilon: 0.010
# Episode 1505, Total Reward: 6996.75, Epsilon: 0.010
# Episode 1506, Total Reward: 6936.85, Epsilon: 0.010
# Episode 1507, Total Reward: 6971.66, Epsilon: 0.010
# Episode 1508, Total Reward: 6948.49, Epsilon: 0.010
# Episode 1509, Total Reward: 6985.55, Epsilon: 0.010
# Episode 1510, Total Reward: 7011.65, Epsilon: 0.010
# Episode 1511, Total Reward: 6951.70, Epsilon: 0.010
# Episode 1512, Total Reward: 6960.69, Epsilon: 0.010
# Episode 1513, Total Reward: 7012.27, Epsilon: 0.010
# Episode 1514, Total Reward: 7025.26, Epsilon: 0.010
# Episode 1515, Total Reward: 6948.95, Epsilon: 0.010
# Episode 1516, Total Reward: 6979.77, Epsilon: 0.010
# Episode 1517, Total Reward: 6971.34, Epsilon: 0.010
# Episode 1518, Total Reward: 7017.27, Epsilon: 0.010
# Episode 1519, Total Reward: 7000.52, Epsilon: 0.010
# Episode 1520, Total Reward: 7021.23, Epsilon: 0.010
# Episode 1521, Total Reward: 7014.88, Epsilon: 0.010
# Episode 1522, Total Reward: 6987.60, Epsilon: 0.010
# Episode 1523, Total Reward: 6984.56, Epsilon: 0.010
# Episode 1524, Total Reward: 6974.67, Epsilon: 0.010
# Episode 1525, Total Reward: 7014.70, Epsilon: 0.010
# Episode 1526, Total Reward: 6959.55, Epsilon: 0.010
# Episode 1527, Total Reward: 7049.61, Epsilon: 0.010
# Episode 1528, Total Reward: 7003.58, Epsilon: 0.010
# Episode 1529, Total Reward: 5416.62, Epsilon: 0.010
# Episode 1530, Total Reward: 6948.65, Epsilon: 0.010
# Episode 1531, Total Reward: 6999.17, Epsilon: 0.010
# Episode 1532, Total Reward: 6969.56, Epsilon: 0.010
# Episode 1533, Total Reward: 7002.92, Epsilon: 0.010
# Episode 1534, Total Reward: 7023.63, Epsilon: 0.010
# Episode 1535, Total Reward: 6895.66, Epsilon: 0.010
# Episode 1536, Total Reward: 7017.36, Epsilon: 0.010
# Episode 1537, Total Reward: 6991.63, Epsilon: 0.010
# Episode 1538, Total Reward: 6463.72, Epsilon: 0.010
# Episode 1539, Total Reward: 6938.45, Epsilon: 0.010
# Episode 1540, Total Reward: 6950.38, Epsilon: 0.010
# Episode 1541, Total Reward: 6958.66, Epsilon: 0.010
# Episode 1542, Total Reward: 6384.96, Epsilon: 0.010
# Episode 1543, Total Reward: 6978.17, Epsilon: 0.010
# Episode 1544, Total Reward: 7008.54, Epsilon: 0.010
# Episode 1545, Total Reward: 6990.24, Epsilon: 0.010
# Episode 1546, Total Reward: 6960.22, Epsilon: 0.010
# Episode 1547, Total Reward: 7007.50, Epsilon: 0.010
# Episode 1548, Total Reward: 6300.23, Epsilon: 0.010
# Episode 1549, Total Reward: 6984.97, Epsilon: 0.010
# Episode 1550, Total Reward: 4643.32, Epsilon: 0.010
# Episode 1551, Total Reward: 6930.20, Epsilon: 0.010
# Episode 1552, Total Reward: 6993.12, Epsilon: 0.010
# Episode 1553, Total Reward: 6984.13, Epsilon: 0.010
# Episode 1554, Total Reward: 6972.05, Epsilon: 0.010
# Episode 1555, Total Reward: 7013.29, Epsilon: 0.010
# Episode 1556, Total Reward: 5560.62, Epsilon: 0.010
# Episode 1557, Total Reward: 6961.70, Epsilon: 0.010
# Episode 1558, Total Reward: 6978.26, Epsilon: 0.010
# Episode 1559, Total Reward: 7006.54, Epsilon: 0.010
# Episode 1560, Total Reward: 6973.51, Epsilon: 0.010
# Episode 1561, Total Reward: 6970.31, Epsilon: 0.010
# Episode 1562, Total Reward: 7003.35, Epsilon: 0.010
# Episode 1563, Total Reward: 6968.44, Epsilon: 0.010
# Episode 1564, Total Reward: 6971.14, Epsilon: 0.010
# Episode 1565, Total Reward: 6376.15, Epsilon: 0.010
# Episode 1566, Total Reward: 6968.50, Epsilon: 0.010
# Episode 1567, Total Reward: 6947.03, Epsilon: 0.010
# Episode 1568, Total Reward: 6956.90, Epsilon: 0.010
# Episode 1569, Total Reward: 7005.37, Epsilon: 0.010
# Episode 1570, Total Reward: 6969.60, Epsilon: 0.010
# Episode 1571, Total Reward: 6936.91, Epsilon: 0.010
# Episode 1572, Total Reward: 6982.43, Epsilon: 0.010
# Episode 1573, Total Reward: 6970.91, Epsilon: 0.010
# Episode 1574, Total Reward: 7016.44, Epsilon: 0.010
# Episode 1575, Total Reward: 7002.43, Epsilon: 0.010
# Episode 1576, Total Reward: 6991.04, Epsilon: 0.010
# Episode 1577, Total Reward: 7015.64, Epsilon: 0.010
# Episode 1578, Total Reward: 6943.03, Epsilon: 0.010
# Episode 1579, Total Reward: 6964.10, Epsilon: 0.010
# Episode 1580, Total Reward: 6953.34, Epsilon: 0.010
# Episode 1581, Total Reward: 6970.77, Epsilon: 0.010
# Episode 1582, Total Reward: 7011.13, Epsilon: 0.010
# Episode 1583, Total Reward: 6982.81, Epsilon: 0.010
# Episode 1584, Total Reward: 6970.76, Epsilon: 0.010
# Episode 1585, Total Reward: 7000.04, Epsilon: 0.010
# Episode 1586, Total Reward: 7011.43, Epsilon: 0.010
# Episode 1587, Total Reward: 7015.20, Epsilon: 0.010
# Episode 1588, Total Reward: 6947.84, Epsilon: 0.010
# Episode 1589, Total Reward: 7002.70, Epsilon: 0.010
# Episode 1590, Total Reward: 6955.46, Epsilon: 0.010
# Episode 1591, Total Reward: 6991.33, Epsilon: 0.010
# Episode 1592, Total Reward: 7001.97, Epsilon: 0.010
# Episode 1593, Total Reward: 6996.93, Epsilon: 0.010
# Episode 1594, Total Reward: 7022.06, Epsilon: 0.010
# Episode 1595, Total Reward: 6947.79, Epsilon: 0.010
# Episode 1596, Total Reward: 6962.33, Epsilon: 0.010
# Episode 1597, Total Reward: 7000.54, Epsilon: 0.010
# Episode 1598, Total Reward: 6999.01, Epsilon: 0.010
# Episode 1599, Total Reward: 6985.48, Epsilon: 0.010
# Episode 1600, Total Reward: 6953.02, Epsilon: 0.010
# Episode 1601, Total Reward: 6966.56, Epsilon: 0.010
# Episode 1602, Total Reward: 6988.41, Epsilon: 0.010
# Episode 1603, Total Reward: 6279.04, Epsilon: 0.010
# Episode 1604, Total Reward: 7015.58, Epsilon: 0.010
# Episode 1605, Total Reward: 6991.95, Epsilon: 0.010
# Episode 1606, Total Reward: 7024.06, Epsilon: 0.010
# Episode 1607, Total Reward: 6972.14, Epsilon: 0.010
# Episode 1608, Total Reward: 6978.83, Epsilon: 0.010
# Episode 1609, Total Reward: 7022.90, Epsilon: 0.010
# Episode 1610, Total Reward: 6989.33, Epsilon: 0.010
# Episode 1611, Total Reward: 6944.01, Epsilon: 0.010
# Episode 1612, Total Reward: 6014.09, Epsilon: 0.010
# Episode 1613, Total Reward: 6987.79, Epsilon: 0.010
# Episode 1614, Total Reward: 6993.18, Epsilon: 0.010
# Episode 1615, Total Reward: 7049.77, Epsilon: 0.010
# Episode 1616, Total Reward: 6974.12, Epsilon: 0.010
# Episode 1617, Total Reward: 6989.47, Epsilon: 0.010
# Episode 1618, Total Reward: 6977.06, Epsilon: 0.010
# Episode 1619, Total Reward: 6998.91, Epsilon: 0.010
# Episode 1620, Total Reward: 6049.13, Epsilon: 0.010
# Episode 1621, Total Reward: 7000.08, Epsilon: 0.010
# Episode 1622, Total Reward: 6929.98, Epsilon: 0.010
# Episode 1623, Total Reward: 6985.14, Epsilon: 0.010
# Episode 1624, Total Reward: 7014.72, Epsilon: 0.010
# Episode 1625, Total Reward: 6934.04, Epsilon: 0.010
# Episode 1626, Total Reward: 6982.04, Epsilon: 0.010
# Episode 1627, Total Reward: 7007.43, Epsilon: 0.010
# Episode 1628, Total Reward: 7010.20, Epsilon: 0.010
# Episode 1629, Total Reward: 7024.09, Epsilon: 0.010
# Episode 1630, Total Reward: 6995.11, Epsilon: 0.010
# Episode 1631, Total Reward: 7022.09, Epsilon: 0.010
# Episode 1632, Total Reward: 6936.92, Epsilon: 0.010
# Episode 1633, Total Reward: 6989.14, Epsilon: 0.010
# Episode 1634, Total Reward: 4796.29, Epsilon: 0.010
# Episode 1635, Total Reward: 6977.14, Epsilon: 0.010
# Episode 1636, Total Reward: 7015.12, Epsilon: 0.010
# Episode 1637, Total Reward: 5756.24, Epsilon: 0.010
# Episode 1638, Total Reward: 7005.52, Epsilon: 0.010
# Episode 1639, Total Reward: 6994.12, Epsilon: 0.010
# Episode 1640, Total Reward: 6918.49, Epsilon: 0.010
# Episode 1641, Total Reward: 6994.34, Epsilon: 0.010
# Episode 1642, Total Reward: 7000.13, Epsilon: 0.010
# Episode 1643, Total Reward: 6978.69, Epsilon: 0.010
# Episode 1644, Total Reward: 6989.69, Epsilon: 0.010
# Episode 1645, Total Reward: 7018.43, Epsilon: 0.010
# Episode 1646, Total Reward: 6988.48, Epsilon: 0.010
# Episode 1647, Total Reward: 7003.15, Epsilon: 0.010
# Episode 1648, Total Reward: 7012.57, Epsilon: 0.010
# Episode 1649, Total Reward: 6988.68, Epsilon: 0.010
# Episode 1650, Total Reward: 6988.32, Epsilon: 0.010
# Episode 1651, Total Reward: 6919.31, Epsilon: 0.010
# Episode 1652, Total Reward: 5015.58, Epsilon: 0.010
# Episode 1653, Total Reward: 6997.69, Epsilon: 0.010
# Episode 1654, Total Reward: 6974.97, Epsilon: 0.010
# Episode 1655, Total Reward: 7001.38, Epsilon: 0.010
# Episode 1656, Total Reward: 7020.53, Epsilon: 0.010
# Episode 1657, Total Reward: 6992.68, Epsilon: 0.010
# Episode 1658, Total Reward: 6955.52, Epsilon: 0.010
# Episode 1659, Total Reward: 7005.49, Epsilon: 0.010
# Episode 1660, Total Reward: 6987.66, Epsilon: 0.010
# Episode 1661, Total Reward: 6953.96, Epsilon: 0.010
# Episode 1662, Total Reward: 6970.53, Epsilon: 0.010
# Episode 1663, Total Reward: 6977.48, Epsilon: 0.010
# Episode 1664, Total Reward: 6965.24, Epsilon: 0.010
# Episode 1665, Total Reward: 6989.40, Epsilon: 0.010
# Episode 1666, Total Reward: 6958.15, Epsilon: 0.010
# Episode 1667, Total Reward: 7008.27, Epsilon: 0.010
# Episode 1668, Total Reward: 6976.14, Epsilon: 0.010
# Episode 1669, Total Reward: 6945.39, Epsilon: 0.010
# Episode 1670, Total Reward: 7004.64, Epsilon: 0.010
# Episode 1671, Total Reward: 6978.06, Epsilon: 0.010
# Episode 1672, Total Reward: 6976.66, Epsilon: 0.010
# Episode 1673, Total Reward: 6971.33, Epsilon: 0.010
# Episode 1674, Total Reward: 7012.01, Epsilon: 0.010
# Episode 1675, Total Reward: 6948.43, Epsilon: 0.010
# Episode 1676, Total Reward: 5118.71, Epsilon: 0.010
# Episode 1677, Total Reward: 6031.35, Epsilon: 0.010
# Episode 1678, Total Reward: 6969.30, Epsilon: 0.010
# Episode 1679, Total Reward: 6915.36, Epsilon: 0.010
# Episode 1680, Total Reward: 6948.65, Epsilon: 0.010
# Episode 1681, Total Reward: 6985.49, Epsilon: 0.010
# Episode 1682, Total Reward: 6991.89, Epsilon: 0.010
# Episode 1683, Total Reward: 6967.73, Epsilon: 0.010
# Episode 1684, Total Reward: 6917.33, Epsilon: 0.010
# Episode 1685, Total Reward: 6944.56, Epsilon: 0.010
# Episode 1686, Total Reward: 7003.49, Epsilon: 0.010
# Episode 1687, Total Reward: 6985.42, Epsilon: 0.010
# Episode 1688, Total Reward: 6999.52, Epsilon: 0.010
# Episode 1689, Total Reward: 6963.95, Epsilon: 0.010
# Episode 1690, Total Reward: 6980.43, Epsilon: 0.010
# Episode 1691, Total Reward: 6972.42, Epsilon: 0.010
# Episode 1692, Total Reward: 7003.51, Epsilon: 0.010
# Episode 1693, Total Reward: 6978.06, Epsilon: 0.010
# Episode 1694, Total Reward: 6987.30, Epsilon: 0.010
# Episode 1695, Total Reward: 7013.22, Epsilon: 0.010
# Episode 1696, Total Reward: 6991.21, Epsilon: 0.010
# Episode 1697, Total Reward: 6937.53, Epsilon: 0.010
# Episode 1698, Total Reward: 6940.83, Epsilon: 0.010
# Episode 1699, Total Reward: 7009.10, Epsilon: 0.010
# Episode 1700, Total Reward: 6971.39, Epsilon: 0.010
# Episode 1701, Total Reward: 6999.17, Epsilon: 0.010
# Episode 1702, Total Reward: 6993.22, Epsilon: 0.010
# Episode 1703, Total Reward: 6981.03, Epsilon: 0.010
# Episode 1704, Total Reward: 6934.79, Epsilon: 0.010
# Episode 1705, Total Reward: 7009.38, Epsilon: 0.010
# Episode 1706, Total Reward: 7004.75, Epsilon: 0.010
# Episode 1707, Total Reward: 6944.23, Epsilon: 0.010
# Episode 1708, Total Reward: 6992.86, Epsilon: 0.010
# Episode 1709, Total Reward: 6969.34, Epsilon: 0.010
# Episode 1710, Total Reward: 6954.32, Epsilon: 0.010
# Episode 1711, Total Reward: 6964.42, Epsilon: 0.010
# Episode 1712, Total Reward: 6977.18, Epsilon: 0.010
# Episode 1713, Total Reward: 6952.81, Epsilon: 0.010
# Episode 1714, Total Reward: 6961.64, Epsilon: 0.010
# Episode 1715, Total Reward: 6939.03, Epsilon: 0.010
# Episode 1716, Total Reward: 7015.70, Epsilon: 0.010
# Episode 1717, Total Reward: 6964.58, Epsilon: 0.010
# Episode 1718, Total Reward: 6961.67, Epsilon: 0.010
# Episode 1719, Total Reward: 6960.39, Epsilon: 0.010
# Episode 1720, Total Reward: 6994.50, Epsilon: 0.010
# Episode 1721, Total Reward: 6983.73, Epsilon: 0.010
# Episode 1722, Total Reward: 6986.52, Epsilon: 0.010
# Episode 1723, Total Reward: 7009.80, Epsilon: 0.010
# Episode 1724, Total Reward: 6977.43, Epsilon: 0.010
# Episode 1725, Total Reward: 6994.53, Epsilon: 0.010
# Episode 1726, Total Reward: 6652.19, Epsilon: 0.010
# Episode 1727, Total Reward: 6982.29, Epsilon: 0.010
# Episode 1728, Total Reward: 6964.59, Epsilon: 0.010
# Episode 1729, Total Reward: 6937.49, Epsilon: 0.010
# Episode 1730, Total Reward: 6984.47, Epsilon: 0.010
# Episode 1731, Total Reward: 7014.85, Epsilon: 0.010
# Episode 1732, Total Reward: 6973.88, Epsilon: 0.010
# Episode 1733, Total Reward: 6989.36, Epsilon: 0.010
# Episode 1734, Total Reward: 6919.80, Epsilon: 0.010
# Episode 1735, Total Reward: 6961.40, Epsilon: 0.010
# Episode 1736, Total Reward: 6987.90, Epsilon: 0.010
# Episode 1737, Total Reward: 6965.36, Epsilon: 0.010
# Episode 1738, Total Reward: 7002.30, Epsilon: 0.010
# Episode 1739, Total Reward: 7007.35, Epsilon: 0.010
# Episode 1740, Total Reward: 6947.48, Epsilon: 0.010
# Episode 1741, Total Reward: 6962.02, Epsilon: 0.010
# Episode 1742, Total Reward: 6974.57, Epsilon: 0.010
# Episode 1743, Total Reward: 6940.16, Epsilon: 0.010
# Episode 1744, Total Reward: 6973.13, Epsilon: 0.010
# Episode 1745, Total Reward: 6959.96, Epsilon: 0.010
# Episode 1746, Total Reward: 6981.39, Epsilon: 0.010
# Episode 1747, Total Reward: 6989.65, Epsilon: 0.010
# Episode 1748, Total Reward: 6992.83, Epsilon: 0.010
# Episode 1749, Total Reward: 6988.84, Epsilon: 0.010
# Episode 1750, Total Reward: 6957.35, Epsilon: 0.010
# Episode 1751, Total Reward: 6961.34, Epsilon: 0.010
# Episode 1752, Total Reward: 6985.61, Epsilon: 0.010
# Episode 1753, Total Reward: 6961.71, Epsilon: 0.010
# Episode 1754, Total Reward: 7012.67, Epsilon: 0.010
# Episode 1755, Total Reward: 6980.20, Epsilon: 0.010
# Episode 1756, Total Reward: 6964.33, Epsilon: 0.010
# Episode 1757, Total Reward: 6982.15, Epsilon: 0.010
# Episode 1758, Total Reward: 6979.03, Epsilon: 0.010
# Episode 1759, Total Reward: 6942.79, Epsilon: 0.010
# Episode 1760, Total Reward: 6958.81, Epsilon: 0.010
# Episode 1761, Total Reward: 6976.31, Epsilon: 0.010
# Episode 1762, Total Reward: 6993.80, Epsilon: 0.010
# Episode 1763, Total Reward: 7017.12, Epsilon: 0.010
# Episode 1764, Total Reward: 6986.16, Epsilon: 0.010
# Episode 1765, Total Reward: 6950.47, Epsilon: 0.010
# Episode 1766, Total Reward: 6989.18, Epsilon: 0.010
# Episode 1767, Total Reward: 7014.86, Epsilon: 0.010
# Episode 1768, Total Reward: 3503.11, Epsilon: 0.010
# Episode 1769, Total Reward: 6988.86, Epsilon: 0.010
# Episode 1770, Total Reward: 6955.11, Epsilon: 0.010
# Episode 1771, Total Reward: 7018.17, Epsilon: 0.010
# Episode 1772, Total Reward: 6961.65, Epsilon: 0.010
# Episode 1773, Total Reward: 6995.00, Epsilon: 0.010
# Episode 1774, Total Reward: 6982.50, Epsilon: 0.010
# Episode 1775, Total Reward: 7008.85, Epsilon: 0.010
# Episode 1776, Total Reward: 6974.43, Epsilon: 0.010
# Episode 1777, Total Reward: 6962.89, Epsilon: 0.010
# Episode 1778, Total Reward: 6987.59, Epsilon: 0.010
# Episode 1779, Total Reward: 6993.39, Epsilon: 0.010
# Episode 1780, Total Reward: 6964.71, Epsilon: 0.010
# Episode 1781, Total Reward: 7011.90, Epsilon: 0.010
# Episode 1782, Total Reward: 6990.25, Epsilon: 0.010
# Episode 1783, Total Reward: 6986.86, Epsilon: 0.010
# Episode 1784, Total Reward: 6961.26, Epsilon: 0.010
# Episode 1785, Total Reward: 6986.74, Epsilon: 0.010
# Episode 1786, Total Reward: 6962.42, Epsilon: 0.010
# Episode 1787, Total Reward: 7002.80, Epsilon: 0.010
# Episode 1788, Total Reward: 6983.94, Epsilon: 0.010
# Episode 1789, Total Reward: 6968.66, Epsilon: 0.010
# Episode 1790, Total Reward: 6987.10, Epsilon: 0.010
# Episode 1791, Total Reward: 7015.21, Epsilon: 0.010
# Episode 1792, Total Reward: 7004.42, Epsilon: 0.010
# Episode 1793, Total Reward: 6968.71, Epsilon: 0.010
# Episode 1794, Total Reward: 6980.87, Epsilon: 0.010
# Episode 1795, Total Reward: 6986.04, Epsilon: 0.010
# Episode 1796, Total Reward: 7013.82, Epsilon: 0.010
# Episode 1797, Total Reward: 6928.34, Epsilon: 0.010
# Episode 1798, Total Reward: 7006.43, Epsilon: 0.010
# Episode 1799, Total Reward: 6986.25, Epsilon: 0.010
# Episode 1800, Total Reward: 6957.79, Epsilon: 0.010
# Episode 1801, Total Reward: 6989.17, Epsilon: 0.010
# Episode 1802, Total Reward: 6963.90, Epsilon: 0.010
# Episode 1803, Total Reward: 6975.71, Epsilon: 0.010
# Episode 1804, Total Reward: 6994.07, Epsilon: 0.010
# Episode 1805, Total Reward: 6962.73, Epsilon: 0.010
# Episode 1806, Total Reward: 6945.84, Epsilon: 0.010
# Episode 1807, Total Reward: 6951.66, Epsilon: 0.010
# Episode 1808, Total Reward: 6956.16, Epsilon: 0.010
# Episode 1809, Total Reward: 6974.13, Epsilon: 0.010
# Episode 1810, Total Reward: 7003.00, Epsilon: 0.010
# Episode 1811, Total Reward: 6950.24, Epsilon: 0.010
# Episode 1812, Total Reward: 7016.61, Epsilon: 0.010
# Episode 1813, Total Reward: 6967.79, Epsilon: 0.010
# Episode 1814, Total Reward: 6963.40, Epsilon: 0.010
# Episode 1815, Total Reward: 6969.39, Epsilon: 0.010
# Episode 1816, Total Reward: 7011.00, Epsilon: 0.010
# Episode 1817, Total Reward: 6948.20, Epsilon: 0.010
# Episode 1818, Total Reward: 6982.38, Epsilon: 0.010
# Episode 1819, Total Reward: 6959.72, Epsilon: 0.010
# Episode 1820, Total Reward: 6972.27, Epsilon: 0.010
# Episode 1821, Total Reward: 6954.79, Epsilon: 0.010
# Episode 1822, Total Reward: 6641.98, Epsilon: 0.010
# Episode 1823, Total Reward: 7012.13, Epsilon: 0.010
# Episode 1824, Total Reward: 6961.34, Epsilon: 0.010
# Episode 1825, Total Reward: 6961.88, Epsilon: 0.010
# Episode 1826, Total Reward: 7010.44, Epsilon: 0.010
# Episode 1827, Total Reward: 6957.92, Epsilon: 0.010
# Episode 1828, Total Reward: 6995.70, Epsilon: 0.010
# Episode 1829, Total Reward: 6987.28, Epsilon: 0.010
# Episode 1830, Total Reward: 6997.90, Epsilon: 0.010
# Episode 1831, Total Reward: 6996.68, Epsilon: 0.010
# Episode 1832, Total Reward: 6958.31, Epsilon: 0.010
# Episode 1833, Total Reward: 6923.98, Epsilon: 0.010
# Episode 1834, Total Reward: 6982.39, Epsilon: 0.010
# Episode 1835, Total Reward: 7019.56, Epsilon: 0.010
# Episode 1836, Total Reward: 6983.98, Epsilon: 0.010
# Episode 1837, Total Reward: 6983.88, Epsilon: 0.010
# Episode 1838, Total Reward: 6965.27, Epsilon: 0.010
# Episode 1839, Total Reward: 6979.21, Epsilon: 0.010
# Episode 1840, Total Reward: 6991.79, Epsilon: 0.010
# Episode 1841, Total Reward: 6994.20, Epsilon: 0.010
# Episode 1842, Total Reward: 6990.14, Epsilon: 0.010
# Episode 1843, Total Reward: 6976.76, Epsilon: 0.010
# Episode 1844, Total Reward: 6971.76, Epsilon: 0.010
# Episode 1845, Total Reward: 6985.66, Epsilon: 0.010
# Episode 1846, Total Reward: 6998.88, Epsilon: 0.010
# Episode 1847, Total Reward: 6973.09, Epsilon: 0.010
# Episode 1848, Total Reward: 6999.43, Epsilon: 0.010
# Episode 1849, Total Reward: 6974.40, Epsilon: 0.010
# Episode 1850, Total Reward: 6957.47, Epsilon: 0.010
# Episode 1851, Total Reward: 6995.37, Epsilon: 0.010
# Episode 1852, Total Reward: 6952.03, Epsilon: 0.010
# Episode 1853, Total Reward: 6972.73, Epsilon: 0.010
# Episode 1854, Total Reward: 6964.51, Epsilon: 0.010
# Episode 1855, Total Reward: 7010.77, Epsilon: 0.010
# Episode 1856, Total Reward: 6983.96, Epsilon: 0.010
# Episode 1857, Total Reward: 6978.33, Epsilon: 0.010
# Episode 1858, Total Reward: 6986.37, Epsilon: 0.010
# Episode 1859, Total Reward: 3958.19, Epsilon: 0.010
# Episode 1860, Total Reward: 6765.10, Epsilon: 0.010
# Episode 1861, Total Reward: 6972.97, Epsilon: 0.010
# Episode 1862, Total Reward: 7015.00, Epsilon: 0.010
# Episode 1863, Total Reward: 6976.97, Epsilon: 0.010
# Episode 1864, Total Reward: 6968.71, Epsilon: 0.010
# Episode 1865, Total Reward: 6990.55, Epsilon: 0.010
# Episode 1866, Total Reward: 6985.55, Epsilon: 0.010
# Episode 1867, Total Reward: 6958.45, Epsilon: 0.010
# Episode 1868, Total Reward: 7005.34, Epsilon: 0.010
# Episode 1869, Total Reward: 6275.95, Epsilon: 0.010
# Episode 1870, Total Reward: 6958.14, Epsilon: 0.010
# Episode 1871, Total Reward: 6960.48, Epsilon: 0.010
# Episode 1872, Total Reward: 7001.06, Epsilon: 0.010
# Episode 1873, Total Reward: 6949.41, Epsilon: 0.010
# Episode 1874, Total Reward: 6970.86, Epsilon: 0.010
# Episode 1875, Total Reward: 6973.75, Epsilon: 0.010
# Episode 1876, Total Reward: 7006.27, Epsilon: 0.010
# Episode 1877, Total Reward: 6965.37, Epsilon: 0.010
# Episode 1878, Total Reward: 6922.83, Epsilon: 0.010
# Episode 1879, Total Reward: 6971.63, Epsilon: 0.010
# Episode 1880, Total Reward: 6990.01, Epsilon: 0.010
# Episode 1881, Total Reward: 7005.44, Epsilon: 0.010
# Episode 1882, Total Reward: 7024.57, Epsilon: 0.010
# Episode 1883, Total Reward: 6965.24, Epsilon: 0.010
# Episode 1884, Total Reward: 7011.10, Epsilon: 0.010
# Episode 1885, Total Reward: 7036.51, Epsilon: 0.010
# Episode 1886, Total Reward: 7012.95, Epsilon: 0.010
# Episode 1887, Total Reward: 6981.39, Epsilon: 0.010
# Episode 1888, Total Reward: 6975.84, Epsilon: 0.010
# Episode 1889, Total Reward: 6968.53, Epsilon: 0.010
# Episode 1890, Total Reward: 5848.70, Epsilon: 0.010
# Episode 1891, Total Reward: 7005.86, Epsilon: 0.010
# Episode 1892, Total Reward: 6979.60, Epsilon: 0.010
# Episode 1893, Total Reward: 6957.72, Epsilon: 0.010
# Episode 1894, Total Reward: 6998.66, Epsilon: 0.010
# Episode 1895, Total Reward: 6966.41, Epsilon: 0.010
# Episode 1896, Total Reward: 6991.55, Epsilon: 0.010
# Episode 1897, Total Reward: 6959.61, Epsilon: 0.010
# Episode 1898, Total Reward: 6987.61, Epsilon: 0.010
# Episode 1899, Total Reward: 6230.14, Epsilon: 0.010
# Episode 1900, Total Reward: 6733.24, Epsilon: 0.010
# Episode 1901, Total Reward: 6969.21, Epsilon: 0.010
# Episode 1902, Total Reward: 7001.15, Epsilon: 0.010
# Episode 1903, Total Reward: 5254.97, Epsilon: 0.010
# Episode 1904, Total Reward: 6971.27, Epsilon: 0.010
# Episode 1905, Total Reward: 6944.15, Epsilon: 0.010
# Episode 1906, Total Reward: 7023.87, Epsilon: 0.010
# Episode 1907, Total Reward: 6981.88, Epsilon: 0.010
# Episode 1908, Total Reward: 7015.44, Epsilon: 0.010
# Episode 1909, Total Reward: 6966.56, Epsilon: 0.010
# Episode 1910, Total Reward: 6934.55, Epsilon: 0.010
# Episode 1911, Total Reward: 6982.51, Epsilon: 0.010
# Episode 1912, Total Reward: 6968.64, Epsilon: 0.010
# Episode 1913, Total Reward: 6969.40, Epsilon: 0.010
# Episode 1914, Total Reward: 6963.07, Epsilon: 0.010
# Episode 1915, Total Reward: 6972.40, Epsilon: 0.010
# Episode 1916, Total Reward: 6936.09, Epsilon: 0.010
# Episode 1917, Total Reward: 6976.87, Epsilon: 0.010
# Episode 1918, Total Reward: 6948.21, Epsilon: 0.010
# Episode 1919, Total Reward: 6986.16, Epsilon: 0.010
# Episode 1920, Total Reward: 6939.54, Epsilon: 0.010
# Episode 1921, Total Reward: 6930.97, Epsilon: 0.010
# Episode 1922, Total Reward: 6502.68, Epsilon: 0.010
# ...
# Episode 5694, Total Reward: 6389.15, Epsilon: 0.010
# Episode 5695, Total Reward: 6945.69, Epsilon: 0.010
# Episode 5696, Total Reward: 7011.74, Epsilon: 0.010
# Episode 5697, Total Reward: 6961.33, Epsilon: 0.010
# Episode 5698, Total Reward: 7017.94, Epsilon: 0.010
# Episode 5699, Total Reward: 7008.48, Epsilon: 0.010
# Episode 5700, Total Reward: 6991.06, Epsilon: 0.010
# Episode 5701, Total Reward: 6969.93, Epsilon: 0.010
# Episode 5702, Total Reward: 6975.96, Epsilon: 0.010
# Episode 5703, Total Reward: 7016.37, Epsilon: 0.010
# Episode 5704, Total Reward: 6989.38, Epsilon: 0.010
# Episode 5705, Total Reward: 6970.59, Epsilon: 0.010
# Episode 5706, Total Reward: 6973.88, Epsilon: 0.010
# Episode 5707, Total Reward: 6966.06, Epsilon: 0.010
# Episode 5708, Total Reward: 7010.75, Epsilon: 0.010
# Episode 5709, Total Reward: 7036.19, Epsilon: 0.010
# Episode 5710, Total Reward: 6999.88, Epsilon: 0.010
# Episode 5711, Total Reward: 6997.16, Epsilon: 0.010
# Episode 5712, Total Reward: 6969.39, Epsilon: 0.010
# Episode 5713, Total Reward: 6988.38, Epsilon: 0.010
# Episode 5714, Total Reward: 6970.68, Epsilon: 0.010
# Episode 5715, Total Reward: 6972.13, Epsilon: 0.010
# Episode 5716, Total Reward: 7020.11, Epsilon: 0.010
# Episode 5717, Total Reward: 6967.47, Epsilon: 0.010
# Episode 5718, Total Reward: 6985.28, Epsilon: 0.010
# Episode 5719, Total Reward: 6981.85, Epsilon: 0.010
# Episode 5720, Total Reward: 6997.33, Epsilon: 0.010
# Episode 5721, Total Reward: 6979.80, Epsilon: 0.010
# Episode 5722, Total Reward: 7023.88, Epsilon: 0.010
# Episode 5723, Total Reward: 6998.67, Epsilon: 0.010
# Episode 5724, Total Reward: 6991.04, Epsilon: 0.010
# Episode 5725, Total Reward: 6980.22, Epsilon: 0.010
# Episode 5726, Total Reward: 6970.81, Epsilon: 0.010
# Episode 5727, Total Reward: 6958.04, Epsilon: 0.010
# Episode 5728, Total Reward: 6962.90, Epsilon: 0.010
# Episode 5729, Total Reward: 7012.77, Epsilon: 0.010
# Episode 5730, Total Reward: 6969.87, Epsilon: 0.010
# Episode 5731, Total Reward: 7013.41, Epsilon: 0.010
# Episode 5732, Total Reward: 7001.83, Epsilon: 0.010
# Episode 5733, Total Reward: 6958.07, Epsilon: 0.010
# Episode 5734, Total Reward: 6979.29, Epsilon: 0.010
# Episode 5735, Total Reward: 6975.46, Epsilon: 0.010
# Episode 5736, Total Reward: 7007.82, Epsilon: 0.010
# Episode 5737, Total Reward: 6974.80, Epsilon: 0.010
# Episode 5738, Total Reward: 7004.99, Epsilon: 0.010
# Episode 5739, Total Reward: 6988.17, Epsilon: 0.010
# Episode 5740, Total Reward: 6940.47, Epsilon: 0.010
# Episode 5741, Total Reward: 6978.05, Epsilon: 0.010
# Episode 5742, Total Reward: 7005.84, Epsilon: 0.010
# Episode 5743, Total Reward: 6917.98, Epsilon: 0.010
# Episode 5744, Total Reward: 6969.99, Epsilon: 0.010
# Episode 5745, Total Reward: 6981.34, Epsilon: 0.010
# Episode 5746, Total Reward: 7018.05, Epsilon: 0.010
# Episode 5747, Total Reward: 6960.56, Epsilon: 0.010
# Episode 5748, Total Reward: 6998.21, Epsilon: 0.010
# Episode 5749, Total Reward: 6943.85, Epsilon: 0.010
# Episode 5750, Total Reward: 7025.76, Epsilon: 0.010
# Episode 5751, Total Reward: 6972.13, Epsilon: 0.010
# Episode 5752, Total Reward: 7028.25, Epsilon: 0.010
# Episode 5753, Total Reward: 6979.91, Epsilon: 0.010
# Episode 5754, Total Reward: 6974.02, Epsilon: 0.010
# Episode 5755, Total Reward: 7006.05, Epsilon: 0.010
# Episode 5756, Total Reward: 6942.66, Epsilon: 0.010
# Episode 5757, Total Reward: 7021.59, Epsilon: 0.010
# Episode 5758, Total Reward: 6973.25, Epsilon: 0.010
# Episode 5759, Total Reward: 6990.83, Epsilon: 0.010
# Episode 5760, Total Reward: 6991.56, Epsilon: 0.010
# Episode 5761, Total Reward: 6985.63, Epsilon: 0.010
# Episode 5762, Total Reward: 6960.11, Epsilon: 0.010
# Episode 5763, Total Reward: 6982.03, Epsilon: 0.010
# Episode 5764, Total Reward: 7011.97, Epsilon: 0.010
# Episode 5765, Total Reward: 6963.36, Epsilon: 0.010
# Episode 5766, Total Reward: 7007.06, Epsilon: 0.010
# Episode 5767, Total Reward: 7016.23, Epsilon: 0.010
# Episode 5768, Total Reward: 6960.19, Epsilon: 0.010
# Episode 5769, Total Reward: 7012.96, Epsilon: 0.010
# Episode 5770, Total Reward: 6962.16, Epsilon: 0.010
# Episode 5771, Total Reward: 7008.03, Epsilon: 0.010
# Episode 5772, Total Reward: 6961.29, Epsilon: 0.010
# Episode 5773, Total Reward: 6984.49, Epsilon: 0.010
# Episode 5774, Total Reward: 6943.57, Epsilon: 0.010
# Episode 5775, Total Reward: 7005.16, Epsilon: 0.010
# Episode 5776, Total Reward: 6993.21, Epsilon: 0.010
# Episode 5777, Total Reward: 7000.67, Epsilon: 0.010
# Episode 5778, Total Reward: 6944.87, Epsilon: 0.010
# Episode 5779, Total Reward: 6972.35, Epsilon: 0.010
# Episode 5780, Total Reward: 7006.11, Epsilon: 0.010
# Episode 5781, Total Reward: 6991.79, Epsilon: 0.010
# Episode 5782, Total Reward: 7013.11, Epsilon: 0.010
# Episode 5783, Total Reward: 6936.10, Epsilon: 0.010
# Episode 5784, Total Reward: 7019.80, Epsilon: 0.010
# Episode 5785, Total Reward: 6251.05, Epsilon: 0.010
# Episode 5786, Total Reward: 6976.03, Epsilon: 0.010
# Episode 5787, Total Reward: 6986.00, Epsilon: 0.010
# Episode 5788, Total Reward: 6860.67, Epsilon: 0.010
# Episode 5789, Total Reward: 6502.13, Epsilon: 0.010
# Episode 5790, Total Reward: 6380.04, Epsilon: 0.010
# Episode 5791, Total Reward: 6959.26, Epsilon: 0.010
# Episode 5792, Total Reward: 6980.66, Epsilon: 0.010
# Episode 5793, Total Reward: 7004.52, Epsilon: 0.010
# Episode 5794, Total Reward: 6986.99, Epsilon: 0.010
# Episode 5795, Total Reward: 6992.47, Epsilon: 0.010
# Episode 5796, Total Reward: 7001.02, Epsilon: 0.010
# Episode 5797, Total Reward: 6977.03, Epsilon: 0.010
# Episode 5798, Total Reward: 6979.62, Epsilon: 0.010
# Episode 5799, Total Reward: 6955.89, Epsilon: 0.010
# Episode 5800, Total Reward: 6996.44, Epsilon: 0.010
# Episode 5801, Total Reward: 6998.14, Epsilon: 0.010
# Episode 5802, Total Reward: 6917.50, Epsilon: 0.010
# Episode 5803, Total Reward: 7007.48, Epsilon: 0.010
# Episode 5804, Total Reward: 6984.21, Epsilon: 0.010
# Episode 5805, Total Reward: 6965.03, Epsilon: 0.010
# Episode 5806, Total Reward: 6973.81, Epsilon: 0.010
# Episode 5807, Total Reward: 6968.13, Epsilon: 0.010
# Episode 5808, Total Reward: 6982.46, Epsilon: 0.010
# Episode 5809, Total Reward: 6984.19, Epsilon: 0.010
# Episode 5810, Total Reward: 6983.06, Epsilon: 0.010
# Episode 5811, Total Reward: 6973.62, Epsilon: 0.010
# Episode 5812, Total Reward: 6984.72, Epsilon: 0.010
# Episode 5813, Total Reward: 6956.24, Epsilon: 0.010
# Episode 5814, Total Reward: 6963.75, Epsilon: 0.010
# Episode 5815, Total Reward: 6971.08, Epsilon: 0.010
# Episode 5816, Total Reward: 6964.70, Epsilon: 0.010
# Episode 5817, Total Reward: 6986.08, Epsilon: 0.010
# Episode 5818, Total Reward: 6945.61, Epsilon: 0.010
# Episode 5819, Total Reward: 6983.43, Epsilon: 0.010
# Episode 5820, Total Reward: 7006.97, Epsilon: 0.010
# Episode 5821, Total Reward: 6985.49, Epsilon: 0.010
# Episode 5822, Total Reward: 7006.76, Epsilon: 0.010
# Episode 5823, Total Reward: 6995.52, Epsilon: 0.010
# Episode 5824, Total Reward: 6970.36, Epsilon: 0.010
# Episode 5825, Total Reward: 6978.17, Epsilon: 0.010
# Episode 5826, Total Reward: 7004.63, Epsilon: 0.010
# Episode 5827, Total Reward: 7015.66, Epsilon: 0.010
# Episode 5828, Total Reward: 6990.21, Epsilon: 0.010
# Episode 5829, Total Reward: 7023.42, Epsilon: 0.010
# Episode 5830, Total Reward: 6986.93, Epsilon: 0.010
# Episode 5831, Total Reward: 6976.94, Epsilon: 0.010
# Episode 5832, Total Reward: 6964.76, Epsilon: 0.010
# Episode 5833, Total Reward: 6971.18, Epsilon: 0.010
# Episode 5834, Total Reward: 7000.02, Epsilon: 0.010
# Episode 5835, Total Reward: 7013.76, Epsilon: 0.010
# Episode 5836, Total Reward: 6976.17, Epsilon: 0.010
# Episode 5837, Total Reward: 7010.16, Epsilon: 0.010
# Episode 5838, Total Reward: 6988.10, Epsilon: 0.010
# Episode 5839, Total Reward: 7004.51, Epsilon: 0.010
# Episode 5840, Total Reward: 6978.32, Epsilon: 0.010
# Episode 5841, Total Reward: 6988.15, Epsilon: 0.010
# Episode 5842, Total Reward: 7003.17, Epsilon: 0.010
# Episode 5843, Total Reward: 7011.94, Epsilon: 0.010
# Episode 5844, Total Reward: 6977.67, Epsilon: 0.010
# Episode 5845, Total Reward: 7008.87, Epsilon: 0.010
# Episode 5846, Total Reward: 6977.20, Epsilon: 0.010
# Episode 5847, Total Reward: 6985.91, Epsilon: 0.010
# Episode 5848, Total Reward: 6986.52, Epsilon: 0.010
# Episode 5849, Total Reward: 4646.63, Epsilon: 0.010
# Episode 5850, Total Reward: 6987.93, Epsilon: 0.010
# Episode 5851, Total Reward: 6971.76, Epsilon: 0.010
# Episode 5852, Total Reward: 6944.20, Epsilon: 0.010
# Episode 5853, Total Reward: 6976.06, Epsilon: 0.010
# Episode 5854, Total Reward: 6976.64, Epsilon: 0.010
# Episode 5855, Total Reward: 7013.94, Epsilon: 0.010
# Episode 5856, Total Reward: 6918.59, Epsilon: 0.010
# Episode 5857, Total Reward: 6952.18, Epsilon: 0.010
# Episode 5858, Total Reward: 7020.42, Epsilon: 0.010
# Episode 5859, Total Reward: 6974.59, Epsilon: 0.010
# Episode 5860, Total Reward: 5266.09, Epsilon: 0.010
# Episode 5861, Total Reward: 6963.87, Epsilon: 0.010
# Episode 5862, Total Reward: 7001.52, Epsilon: 0.010
# Episode 5863, Total Reward: 6981.06, Epsilon: 0.010
# Episode 5864, Total Reward: 6987.54, Epsilon: 0.010
# Episode 5865, Total Reward: 6967.07, Epsilon: 0.010
# Episode 5866, Total Reward: 7007.78, Epsilon: 0.010
# Episode 5867, Total Reward: 6943.81, Epsilon: 0.010
# Episode 5868, Total Reward: 7006.63, Epsilon: 0.010
# Episode 5869, Total Reward: 5632.84, Epsilon: 0.010
# Episode 5870, Total Reward: 7002.44, Epsilon: 0.010
# Episode 5871, Total Reward: 7009.88, Epsilon: 0.010
# Episode 5872, Total Reward: 6971.73, Epsilon: 0.010
# Episode 5873, Total Reward: 6965.05, Epsilon: 0.010
# Episode 5874, Total Reward: 7020.20, Epsilon: 0.010
# Episode 5875, Total Reward: 6928.93, Epsilon: 0.010
# Episode 5876, Total Reward: 6983.48, Epsilon: 0.010
# Episode 5877, Total Reward: 7003.70, Epsilon: 0.010
# Episode 5878, Total Reward: 6966.14, Epsilon: 0.010
# Episode 5879, Total Reward: 6957.77, Epsilon: 0.010
# Episode 5880, Total Reward: 6974.66, Epsilon: 0.010
# Episode 5881, Total Reward: 6634.73, Epsilon: 0.010
# Episode 5882, Total Reward: 6977.94, Epsilon: 0.010
# Episode 5883, Total Reward: 5990.54, Epsilon: 0.010
# Episode 5884, Total Reward: 6982.10, Epsilon: 0.010
# Episode 5885, Total Reward: 6991.07, Epsilon: 0.010
# Episode 5886, Total Reward: 6963.29, Epsilon: 0.010
# Episode 5887, Total Reward: 6737.21, Epsilon: 0.010
# Episode 5888, Total Reward: 6959.36, Epsilon: 0.010
# Episode 5889, Total Reward: 6991.98, Epsilon: 0.010
# Episode 5890, Total Reward: 6973.43, Epsilon: 0.010
# Episode 5891, Total Reward: 7001.20, Epsilon: 0.010
# Episode 5892, Total Reward: 6986.49, Epsilon: 0.010
# Episode 5893, Total Reward: 7026.90, Epsilon: 0.010
# Episode 5894, Total Reward: 6941.57, Epsilon: 0.010
# Episode 5895, Total Reward: 7014.50, Epsilon: 0.010
# Episode 5896, Total Reward: 7002.56, Epsilon: 0.010
# Episode 5897, Total Reward: 7001.71, Epsilon: 0.010
# Episode 5898, Total Reward: 7021.01, Epsilon: 0.010
# Episode 5899, Total Reward: 6995.74, Epsilon: 0.010
# Episode 5900, Total Reward: 6887.61, Epsilon: 0.010
# Episode 5901, Total Reward: 6990.07, Epsilon: 0.010
# Episode 5902, Total Reward: 6973.44, Epsilon: 0.010
# Episode 5903, Total Reward: 7002.83, Epsilon: 0.010
# Episode 5904, Total Reward: 6998.87, Epsilon: 0.010
# Episode 5905, Total Reward: 6997.98, Epsilon: 0.010
# Episode 5906, Total Reward: 6959.63, Epsilon: 0.010
# Episode 5907, Total Reward: 6976.26, Epsilon: 0.010
# Episode 5908, Total Reward: 6972.34, Epsilon: 0.010
# Episode 5909, Total Reward: 7000.98, Epsilon: 0.010
# Episode 5910, Total Reward: 7015.03, Epsilon: 0.010
# Episode 5911, Total Reward: 6247.91, Epsilon: 0.010
# Episode 5912, Total Reward: 6976.11, Epsilon: 0.010
# Episode 5913, Total Reward: 5869.97, Epsilon: 0.010
# Episode 5914, Total Reward: 7001.24, Epsilon: 0.010
# Episode 5915, Total Reward: 6952.69, Epsilon: 0.010
# Episode 5916, Total Reward: 6980.76, Epsilon: 0.010
# Episode 5917, Total Reward: 6982.20, Epsilon: 0.010
# Episode 5918, Total Reward: 6974.06, Epsilon: 0.010
# Episode 5919, Total Reward: 6977.52, Epsilon: 0.010
# Episode 5920, Total Reward: 6988.09, Epsilon: 0.010
# Episode 5921, Total Reward: 6955.22, Epsilon: 0.010
# Episode 5922, Total Reward: 6986.84, Epsilon: 0.010
# Episode 5923, Total Reward: 6988.59, Epsilon: 0.010
# Episode 5924, Total Reward: 7007.67, Epsilon: 0.010
# Episode 5925, Total Reward: 6997.44, Epsilon: 0.010
# Episode 5926, Total Reward: 6952.60, Epsilon: 0.010
# Episode 5927, Total Reward: 6233.38, Epsilon: 0.010
# Episode 5928, Total Reward: 6963.69, Epsilon: 0.010
# Episode 5929, Total Reward: 6968.71, Epsilon: 0.010
# Episode 5930, Total Reward: 7021.52, Epsilon: 0.010
# Episode 5931, Total Reward: 6987.60, Epsilon: 0.010
# Episode 5932, Total Reward: 6969.33, Epsilon: 0.010
# Episode 5933, Total Reward: 6998.69, Epsilon: 0.010
# Episode 5934, Total Reward: 6987.72, Epsilon: 0.010
# Episode 5935, Total Reward: 6988.99, Epsilon: 0.010
# Episode 5936, Total Reward: 6945.44, Epsilon: 0.010
# Episode 5937, Total Reward: 7006.24, Epsilon: 0.010
# Episode 5938, Total Reward: 6905.89, Epsilon: 0.010
# Episode 5939, Total Reward: 6980.84, Epsilon: 0.010
# Episode 5940, Total Reward: 6987.85, Epsilon: 0.010
# Episode 5941, Total Reward: 7011.27, Epsilon: 0.010
# Episode 5942, Total Reward: 6993.44, Epsilon: 0.010
# Episode 5943, Total Reward: 6938.34, Epsilon: 0.010
# Episode 5944, Total Reward: 6960.85, Epsilon: 0.010
# Episode 5945, Total Reward: 6970.66, Epsilon: 0.010
# Episode 5946, Total Reward: 7015.46, Epsilon: 0.010
# Episode 5947, Total Reward: 6973.06, Epsilon: 0.010
# Episode 5948, Total Reward: 7003.04, Epsilon: 0.010
# Episode 5949, Total Reward: 6982.80, Epsilon: 0.010
# Episode 5950, Total Reward: 6971.40, Epsilon: 0.010
# Episode 5951, Total Reward: 6992.35, Epsilon: 0.010
# Episode 5952, Total Reward: 6996.37, Epsilon: 0.010
# Episode 5953, Total Reward: 6980.76, Epsilon: 0.010
# Episode 5954, Total Reward: 6981.06, Epsilon: 0.010
# Episode 5955, Total Reward: 6945.40, Epsilon: 0.010
# Episode 5956, Total Reward: 6757.29, Epsilon: 0.010
# Episode 5957, Total Reward: 7029.73, Epsilon: 0.010
# Episode 5958, Total Reward: 7007.55, Epsilon: 0.010
# Episode 5959, Total Reward: 6941.19, Epsilon: 0.010
# Episode 5960, Total Reward: 6957.12, Epsilon: 0.010
# Episode 5961, Total Reward: 6976.14, Epsilon: 0.010
# Episode 5962, Total Reward: 7021.89, Epsilon: 0.010
# Episode 5963, Total Reward: 6999.37, Epsilon: 0.010
# Episode 5964, Total Reward: 6995.65, Epsilon: 0.010
# Episode 5965, Total Reward: 6967.38, Epsilon: 0.010
# Episode 5966, Total Reward: 7021.79, Epsilon: 0.010
# Episode 5967, Total Reward: 6985.97, Epsilon: 0.010
# Episode 5968, Total Reward: 6667.77, Epsilon: 0.010
# Episode 5969, Total Reward: 6277.46, Epsilon: 0.010
# Episode 5970, Total Reward: 6993.04, Epsilon: 0.010
# Episode 5971, Total Reward: 6972.16, Epsilon: 0.010
# Episode 5972, Total Reward: 6979.04, Epsilon: 0.010
# Episode 5973, Total Reward: 7031.18, Epsilon: 0.010
# Episode 5974, Total Reward: 7013.70, Epsilon: 0.010
# Episode 5975, Total Reward: 6998.11, Epsilon: 0.010
# Episode 5976, Total Reward: 6414.81, Epsilon: 0.010
# Episode 5977, Total Reward: 6976.56, Epsilon: 0.010
# Episode 5978, Total Reward: 6973.77, Epsilon: 0.010
# Episode 5979, Total Reward: 6983.86, Epsilon: 0.010
# Episode 5980, Total Reward: 6928.79, Epsilon: 0.010
# Episode 5981, Total Reward: 5779.94, Epsilon: 0.010
# Episode 5982, Total Reward: 6965.67, Epsilon: 0.010
# Episode 5983, Total Reward: 7002.48, Epsilon: 0.010
# Episode 5984, Total Reward: 7027.80, Epsilon: 0.010
# Episode 5985, Total Reward: 6962.17, Epsilon: 0.010
# Episode 5986, Total Reward: 6975.39, Epsilon: 0.010
# Episode 5987, Total Reward: 6980.87, Epsilon: 0.010
# Episode 5988, Total Reward: 7020.09, Epsilon: 0.010
# Episode 5989, Total Reward: 6991.44, Epsilon: 0.010
# Episode 5990, Total Reward: 7009.08, Epsilon: 0.010
# Episode 5991, Total Reward: 6960.26, Epsilon: 0.010
# Episode 5992, Total Reward: 6954.82, Epsilon: 0.010
# Episode 5993, Total Reward: 6952.16, Epsilon: 0.010
# Episode 5994, Total Reward: 7017.20, Epsilon: 0.010
# Episode 5995, Total Reward: 6989.20, Epsilon: 0.010
# Episode 5996, Total Reward: 7007.87, Epsilon: 0.010
# Episode 5997, Total Reward: 7009.01, Epsilon: 0.010
# Episode 5998, Total Reward: 7037.13, Epsilon: 0.010
# Episode 5999, Total Reward: 7007.48, Epsilon: 0.010
# Episode 6000, Total Reward: 7007.22, Epsilon: 0.010

# %% [markdown]
# DQN + KM Matching

# %% [markdown]
# (not the right graph)
# (incorrect model)

# %%
# Final Deep Q-Network + KM Matching for Vehicular Edge Computing

import random
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment

# Constants
m = 10**6
k = 10**3
g = 10**9
W = 10 * m
P_u = 0.1
sigma2 = 10**(-17.4)
I = 1e-10

# RSU and Vehicle Models
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

# Replay Memory
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.idx = 0

    def store(self, state, action, next_state, reward, done):
        data = (state, action, next_state, reward, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(data)
        else:
            self.buffer[self.idx] = data
        self.idx = (self.idx + 1) % self.capacity

    def sample(self, batch_size, device):
        batch = random.sample(self.buffer, batch_size)
        states, actions, next_states, rewards, dones = zip(*batch)
        return (
            torch.tensor(states, dtype=torch.float32).to(device),
            torch.tensor(actions, dtype=torch.int64).to(device),
            torch.tensor(next_states, dtype=torch.float32).to(device),
            torch.tensor(rewards, dtype=torch.float32).to(device),
            torch.tensor(dones, dtype=torch.bool).to(device)
        )

    def __len__(self):
        return len(self.buffer)

# DQN Network
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size, device):
        self.device = device
        self.epsilon = 0.9
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.discount = 0.99
        self.memory = ReplayMemory(10000)
        self.policy_net = DQNNet(state_size, action_size).to(device)
        self.target_net = DQNNet(state_size, action_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=0.0008)

    def learn(self, batch_size):
        if len(self.memory) < batch_size:
            return
        states, actions, next_states, rewards, dones = self.memory.sample(batch_size, self.device)
        q_values = self.policy_net(states).gather(1, actions.view(-1, 1))
        max_next_q = self.target_net(next_states).max(1).values
        targets = rewards + self.discount * max_next_q * (~dones)
        loss = F.mse_loss(q_values.view(-1), targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_target_net(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# Environment
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0), (2400, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

    def rsu_return_delay(self, d_n):
        rate = W * math.log2(1 + (P_u * 1e-7) / (sigma2 + I))
        return d_n / rate

    def step(self, actions):
        rewards = []
        rsu_remaining = self.rsu.resource_capacity

        for i, vid in enumerate(self.vehicle_ids):
            cpu_cycles = random.uniform(0.5, 1.2) * g
            data_size = random.uniform(0.3, 1.0) * m
            task_deadline = 1.2
            x, y, _, _ = self.trajectories[vid][self.current_step]

            action = actions[i]
            if action == 0:
                delay = self.vehicles[vid].compDelay(cpu_cycles)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 0
            else:
                comp = self.rsu.compDelay(cpu_cycles)
                t_ret = self.rsu_return_delay(data_size)
                delay = comp + t_ret
                stable = any(math.hypot(x - rx, y - ry) <= self.rsu.radius for rx, ry in self.rsu_positions)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 5 if stable else -5
                rsu_remaining -= 1
                self.Salloc[i] = 1

            delay_ratio = delay / max(0.0001, task_deadline)
            rtime = 5 * (1 - min(1, delay_ratio))
            reward = 0.4 * rsuc + 0.4 * rtime + 0.2 * roffsuc
            rewards.append(reward)

            self.Soff[i] = action
            self.Ssche[i] = 1 if delay <= task_deadline else 0

        self.Srest = [max(0, rsu_remaining)]
        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_state = self.Soff + self.Ssche + self.Salloc + self.Srest
        return next_state, rewards, done

# KM Matching-based action selection

def get_q_matrix(agent, state, vehicle_ids):
    q_matrix = []
    s = torch.tensor([state], dtype=torch.float32).to(agent.device)
    with torch.no_grad():
        q_values = agent.policy_net(s).cpu().numpy().flatten()
    for _ in vehicle_ids:
        q_matrix.append(q_values)
    return np.array(q_matrix)

def km_match(q_matrix):
    cost_matrix = -q_matrix  # maximize Q-values
    row_ind, col_ind = linear_sum_assignment(cost_matrix)
    return [col_ind[i % len(col_ind)] for i in range(q_matrix.shape[0])]

# Main Training
if __name__ == '__main__':
    data = np.load("test_predictions_full_300.npz")
    predicted = data['predicted']
    vehicle_ids = data['vehicle_ids']

    df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1,1), predicted]),
                      columns=["vehicle_id", "lat", "lon", "vx", "vy"])
    top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
    trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

    vehicles = {vid: Vehicle() for vid in top_15_ids}
    rsu = RSU()
    env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

    state_size = len(env.reset())
    action_size = 4  # 0: local, 1/2/3: RSU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    agent = DQNAgent(state_size, action_size, device)

    episodes = 6000
    reward_log = []

    for ep in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            q_matrix = get_q_matrix(agent, state, top_15_ids)
            actions = km_match(q_matrix)
            next_state, rewards, done = env.step(actions)

            for i, vid in enumerate(top_15_ids):
                action = actions[i]
                reward = rewards[i]
                agent.memory.store(state, action, next_state, reward, done)

            agent.learn(32)
            state = next_state
            total_reward += sum(rewards)

        agent.update_epsilon()
        agent.update_target_net()
        reward_log.append(total_reward)
        print(f"Episode {ep+1}, Total Reward: {total_reward:.2f}, Epsilon: {agent.epsilon:.3f}")

    torch.save(agent.policy_net.state_dict(), "dqn_multi_vehicle.pth")

    plt.plot(range(1, episodes + 1), reward_log)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("DQN + KM Training: Reward vs Episode")
    plt.grid(True)
    plt.savefig("reward_vs_episode_km.png")
    plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 1001, Total Reward: 5896.90, Epsilon: 0.010
# Episode 1002, Total Reward: 5909.35, Epsilon: 0.010
# Episode 1003, Total Reward: 5884.03, Epsilon: 0.010
# Episode 1004, Total Reward: 5902.10, Epsilon: 0.010
# Episode 1005, Total Reward: 5894.03, Epsilon: 0.010
# Episode 1006, Total Reward: 5897.35, Epsilon: 0.010
# Episode 1007, Total Reward: 5893.61, Epsilon: 0.010
# Episode 1008, Total Reward: 5902.36, Epsilon: 0.010
# Episode 1009, Total Reward: 5887.68, Epsilon: 0.010
# Episode 1010, Total Reward: 5888.06, Epsilon: 0.010
# Episode 1011, Total Reward: 5897.71, Epsilon: 0.010
# Episode 1012, Total Reward: 5900.65, Epsilon: 0.010
# Episode 1013, Total Reward: 5896.74, Epsilon: 0.010
# Episode 1014, Total Reward: 5888.40, Epsilon: 0.010
# Episode 1015, Total Reward: 5894.33, Epsilon: 0.010
# Episode 1016, Total Reward: 5895.20, Epsilon: 0.010
# Episode 1017, Total Reward: 5895.04, Epsilon: 0.010
# Episode 1018, Total Reward: 5904.41, Epsilon: 0.010
# Episode 1019, Total Reward: 5905.93, Epsilon: 0.010
# Episode 1020, Total Reward: 5897.80, Epsilon: 0.010
# Episode 1021, Total Reward: 5881.62, Epsilon: 0.010
# Episode 1022, Total Reward: 5898.69, Epsilon: 0.010
# Episode 1023, Total Reward: 5892.18, Epsilon: 0.010
# Episode 1024, Total Reward: 5888.23, Epsilon: 0.010
# Episode 1025, Total Reward: 5886.92, Epsilon: 0.010
# Episode 1026, Total Reward: 5903.28, Epsilon: 0.010
# Episode 1027, Total Reward: 5890.47, Epsilon: 0.010
# Episode 1028, Total Reward: 5894.98, Epsilon: 0.010
# Episode 1029, Total Reward: 5896.37, Epsilon: 0.010
# Episode 1030, Total Reward: 5895.13, Epsilon: 0.010
# Episode 1031, Total Reward: 5894.63, Epsilon: 0.010
# Episode 1032, Total Reward: 5906.37, Epsilon: 0.010
# Episode 1033, Total Reward: 5884.32, Epsilon: 0.010
# Episode 1034, Total Reward: 5897.04, Epsilon: 0.010
# Episode 1035, Total Reward: 5896.42, Epsilon: 0.010
# Episode 1036, Total Reward: 5891.19, Epsilon: 0.010
# Episode 1037, Total Reward: 5891.06, Epsilon: 0.010
# Episode 1038, Total Reward: 5889.83, Epsilon: 0.010
# Episode 1039, Total Reward: 5894.28, Epsilon: 0.010
# Episode 1040, Total Reward: 5881.60, Epsilon: 0.010
# Episode 1041, Total Reward: 5889.14, Epsilon: 0.010
# Episode 1042, Total Reward: 5887.50, Epsilon: 0.010
# Episode 1043, Total Reward: 5891.83, Epsilon: 0.010
# Episode 1044, Total Reward: 5902.12, Epsilon: 0.010
# Episode 1045, Total Reward: 5891.43, Epsilon: 0.010
# Episode 1046, Total Reward: 5884.58, Epsilon: 0.010
# Episode 1047, Total Reward: 5894.44, Epsilon: 0.010
# Episode 1048, Total Reward: 5892.82, Epsilon: 0.010
# Episode 1049, Total Reward: 5896.03, Epsilon: 0.010
# Episode 1050, Total Reward: 5889.93, Epsilon: 0.010
# Episode 1051, Total Reward: 5894.91, Epsilon: 0.010
# Episode 1052, Total Reward: 5889.63, Epsilon: 0.010
# Episode 1053, Total Reward: 5892.63, Epsilon: 0.010
# Episode 1054, Total Reward: 5895.96, Epsilon: 0.010
# Episode 1055, Total Reward: 5901.46, Epsilon: 0.010
# Episode 1056, Total Reward: 5885.47, Epsilon: 0.010
# Episode 1057, Total Reward: 5887.10, Epsilon: 0.010
# Episode 1058, Total Reward: 5905.76, Epsilon: 0.010
# Episode 1059, Total Reward: 5897.59, Epsilon: 0.010
# Episode 1060, Total Reward: 5891.85, Epsilon: 0.010
# Episode 1061, Total Reward: 5894.57, Epsilon: 0.010
# Episode 1062, Total Reward: 5897.00, Epsilon: 0.010
# Episode 1063, Total Reward: 5893.17, Epsilon: 0.010
# Episode 1064, Total Reward: 5889.01, Epsilon: 0.010
# Episode 1065, Total Reward: 5896.47, Epsilon: 0.010
# Episode 1066, Total Reward: 5893.84, Epsilon: 0.010
# Episode 1067, Total Reward: 5893.32, Epsilon: 0.010
# Episode 1068, Total Reward: 5893.74, Epsilon: 0.010
# Episode 1069, Total Reward: 5897.90, Epsilon: 0.010
# Episode 1070, Total Reward: 5893.48, Epsilon: 0.010
# Episode 1071, Total Reward: 5900.61, Epsilon: 0.010
# Episode 1072, Total Reward: 5896.14, Epsilon: 0.010
# Episode 1073, Total Reward: 5903.49, Epsilon: 0.010
# Episode 1074, Total Reward: 5898.98, Epsilon: 0.010
# Episode 1075, Total Reward: 5899.58, Epsilon: 0.010
# Episode 1076, Total Reward: 5899.91, Epsilon: 0.010
# Episode 1077, Total Reward: 5897.32, Epsilon: 0.010
# Episode 1078, Total Reward: 5883.80, Epsilon: 0.010
# Episode 1079, Total Reward: 5894.00, Epsilon: 0.010
# Episode 1080, Total Reward: 5885.36, Epsilon: 0.010
# Episode 1081, Total Reward: 5890.61, Epsilon: 0.010
# Episode 1082, Total Reward: 5903.93, Epsilon: 0.010
# Episode 1083, Total Reward: 5886.39, Epsilon: 0.010
# Episode 1084, Total Reward: 5894.59, Epsilon: 0.010
# Episode 1085, Total Reward: 5889.62, Epsilon: 0.010
# Episode 1086, Total Reward: 5887.87, Epsilon: 0.010
# Episode 1087, Total Reward: 5895.12, Epsilon: 0.010
# Episode 1088, Total Reward: 5903.75, Epsilon: 0.010
# Episode 1089, Total Reward: 5885.31, Epsilon: 0.010
# Episode 1090, Total Reward: 5899.13, Epsilon: 0.010
# Episode 1091, Total Reward: 5888.47, Epsilon: 0.010
# Episode 1092, Total Reward: 5898.30, Epsilon: 0.010
# Episode 1093, Total Reward: 5901.85, Epsilon: 0.010
# Episode 1094, Total Reward: 5894.58, Epsilon: 0.010
# Episode 1095, Total Reward: 5893.07, Epsilon: 0.010
# Episode 1096, Total Reward: 5895.07, Epsilon: 0.010
# Episode 1097, Total Reward: 5890.23, Epsilon: 0.010
# Episode 1098, Total Reward: 5885.32, Epsilon: 0.010
# Episode 1099, Total Reward: 5891.60, Epsilon: 0.010
# Episode 1100, Total Reward: 5891.76, Epsilon: 0.010
# Episode 1101, Total Reward: 5897.59, Epsilon: 0.010
# Episode 1102, Total Reward: 5895.98, Epsilon: 0.010
# Episode 1103, Total Reward: 5894.63, Epsilon: 0.010
# Episode 1104, Total Reward: 5897.80, Epsilon: 0.010
# Episode 1105, Total Reward: 5903.09, Epsilon: 0.010
# Episode 1106, Total Reward: 5891.11, Epsilon: 0.010
# Episode 1107, Total Reward: 5887.84, Epsilon: 0.010
# Episode 1108, Total Reward: 5893.32, Epsilon: 0.010
# Episode 1109, Total Reward: 5892.41, Epsilon: 0.010
# Episode 1110, Total Reward: 5900.02, Epsilon: 0.010
# Episode 1111, Total Reward: 5899.31, Epsilon: 0.010
# Episode 1112, Total Reward: 5891.12, Epsilon: 0.010
# Episode 1113, Total Reward: 5895.75, Epsilon: 0.010
# Episode 1114, Total Reward: 5891.05, Epsilon: 0.010
# Episode 1115, Total Reward: 5889.95, Epsilon: 0.010
# Episode 1116, Total Reward: 5897.93, Epsilon: 0.010
# Episode 1117, Total Reward: 5902.91, Epsilon: 0.010
# Episode 1118, Total Reward: 5892.51, Epsilon: 0.010
# Episode 1119, Total Reward: 5893.80, Epsilon: 0.010
# Episode 1120, Total Reward: 5891.25, Epsilon: 0.010
# Episode 1121, Total Reward: 5887.36, Epsilon: 0.010
# Episode 1122, Total Reward: 5896.26, Epsilon: 0.010
# Episode 1123, Total Reward: 5890.54, Epsilon: 0.010
# Episode 1124, Total Reward: 5899.77, Epsilon: 0.010
# Episode 1125, Total Reward: 5894.67, Epsilon: 0.010
# Episode 1126, Total Reward: 5891.25, Epsilon: 0.010
# Episode 1127, Total Reward: 5890.62, Epsilon: 0.010
# Episode 1128, Total Reward: 5888.29, Epsilon: 0.010
# Episode 1129, Total Reward: 5898.32, Epsilon: 0.010
# Episode 1130, Total Reward: 5896.54, Epsilon: 0.010
# Episode 1131, Total Reward: 5891.79, Epsilon: 0.010
# Episode 1132, Total Reward: 5887.89, Epsilon: 0.010
# Episode 1133, Total Reward: 5893.76, Epsilon: 0.010
# Episode 1134, Total Reward: 5892.74, Epsilon: 0.010
# Episode 1135, Total Reward: 5892.09, Epsilon: 0.010
# Episode 1136, Total Reward: 5884.78, Epsilon: 0.010
# Episode 1137, Total Reward: 5884.82, Epsilon: 0.010
# Episode 1138, Total Reward: 5893.93, Epsilon: 0.010
# Episode 1139, Total Reward: 5898.23, Epsilon: 0.010
# Episode 1140, Total Reward: 5881.46, Epsilon: 0.010
# Episode 1141, Total Reward: 5901.69, Epsilon: 0.010
# Episode 1142, Total Reward: 5898.60, Epsilon: 0.010
# Episode 1143, Total Reward: 5894.69, Epsilon: 0.010
# Episode 1144, Total Reward: 5891.27, Epsilon: 0.010
# Episode 1145, Total Reward: 5886.24, Epsilon: 0.010
# Episode 1146, Total Reward: 5890.39, Epsilon: 0.010
# Episode 1147, Total Reward: 5896.67, Epsilon: 0.010
# Episode 1148, Total Reward: 5893.67, Epsilon: 0.010
# Episode 1149, Total Reward: 5893.68, Epsilon: 0.010
# Episode 1150, Total Reward: 5900.11, Epsilon: 0.010
# Episode 1151, Total Reward: 5879.82, Epsilon: 0.010
# Episode 1152, Total Reward: 5894.52, Epsilon: 0.010
# Episode 1153, Total Reward: 5895.93, Epsilon: 0.010
# Episode 1154, Total Reward: 5897.78, Epsilon: 0.010
# Episode 1155, Total Reward: 5887.80, Epsilon: 0.010
# Episode 1156, Total Reward: 5905.05, Epsilon: 0.010
# Episode 1157, Total Reward: 5889.17, Epsilon: 0.010
# Episode 1158, Total Reward: 5902.16, Epsilon: 0.010
# Episode 1159, Total Reward: 5899.28, Epsilon: 0.010
# Episode 1160, Total Reward: 5896.92, Epsilon: 0.010
# Episode 1161, Total Reward: 5892.96, Epsilon: 0.010
# Episode 1162, Total Reward: 5896.74, Epsilon: 0.010
# Episode 1163, Total Reward: 5897.36, Epsilon: 0.010
# Episode 1164, Total Reward: 5902.53, Epsilon: 0.010
# Episode 1165, Total Reward: 5902.77, Epsilon: 0.010
# Episode 1166, Total Reward: 5893.01, Epsilon: 0.010
# Episode 1167, Total Reward: 5892.65, Epsilon: 0.010
# Episode 1168, Total Reward: 5904.83, Epsilon: 0.010
# Episode 1169, Total Reward: 5892.50, Epsilon: 0.010
# Episode 1170, Total Reward: 5888.86, Epsilon: 0.010
# Episode 1171, Total Reward: 5887.22, Epsilon: 0.010
# Episode 1172, Total Reward: 5900.86, Epsilon: 0.010
# Episode 1173, Total Reward: 5900.33, Epsilon: 0.010
# Episode 1174, Total Reward: 5886.85, Epsilon: 0.010
# Episode 1175, Total Reward: 5891.81, Epsilon: 0.010
# Episode 1176, Total Reward: 5896.14, Epsilon: 0.010
# Episode 1177, Total Reward: 5893.38, Epsilon: 0.010
# Episode 1178, Total Reward: 5896.33, Epsilon: 0.010
# Episode 1179, Total Reward: 5894.50, Epsilon: 0.010
# Episode 1180, Total Reward: 5889.91, Epsilon: 0.010
# Episode 1181, Total Reward: 5893.41, Epsilon: 0.010
# Episode 1182, Total Reward: 5898.54, Epsilon: 0.010
# Episode 1183, Total Reward: 5892.86, Epsilon: 0.010
# Episode 1184, Total Reward: 5888.35, Epsilon: 0.010
# Episode 1185, Total Reward: 5884.47, Epsilon: 0.010
# Episode 1186, Total Reward: 5898.80, Epsilon: 0.010
# Episode 1187, Total Reward: 5897.33, Epsilon: 0.010
# Episode 1188, Total Reward: 5895.34, Epsilon: 0.010
# Episode 1189, Total Reward: 5893.66, Epsilon: 0.010
# Episode 1190, Total Reward: 5899.94, Epsilon: 0.010
# Episode 1191, Total Reward: 5892.71, Epsilon: 0.010
# Episode 1192, Total Reward: 5901.83, Epsilon: 0.010
# Episode 1193, Total Reward: 5888.33, Epsilon: 0.010
# Episode 1194, Total Reward: 5899.40, Epsilon: 0.010
# Episode 1195, Total Reward: 5894.97, Epsilon: 0.010
# Episode 1196, Total Reward: 5892.82, Epsilon: 0.010
# Episode 1197, Total Reward: 5893.34, Epsilon: 0.010
# Episode 1198, Total Reward: 5889.06, Epsilon: 0.010
# Episode 1199, Total Reward: 5900.49, Epsilon: 0.010
# Episode 1200, Total Reward: 5902.21, Epsilon: 0.010
# Episode 1201, Total Reward: 5892.63, Epsilon: 0.010
# Episode 1202, Total Reward: 5888.16, Epsilon: 0.010
# Episode 1203, Total Reward: 5897.89, Epsilon: 0.010
# Episode 1204, Total Reward: 5896.96, Epsilon: 0.010
# Episode 1205, Total Reward: 5898.14, Epsilon: 0.010
# Episode 1206, Total Reward: 5900.39, Epsilon: 0.010
# Episode 1207, Total Reward: 5880.65, Epsilon: 0.010
# Episode 1208, Total Reward: 5892.17, Epsilon: 0.010
# Episode 1209, Total Reward: 5895.53, Epsilon: 0.010
# Episode 1210, Total Reward: 5885.37, Epsilon: 0.010
# Episode 1211, Total Reward: 5893.90, Epsilon: 0.010
# Episode 1212, Total Reward: 5883.32, Epsilon: 0.010
# Episode 1213, Total Reward: 5895.20, Epsilon: 0.010
# Episode 1214, Total Reward: 5903.40, Epsilon: 0.010
# Episode 1215, Total Reward: 5888.28, Epsilon: 0.010
# Episode 1216, Total Reward: 5890.59, Epsilon: 0.010
# Episode 1217, Total Reward: 5902.58, Epsilon: 0.010
# Episode 1218, Total Reward: 5895.06, Epsilon: 0.010
# Episode 1219, Total Reward: 5897.61, Epsilon: 0.010
# Episode 1220, Total Reward: 5886.33, Epsilon: 0.010
# Episode 1221, Total Reward: 5897.19, Epsilon: 0.010
# Episode 1222, Total Reward: 5892.12, Epsilon: 0.010
# Episode 1223, Total Reward: 5893.29, Epsilon: 0.010
# Episode 1224, Total Reward: 5897.45, Epsilon: 0.010
# Episode 1225, Total Reward: 5895.52, Epsilon: 0.010
# Episode 1226, Total Reward: 5892.22, Epsilon: 0.010
# Episode 1227, Total Reward: 5896.46, Epsilon: 0.010
# Episode 1228, Total Reward: 5887.98, Epsilon: 0.010
# Episode 1229, Total Reward: 5891.26, Epsilon: 0.010
# Episode 1230, Total Reward: 5894.00, Epsilon: 0.010
# Episode 1231, Total Reward: 5896.02, Epsilon: 0.010
# Episode 1232, Total Reward: 5899.14, Epsilon: 0.010
# Episode 1233, Total Reward: 5897.18, Epsilon: 0.010
# Episode 1234, Total Reward: 5890.86, Epsilon: 0.010
# Episode 1235, Total Reward: 5889.78, Epsilon: 0.010
# Episode 1236, Total Reward: 5896.01, Epsilon: 0.010
# Episode 1237, Total Reward: 5893.78, Epsilon: 0.010
# Episode 1238, Total Reward: 5897.19, Epsilon: 0.010
# Episode 1239, Total Reward: 5896.41, Epsilon: 0.010
# Episode 1240, Total Reward: 5897.01, Epsilon: 0.010
# Episode 1241, Total Reward: 5900.28, Epsilon: 0.010
# Episode 1242, Total Reward: 5892.36, Epsilon: 0.010
# Episode 1243, Total Reward: 5880.73, Epsilon: 0.010
# Episode 1244, Total Reward: 5890.59, Epsilon: 0.010
# Episode 1245, Total Reward: 5889.61, Epsilon: 0.010
# Episode 1246, Total Reward: 5883.40, Epsilon: 0.010
# Episode 1247, Total Reward: 5880.96, Epsilon: 0.010
# Episode 1248, Total Reward: 5894.10, Epsilon: 0.010
# Episode 1249, Total Reward: 5889.99, Epsilon: 0.010
# Episode 1250, Total Reward: 5895.84, Epsilon: 0.010
# Episode 1251, Total Reward: 5904.50, Epsilon: 0.010
# Episode 1252, Total Reward: 5891.05, Epsilon: 0.010
# Episode 1253, Total Reward: 5900.47, Epsilon: 0.010
# Episode 1254, Total Reward: 5899.70, Epsilon: 0.010
# Episode 1255, Total Reward: 5890.71, Epsilon: 0.010
# Episode 1256, Total Reward: 5897.81, Epsilon: 0.010
# Episode 1257, Total Reward: 5896.67, Epsilon: 0.010
# Episode 1258, Total Reward: 5891.64, Epsilon: 0.010
# Episode 1259, Total Reward: 5893.01, Epsilon: 0.010
# Episode 1260, Total Reward: 5884.49, Epsilon: 0.010
# Episode 1261, Total Reward: 5899.32, Epsilon: 0.010
# Episode 1262, Total Reward: 5897.40, Epsilon: 0.010
# Episode 1263, Total Reward: 5901.63, Epsilon: 0.010
# Episode 1264, Total Reward: 5896.08, Epsilon: 0.010
# Episode 1265, Total Reward: 5897.83, Epsilon: 0.010
# Episode 1266, Total Reward: 5898.34, Epsilon: 0.010
# Episode 1267, Total Reward: 5900.60, Epsilon: 0.010
# Episode 1268, Total Reward: 5897.78, Epsilon: 0.010
# Episode 1269, Total Reward: 5884.85, Epsilon: 0.010
# Episode 1270, Total Reward: 5890.31, Epsilon: 0.010
# Episode 1271, Total Reward: 5903.04, Epsilon: 0.010
# Episode 1272, Total Reward: 5882.09, Epsilon: 0.010
# Episode 1273, Total Reward: 5900.05, Epsilon: 0.010
# Episode 1274, Total Reward: 5898.36, Epsilon: 0.010
# Episode 1275, Total Reward: 5897.84, Epsilon: 0.010
# Episode 1276, Total Reward: 5897.53, Epsilon: 0.010
# Episode 1277, Total Reward: 5902.31, Epsilon: 0.010
# Episode 1278, Total Reward: 5884.91, Epsilon: 0.010
# Episode 1279, Total Reward: 5882.97, Epsilon: 0.010
# Episode 1280, Total Reward: 5891.60, Epsilon: 0.010
# Episode 1281, Total Reward: 5887.45, Epsilon: 0.010
# Episode 1282, Total Reward: 5893.54, Epsilon: 0.010
# Episode 1283, Total Reward: 5894.37, Epsilon: 0.010
# Episode 1284, Total Reward: 5900.03, Epsilon: 0.010
# Episode 1285, Total Reward: 5888.85, Epsilon: 0.010
# Episode 1286, Total Reward: 5897.07, Epsilon: 0.010
# Episode 1287, Total Reward: 5895.55, Epsilon: 0.010
# Episode 1288, Total Reward: 5899.80, Epsilon: 0.010
# Episode 1289, Total Reward: 5893.30, Epsilon: 0.010
# Episode 1290, Total Reward: 5887.08, Epsilon: 0.010
# Episode 1291, Total Reward: 5894.28, Epsilon: 0.010
# Episode 1292, Total Reward: 5913.37, Epsilon: 0.010
# Episode 1293, Total Reward: 5894.13, Epsilon: 0.010
# Episode 1294, Total Reward: 5883.54, Epsilon: 0.010
# Episode 1295, Total Reward: 5889.76, Epsilon: 0.010
# Episode 1296, Total Reward: 5879.75, Epsilon: 0.010
# Episode 1297, Total Reward: 5902.72, Epsilon: 0.010
# Episode 1298, Total Reward: 5894.15, Epsilon: 0.010
# Episode 1299, Total Reward: 5892.43, Epsilon: 0.010
# Episode 1300, Total Reward: 5897.18, Epsilon: 0.010
# Episode 1301, Total Reward: 5894.90, Epsilon: 0.010
# Episode 1302, Total Reward: 5898.60, Epsilon: 0.010
# Episode 1303, Total Reward: 5885.19, Epsilon: 0.010
# Episode 1304, Total Reward: 5890.51, Epsilon: 0.010
# Episode 1305, Total Reward: 5890.84, Epsilon: 0.010
# Episode 1306, Total Reward: 5891.45, Epsilon: 0.010
# Episode 1307, Total Reward: 5885.81, Epsilon: 0.010
# Episode 1308, Total Reward: 5894.31, Epsilon: 0.010
# Episode 1309, Total Reward: 5899.83, Epsilon: 0.010
# Episode 1310, Total Reward: 5905.23, Epsilon: 0.010
# Episode 1311, Total Reward: 5902.57, Epsilon: 0.010
# Episode 1312, Total Reward: 5897.66, Epsilon: 0.010
# Episode 1313, Total Reward: 5895.37, Epsilon: 0.010
# Episode 1314, Total Reward: 5891.92, Epsilon: 0.010
# Episode 1315, Total Reward: 5883.45, Epsilon: 0.010
# Episode 1316, Total Reward: 5893.29, Epsilon: 0.010
# Episode 1317, Total Reward: 5890.60, Epsilon: 0.010
# Episode 1318, Total Reward: 5891.44, Epsilon: 0.010
# Episode 1319, Total Reward: 5887.15, Epsilon: 0.010
# Episode 1320, Total Reward: 5894.88, Epsilon: 0.010
# Episode 1321, Total Reward: 5897.03, Epsilon: 0.010
# Episode 1322, Total Reward: 5901.69, Epsilon: 0.010
# Episode 1323, Total Reward: 5891.13, Epsilon: 0.010
# Episode 1324, Total Reward: 5897.88, Epsilon: 0.010
# Episode 1325, Total Reward: 5893.15, Epsilon: 0.010
# Episode 1326, Total Reward: 5890.82, Epsilon: 0.010
# Episode 1327, Total Reward: 5892.62, Epsilon: 0.010
# Episode 1328, Total Reward: 5890.27, Epsilon: 0.010
# Episode 1329, Total Reward: 5899.05, Epsilon: 0.010
# Episode 1330, Total Reward: 5895.86, Epsilon: 0.010
# Episode 1331, Total Reward: 5879.32, Epsilon: 0.010
# Episode 1332, Total Reward: 5890.77, Epsilon: 0.010
# Episode 1333, Total Reward: 5893.64, Epsilon: 0.010
# Episode 1334, Total Reward: 5894.06, Epsilon: 0.010
# Episode 1335, Total Reward: 5883.80, Epsilon: 0.010
# Episode 1336, Total Reward: 5900.68, Epsilon: 0.010
# Episode 1337, Total Reward: 5896.37, Epsilon: 0.010
# Episode 1338, Total Reward: 5894.46, Epsilon: 0.010
# Episode 1339, Total Reward: 5896.78, Epsilon: 0.010
# Episode 1340, Total Reward: 5896.91, Epsilon: 0.010
# Episode 1341, Total Reward: 5893.38, Epsilon: 0.010
# Episode 1342, Total Reward: 5894.22, Epsilon: 0.010
# Episode 1343, Total Reward: 5903.88, Epsilon: 0.010
# Episode 1344, Total Reward: 5900.20, Epsilon: 0.010
# Episode 1345, Total Reward: 5892.08, Epsilon: 0.010
# Episode 1346, Total Reward: 5884.28, Epsilon: 0.010
# Episode 1347, Total Reward: 5887.80, Epsilon: 0.010
# Episode 1348, Total Reward: 5899.11, Epsilon: 0.010
# Episode 1349, Total Reward: 5886.66, Epsilon: 0.010
# Episode 1350, Total Reward: 5887.14, Epsilon: 0.010
# Episode 1351, Total Reward: 5894.38, Epsilon: 0.010
# Episode 1352, Total Reward: 5889.94, Epsilon: 0.010
# Episode 1353, Total Reward: 5893.15, Epsilon: 0.010
# Episode 1354, Total Reward: 5889.04, Epsilon: 0.010
# Episode 1355, Total Reward: 5886.18, Epsilon: 0.010
# Episode 1356, Total Reward: 5890.64, Epsilon: 0.010
# Episode 1357, Total Reward: 5899.41, Epsilon: 0.010
# Episode 1358, Total Reward: 5891.94, Epsilon: 0.010
# Episode 1359, Total Reward: 5893.91, Epsilon: 0.010
# Episode 1360, Total Reward: 5900.62, Epsilon: 0.010
# Episode 1361, Total Reward: 5897.35, Epsilon: 0.010
# Episode 1362, Total Reward: 5899.08, Epsilon: 0.010
# Episode 1363, Total Reward: 5888.89, Epsilon: 0.010
# Episode 1364, Total Reward: 5886.65, Epsilon: 0.010
# Episode 1365, Total Reward: 5901.26, Epsilon: 0.010
# Episode 1366, Total Reward: 5890.41, Epsilon: 0.010
# Episode 1367, Total Reward: 5894.59, Epsilon: 0.010
# Episode 1368, Total Reward: 5898.64, Epsilon: 0.010
# Episode 1369, Total Reward: 5894.82, Epsilon: 0.010
# Episode 1370, Total Reward: 5893.52, Epsilon: 0.010
# Episode 1371, Total Reward: 5881.51, Epsilon: 0.010
# Episode 1372, Total Reward: 5903.61, Epsilon: 0.010
# Episode 1373, Total Reward: 5886.52, Epsilon: 0.010
# Episode 1374, Total Reward: 5899.17, Epsilon: 0.010
# Episode 1375, Total Reward: 5889.42, Epsilon: 0.010
# Episode 1376, Total Reward: 5887.31, Epsilon: 0.010
# Episode 1377, Total Reward: 5895.89, Epsilon: 0.010
# Episode 1378, Total Reward: 5902.54, Epsilon: 0.010
# Episode 1379, Total Reward: 5896.28, Epsilon: 0.010
# Episode 1380, Total Reward: 5894.38, Epsilon: 0.010
# Episode 1381, Total Reward: 5896.85, Epsilon: 0.010
# Episode 1382, Total Reward: 5889.89, Epsilon: 0.010
# Episode 1383, Total Reward: 5892.38, Epsilon: 0.010
# Episode 1384, Total Reward: 5904.25, Epsilon: 0.010
# Episode 1385, Total Reward: 5891.53, Epsilon: 0.010
# Episode 1386, Total Reward: 5895.43, Epsilon: 0.010
# Episode 1387, Total Reward: 5889.55, Epsilon: 0.010
# Episode 1388, Total Reward: 5891.66, Epsilon: 0.010
# Episode 1389, Total Reward: 5898.69, Epsilon: 0.010
# Episode 1390, Total Reward: 5900.07, Epsilon: 0.010
# Episode 1391, Total Reward: 5889.21, Epsilon: 0.010
# Episode 1392, Total Reward: 5899.65, Epsilon: 0.010
# Episode 1393, Total Reward: 5900.27, Epsilon: 0.010
# Episode 1394, Total Reward: 5889.14, Epsilon: 0.010
# Episode 1395, Total Reward: 5897.08, Epsilon: 0.010
# Episode 1396, Total Reward: 5893.90, Epsilon: 0.010
# Episode 1397, Total Reward: 5896.54, Epsilon: 0.010
# Episode 1398, Total Reward: 5891.68, Epsilon: 0.010
# Episode 1399, Total Reward: 5893.32, Epsilon: 0.010
# Episode 1400, Total Reward: 5891.63, Epsilon: 0.010
# Episode 1401, Total Reward: 5891.98, Epsilon: 0.010
# Episode 1402, Total Reward: 5892.66, Epsilon: 0.010
# Episode 1403, Total Reward: 5883.57, Epsilon: 0.010
# Episode 1404, Total Reward: 5901.67, Epsilon: 0.010
# Episode 1405, Total Reward: 5897.90, Epsilon: 0.010
# Episode 1406, Total Reward: 5901.69, Epsilon: 0.010
# Episode 1407, Total Reward: 5895.53, Epsilon: 0.010
# Episode 1408, Total Reward: 5883.49, Epsilon: 0.010
# Episode 1409, Total Reward: 5887.27, Epsilon: 0.010
# Episode 1410, Total Reward: 5898.34, Epsilon: 0.010
# Episode 1411, Total Reward: 5900.54, Epsilon: 0.010
# Episode 1412, Total Reward: 5894.78, Epsilon: 0.010
# Episode 1413, Total Reward: 5902.64, Epsilon: 0.010
# Episode 1414, Total Reward: 5889.04, Epsilon: 0.010
# Episode 1415, Total Reward: 5893.83, Epsilon: 0.010
# Episode 1416, Total Reward: 5892.00, Epsilon: 0.010
# Episode 1417, Total Reward: 5887.90, Epsilon: 0.010
# Episode 1418, Total Reward: 5902.41, Epsilon: 0.010
# Episode 1419, Total Reward: 5887.70, Epsilon: 0.010
# Episode 1420, Total Reward: 5889.19, Epsilon: 0.010
# Episode 1421, Total Reward: 5883.48, Epsilon: 0.010
# Episode 1422, Total Reward: 5896.93, Epsilon: 0.010
# Episode 1423, Total Reward: 5889.10, Epsilon: 0.010
# Episode 1424, Total Reward: 5893.20, Epsilon: 0.010
# Episode 1425, Total Reward: 5891.50, Epsilon: 0.010
# Episode 1426, Total Reward: 5893.63, Epsilon: 0.010
# Episode 1427, Total Reward: 5898.59, Epsilon: 0.010
# Episode 1428, Total Reward: 5898.02, Epsilon: 0.010
# Episode 1429, Total Reward: 5899.80, Epsilon: 0.010
# Episode 1430, Total Reward: 5893.45, Epsilon: 0.010
# Episode 1431, Total Reward: 5896.72, Epsilon: 0.010
# Episode 1432, Total Reward: 5891.23, Epsilon: 0.010
# Episode 1433, Total Reward: 5893.37, Epsilon: 0.010
# Episode 1434, Total Reward: 5894.56, Epsilon: 0.010
# Episode 1435, Total Reward: 5902.95, Epsilon: 0.010
# Episode 1436, Total Reward: 5889.51, Epsilon: 0.010
# Episode 1437, Total Reward: 5897.24, Epsilon: 0.010
# Episode 1438, Total Reward: 5892.20, Epsilon: 0.010
# Episode 1439, Total Reward: 5901.29, Epsilon: 0.010
# Episode 1440, Total Reward: 5887.44, Epsilon: 0.010
# Episode 1441, Total Reward: 5906.26, Epsilon: 0.010
# Episode 1442, Total Reward: 5894.03, Epsilon: 0.010
# Episode 1443, Total Reward: 5889.30, Epsilon: 0.010
# Episode 1444, Total Reward: 5904.61, Epsilon: 0.010
# Episode 1445, Total Reward: 5898.08, Epsilon: 0.010
# Episode 1446, Total Reward: 5889.12, Epsilon: 0.010
# Episode 1447, Total Reward: 5900.20, Epsilon: 0.010
# Episode 1448, Total Reward: 5899.60, Epsilon: 0.010
# Episode 1449, Total Reward: 5903.51, Epsilon: 0.010
# Episode 1450, Total Reward: 5896.20, Epsilon: 0.010
# Episode 1451, Total Reward: 5897.74, Epsilon: 0.010
# Episode 1452, Total Reward: 5883.99, Epsilon: 0.010
# Episode 1453, Total Reward: 5897.47, Epsilon: 0.010
# Episode 1454, Total Reward: 5903.51, Epsilon: 0.010
# Episode 1455, Total Reward: 5888.46, Epsilon: 0.010
# Episode 1456, Total Reward: 5889.66, Epsilon: 0.010
# Episode 1457, Total Reward: 5892.32, Epsilon: 0.010
# Episode 1458, Total Reward: 5886.50, Epsilon: 0.010
# Episode 1459, Total Reward: 5902.98, Epsilon: 0.010
# Episode 1460, Total Reward: 5893.47, Epsilon: 0.010
# Episode 1461, Total Reward: 5887.03, Epsilon: 0.010
# Episode 1462, Total Reward: 5889.83, Epsilon: 0.010
# Episode 1463, Total Reward: 5895.70, Epsilon: 0.010
# Episode 1464, Total Reward: 5896.00, Epsilon: 0.010
# Episode 1465, Total Reward: 5891.84, Epsilon: 0.010
# Episode 1466, Total Reward: 5890.44, Epsilon: 0.010
# Episode 1467, Total Reward: 5889.66, Epsilon: 0.010
# Episode 1468, Total Reward: 5899.10, Epsilon: 0.010
# Episode 1469, Total Reward: 5880.83, Epsilon: 0.010
# Episode 1470, Total Reward: 5886.53, Epsilon: 0.010
# Episode 1471, Total Reward: 5893.14, Epsilon: 0.010
# Episode 1472, Total Reward: 5897.99, Epsilon: 0.010
# Episode 1473, Total Reward: 5892.39, Epsilon: 0.010
# Episode 1474, Total Reward: 5883.54, Epsilon: 0.010
# Episode 1475, Total Reward: 5897.25, Epsilon: 0.010
# Episode 1476, Total Reward: 5896.07, Epsilon: 0.010
# Episode 1477, Total Reward: 5893.60, Epsilon: 0.010
# Episode 1478, Total Reward: 5896.79, Epsilon: 0.010
# Episode 1479, Total Reward: 5884.85, Epsilon: 0.010
# Episode 1480, Total Reward: 5893.29, Epsilon: 0.010
# Episode 1481, Total Reward: 5901.22, Epsilon: 0.010
# Episode 1482, Total Reward: 5888.09, Epsilon: 0.010
# Episode 1483, Total Reward: 5895.43, Epsilon: 0.010
# Episode 1484, Total Reward: 5894.40, Epsilon: 0.010
# Episode 1485, Total Reward: 5892.35, Epsilon: 0.010
# Episode 1486, Total Reward: 5901.00, Epsilon: 0.010
# Episode 1487, Total Reward: 5892.60, Epsilon: 0.010
# Episode 1488, Total Reward: 5895.10, Epsilon: 0.010
# Episode 1489, Total Reward: 5897.62, Epsilon: 0.010
# Episode 1490, Total Reward: 5896.99, Epsilon: 0.010
# Episode 1491, Total Reward: 5904.81, Epsilon: 0.010
# Episode 1492, Total Reward: 5900.05, Epsilon: 0.010
# Episode 1493, Total Reward: 5889.53, Epsilon: 0.010
# Episode 1494, Total Reward: 5897.06, Epsilon: 0.010
# Episode 1495, Total Reward: 5885.55, Epsilon: 0.010
# Episode 1496, Total Reward: 5894.61, Epsilon: 0.010
# Episode 1497, Total Reward: 5895.54, Epsilon: 0.010
# Episode 1498, Total Reward: 5904.62, Epsilon: 0.010
# Episode 1499, Total Reward: 5899.10, Epsilon: 0.010
# Episode 1500, Total Reward: 5890.67, Epsilon: 0.010
# Episode 1501, Total Reward: 5890.17, Epsilon: 0.010
# Episode 1502, Total Reward: 5891.94, Epsilon: 0.010
# Episode 1503, Total Reward: 5893.09, Epsilon: 0.010
# Episode 1504, Total Reward: 5898.69, Epsilon: 0.010
# Episode 1505, Total Reward: 5890.49, Epsilon: 0.010
# Episode 1506, Total Reward: 5874.33, Epsilon: 0.010
# Episode 1507, Total Reward: 5893.95, Epsilon: 0.010
# Episode 1508, Total Reward: 5900.85, Epsilon: 0.010
# Episode 1509, Total Reward: 5895.67, Epsilon: 0.010
# Episode 1510, Total Reward: 5896.11, Epsilon: 0.010
# Episode 1511, Total Reward: 5891.89, Epsilon: 0.010
# Episode 1512, Total Reward: 5885.94, Epsilon: 0.010
# Episode 1513, Total Reward: 5886.34, Epsilon: 0.010
# Episode 1514, Total Reward: 5890.25, Epsilon: 0.010
# Episode 1515, Total Reward: 5891.93, Epsilon: 0.010
# Episode 1516, Total Reward: 5890.68, Epsilon: 0.010
# Episode 1517, Total Reward: 5900.66, Epsilon: 0.010
# Episode 1518, Total Reward: 5892.89, Epsilon: 0.010
# Episode 1519, Total Reward: 5892.93, Epsilon: 0.010
# Episode 1520, Total Reward: 5895.65, Epsilon: 0.010
# Episode 1521, Total Reward: 5890.17, Epsilon: 0.010
# Episode 1522, Total Reward: 5890.68, Epsilon: 0.010
# Episode 1523, Total Reward: 5894.33, Epsilon: 0.010
# Episode 1524, Total Reward: 5894.39, Epsilon: 0.010
# Episode 1525, Total Reward: 5886.64, Epsilon: 0.010
# Episode 1526, Total Reward: 5888.18, Epsilon: 0.010
# Episode 1527, Total Reward: 5901.04, Epsilon: 0.010
# Episode 1528, Total Reward: 5887.97, Epsilon: 0.010
# Episode 1529, Total Reward: 5889.79, Epsilon: 0.010
# Episode 1530, Total Reward: 5900.52, Epsilon: 0.010
# Episode 1531, Total Reward: 5901.09, Epsilon: 0.010
# Episode 1532, Total Reward: 5904.64, Epsilon: 0.010
# Episode 1533, Total Reward: 5894.85, Epsilon: 0.010
# Episode 1534, Total Reward: 5891.75, Epsilon: 0.010
# Episode 1535, Total Reward: 5891.40, Epsilon: 0.010
# Episode 1536, Total Reward: 5894.33, Epsilon: 0.010
# Episode 1537, Total Reward: 5895.95, Epsilon: 0.010
# Episode 1538, Total Reward: 5890.20, Epsilon: 0.010
# Episode 1539, Total Reward: 5894.33, Epsilon: 0.010
# Episode 1540, Total Reward: 5897.85, Epsilon: 0.010
# Episode 1541, Total Reward: 5882.31, Epsilon: 0.010
# Episode 1542, Total Reward: 5897.81, Epsilon: 0.010
# Episode 1543, Total Reward: 5892.72, Epsilon: 0.010
# Episode 1544, Total Reward: 5895.32, Epsilon: 0.010
# Episode 1545, Total Reward: 5902.33, Epsilon: 0.010
# Episode 1546, Total Reward: 5892.62, Epsilon: 0.010
# Episode 1547, Total Reward: 5902.59, Epsilon: 0.010
# Episode 1548, Total Reward: 5891.56, Epsilon: 0.010
# Episode 1549, Total Reward: 5902.41, Epsilon: 0.010
# Episode 1550, Total Reward: 5886.73, Epsilon: 0.010
# Episode 1551, Total Reward: 5896.36, Epsilon: 0.010
# Episode 1552, Total Reward: 5902.79, Epsilon: 0.010
# Episode 1553, Total Reward: 5906.05, Epsilon: 0.010
# Episode 1554, Total Reward: 5894.27, Epsilon: 0.010
# Episode 1555, Total Reward: 5889.61, Epsilon: 0.010
# Episode 1556, Total Reward: 5900.89, Epsilon: 0.010
# Episode 1557, Total Reward: 5883.83, Epsilon: 0.010
# Episode 1558, Total Reward: 5892.01, Epsilon: 0.010
# Episode 1559, Total Reward: 5889.58, Epsilon: 0.010
# Episode 1560, Total Reward: 5893.92, Epsilon: 0.010
# Episode 1561, Total Reward: 5886.16, Epsilon: 0.010
# Episode 1562, Total Reward: 5888.85, Epsilon: 0.010
# Episode 1563, Total Reward: 5896.10, Epsilon: 0.010
# Episode 1564, Total Reward: 5894.22, Epsilon: 0.010
# Episode 1565, Total Reward: 5896.00, Epsilon: 0.010
# Episode 1566, Total Reward: 5886.80, Epsilon: 0.010
# Episode 1567, Total Reward: 5902.03, Epsilon: 0.010
# Episode 1568, Total Reward: 5896.38, Epsilon: 0.010
# Episode 1569, Total Reward: 5899.28, Epsilon: 0.010
# Episode 1570, Total Reward: 5895.95, Epsilon: 0.010
# Episode 1571, Total Reward: 5903.57, Epsilon: 0.010
# Episode 1572, Total Reward: 5892.90, Epsilon: 0.010
# Episode 1573, Total Reward: 5893.19, Epsilon: 0.010
# Episode 1574, Total Reward: 5894.04, Epsilon: 0.010
# Episode 1575, Total Reward: 5900.52, Epsilon: 0.010
# Episode 1576, Total Reward: 5893.10, Epsilon: 0.010
# Episode 1577, Total Reward: 5898.50, Epsilon: 0.010
# Episode 1578, Total Reward: 5894.10, Epsilon: 0.010
# Episode 1579, Total Reward: 5889.18, Epsilon: 0.010
# Episode 1580, Total Reward: 5879.74, Epsilon: 0.010
# Episode 1581, Total Reward: 5897.24, Epsilon: 0.010
# Episode 1582, Total Reward: 5894.83, Epsilon: 0.010
# Episode 1583, Total Reward: 5893.67, Epsilon: 0.010
# Episode 1584, Total Reward: 5894.62, Epsilon: 0.010
# Episode 1585, Total Reward: 5897.29, Epsilon: 0.010
# Episode 1586, Total Reward: 5898.40, Epsilon: 0.010
# Episode 1587, Total Reward: 5885.22, Epsilon: 0.010
# Episode 1588, Total Reward: 5889.76, Epsilon: 0.010
# Episode 1589, Total Reward: 5886.29, Epsilon: 0.010
# Episode 1590, Total Reward: 5899.03, Epsilon: 0.010
# Episode 1591, Total Reward: 5907.09, Epsilon: 0.010
# Episode 1592, Total Reward: 5883.77, Epsilon: 0.010
# Episode 1593, Total Reward: 5888.39, Epsilon: 0.010
# Episode 1594, Total Reward: 5890.20, Epsilon: 0.010
# Episode 1595, Total Reward: 5902.48, Epsilon: 0.010
# Episode 1596, Total Reward: 5899.92, Epsilon: 0.010
# Episode 1597, Total Reward: 5894.43, Epsilon: 0.010
# Episode 1598, Total Reward: 5889.03, Epsilon: 0.010
# Episode 1599, Total Reward: 5884.13, Epsilon: 0.010
# Episode 1600, Total Reward: 5895.51, Epsilon: 0.010
# Episode 1601, Total Reward: 5891.79, Epsilon: 0.010
# Episode 1602, Total Reward: 5893.12, Epsilon: 0.010
# Episode 1603, Total Reward: 5894.93, Epsilon: 0.010
# Episode 1604, Total Reward: 5893.92, Epsilon: 0.010
# Episode 1605, Total Reward: 5892.25, Epsilon: 0.010
# Episode 1606, Total Reward: 5890.12, Epsilon: 0.010
# Episode 1607, Total Reward: 5895.34, Epsilon: 0.010
# Episode 1608, Total Reward: 5902.26, Epsilon: 0.010
# Episode 1609, Total Reward: 5895.32, Epsilon: 0.010
# Episode 1610, Total Reward: 5896.63, Epsilon: 0.010
# Episode 1611, Total Reward: 5891.13, Epsilon: 0.010
# Episode 1612, Total Reward: 5890.76, Epsilon: 0.010
# Episode 1613, Total Reward: 5912.99, Epsilon: 0.010
# Episode 1614, Total Reward: 5891.97, Epsilon: 0.010
# Episode 1615, Total Reward: 5894.72, Epsilon: 0.010
# Episode 1616, Total Reward: 5875.91, Epsilon: 0.010
# Episode 1617, Total Reward: 5900.02, Epsilon: 0.010
# Episode 1618, Total Reward: 5891.69, Epsilon: 0.010
# Episode 1619, Total Reward: 5894.02, Epsilon: 0.010
# Episode 1620, Total Reward: 5896.65, Epsilon: 0.010
# Episode 1621, Total Reward: 5902.38, Epsilon: 0.010
# Episode 1622, Total Reward: 5902.53, Epsilon: 0.010
# Episode 1623, Total Reward: 5893.68, Epsilon: 0.010
# Episode 1624, Total Reward: 5894.66, Epsilon: 0.010
# Episode 1625, Total Reward: 5889.57, Epsilon: 0.010
# Episode 1626, Total Reward: 5893.69, Epsilon: 0.010
# Episode 1627, Total Reward: 5894.46, Epsilon: 0.010
# Episode 1628, Total Reward: 5893.54, Epsilon: 0.010
# Episode 1629, Total Reward: 5891.61, Epsilon: 0.010
# Episode 1630, Total Reward: 5899.34, Epsilon: 0.010
# Episode 1631, Total Reward: 5903.48, Epsilon: 0.010
# Episode 1632, Total Reward: 5892.55, Epsilon: 0.010
# Episode 1633, Total Reward: 5885.55, Epsilon: 0.010
# Episode 1634, Total Reward: 5904.99, Epsilon: 0.010
# Episode 1635, Total Reward: 5900.82, Epsilon: 0.010
# Episode 1636, Total Reward: 5898.59, Epsilon: 0.010
# Episode 1637, Total Reward: 5886.70, Epsilon: 0.010
# Episode 1638, Total Reward: 5898.16, Epsilon: 0.010
# Episode 1639, Total Reward: 5907.92, Epsilon: 0.010
# Episode 1640, Total Reward: 5887.73, Epsilon: 0.010
# Episode 1641, Total Reward: 5889.19, Epsilon: 0.010
# Episode 1642, Total Reward: 5902.78, Epsilon: 0.010
# Episode 1643, Total Reward: 5888.77, Epsilon: 0.010
# Episode 1644, Total Reward: 5888.18, Epsilon: 0.010
# Episode 1645, Total Reward: 5878.09, Epsilon: 0.010
# Episode 1646, Total Reward: 5882.70, Epsilon: 0.010
# Episode 1647, Total Reward: 5886.69, Epsilon: 0.010
# Episode 1648, Total Reward: 5886.80, Epsilon: 0.010
# Episode 1649, Total Reward: 5896.98, Epsilon: 0.010
# Episode 1650, Total Reward: 5884.77, Epsilon: 0.010
# Episode 1651, Total Reward: 5890.96, Epsilon: 0.010
# Episode 1652, Total Reward: 5885.52, Epsilon: 0.010
# Episode 1653, Total Reward: 5892.04, Epsilon: 0.010
# Episode 1654, Total Reward: 5887.36, Epsilon: 0.010
# Episode 1655, Total Reward: 5895.63, Epsilon: 0.010
# Episode 1656, Total Reward: 5899.41, Epsilon: 0.010
# Episode 1657, Total Reward: 5895.39, Epsilon: 0.010
# Episode 1658, Total Reward: 5898.02, Epsilon: 0.010
# Episode 1659, Total Reward: 5888.05, Epsilon: 0.010
# Episode 1660, Total Reward: 5891.94, Epsilon: 0.010
# Episode 1661, Total Reward: 5894.78, Epsilon: 0.010
# Episode 1662, Total Reward: 5881.58, Epsilon: 0.010
# Episode 1663, Total Reward: 5891.48, Epsilon: 0.010
# Episode 1664, Total Reward: 5893.05, Epsilon: 0.010
# Episode 1665, Total Reward: 5887.18, Epsilon: 0.010
# Episode 1666, Total Reward: 5896.30, Epsilon: 0.010
# Episode 1667, Total Reward: 5898.94, Epsilon: 0.010
# Episode 1668, Total Reward: 5889.84, Epsilon: 0.010
# Episode 1669, Total Reward: 5888.46, Epsilon: 0.010
# Episode 1670, Total Reward: 5896.73, Epsilon: 0.010
# Episode 1671, Total Reward: 5884.47, Epsilon: 0.010
# Episode 1672, Total Reward: 5889.93, Epsilon: 0.010
# Episode 1673, Total Reward: 5896.95, Epsilon: 0.010
# Episode 1674, Total Reward: 5896.16, Epsilon: 0.010
# Episode 1675, Total Reward: 5892.56, Epsilon: 0.010
# Episode 1676, Total Reward: 5891.88, Epsilon: 0.010
# Episode 1677, Total Reward: 5903.32, Epsilon: 0.010
# Episode 1678, Total Reward: 5895.21, Epsilon: 0.010
# Episode 1679, Total Reward: 5894.88, Epsilon: 0.010
# Episode 1680, Total Reward: 5891.39, Epsilon: 0.010
# Episode 1681, Total Reward: 5888.28, Epsilon: 0.010
# Episode 1682, Total Reward: 5892.77, Epsilon: 0.010
# Episode 1683, Total Reward: 5888.95, Epsilon: 0.010
# Episode 1684, Total Reward: 5900.15, Epsilon: 0.010
# Episode 1685, Total Reward: 5896.24, Epsilon: 0.010
# Episode 1686, Total Reward: 5900.16, Epsilon: 0.010
# Episode 1687, Total Reward: 5891.68, Epsilon: 0.010
# Episode 1688, Total Reward: 5895.85, Epsilon: 0.010
# Episode 1689, Total Reward: 5897.38, Epsilon: 0.010
# Episode 1690, Total Reward: 5887.07, Epsilon: 0.010
# Episode 1691, Total Reward: 5899.39, Epsilon: 0.010
# Episode 1692, Total Reward: 5898.82, Epsilon: 0.010
# Episode 1693, Total Reward: 5894.02, Epsilon: 0.010
# Episode 1694, Total Reward: 5896.36, Epsilon: 0.010
# Episode 1695, Total Reward: 5900.98, Epsilon: 0.010
# Episode 1696, Total Reward: 5880.22, Epsilon: 0.010
# Episode 1697, Total Reward: 5892.71, Epsilon: 0.010
# Episode 1698, Total Reward: 5878.84, Epsilon: 0.010
# Episode 1699, Total Reward: 5886.07, Epsilon: 0.010
# Episode 1700, Total Reward: 5892.48, Epsilon: 0.010
# Episode 1701, Total Reward: 5895.21, Epsilon: 0.010
# Episode 1702, Total Reward: 5901.71, Epsilon: 0.010
# Episode 1703, Total Reward: 5893.12, Epsilon: 0.010
# Episode 1704, Total Reward: 5894.08, Epsilon: 0.010
# Episode 1705, Total Reward: 5892.37, Epsilon: 0.010
# Episode 1706, Total Reward: 5901.16, Epsilon: 0.010
# Episode 1707, Total Reward: 5899.02, Epsilon: 0.010
# Episode 1708, Total Reward: 5897.78, Epsilon: 0.010
# Episode 1709, Total Reward: 5895.53, Epsilon: 0.010
# Episode 1710, Total Reward: 5894.22, Epsilon: 0.010
# Episode 1711, Total Reward: 5886.43, Epsilon: 0.010
# Episode 1712, Total Reward: 5891.29, Epsilon: 0.010
# Episode 1713, Total Reward: 5894.44, Epsilon: 0.010
# Episode 1714, Total Reward: 5896.37, Epsilon: 0.010
# Episode 1715, Total Reward: 5887.29, Epsilon: 0.010
# Episode 1716, Total Reward: 5889.11, Epsilon: 0.010
# Episode 1717, Total Reward: 5894.99, Epsilon: 0.010
# Episode 1718, Total Reward: 5892.65, Epsilon: 0.010
# Episode 1719, Total Reward: 5886.56, Epsilon: 0.010
# Episode 1720, Total Reward: 5894.84, Epsilon: 0.010
# Episode 1721, Total Reward: 5895.32, Epsilon: 0.010
# Episode 1722, Total Reward: 5890.82, Epsilon: 0.010
# Episode 1723, Total Reward: 5900.15, Epsilon: 0.010
# Episode 1724, Total Reward: 5900.53, Epsilon: 0.010
# Episode 1725, Total Reward: 5885.13, Epsilon: 0.010
# Episode 1726, Total Reward: 5901.33, Epsilon: 0.010
# Episode 1727, Total Reward: 5889.01, Epsilon: 0.010
# Episode 1728, Total Reward: 5888.48, Epsilon: 0.010
# Episode 1729, Total Reward: 5896.13, Epsilon: 0.010
# Episode 1730, Total Reward: 5888.81, Epsilon: 0.010
# Episode 1731, Total Reward: 5887.71, Epsilon: 0.010
# Episode 1732, Total Reward: 5899.48, Epsilon: 0.010
# Episode 1733, Total Reward: 5901.61, Epsilon: 0.010
# Episode 1734, Total Reward: 5892.33, Epsilon: 0.010
# Episode 1735, Total Reward: 5904.51, Epsilon: 0.010
# Episode 1736, Total Reward: 5892.45, Epsilon: 0.010
# Episode 1737, Total Reward: 5899.75, Epsilon: 0.010
# Episode 1738, Total Reward: 5891.33, Epsilon: 0.010
# Episode 1739, Total Reward: 5894.85, Epsilon: 0.010
# Episode 1740, Total Reward: 5896.22, Epsilon: 0.010
# Episode 1741, Total Reward: 5895.51, Epsilon: 0.010
# Episode 1742, Total Reward: 5880.63, Epsilon: 0.010
# Episode 1743, Total Reward: 5892.27, Epsilon: 0.010
# Episode 1744, Total Reward: 5885.37, Epsilon: 0.010
# Episode 1745, Total Reward: 5883.29, Epsilon: 0.010
# Episode 1746, Total Reward: 5904.96, Epsilon: 0.010
# Episode 1747, Total Reward: 5895.06, Epsilon: 0.010
# Episode 1748, Total Reward: 5896.65, Epsilon: 0.010
# Episode 1749, Total Reward: 5895.47, Epsilon: 0.010
# Episode 1750, Total Reward: 5890.35, Epsilon: 0.010
# Episode 1751, Total Reward: 5899.63, Epsilon: 0.010
# Episode 1752, Total Reward: 5897.25, Epsilon: 0.010
# Episode 1753, Total Reward: 5895.88, Epsilon: 0.010
# Episode 1754, Total Reward: 5890.89, Epsilon: 0.010
# Episode 1755, Total Reward: 5896.23, Epsilon: 0.010
# Episode 1756, Total Reward: 5887.15, Epsilon: 0.010
# Episode 1757, Total Reward: 5901.86, Epsilon: 0.010
# Episode 1758, Total Reward: 5896.89, Epsilon: 0.010
# Episode 1759, Total Reward: 5888.95, Epsilon: 0.010
# Episode 1760, Total Reward: 5891.24, Epsilon: 0.010
# Episode 1761, Total Reward: 5900.27, Epsilon: 0.010
# Episode 1762, Total Reward: 5897.91, Epsilon: 0.010
# Episode 1763, Total Reward: 5892.88, Epsilon: 0.010
# Episode 1764, Total Reward: 5899.41, Epsilon: 0.010
# Episode 1765, Total Reward: 5888.01, Epsilon: 0.010
# Episode 1766, Total Reward: 5883.42, Epsilon: 0.010
# Episode 1767, Total Reward: 5905.21, Epsilon: 0.010
# Episode 1768, Total Reward: 5880.51, Epsilon: 0.010
# Episode 1769, Total Reward: 5893.33, Epsilon: 0.010
# Episode 1770, Total Reward: 5898.59, Epsilon: 0.010
# Episode 1771, Total Reward: 5883.29, Epsilon: 0.010
# Episode 1772, Total Reward: 5885.82, Epsilon: 0.010
# Episode 1773, Total Reward: 5884.53, Epsilon: 0.010
# Episode 1774, Total Reward: 5893.67, Epsilon: 0.010
# Episode 1775, Total Reward: 5891.55, Epsilon: 0.010
# Episode 1776, Total Reward: 5903.48, Epsilon: 0.010
# Episode 1777, Total Reward: 5892.85, Epsilon: 0.010
# Episode 1778, Total Reward: 5890.14, Epsilon: 0.010
# Episode 1779, Total Reward: 5896.04, Epsilon: 0.010
# Episode 1780, Total Reward: 5894.37, Epsilon: 0.010
# Episode 1781, Total Reward: 5899.14, Epsilon: 0.010
# Episode 1782, Total Reward: 5893.15, Epsilon: 0.010
# Episode 1783, Total Reward: 5889.07, Epsilon: 0.010
# Episode 1784, Total Reward: 5891.38, Epsilon: 0.010
# Episode 1785, Total Reward: 5890.36, Epsilon: 0.010
# Episode 1786, Total Reward: 5896.00, Epsilon: 0.010
# Episode 1787, Total Reward: 5891.38, Epsilon: 0.010
# Episode 1788, Total Reward: 5895.26, Epsilon: 0.010
# Episode 1789, Total Reward: 5887.93, Epsilon: 0.010
# Episode 1790, Total Reward: 5894.30, Epsilon: 0.010
# Episode 1791, Total Reward: 5892.70, Epsilon: 0.010
# Episode 1792, Total Reward: 5898.35, Epsilon: 0.010
# Episode 1793, Total Reward: 5890.32, Epsilon: 0.010
# Episode 1794, Total Reward: 5908.03, Epsilon: 0.010
# Episode 1795, Total Reward: 5895.00, Epsilon: 0.010
# Episode 1796, Total Reward: 5900.45, Epsilon: 0.010
# Episode 1797, Total Reward: 5892.20, Epsilon: 0.010
# Episode 1798, Total Reward: 5889.27, Epsilon: 0.010
# Episode 1799, Total Reward: 5893.75, Epsilon: 0.010
# Episode 1800, Total Reward: 5891.31, Epsilon: 0.010
# Episode 1801, Total Reward: 5891.11, Epsilon: 0.010
# Episode 1802, Total Reward: 5890.10, Epsilon: 0.010
# Episode 1803, Total Reward: 5900.21, Epsilon: 0.010
# Episode 1804, Total Reward: 5894.64, Epsilon: 0.010
# Episode 1805, Total Reward: 5890.26, Epsilon: 0.010
# Episode 1806, Total Reward: 5894.62, Epsilon: 0.010
# Episode 1807, Total Reward: 5896.44, Epsilon: 0.010
# Episode 1808, Total Reward: 5884.59, Epsilon: 0.010
# Episode 1809, Total Reward: 5895.22, Epsilon: 0.010
# Episode 1810, Total Reward: 5893.20, Epsilon: 0.010
# Episode 1811, Total Reward: 5902.65, Epsilon: 0.010
# Episode 1812, Total Reward: 5883.06, Epsilon: 0.010
# Episode 1813, Total Reward: 5894.53, Epsilon: 0.010
# Episode 1814, Total Reward: 5895.17, Epsilon: 0.010
# Episode 1815, Total Reward: 5898.01, Epsilon: 0.010
# Episode 1816, Total Reward: 5893.26, Epsilon: 0.010
# Episode 1817, Total Reward: 5896.90, Epsilon: 0.010
# Episode 1818, Total Reward: 5887.77, Epsilon: 0.010
# Episode 1819, Total Reward: 5893.03, Epsilon: 0.010
# Episode 1820, Total Reward: 5892.78, Epsilon: 0.010
# Episode 1821, Total Reward: 5897.22, Epsilon: 0.010
# Episode 1822, Total Reward: 5897.28, Epsilon: 0.010
# Episode 1823, Total Reward: 5872.54, Epsilon: 0.010
# Episode 1824, Total Reward: 5891.78, Epsilon: 0.010
# Episode 1825, Total Reward: 5902.35, Epsilon: 0.010
# Episode 1826, Total Reward: 5896.57, Epsilon: 0.010
# Episode 1827, Total Reward: 5891.91, Epsilon: 0.010
# Episode 1828, Total Reward: 5897.51, Epsilon: 0.010
# Episode 1829, Total Reward: 5891.96, Epsilon: 0.010
# Episode 1830, Total Reward: 5901.28, Epsilon: 0.010
# Episode 1831, Total Reward: 5900.33, Epsilon: 0.010
# Episode 1832, Total Reward: 5891.41, Epsilon: 0.010
# Episode 1833, Total Reward: 5891.80, Epsilon: 0.010
# Episode 1834, Total Reward: 5902.61, Epsilon: 0.010
# Episode 1835, Total Reward: 5894.84, Epsilon: 0.010
# Episode 1836, Total Reward: 5892.34, Epsilon: 0.010
# Episode 1837, Total Reward: 5904.31, Epsilon: 0.010
# Episode 1838, Total Reward: 5904.21, Epsilon: 0.010
# Episode 1839, Total Reward: 5891.60, Epsilon: 0.010
# Episode 1840, Total Reward: 5883.73, Epsilon: 0.010
# Episode 1841, Total Reward: 5898.42, Epsilon: 0.010
# Episode 1842, Total Reward: 5891.27, Epsilon: 0.010
# Episode 1843, Total Reward: 5888.11, Epsilon: 0.010
# Episode 1844, Total Reward: 5893.93, Epsilon: 0.010
# Episode 1845, Total Reward: 5900.90, Epsilon: 0.010
# Episode 1846, Total Reward: 5900.11, Epsilon: 0.010
# Episode 1847, Total Reward: 5893.01, Epsilon: 0.010
# Episode 1848, Total Reward: 5890.80, Epsilon: 0.010
# Episode 1849, Total Reward: 5903.84, Epsilon: 0.010
# Episode 1850, Total Reward: 5897.88, Epsilon: 0.010
# Episode 1851, Total Reward: 5898.81, Epsilon: 0.010
# Episode 1852, Total Reward: 5884.64, Epsilon: 0.010
# Episode 1853, Total Reward: 5886.67, Epsilon: 0.010
# Episode 1854, Total Reward: 5896.59, Epsilon: 0.010
# Episode 1855, Total Reward: 5884.63, Epsilon: 0.010
# Episode 1856, Total Reward: 5896.91, Epsilon: 0.010
# Episode 1857, Total Reward: 5890.81, Epsilon: 0.010
# Episode 1858, Total Reward: 5899.91, Epsilon: 0.010
# Episode 1859, Total Reward: 5888.48, Epsilon: 0.010
# Episode 1860, Total Reward: 5888.32, Epsilon: 0.010
# Episode 1861, Total Reward: 5881.59, Epsilon: 0.010
# Episode 1862, Total Reward: 5897.17, Epsilon: 0.010
# Episode 1863, Total Reward: 5903.69, Epsilon: 0.010
# Episode 1864, Total Reward: 5888.89, Epsilon: 0.010
# Episode 1865, Total Reward: 5902.89, Epsilon: 0.010
# Episode 1866, Total Reward: 5904.03, Epsilon: 0.010
# Episode 1867, Total Reward: 5894.25, Epsilon: 0.010
# Episode 1868, Total Reward: 5892.70, Epsilon: 0.010
# Episode 1869, Total Reward: 5895.93, Epsilon: 0.010
# Episode 1870, Total Reward: 5897.82, Epsilon: 0.010
# Episode 1871, Total Reward: 5889.19, Epsilon: 0.010
# Episode 1872, Total Reward: 5899.68, Epsilon: 0.010
# Episode 1873, Total Reward: 5895.79, Epsilon: 0.010
# Episode 1874, Total Reward: 5895.17, Epsilon: 0.010
# Episode 1875, Total Reward: 5888.24, Epsilon: 0.010
# Episode 1876, Total Reward: 5894.11, Epsilon: 0.010
# Episode 1877, Total Reward: 5899.44, Epsilon: 0.010
# Episode 1878, Total Reward: 5891.28, Epsilon: 0.010
# Episode 1879, Total Reward: 5886.63, Epsilon: 0.010
# Episode 1880, Total Reward: 5898.80, Epsilon: 0.010
# Episode 1881, Total Reward: 5896.71, Epsilon: 0.010
# Episode 1882, Total Reward: 5892.02, Epsilon: 0.010
# Episode 1883, Total Reward: 5889.55, Epsilon: 0.010
# Episode 1884, Total Reward: 5902.50, Epsilon: 0.010
# Episode 1885, Total Reward: 5890.59, Epsilon: 0.010
# Episode 1886, Total Reward: 5893.27, Epsilon: 0.010
# Episode 1887, Total Reward: 5895.93, Epsilon: 0.010
# Episode 1888, Total Reward: 5895.06, Epsilon: 0.010
# Episode 1889, Total Reward: 5886.52, Epsilon: 0.010
# Episode 1890, Total Reward: 5897.49, Epsilon: 0.010
# Episode 1891, Total Reward: 5889.59, Epsilon: 0.010
# Episode 1892, Total Reward: 5894.34, Epsilon: 0.010
# Episode 1893, Total Reward: 5884.35, Epsilon: 0.010
# Episode 1894, Total Reward: 5883.26, Epsilon: 0.010
# Episode 1895, Total Reward: 5893.48, Epsilon: 0.010
# Episode 1896, Total Reward: 5900.04, Epsilon: 0.010
# Episode 1897, Total Reward: 5890.30, Epsilon: 0.010
# Episode 1898, Total Reward: 5888.26, Epsilon: 0.010
# Episode 1899, Total Reward: 5890.43, Epsilon: 0.010
# Episode 1900, Total Reward: 5895.11, Epsilon: 0.010
# Episode 1901, Total Reward: 5889.63, Epsilon: 0.010
# Episode 1902, Total Reward: 5896.03, Epsilon: 0.010
# Episode 1903, Total Reward: 5906.57, Epsilon: 0.010
# Episode 1904, Total Reward: 5900.00, Epsilon: 0.010
# Episode 1905, Total Reward: 5897.23, Epsilon: 0.010
# Episode 1906, Total Reward: 5882.25, Epsilon: 0.010
# Episode 1907, Total Reward: 5895.54, Epsilon: 0.010
# Episode 1908, Total Reward: 5894.53, Epsilon: 0.010
# Episode 1909, Total Reward: 5882.88, Epsilon: 0.010
# Episode 1910, Total Reward: 5895.95, Epsilon: 0.010
# Episode 1911, Total Reward: 5887.20, Epsilon: 0.010
# Episode 1912, Total Reward: 5892.55, Epsilon: 0.010
# Episode 1913, Total Reward: 5911.57, Epsilon: 0.010
# Episode 1914, Total Reward: 5898.80, Epsilon: 0.010
# Episode 1915, Total Reward: 5888.59, Epsilon: 0.010
# Episode 1916, Total Reward: 5894.91, Epsilon: 0.010
# Episode 1917, Total Reward: 5896.68, Epsilon: 0.010
# Episode 1918, Total Reward: 5887.39, Epsilon: 0.010
# Episode 1919, Total Reward: 5896.16, Epsilon: 0.010
# Episode 1920, Total Reward: 5893.66, Epsilon: 0.010
# Episode 1921, Total Reward: 5885.65, Epsilon: 0.010
# Episode 1922, Total Reward: 5887.81, Epsilon: 0.010
# ...
# Episode 5694, Total Reward: 5891.13, Epsilon: 0.010
# Episode 5695, Total Reward: 5887.95, Epsilon: 0.010
# Episode 5696, Total Reward: 5890.17, Epsilon: 0.010
# Episode 5697, Total Reward: 5894.31, Epsilon: 0.010
# Episode 5698, Total Reward: 5889.35, Epsilon: 0.010
# Episode 5699, Total Reward: 5893.90, Epsilon: 0.010
# Episode 5700, Total Reward: 5892.03, Epsilon: 0.010
# Episode 5701, Total Reward: 5892.02, Epsilon: 0.010
# Episode 5702, Total Reward: 5892.15, Epsilon: 0.010
# Episode 5703, Total Reward: 5889.80, Epsilon: 0.010
# Episode 5704, Total Reward: 5896.87, Epsilon: 0.010
# Episode 5705, Total Reward: 5896.60, Epsilon: 0.010
# Episode 5706, Total Reward: 5898.06, Epsilon: 0.010
# Episode 5707, Total Reward: 5892.33, Epsilon: 0.010
# Episode 5708, Total Reward: 5896.33, Epsilon: 0.010
# Episode 5709, Total Reward: 5900.98, Epsilon: 0.010
# Episode 5710, Total Reward: 5885.43, Epsilon: 0.010
# Episode 5711, Total Reward: 5886.73, Epsilon: 0.010
# Episode 5712, Total Reward: 5899.42, Epsilon: 0.010
# Episode 5713, Total Reward: 5902.44, Epsilon: 0.010
# Episode 5714, Total Reward: 5898.41, Epsilon: 0.010
# Episode 5715, Total Reward: 5887.96, Epsilon: 0.010
# Episode 5716, Total Reward: 5890.37, Epsilon: 0.010
# Episode 5717, Total Reward: 5887.75, Epsilon: 0.010
# Episode 5718, Total Reward: 5885.64, Epsilon: 0.010
# Episode 5719, Total Reward: 5895.55, Epsilon: 0.010
# Episode 5720, Total Reward: 5891.03, Epsilon: 0.010
# Episode 5721, Total Reward: 5889.92, Epsilon: 0.010
# Episode 5722, Total Reward: 5882.91, Epsilon: 0.010
# Episode 5723, Total Reward: 5900.56, Epsilon: 0.010
# Episode 5724, Total Reward: 5890.48, Epsilon: 0.010
# Episode 5725, Total Reward: 5892.69, Epsilon: 0.010
# Episode 5726, Total Reward: 5902.38, Epsilon: 0.010
# Episode 5727, Total Reward: 5895.56, Epsilon: 0.010
# Episode 5728, Total Reward: 5896.40, Epsilon: 0.010
# Episode 5729, Total Reward: 5893.16, Epsilon: 0.010
# Episode 5730, Total Reward: 5890.74, Epsilon: 0.010
# Episode 5731, Total Reward: 5895.41, Epsilon: 0.010
# Episode 5732, Total Reward: 5890.09, Epsilon: 0.010
# Episode 5733, Total Reward: 5890.97, Epsilon: 0.010
# Episode 5734, Total Reward: 5893.52, Epsilon: 0.010
# Episode 5735, Total Reward: 5900.38, Epsilon: 0.010
# Episode 5736, Total Reward: 5888.20, Epsilon: 0.010
# Episode 5737, Total Reward: 5893.72, Epsilon: 0.010
# Episode 5738, Total Reward: 5899.16, Epsilon: 0.010
# Episode 5739, Total Reward: 5901.07, Epsilon: 0.010
# Episode 5740, Total Reward: 5887.71, Epsilon: 0.010
# Episode 5741, Total Reward: 5886.57, Epsilon: 0.010
# Episode 5742, Total Reward: 5879.05, Epsilon: 0.010
# Episode 5743, Total Reward: 5889.81, Epsilon: 0.010
# Episode 5744, Total Reward: 5891.97, Epsilon: 0.010
# Episode 5745, Total Reward: 5897.93, Epsilon: 0.010
# Episode 5746, Total Reward: 5894.50, Epsilon: 0.010
# Episode 5747, Total Reward: 5893.71, Epsilon: 0.010
# Episode 5748, Total Reward: 5906.39, Epsilon: 0.010
# Episode 5749, Total Reward: 5892.06, Epsilon: 0.010
# Episode 5750, Total Reward: 5890.59, Epsilon: 0.010
# Episode 5751, Total Reward: 5896.02, Epsilon: 0.010
# Episode 5752, Total Reward: 5893.12, Epsilon: 0.010
# Episode 5753, Total Reward: 5901.74, Epsilon: 0.010
# Episode 5754, Total Reward: 5897.32, Epsilon: 0.010
# Episode 5755, Total Reward: 5899.82, Epsilon: 0.010
# Episode 5756, Total Reward: 5890.29, Epsilon: 0.010
# Episode 5757, Total Reward: 5890.14, Epsilon: 0.010
# Episode 5758, Total Reward: 5906.41, Epsilon: 0.010
# Episode 5759, Total Reward: 5898.71, Epsilon: 0.010
# Episode 5760, Total Reward: 5885.30, Epsilon: 0.010
# Episode 5761, Total Reward: 5898.91, Epsilon: 0.010
# Episode 5762, Total Reward: 5904.88, Epsilon: 0.010
# Episode 5763, Total Reward: 5892.11, Epsilon: 0.010
# Episode 5764, Total Reward: 5894.53, Epsilon: 0.010
# Episode 5765, Total Reward: 5899.28, Epsilon: 0.010
# Episode 5766, Total Reward: 5895.89, Epsilon: 0.010
# Episode 5767, Total Reward: 5884.72, Epsilon: 0.010
# Episode 5768, Total Reward: 5893.86, Epsilon: 0.010
# Episode 5769, Total Reward: 5885.66, Epsilon: 0.010
# Episode 5770, Total Reward: 5893.51, Epsilon: 0.010
# Episode 5771, Total Reward: 5899.89, Epsilon: 0.010
# Episode 5772, Total Reward: 5892.74, Epsilon: 0.010
# Episode 5773, Total Reward: 5911.18, Epsilon: 0.010
# Episode 5774, Total Reward: 5888.39, Epsilon: 0.010
# Episode 5775, Total Reward: 5896.25, Epsilon: 0.010
# Episode 5776, Total Reward: 5893.37, Epsilon: 0.010
# Episode 5777, Total Reward: 5891.68, Epsilon: 0.010
# Episode 5778, Total Reward: 5884.46, Epsilon: 0.010
# Episode 5779, Total Reward: 5888.07, Epsilon: 0.010
# Episode 5780, Total Reward: 5892.60, Epsilon: 0.010
# Episode 5781, Total Reward: 5884.57, Epsilon: 0.010
# Episode 5782, Total Reward: 5892.38, Epsilon: 0.010
# Episode 5783, Total Reward: 5902.33, Epsilon: 0.010
# Episode 5784, Total Reward: 5895.90, Epsilon: 0.010
# Episode 5785, Total Reward: 5889.71, Epsilon: 0.010
# Episode 5786, Total Reward: 5892.76, Epsilon: 0.010
# Episode 5787, Total Reward: 5894.00, Epsilon: 0.010
# Episode 5788, Total Reward: 5889.71, Epsilon: 0.010
# Episode 5789, Total Reward: 5889.37, Epsilon: 0.010
# Episode 5790, Total Reward: 5892.16, Epsilon: 0.010
# Episode 5791, Total Reward: 5902.59, Epsilon: 0.010
# Episode 5792, Total Reward: 5902.60, Epsilon: 0.010
# Episode 5793, Total Reward: 5901.87, Epsilon: 0.010
# Episode 5794, Total Reward: 5895.99, Epsilon: 0.010
# Episode 5795, Total Reward: 5893.22, Epsilon: 0.010
# Episode 5796, Total Reward: 5895.13, Epsilon: 0.010
# Episode 5797, Total Reward: 5883.93, Epsilon: 0.010
# Episode 5798, Total Reward: 5895.57, Epsilon: 0.010
# Episode 5799, Total Reward: 5896.65, Epsilon: 0.010
# Episode 5800, Total Reward: 5892.71, Epsilon: 0.010
# Episode 5801, Total Reward: 5899.32, Epsilon: 0.010
# Episode 5802, Total Reward: 5890.82, Epsilon: 0.010
# Episode 5803, Total Reward: 5887.15, Epsilon: 0.010
# Episode 5804, Total Reward: 5896.68, Epsilon: 0.010
# Episode 5805, Total Reward: 5892.98, Epsilon: 0.010
# Episode 5806, Total Reward: 5893.15, Epsilon: 0.010
# Episode 5807, Total Reward: 5891.47, Epsilon: 0.010
# Episode 5808, Total Reward: 5894.70, Epsilon: 0.010
# Episode 5809, Total Reward: 5893.24, Epsilon: 0.010
# Episode 5810, Total Reward: 5899.90, Epsilon: 0.010
# Episode 5811, Total Reward: 5889.46, Epsilon: 0.010
# Episode 5812, Total Reward: 5880.49, Epsilon: 0.010
# Episode 5813, Total Reward: 5895.98, Epsilon: 0.010
# Episode 5814, Total Reward: 5893.22, Epsilon: 0.010
# Episode 5815, Total Reward: 5889.26, Epsilon: 0.010
# Episode 5816, Total Reward: 5890.94, Epsilon: 0.010
# Episode 5817, Total Reward: 5897.79, Epsilon: 0.010
# Episode 5818, Total Reward: 5899.01, Epsilon: 0.010
# Episode 5819, Total Reward: 5897.74, Epsilon: 0.010
# Episode 5820, Total Reward: 5897.67, Epsilon: 0.010
# Episode 5821, Total Reward: 5899.95, Epsilon: 0.010
# Episode 5822, Total Reward: 5886.37, Epsilon: 0.010
# Episode 5823, Total Reward: 5901.51, Epsilon: 0.010
# Episode 5824, Total Reward: 5897.25, Epsilon: 0.010
# Episode 5825, Total Reward: 5890.63, Epsilon: 0.010
# Episode 5826, Total Reward: 5897.14, Epsilon: 0.010
# Episode 5827, Total Reward: 5899.75, Epsilon: 0.010
# Episode 5828, Total Reward: 5890.20, Epsilon: 0.010
# Episode 5829, Total Reward: 5893.24, Epsilon: 0.010
# Episode 5830, Total Reward: 5893.00, Epsilon: 0.010
# Episode 5831, Total Reward: 5897.43, Epsilon: 0.010
# Episode 5832, Total Reward: 5895.46, Epsilon: 0.010
# Episode 5833, Total Reward: 5890.27, Epsilon: 0.010
# Episode 5834, Total Reward: 5897.11, Epsilon: 0.010
# Episode 5835, Total Reward: 5901.71, Epsilon: 0.010
# Episode 5836, Total Reward: 5894.37, Epsilon: 0.010
# Episode 5837, Total Reward: 5885.89, Epsilon: 0.010
# Episode 5838, Total Reward: 5897.05, Epsilon: 0.010
# Episode 5839, Total Reward: 5901.56, Epsilon: 0.010
# Episode 5840, Total Reward: 5886.21, Epsilon: 0.010
# Episode 5841, Total Reward: 5893.63, Epsilon: 0.010
# Episode 5842, Total Reward: 5881.73, Epsilon: 0.010
# Episode 5843, Total Reward: 5892.88, Epsilon: 0.010
# Episode 5844, Total Reward: 5883.64, Epsilon: 0.010
# Episode 5845, Total Reward: 5902.43, Epsilon: 0.010
# Episode 5846, Total Reward: 5892.24, Epsilon: 0.010
# Episode 5847, Total Reward: 5888.15, Epsilon: 0.010
# Episode 5848, Total Reward: 5900.43, Epsilon: 0.010
# Episode 5849, Total Reward: 5893.30, Epsilon: 0.010
# Episode 5850, Total Reward: 5886.00, Epsilon: 0.010
# Episode 5851, Total Reward: 5881.06, Epsilon: 0.010
# Episode 5852, Total Reward: 5896.84, Epsilon: 0.010
# Episode 5853, Total Reward: 5882.82, Epsilon: 0.010
# Episode 5854, Total Reward: 5904.41, Epsilon: 0.010
# Episode 5855, Total Reward: 5897.62, Epsilon: 0.010
# Episode 5856, Total Reward: 5896.13, Epsilon: 0.010
# Episode 5857, Total Reward: 5899.12, Epsilon: 0.010
# Episode 5858, Total Reward: 5894.47, Epsilon: 0.010
# Episode 5859, Total Reward: 5896.56, Epsilon: 0.010
# Episode 5860, Total Reward: 5904.96, Epsilon: 0.010
# Episode 5861, Total Reward: 5890.24, Epsilon: 0.010
# Episode 5862, Total Reward: 5896.48, Epsilon: 0.010
# Episode 5863, Total Reward: 5899.27, Epsilon: 0.010
# Episode 5864, Total Reward: 5897.43, Epsilon: 0.010
# Episode 5865, Total Reward: 5897.19, Epsilon: 0.010
# Episode 5866, Total Reward: 5892.60, Epsilon: 0.010
# Episode 5867, Total Reward: 5891.47, Epsilon: 0.010
# Episode 5868, Total Reward: 5902.35, Epsilon: 0.010
# Episode 5869, Total Reward: 5902.76, Epsilon: 0.010
# Episode 5870, Total Reward: 5893.41, Epsilon: 0.010
# Episode 5871, Total Reward: 5881.81, Epsilon: 0.010
# Episode 5872, Total Reward: 5894.53, Epsilon: 0.010
# Episode 5873, Total Reward: 5895.88, Epsilon: 0.010
# Episode 5874, Total Reward: 5893.88, Epsilon: 0.010
# Episode 5875, Total Reward: 5892.15, Epsilon: 0.010
# Episode 5876, Total Reward: 5898.64, Epsilon: 0.010
# Episode 5877, Total Reward: 5892.21, Epsilon: 0.010
# Episode 5878, Total Reward: 5893.22, Epsilon: 0.010
# Episode 5879, Total Reward: 5888.55, Epsilon: 0.010
# Episode 5880, Total Reward: 5889.23, Epsilon: 0.010
# Episode 5881, Total Reward: 5898.66, Epsilon: 0.010
# Episode 5882, Total Reward: 5890.93, Epsilon: 0.010
# Episode 5883, Total Reward: 5892.86, Epsilon: 0.010
# Episode 5884, Total Reward: 5898.05, Epsilon: 0.010
# Episode 5885, Total Reward: 5883.34, Epsilon: 0.010
# Episode 5886, Total Reward: 5896.73, Epsilon: 0.010
# Episode 5887, Total Reward: 5889.14, Epsilon: 0.010
# Episode 5888, Total Reward: 5898.51, Epsilon: 0.010
# Episode 5889, Total Reward: 5891.41, Epsilon: 0.010
# Episode 5890, Total Reward: 5897.14, Epsilon: 0.010
# Episode 5891, Total Reward: 5901.78, Epsilon: 0.010
# Episode 5892, Total Reward: 5894.08, Epsilon: 0.010
# Episode 5893, Total Reward: 5888.17, Epsilon: 0.010
# Episode 5894, Total Reward: 5896.90, Epsilon: 0.010
# Episode 5895, Total Reward: 5891.57, Epsilon: 0.010
# Episode 5896, Total Reward: 5884.43, Epsilon: 0.010
# Episode 5897, Total Reward: 5883.09, Epsilon: 0.010
# Episode 5898, Total Reward: 5895.45, Epsilon: 0.010
# Episode 5899, Total Reward: 5894.45, Epsilon: 0.010
# Episode 5900, Total Reward: 5889.67, Epsilon: 0.010
# Episode 5901, Total Reward: 5896.29, Epsilon: 0.010
# Episode 5902, Total Reward: 5904.17, Epsilon: 0.010
# Episode 5903, Total Reward: 5902.52, Epsilon: 0.010
# Episode 5904, Total Reward: 5891.85, Epsilon: 0.010
# Episode 5905, Total Reward: 5899.62, Epsilon: 0.010
# Episode 5906, Total Reward: 5900.62, Epsilon: 0.010
# Episode 5907, Total Reward: 5899.37, Epsilon: 0.010
# Episode 5908, Total Reward: 5902.62, Epsilon: 0.010
# Episode 5909, Total Reward: 5903.38, Epsilon: 0.010
# Episode 5910, Total Reward: 5898.26, Epsilon: 0.010
# Episode 5911, Total Reward: 5893.26, Epsilon: 0.010
# Episode 5912, Total Reward: 5881.81, Epsilon: 0.010
# Episode 5913, Total Reward: 5891.92, Epsilon: 0.010
# Episode 5914, Total Reward: 5896.68, Epsilon: 0.010
# Episode 5915, Total Reward: 5889.91, Epsilon: 0.010
# Episode 5916, Total Reward: 5894.55, Epsilon: 0.010
# Episode 5917, Total Reward: 5895.52, Epsilon: 0.010
# Episode 5918, Total Reward: 5899.81, Epsilon: 0.010
# Episode 5919, Total Reward: 5896.20, Epsilon: 0.010
# Episode 5920, Total Reward: 5896.37, Epsilon: 0.010
# Episode 5921, Total Reward: 5890.18, Epsilon: 0.010
# Episode 5922, Total Reward: 5885.07, Epsilon: 0.010
# Episode 5923, Total Reward: 5896.13, Epsilon: 0.010
# Episode 5924, Total Reward: 5895.04, Epsilon: 0.010
# Episode 5925, Total Reward: 5890.88, Epsilon: 0.010
# Episode 5926, Total Reward: 5894.96, Epsilon: 0.010
# Episode 5927, Total Reward: 5889.53, Epsilon: 0.010
# Episode 5928, Total Reward: 5884.91, Epsilon: 0.010
# Episode 5929, Total Reward: 5893.80, Epsilon: 0.010
# Episode 5930, Total Reward: 5891.79, Epsilon: 0.010
# Episode 5931, Total Reward: 5905.85, Epsilon: 0.010
# Episode 5932, Total Reward: 5886.92, Epsilon: 0.010
# Episode 5933, Total Reward: 5887.22, Epsilon: 0.010
# Episode 5934, Total Reward: 5896.27, Epsilon: 0.010
# Episode 5935, Total Reward: 5904.71, Epsilon: 0.010
# Episode 5936, Total Reward: 5887.27, Epsilon: 0.010
# Episode 5937, Total Reward: 5884.49, Epsilon: 0.010
# Episode 5938, Total Reward: 5903.19, Epsilon: 0.010
# Episode 5939, Total Reward: 5885.53, Epsilon: 0.010
# Episode 5940, Total Reward: 5900.89, Epsilon: 0.010
# Episode 5941, Total Reward: 5894.53, Epsilon: 0.010
# Episode 5942, Total Reward: 5898.52, Epsilon: 0.010
# Episode 5943, Total Reward: 5894.50, Epsilon: 0.010
# Episode 5944, Total Reward: 5889.51, Epsilon: 0.010
# Episode 5945, Total Reward: 5886.61, Epsilon: 0.010
# Episode 5946, Total Reward: 5906.62, Epsilon: 0.010
# Episode 5947, Total Reward: 5903.19, Epsilon: 0.010
# Episode 5948, Total Reward: 5900.99, Epsilon: 0.010
# Episode 5949, Total Reward: 5899.39, Epsilon: 0.010
# Episode 5950, Total Reward: 5896.34, Epsilon: 0.010
# Episode 5951, Total Reward: 5891.49, Epsilon: 0.010
# Episode 5952, Total Reward: 5894.89, Epsilon: 0.010
# Episode 5953, Total Reward: 5879.23, Epsilon: 0.010
# Episode 5954, Total Reward: 5887.33, Epsilon: 0.010
# Episode 5955, Total Reward: 5891.42, Epsilon: 0.010
# Episode 5956, Total Reward: 5895.77, Epsilon: 0.010
# Episode 5957, Total Reward: 5890.52, Epsilon: 0.010
# Episode 5958, Total Reward: 5902.36, Epsilon: 0.010
# Episode 5959, Total Reward: 5888.85, Epsilon: 0.010
# Episode 5960, Total Reward: 5895.06, Epsilon: 0.010
# Episode 5961, Total Reward: 5884.53, Epsilon: 0.010
# Episode 5962, Total Reward: 5894.39, Epsilon: 0.010
# Episode 5963, Total Reward: 5885.50, Epsilon: 0.010
# Episode 5964, Total Reward: 5896.70, Epsilon: 0.010
# Episode 5965, Total Reward: 5894.21, Epsilon: 0.010
# Episode 5966, Total Reward: 5894.21, Epsilon: 0.010
# Episode 5967, Total Reward: 5897.43, Epsilon: 0.010
# Episode 5968, Total Reward: 5906.92, Epsilon: 0.010
# Episode 5969, Total Reward: 5891.14, Epsilon: 0.010
# Episode 5970, Total Reward: 5900.86, Epsilon: 0.010
# Episode 5971, Total Reward: 5898.64, Epsilon: 0.010
# Episode 5972, Total Reward: 5898.53, Epsilon: 0.010
# Episode 5973, Total Reward: 5892.70, Epsilon: 0.010
# Episode 5974, Total Reward: 5887.70, Epsilon: 0.010
# Episode 5975, Total Reward: 5889.76, Epsilon: 0.010
# Episode 5976, Total Reward: 5896.15, Epsilon: 0.010
# Episode 5977, Total Reward: 5885.01, Epsilon: 0.010
# Episode 5978, Total Reward: 5895.08, Epsilon: 0.010
# Episode 5979, Total Reward: 5887.88, Epsilon: 0.010
# Episode 5980, Total Reward: 5898.77, Epsilon: 0.010
# Episode 5981, Total Reward: 5900.76, Epsilon: 0.010
# Episode 5982, Total Reward: 5900.29, Epsilon: 0.010
# Episode 5983, Total Reward: 5895.96, Epsilon: 0.010
# Episode 5984, Total Reward: 5889.67, Epsilon: 0.010
# Episode 5985, Total Reward: 5894.50, Epsilon: 0.010
# Episode 5986, Total Reward: 5894.14, Epsilon: 0.010
# Episode 5987, Total Reward: 5896.93, Epsilon: 0.010
# Episode 5988, Total Reward: 5898.81, Epsilon: 0.010
# Episode 5989, Total Reward: 5884.23, Epsilon: 0.010
# Episode 5990, Total Reward: 5899.95, Epsilon: 0.010
# Episode 5991, Total Reward: 5889.97, Epsilon: 0.010
# Episode 5992, Total Reward: 5894.18, Epsilon: 0.010
# Episode 5993, Total Reward: 5891.43, Epsilon: 0.010
# Episode 5994, Total Reward: 5899.63, Epsilon: 0.010
# Episode 5995, Total Reward: 5896.45, Epsilon: 0.010
# Episode 5996, Total Reward: 5899.93, Epsilon: 0.010
# Episode 5997, Total Reward: 5889.65, Epsilon: 0.010
# Episode 5998, Total Reward: 5900.66, Epsilon: 0.010
# Episode 5999, Total Reward: 5884.69, Epsilon: 0.010
# Episode 6000, Total Reward: 5892.88, Epsilon: 0.010

# %% [markdown]
# KM doesnt work+ 3 rsus

# %% [markdown]
# too many errors

# %%
# Final Deep Q-Network Training with Post-Hoc KM Matching for Vehicular Edge Computing

import random
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import linear_sum_assignment
import networkx as nx

# -------- Constants --------
m = 10**6
g = 10**9
W = 10 * m
P_u = 0.1
sigma2 = 10**(-17.4)
I = 1e-10

# -------- RSU and Vehicle --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0), (2400, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

    def rsu_return_delay(self, d_n):
        rate = W * math.log2(1 + (P_u * 1e-7) / (sigma2 + I))
        return d_n / rate

    def step(self, actions):
        rewards = []
        rsu_remaining = self.rsu.resource_capacity

        for i, vid in enumerate(self.vehicle_ids):
            cpu_cycles = random.uniform(0.5, 1.2) * g
            data_size = random.uniform(0.3, 1.0) * m
            task_deadline = 1.2
            x, y, _, _ = self.trajectories[vid][self.current_step]

            action = actions[i]
            if action == 0:
                delay = self.vehicles[vid].compDelay(cpu_cycles)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 0
            else:
                comp = self.rsu.compDelay(cpu_cycles)
                t_ret = self.rsu_return_delay(data_size)
                delay = comp + t_ret
                stable = any(math.hypot(x - rx, y - ry) <= self.rsu.radius for rx, ry in self.rsu_positions)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 5 if stable else -5
                rsu_remaining -= 1
                self.Salloc[i] = 1

            delay_ratio = delay / max(0.0001, task_deadline)
            rtime = 5 * (1 - min(1, delay_ratio))
            reward = 0.4 * rsuc + 0.4 * rtime + 0.2 * roffsuc
            rewards.append(reward)

            self.Soff[i] = action
            self.Ssche[i] = 1 if delay <= task_deadline else 0

        self.Srest = [max(0, rsu_remaining)]
        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_state = self.Soff + self.Ssche + self.Salloc + self.Srest
        return next_state, rewards, done

# -------- Replay Memory --------
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.idx = 0

    def store(self, state, action, next_state, reward, done):
        data = (state, action, next_state, reward, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(data)
        else:
            self.buffer[self.idx] = data
        self.idx = (self.idx + 1) % self.capacity

    def sample(self, batch_size, device):
        batch = random.sample(self.buffer, batch_size)
        states, actions, next_states, rewards, dones = zip(*batch)
        return (
            torch.tensor(states, dtype=torch.float32).to(device),
            torch.tensor(actions, dtype=torch.int64).to(device),
            torch.tensor(next_states, dtype=torch.float32).to(device),
            torch.tensor(rewards, dtype=torch.float32).to(device),
            torch.tensor(dones, dtype=torch.bool).to(device)
        )

    def __len__(self):
        return len(self.buffer)

# -------- DQN Network --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- DQN Agent --------
class DQNAgent:
    def __init__(self, state_size, action_size, device):
        self.device = device
        self.epsilon = 0.9
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.discount = 0.99
        self.memory = ReplayMemory(10000)
        self.policy_net = DQNNet(state_size, action_size).to(device)
        self.target_net = DQNNet(state_size, action_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=0.0008)

    def learn(self, batch_size):
        if len(self.memory) < batch_size:
            return
        states, actions, next_states, rewards, dones = self.memory.sample(batch_size, self.device)
        q_values = self.policy_net(states).gather(1, actions.view(-1, 1))
        max_next_q = self.target_net(next_states).max(1).values
        targets = rewards + self.discount * max_next_q * (~dones)
        loss = F.mse_loss(q_values.view(-1), targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_target_net(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# -------- Action Selection (ε-greedy) --------
def select_actions_epsilon_greedy(agent, state, vehicle_ids, action_size):
    actions = []
    for _ in vehicle_ids:
        if random.random() < agent.epsilon:
            actions.append(random.randint(0, action_size - 1))
        else:
            s = torch.tensor([state], dtype=torch.float32).to(agent.device)
            with torch.no_grad():
                q_values = agent.policy_net(s).cpu().numpy().flatten()
                actions.append(np.argmax(q_values))
    return actions

# -------- Post-Training KM Matching --------
def km_match_posthoc(agent, state, vehicle_ids):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(agent.device)
        with torch.no_grad():
            q_values = agent.policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)
    cost_matrix = -np.array(q_matrix)
    _, col_ind = linear_sum_assignment(cost_matrix)
    return col_ind, np.array(q_matrix)

# -------- Plot Bipartite Graph --------
def plot_bipartite_graph(q_matrix, actions, vehicle_ids, filename):
    B = nx.Graph()
    left_nodes = [f'V{i}' for i in range(len(vehicle_ids))]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    for i, v in enumerate(left_nodes):
        for j, a in enumerate(right_nodes):
            weight = q_matrix[i][j]
            B.add_edge(v, a, weight=round(weight, 1))

    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    for i, j in enumerate(actions):
        v = f'V{i}'
        a = f'A{j}'
        if B.has_edge(v, a):
            nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with KM Matching")
    plt.axis('off')
    plt.savefig(filename)
    plt.show()

# -------- Main --------
if __name__ == '__main__':
    data = np.load("test_predictions_full_300.npz")
    predicted = data['predicted']
    vehicle_ids = data['vehicle_ids']

    df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                      columns=["vehicle_id", "lat", "lon", "vx", "vy"])
    top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
    trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

    vehicles = {vid: Vehicle() for vid in top_15_ids}
    rsu = RSU()
    env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

    state_size = len(env.reset())
    action_size = 4  # 0: local, 1–3: RSUs
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    agent = DQNAgent(state_size, action_size, device)

    episodes = 6000
    reward_log = []

    for ep in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            actions = select_actions_epsilon_greedy(agent, state, top_15_ids, action_size)
            next_state, rewards, done = env.step(actions)

            for i, vid in enumerate(top_15_ids):
                action = actions[i]
                reward = rewards[i]
                agent.memory.store(state, action, next_state, reward, done)

            agent.learn(32)
            state = next_state
            total_reward += sum(rewards)

        agent.update_epsilon()
        agent.update_target_net()
        reward_log.append(total_reward)
        print(f"Episode {ep+1}, Total Reward: {total_reward:.2f}, Epsilon: {agent.epsilon:.3f}")

    torch.save(agent.policy_net.state_dict(), "dqn_multi_vehicle.pth")

    plt.plot(range(1, episodes + 1), reward_log)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("DQN Training: Reward vs Episode")
    plt.grid(True)
    plt.savefig("reward_vs_episode.png")
    plt.show()

    # --- Post-training Evaluation using KM Matching ---
    print("\nEvaluating policy using KM matching:")
    state = env.reset()
    done = False
    total_reward = 0
    while not done:
        actions, q_matrix = km_match_posthoc(agent, state, top_15_ids)
        next_state, rewards, done = env.step(actions)
        state = next_state
        total_reward += sum(rewards)
    print(f"Total Reward with KM matching after training: {total_reward:.2f}")

    # --- Plot Bipartite Graph ---
    plot_bipartite_graph(q_matrix, actions, top_15_ids, "bipartite_km_match.png")
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 1001, Total Reward: 10370.35, Epsilon: 0.010
# Episode 1002, Total Reward: 10405.39, Epsilon: 0.010
# Episode 1003, Total Reward: 10310.08, Epsilon: 0.010
# Episode 1004, Total Reward: 10359.14, Epsilon: 0.010
# Episode 1005, Total Reward: 10359.24, Epsilon: 0.010
# Episode 1006, Total Reward: 7660.92, Epsilon: 0.010
# Episode 1007, Total Reward: 10381.80, Epsilon: 0.010
# Episode 1008, Total Reward: 10384.37, Epsilon: 0.010
# Episode 1009, Total Reward: 10400.68, Epsilon: 0.010
# Episode 1010, Total Reward: 8858.84, Epsilon: 0.010
# Episode 1011, Total Reward: 10396.44, Epsilon: 0.010
# Episode 1012, Total Reward: 10365.16, Epsilon: 0.010
# Episode 1013, Total Reward: 10383.50, Epsilon: 0.010
# Episode 1014, Total Reward: 10417.72, Epsilon: 0.010
# Episode 1015, Total Reward: 7250.00, Epsilon: 0.010
# Episode 1016, Total Reward: 10393.12, Epsilon: 0.010
# Episode 1017, Total Reward: 10361.85, Epsilon: 0.010
# Episode 1018, Total Reward: 10391.02, Epsilon: 0.010
# Episode 1019, Total Reward: 10353.38, Epsilon: 0.010
# Episode 1020, Total Reward: 10383.78, Epsilon: 0.010
# Episode 1021, Total Reward: 10410.23, Epsilon: 0.010
# Episode 1022, Total Reward: 10401.14, Epsilon: 0.010
# Episode 1023, Total Reward: 10379.33, Epsilon: 0.010
# Episode 1024, Total Reward: 10387.96, Epsilon: 0.010
# Episode 1025, Total Reward: 10409.31, Epsilon: 0.010
# Episode 1026, Total Reward: 10404.02, Epsilon: 0.010
# Episode 1027, Total Reward: 10374.85, Epsilon: 0.010
# Episode 1028, Total Reward: 10400.68, Epsilon: 0.010
# Episode 1029, Total Reward: 10385.31, Epsilon: 0.010
# Episode 1030, Total Reward: 10391.53, Epsilon: 0.010
# Episode 1031, Total Reward: 10355.97, Epsilon: 0.010
# Episode 1032, Total Reward: 10366.00, Epsilon: 0.010
# Episode 1033, Total Reward: 10387.84, Epsilon: 0.010
# Episode 1034, Total Reward: 10376.52, Epsilon: 0.010
# Episode 1035, Total Reward: 10392.28, Epsilon: 0.010
# Episode 1036, Total Reward: 10377.60, Epsilon: 0.010
# Episode 1037, Total Reward: 10383.76, Epsilon: 0.010
# Episode 1038, Total Reward: 10380.22, Epsilon: 0.010
# Episode 1039, Total Reward: 10379.07, Epsilon: 0.010
# Episode 1040, Total Reward: 10078.00, Epsilon: 0.010
# Episode 1041, Total Reward: 9326.62, Epsilon: 0.010
# Episode 1042, Total Reward: 9937.49, Epsilon: 0.010
# Episode 1043, Total Reward: 10364.54, Epsilon: 0.010
# Episode 1044, Total Reward: 10375.51, Epsilon: 0.010
# Episode 1045, Total Reward: 10364.41, Epsilon: 0.010
# Episode 1046, Total Reward: 10352.35, Epsilon: 0.010
# Episode 1047, Total Reward: 10370.52, Epsilon: 0.010
# Episode 1048, Total Reward: 10373.60, Epsilon: 0.010
# Episode 1049, Total Reward: 10361.92, Epsilon: 0.010
# Episode 1050, Total Reward: 10358.65, Epsilon: 0.010
# Episode 1051, Total Reward: 10405.17, Epsilon: 0.010
# Episode 1052, Total Reward: 10358.63, Epsilon: 0.010
# Episode 1053, Total Reward: 10394.67, Epsilon: 0.010
# Episode 1054, Total Reward: 10347.93, Epsilon: 0.010
# Episode 1055, Total Reward: 10381.35, Epsilon: 0.010
# Episode 1056, Total Reward: 10357.40, Epsilon: 0.010
# Episode 1057, Total Reward: 10420.77, Epsilon: 0.010
# Episode 1058, Total Reward: 10366.47, Epsilon: 0.010
# Episode 1059, Total Reward: 10388.88, Epsilon: 0.010
# Episode 1060, Total Reward: 10371.26, Epsilon: 0.010
# Episode 1061, Total Reward: 10403.12, Epsilon: 0.010
# Episode 1062, Total Reward: 10384.03, Epsilon: 0.010
# Episode 1063, Total Reward: 10395.86, Epsilon: 0.010
# Episode 1064, Total Reward: 10236.25, Epsilon: 0.010
# Episode 1065, Total Reward: 4899.13, Epsilon: 0.010
# Episode 1066, Total Reward: 6395.26, Epsilon: 0.010
# Episode 1067, Total Reward: 10378.74, Epsilon: 0.010
# Episode 1068, Total Reward: 10392.92, Epsilon: 0.010
# Episode 1069, Total Reward: 10411.67, Epsilon: 0.010
# Episode 1070, Total Reward: 10401.25, Epsilon: 0.010
# Episode 1071, Total Reward: 10404.70, Epsilon: 0.010
# Episode 1072, Total Reward: 10399.72, Epsilon: 0.010
# Episode 1073, Total Reward: 10414.96, Epsilon: 0.010
# Episode 1074, Total Reward: 10365.94, Epsilon: 0.010
# Episode 1075, Total Reward: 10396.59, Epsilon: 0.010
# Episode 1076, Total Reward: 10372.15, Epsilon: 0.010
# Episode 1077, Total Reward: 10407.36, Epsilon: 0.010
# Episode 1078, Total Reward: 10399.88, Epsilon: 0.010
# Episode 1079, Total Reward: 10375.58, Epsilon: 0.010
# Episode 1080, Total Reward: 10387.36, Epsilon: 0.010
# Episode 1081, Total Reward: 10393.69, Epsilon: 0.010
# Episode 1082, Total Reward: 10361.35, Epsilon: 0.010
# Episode 1083, Total Reward: 10403.09, Epsilon: 0.010
# Episode 1084, Total Reward: 10406.15, Epsilon: 0.010
# Episode 1085, Total Reward: 10394.20, Epsilon: 0.010
# Episode 1086, Total Reward: 10395.91, Epsilon: 0.010
# Episode 1087, Total Reward: 10367.50, Epsilon: 0.010
# Episode 1088, Total Reward: 10400.65, Epsilon: 0.010
# Episode 1089, Total Reward: 10371.72, Epsilon: 0.010
# Episode 1090, Total Reward: 10388.10, Epsilon: 0.010
# Episode 1091, Total Reward: 10421.97, Epsilon: 0.010
# Episode 1092, Total Reward: 10386.60, Epsilon: 0.010
# Episode 1093, Total Reward: 10381.85, Epsilon: 0.010
# Episode 1094, Total Reward: 10385.24, Epsilon: 0.010
# Episode 1095, Total Reward: 10389.65, Epsilon: 0.010
# Episode 1096, Total Reward: 10385.84, Epsilon: 0.010
# Episode 1097, Total Reward: 10393.66, Epsilon: 0.010
# Episode 1098, Total Reward: 9649.36, Epsilon: 0.010
# Episode 1099, Total Reward: 8878.27, Epsilon: 0.010
# Episode 1100, Total Reward: 6591.28, Epsilon: 0.010
# Episode 1101, Total Reward: 10393.44, Epsilon: 0.010
# Episode 1102, Total Reward: 10417.33, Epsilon: 0.010
# Episode 1103, Total Reward: 9021.27, Epsilon: 0.010
# Episode 1104, Total Reward: 8380.37, Epsilon: 0.010
# Episode 1105, Total Reward: 10075.13, Epsilon: 0.010
# Episode 1106, Total Reward: 10396.93, Epsilon: 0.010
# Episode 1107, Total Reward: 8268.21, Epsilon: 0.010
# Episode 1108, Total Reward: 10029.92, Epsilon: 0.010
# Episode 1109, Total Reward: 10404.34, Epsilon: 0.010
# Episode 1110, Total Reward: 9904.24, Epsilon: 0.010
# Episode 1111, Total Reward: 10384.63, Epsilon: 0.010
# Episode 1112, Total Reward: 10410.50, Epsilon: 0.010
# Episode 1113, Total Reward: 10407.62, Epsilon: 0.010
# Episode 1114, Total Reward: 10382.25, Epsilon: 0.010
# Episode 1115, Total Reward: 10387.49, Epsilon: 0.010
# Episode 1116, Total Reward: 10395.52, Epsilon: 0.010
# Episode 1117, Total Reward: 10398.85, Epsilon: 0.010
# Episode 1118, Total Reward: 10388.19, Epsilon: 0.010
# Episode 1119, Total Reward: 10413.61, Epsilon: 0.010
# Episode 1120, Total Reward: 10345.13, Epsilon: 0.010
# Episode 1121, Total Reward: 10389.53, Epsilon: 0.010
# Episode 1122, Total Reward: 10360.35, Epsilon: 0.010
# Episode 1123, Total Reward: 10365.16, Epsilon: 0.010
# Episode 1124, Total Reward: 10355.12, Epsilon: 0.010
# Episode 1125, Total Reward: 10371.50, Epsilon: 0.010
# Episode 1126, Total Reward: 10397.23, Epsilon: 0.010
# Episode 1127, Total Reward: 10338.10, Epsilon: 0.010
# Episode 1128, Total Reward: 10378.93, Epsilon: 0.010
# Episode 1129, Total Reward: 10392.97, Epsilon: 0.010
# Episode 1130, Total Reward: 10426.30, Epsilon: 0.010
# Episode 1131, Total Reward: 10386.15, Epsilon: 0.010
# Episode 1132, Total Reward: 10390.65, Epsilon: 0.010
# Episode 1133, Total Reward: 10411.49, Epsilon: 0.010
# Episode 1134, Total Reward: 10343.14, Epsilon: 0.010
# Episode 1135, Total Reward: 10401.29, Epsilon: 0.010
# Episode 1136, Total Reward: 10406.40, Epsilon: 0.010
# Episode 1137, Total Reward: 10368.10, Epsilon: 0.010
# Episode 1138, Total Reward: 10355.24, Epsilon: 0.010
# Episode 1139, Total Reward: 10367.47, Epsilon: 0.010
# Episode 1140, Total Reward: 10354.39, Epsilon: 0.010
# Episode 1141, Total Reward: 10370.34, Epsilon: 0.010
# Episode 1142, Total Reward: 10390.31, Epsilon: 0.010
# Episode 1143, Total Reward: 10391.95, Epsilon: 0.010
# Episode 1144, Total Reward: 10390.49, Epsilon: 0.010
# Episode 1145, Total Reward: 10402.72, Epsilon: 0.010
# Episode 1146, Total Reward: 10367.31, Epsilon: 0.010
# Episode 1147, Total Reward: 10359.68, Epsilon: 0.010
# Episode 1148, Total Reward: 10316.07, Epsilon: 0.010
# Episode 1149, Total Reward: 10371.89, Epsilon: 0.010
# Episode 1150, Total Reward: 10391.46, Epsilon: 0.010
# Episode 1151, Total Reward: 10394.98, Epsilon: 0.010
# Episode 1152, Total Reward: 10388.70, Epsilon: 0.010
# Episode 1153, Total Reward: 10363.93, Epsilon: 0.010
# Episode 1154, Total Reward: 10349.50, Epsilon: 0.010
# Episode 1155, Total Reward: 10373.96, Epsilon: 0.010
# Episode 1156, Total Reward: 10391.22, Epsilon: 0.010
# Episode 1157, Total Reward: 6580.70, Epsilon: 0.010
# Episode 1158, Total Reward: 7509.99, Epsilon: 0.010
# Episode 1159, Total Reward: 9020.32, Epsilon: 0.010
# Episode 1160, Total Reward: 7332.89, Epsilon: 0.010
# Episode 1161, Total Reward: 8224.88, Epsilon: 0.010
# Episode 1162, Total Reward: 10344.88, Epsilon: 0.010
# Episode 1163, Total Reward: 10363.89, Epsilon: 0.010
# Episode 1164, Total Reward: 10378.24, Epsilon: 0.010
# Episode 1165, Total Reward: 10385.28, Epsilon: 0.010
# Episode 1166, Total Reward: 10376.15, Epsilon: 0.010
# Episode 1167, Total Reward: 10407.34, Epsilon: 0.010
# Episode 1168, Total Reward: 10376.83, Epsilon: 0.010
# Episode 1169, Total Reward: 10342.94, Epsilon: 0.010
# Episode 1170, Total Reward: 10362.36, Epsilon: 0.010
# Episode 1171, Total Reward: 10352.63, Epsilon: 0.010
# Episode 1172, Total Reward: 10406.93, Epsilon: 0.010
# Episode 1173, Total Reward: 10361.60, Epsilon: 0.010
# Episode 1174, Total Reward: 10383.61, Epsilon: 0.010
# Episode 1175, Total Reward: 10386.28, Epsilon: 0.010
# Episode 1176, Total Reward: 10407.62, Epsilon: 0.010
# Episode 1177, Total Reward: 10370.58, Epsilon: 0.010
# Episode 1178, Total Reward: 10329.16, Epsilon: 0.010
# Episode 1179, Total Reward: 10364.61, Epsilon: 0.010
# Episode 1180, Total Reward: 10394.06, Epsilon: 0.010
# Episode 1181, Total Reward: 10383.72, Epsilon: 0.010
# Episode 1182, Total Reward: 10384.36, Epsilon: 0.010
# Episode 1183, Total Reward: 8082.83, Epsilon: 0.010
# Episode 1184, Total Reward: 10379.34, Epsilon: 0.010
# Episode 1185, Total Reward: 10398.68, Epsilon: 0.010
# Episode 1186, Total Reward: 10403.48, Epsilon: 0.010
# Episode 1187, Total Reward: 10389.32, Epsilon: 0.010
# Episode 1188, Total Reward: 10391.52, Epsilon: 0.010
# Episode 1189, Total Reward: 10364.51, Epsilon: 0.010
# Episode 1190, Total Reward: 10369.30, Epsilon: 0.010
# Episode 1191, Total Reward: 10327.18, Epsilon: 0.010
# Episode 1192, Total Reward: 10349.77, Epsilon: 0.010
# Episode 1193, Total Reward: 10352.01, Epsilon: 0.010
# Episode 1194, Total Reward: 10390.09, Epsilon: 0.010
# Episode 1195, Total Reward: 10356.72, Epsilon: 0.010
# Episode 1196, Total Reward: 10396.37, Epsilon: 0.010
# Episode 1197, Total Reward: 10393.22, Epsilon: 0.010
# Episode 1198, Total Reward: 10092.66, Epsilon: 0.010
# Episode 1199, Total Reward: 10407.29, Epsilon: 0.010
# Episode 1200, Total Reward: 10413.82, Epsilon: 0.010
# Episode 1201, Total Reward: 10370.52, Epsilon: 0.010
# Episode 1202, Total Reward: 10371.64, Epsilon: 0.010
# Episode 1203, Total Reward: 10395.70, Epsilon: 0.010
# Episode 1204, Total Reward: 10411.94, Epsilon: 0.010
# Episode 1205, Total Reward: 10419.84, Epsilon: 0.010
# Episode 1206, Total Reward: 10369.88, Epsilon: 0.010
# Episode 1207, Total Reward: 10395.96, Epsilon: 0.010
# Episode 1208, Total Reward: 10404.39, Epsilon: 0.010
# Episode 1209, Total Reward: 10359.19, Epsilon: 0.010
# Episode 1210, Total Reward: 10370.07, Epsilon: 0.010
# Episode 1211, Total Reward: 8561.34, Epsilon: 0.010
# Episode 1212, Total Reward: 10372.78, Epsilon: 0.010
# Episode 1213, Total Reward: 10417.62, Epsilon: 0.010
# Episode 1214, Total Reward: 10387.35, Epsilon: 0.010
# Episode 1215, Total Reward: 10397.64, Epsilon: 0.010
# Episode 1216, Total Reward: 10408.61, Epsilon: 0.010
# Episode 1217, Total Reward: 10368.93, Epsilon: 0.010
# Episode 1218, Total Reward: 10379.12, Epsilon: 0.010
# Episode 1219, Total Reward: 10382.45, Epsilon: 0.010
# Episode 1220, Total Reward: 10397.39, Epsilon: 0.010
# Episode 1221, Total Reward: 10350.64, Epsilon: 0.010
# Episode 1222, Total Reward: 10386.57, Epsilon: 0.010
# Episode 1223, Total Reward: 10401.54, Epsilon: 0.010
# Episode 1224, Total Reward: 10370.77, Epsilon: 0.010
# Episode 1225, Total Reward: 10385.84, Epsilon: 0.010
# Episode 1226, Total Reward: 10342.76, Epsilon: 0.010
# Episode 1227, Total Reward: 10337.94, Epsilon: 0.010
# Episode 1228, Total Reward: 10364.95, Epsilon: 0.010
# Episode 1229, Total Reward: 10362.10, Epsilon: 0.010
# Episode 1230, Total Reward: 10412.11, Epsilon: 0.010
# Episode 1231, Total Reward: 8098.44, Epsilon: 0.010
# Episode 1232, Total Reward: 10392.90, Epsilon: 0.010
# Episode 1233, Total Reward: 9157.89, Epsilon: 0.010
# Episode 1234, Total Reward: 10411.03, Epsilon: 0.010
# Episode 1235, Total Reward: 10356.80, Epsilon: 0.010
# Episode 1236, Total Reward: 10334.07, Epsilon: 0.010
# Episode 1237, Total Reward: 10372.69, Epsilon: 0.010
# Episode 1238, Total Reward: 10376.65, Epsilon: 0.010
# Episode 1239, Total Reward: 10411.99, Epsilon: 0.010
# Episode 1240, Total Reward: 10365.31, Epsilon: 0.010
# Episode 1241, Total Reward: 10378.84, Epsilon: 0.010
# Episode 1242, Total Reward: 9726.01, Epsilon: 0.010
# Episode 1243, Total Reward: 10377.97, Epsilon: 0.010
# Episode 1244, Total Reward: 10370.45, Epsilon: 0.010
# Episode 1245, Total Reward: 10362.44, Epsilon: 0.010
# Episode 1246, Total Reward: 10319.28, Epsilon: 0.010
# Episode 1247, Total Reward: 10365.78, Epsilon: 0.010
# Episode 1248, Total Reward: 10346.18, Epsilon: 0.010
# Episode 1249, Total Reward: 10297.30, Epsilon: 0.010
# Episode 1250, Total Reward: 10419.58, Epsilon: 0.010
# Episode 1251, Total Reward: 10347.71, Epsilon: 0.010
# Episode 1252, Total Reward: 10386.12, Epsilon: 0.010
# Episode 1253, Total Reward: 10392.91, Epsilon: 0.010
# Episode 1254, Total Reward: 10402.65, Epsilon: 0.010
# Episode 1255, Total Reward: 10414.17, Epsilon: 0.010
# Episode 1256, Total Reward: 10385.40, Epsilon: 0.010
# Episode 1257, Total Reward: 10364.31, Epsilon: 0.010
# Episode 1258, Total Reward: 10352.32, Epsilon: 0.010
# Episode 1259, Total Reward: 10339.95, Epsilon: 0.010
# Episode 1260, Total Reward: 10390.35, Epsilon: 0.010
# Episode 1261, Total Reward: 10390.29, Epsilon: 0.010
# Episode 1262, Total Reward: 10395.37, Epsilon: 0.010
# Episode 1263, Total Reward: 10403.60, Epsilon: 0.010
# Episode 1264, Total Reward: 10407.48, Epsilon: 0.010
# Episode 1265, Total Reward: 10390.29, Epsilon: 0.010
# Episode 1266, Total Reward: 10379.47, Epsilon: 0.010
# Episode 1267, Total Reward: 10401.21, Epsilon: 0.010
# Episode 1268, Total Reward: 10388.31, Epsilon: 0.010
# Episode 1269, Total Reward: 10376.38, Epsilon: 0.010
# Episode 1270, Total Reward: 10375.55, Epsilon: 0.010
# Episode 1271, Total Reward: 10395.17, Epsilon: 0.010
# Episode 1272, Total Reward: 10413.32, Epsilon: 0.010
# Episode 1273, Total Reward: 7059.62, Epsilon: 0.010
# Episode 1274, Total Reward: 9953.91, Epsilon: 0.010
# Episode 1275, Total Reward: 6438.66, Epsilon: 0.010
# Episode 1276, Total Reward: 10097.37, Epsilon: 0.010
# Episode 1277, Total Reward: 10406.76, Epsilon: 0.010
# Episode 1278, Total Reward: 6740.02, Epsilon: 0.010
# Episode 1279, Total Reward: 9940.39, Epsilon: 0.010
# Episode 1280, Total Reward: 6557.67, Epsilon: 0.010
# Episode 1281, Total Reward: 9485.35, Epsilon: 0.010
# Episode 1282, Total Reward: 8241.83, Epsilon: 0.010
# Episode 1283, Total Reward: 9618.89, Epsilon: 0.010
# Episode 1284, Total Reward: 9335.54, Epsilon: 0.010
# Episode 1285, Total Reward: 8549.51, Epsilon: 0.010
# Episode 1286, Total Reward: 6728.07, Epsilon: 0.010
# Episode 1287, Total Reward: 8081.85, Epsilon: 0.010
# Episode 1288, Total Reward: 9944.68, Epsilon: 0.010
# Episode 1289, Total Reward: 9645.51, Epsilon: 0.010
# Episode 1290, Total Reward: 10395.66, Epsilon: 0.010
# Episode 1291, Total Reward: 10354.31, Epsilon: 0.010
# Episode 1292, Total Reward: 8569.91, Epsilon: 0.010
# Episode 1293, Total Reward: 10384.43, Epsilon: 0.010
# Episode 1294, Total Reward: 9339.53, Epsilon: 0.010
# Episode 1295, Total Reward: 10375.64, Epsilon: 0.010
# Episode 1296, Total Reward: 10382.52, Epsilon: 0.010
# Episode 1297, Total Reward: 10374.67, Epsilon: 0.010
# Episode 1298, Total Reward: 10369.81, Epsilon: 0.010
# Episode 1299, Total Reward: 10397.51, Epsilon: 0.010
# Episode 1300, Total Reward: 10379.17, Epsilon: 0.010
# Episode 1301, Total Reward: 10397.34, Epsilon: 0.010
# Episode 1302, Total Reward: 10383.80, Epsilon: 0.010
# Episode 1303, Total Reward: 10378.32, Epsilon: 0.010
# Episode 1304, Total Reward: 10382.78, Epsilon: 0.010
# Episode 1305, Total Reward: 10418.69, Epsilon: 0.010
# Episode 1306, Total Reward: 10302.43, Epsilon: 0.010
# Episode 1307, Total Reward: 10404.83, Epsilon: 0.010
# Episode 1308, Total Reward: 10356.59, Epsilon: 0.010
# Episode 1309, Total Reward: 10376.21, Epsilon: 0.010
# Episode 1310, Total Reward: 10404.71, Epsilon: 0.010
# Episode 1311, Total Reward: 10391.43, Epsilon: 0.010
# Episode 1312, Total Reward: 10405.42, Epsilon: 0.010
# Episode 1313, Total Reward: 10366.86, Epsilon: 0.010
# Episode 1314, Total Reward: 10364.36, Epsilon: 0.010
# Episode 1315, Total Reward: 10386.00, Epsilon: 0.010
# Episode 1316, Total Reward: 10327.34, Epsilon: 0.010
# Episode 1317, Total Reward: 10379.50, Epsilon: 0.010
# Episode 1318, Total Reward: 10371.22, Epsilon: 0.010
# Episode 1319, Total Reward: 10380.81, Epsilon: 0.010
# Episode 1320, Total Reward: 10414.85, Epsilon: 0.010
# Episode 1321, Total Reward: 10379.26, Epsilon: 0.010
# Episode 1322, Total Reward: 10394.68, Epsilon: 0.010
# Episode 1323, Total Reward: 10381.84, Epsilon: 0.010
# Episode 1324, Total Reward: 10415.08, Epsilon: 0.010
# Episode 1325, Total Reward: 10387.87, Epsilon: 0.010
# Episode 1326, Total Reward: 10403.38, Epsilon: 0.010
# Episode 1327, Total Reward: 10386.67, Epsilon: 0.010
# Episode 1328, Total Reward: 10401.85, Epsilon: 0.010
# Episode 1329, Total Reward: 10398.50, Epsilon: 0.010
# Episode 1330, Total Reward: 10353.74, Epsilon: 0.010
# Episode 1331, Total Reward: 10368.64, Epsilon: 0.010
# Episode 1332, Total Reward: 10375.64, Epsilon: 0.010
# Episode 1333, Total Reward: 10402.99, Epsilon: 0.010
# Episode 1334, Total Reward: 10390.72, Epsilon: 0.010
# Episode 1335, Total Reward: 10430.11, Epsilon: 0.010
# Episode 1336, Total Reward: 10411.04, Epsilon: 0.010
# Episode 1337, Total Reward: 10391.77, Epsilon: 0.010
# Episode 1338, Total Reward: 10409.07, Epsilon: 0.010
# Episode 1339, Total Reward: 10411.79, Epsilon: 0.010
# Episode 1340, Total Reward: 10392.96, Epsilon: 0.010
# Episode 1341, Total Reward: 10386.25, Epsilon: 0.010
# Episode 1342, Total Reward: 10366.14, Epsilon: 0.010
# Episode 1343, Total Reward: 10337.57, Epsilon: 0.010
# Episode 1344, Total Reward: 10375.65, Epsilon: 0.010
# Episode 1345, Total Reward: 10394.50, Epsilon: 0.010
# Episode 1346, Total Reward: 10323.23, Epsilon: 0.010
# Episode 1347, Total Reward: 10326.48, Epsilon: 0.010
# Episode 1348, Total Reward: 10370.25, Epsilon: 0.010
# Episode 1349, Total Reward: 10346.59, Epsilon: 0.010
# Episode 1350, Total Reward: 10366.78, Epsilon: 0.010
# Episode 1351, Total Reward: 10350.00, Epsilon: 0.010
# Episode 1352, Total Reward: 10387.64, Epsilon: 0.010
# Episode 1353, Total Reward: 10334.03, Epsilon: 0.010
# Episode 1354, Total Reward: 10377.20, Epsilon: 0.010
# Episode 1355, Total Reward: 10374.52, Epsilon: 0.010
# Episode 1356, Total Reward: 10376.42, Epsilon: 0.010
# Episode 1357, Total Reward: 10399.24, Epsilon: 0.010
# Episode 1358, Total Reward: 10383.20, Epsilon: 0.010
# Episode 1359, Total Reward: 10379.19, Epsilon: 0.010
# Episode 1360, Total Reward: 10386.19, Epsilon: 0.010
# Episode 1361, Total Reward: 10394.54, Epsilon: 0.010
# Episode 1362, Total Reward: 10355.30, Epsilon: 0.010
# Episode 1363, Total Reward: 10382.03, Epsilon: 0.010
# Episode 1364, Total Reward: 10353.01, Epsilon: 0.010
# Episode 1365, Total Reward: 10406.98, Epsilon: 0.010
# Episode 1366, Total Reward: 10401.02, Epsilon: 0.010
# Episode 1367, Total Reward: 10413.19, Epsilon: 0.010
# Episode 1368, Total Reward: 10357.28, Epsilon: 0.010
# Episode 1369, Total Reward: 10371.76, Epsilon: 0.010
# Episode 1370, Total Reward: 10365.86, Epsilon: 0.010
# Episode 1371, Total Reward: 10401.34, Epsilon: 0.010
# Episode 1372, Total Reward: 10437.49, Epsilon: 0.010
# Episode 1373, Total Reward: 10359.36, Epsilon: 0.010
# Episode 1374, Total Reward: 10389.41, Epsilon: 0.010
# Episode 1375, Total Reward: 10375.85, Epsilon: 0.010
# Episode 1376, Total Reward: 10317.92, Epsilon: 0.010
# Episode 1377, Total Reward: 10383.63, Epsilon: 0.010
# Episode 1378, Total Reward: 10312.01, Epsilon: 0.010
# Episode 1379, Total Reward: 10357.58, Epsilon: 0.010
# Episode 1380, Total Reward: 10364.27, Epsilon: 0.010
# Episode 1381, Total Reward: 10384.55, Epsilon: 0.010
# Episode 1382, Total Reward: 10327.48, Epsilon: 0.010
# Episode 1383, Total Reward: 10388.70, Epsilon: 0.010
# Episode 1384, Total Reward: 10407.05, Epsilon: 0.010
# Episode 1385, Total Reward: 10396.94, Epsilon: 0.010
# Episode 1386, Total Reward: 10398.05, Epsilon: 0.010
# Episode 1387, Total Reward: 10336.95, Epsilon: 0.010
# Episode 1388, Total Reward: 10356.47, Epsilon: 0.010
# Episode 1389, Total Reward: 10418.21, Epsilon: 0.010
# Episode 1390, Total Reward: 10383.90, Epsilon: 0.010
# Episode 1391, Total Reward: 10376.03, Epsilon: 0.010
# Episode 1392, Total Reward: 10398.61, Epsilon: 0.010
# Episode 1393, Total Reward: 10380.29, Epsilon: 0.010
# Episode 1394, Total Reward: 10395.31, Epsilon: 0.010
# Episode 1395, Total Reward: 10370.67, Epsilon: 0.010
# Episode 1396, Total Reward: 10354.18, Epsilon: 0.010
# Episode 1397, Total Reward: 10424.21, Epsilon: 0.010
# Episode 1398, Total Reward: 10375.19, Epsilon: 0.010
# Episode 1399, Total Reward: 10371.47, Epsilon: 0.010
# Episode 1400, Total Reward: 10384.89, Epsilon: 0.010
# Episode 1401, Total Reward: 10380.17, Epsilon: 0.010
# Episode 1402, Total Reward: 10375.63, Epsilon: 0.010
# Episode 1403, Total Reward: 10369.69, Epsilon: 0.010
# Episode 1404, Total Reward: 10377.96, Epsilon: 0.010
# Episode 1405, Total Reward: 10377.86, Epsilon: 0.010
# Episode 1406, Total Reward: 10411.25, Epsilon: 0.010
# Episode 1407, Total Reward: 10334.01, Epsilon: 0.010
# Episode 1408, Total Reward: 10402.21, Epsilon: 0.010
# Episode 1409, Total Reward: 10396.48, Epsilon: 0.010
# Episode 1410, Total Reward: 10382.00, Epsilon: 0.010
# Episode 1411, Total Reward: 10401.22, Epsilon: 0.010
# Episode 1412, Total Reward: 10371.37, Epsilon: 0.010
# Episode 1413, Total Reward: 10332.73, Epsilon: 0.010
# Episode 1414, Total Reward: 10400.05, Epsilon: 0.010
# Episode 1415, Total Reward: 10355.50, Epsilon: 0.010
# Episode 1416, Total Reward: 10396.43, Epsilon: 0.010
# Episode 1417, Total Reward: 10397.93, Epsilon: 0.010
# Episode 1418, Total Reward: 10406.55, Epsilon: 0.010
# Episode 1419, Total Reward: 10401.02, Epsilon: 0.010
# Episode 1420, Total Reward: 10374.99, Epsilon: 0.010
# Episode 1421, Total Reward: 10385.87, Epsilon: 0.010
# Episode 1422, Total Reward: 10421.01, Epsilon: 0.010
# Episode 1423, Total Reward: 10388.90, Epsilon: 0.010
# Episode 1424, Total Reward: 10384.52, Epsilon: 0.010
# Episode 1425, Total Reward: 8260.18, Epsilon: 0.010
# Episode 1426, Total Reward: 10376.24, Epsilon: 0.010
# Episode 1427, Total Reward: 10396.43, Epsilon: 0.010
# Episode 1428, Total Reward: 10357.17, Epsilon: 0.010
# Episode 1429, Total Reward: 10436.77, Epsilon: 0.010
# Episode 1430, Total Reward: 10379.31, Epsilon: 0.010
# Episode 1431, Total Reward: 10375.09, Epsilon: 0.010
# Episode 1432, Total Reward: 10410.77, Epsilon: 0.010
# Episode 1433, Total Reward: 10344.77, Epsilon: 0.010
# Episode 1434, Total Reward: 10367.18, Epsilon: 0.010
# Episode 1435, Total Reward: 10362.51, Epsilon: 0.010
# Episode 1436, Total Reward: 10303.25, Epsilon: 0.010
# Episode 1437, Total Reward: 10379.33, Epsilon: 0.010
# Episode 1438, Total Reward: 10403.50, Epsilon: 0.010
# Episode 1439, Total Reward: 10358.15, Epsilon: 0.010
# Episode 1440, Total Reward: 10380.53, Epsilon: 0.010
# Episode 1441, Total Reward: 10377.38, Epsilon: 0.010
# Episode 1442, Total Reward: 10383.65, Epsilon: 0.010
# Episode 1443, Total Reward: 10345.00, Epsilon: 0.010
# Episode 1444, Total Reward: 10409.22, Epsilon: 0.010
# Episode 1445, Total Reward: 10391.56, Epsilon: 0.010
# Episode 1446, Total Reward: 10412.61, Epsilon: 0.010
# Episode 1447, Total Reward: 10372.23, Epsilon: 0.010
# Episode 1448, Total Reward: 10347.22, Epsilon: 0.010
# Episode 1449, Total Reward: 10367.35, Epsilon: 0.010
# Episode 1450, Total Reward: 10393.73, Epsilon: 0.010
# Episode 1451, Total Reward: 10393.36, Epsilon: 0.010
# Episode 1452, Total Reward: 10359.71, Epsilon: 0.010
# Episode 1453, Total Reward: 10331.05, Epsilon: 0.010
# Episode 1454, Total Reward: 10377.53, Epsilon: 0.010
# Episode 1455, Total Reward: 10416.45, Epsilon: 0.010
# Episode 1456, Total Reward: 10374.42, Epsilon: 0.010
# Episode 1457, Total Reward: 10383.44, Epsilon: 0.010
# Episode 1458, Total Reward: 10343.03, Epsilon: 0.010
# Episode 1459, Total Reward: 10379.81, Epsilon: 0.010
# Episode 1460, Total Reward: 10361.07, Epsilon: 0.010
# Episode 1461, Total Reward: 10410.22, Epsilon: 0.010
# Episode 1462, Total Reward: 10365.11, Epsilon: 0.010
# Episode 1463, Total Reward: 10389.20, Epsilon: 0.010
# Episode 1464, Total Reward: 10389.46, Epsilon: 0.010
# Episode 1465, Total Reward: 10387.14, Epsilon: 0.010
# Episode 1466, Total Reward: 10338.97, Epsilon: 0.010
# Episode 1467, Total Reward: 10415.46, Epsilon: 0.010
# Episode 1468, Total Reward: 10326.41, Epsilon: 0.010
# Episode 1469, Total Reward: 10386.89, Epsilon: 0.010
# Episode 1470, Total Reward: 10380.65, Epsilon: 0.010
# Episode 1471, Total Reward: 10368.50, Epsilon: 0.010
# Episode 1472, Total Reward: 10417.77, Epsilon: 0.010
# Episode 1473, Total Reward: 10351.16, Epsilon: 0.010
# Episode 1474, Total Reward: 10415.72, Epsilon: 0.010
# Episode 1475, Total Reward: 10401.39, Epsilon: 0.010
# Episode 1476, Total Reward: 10364.62, Epsilon: 0.010
# Episode 1477, Total Reward: 10397.47, Epsilon: 0.010
# Episode 1478, Total Reward: 10381.20, Epsilon: 0.010
# Episode 1479, Total Reward: 10372.67, Epsilon: 0.010
# Episode 1480, Total Reward: 10335.39, Epsilon: 0.010
# Episode 1481, Total Reward: 10380.14, Epsilon: 0.010
# Episode 1482, Total Reward: 10404.24, Epsilon: 0.010
# Episode 1483, Total Reward: 10374.19, Epsilon: 0.010
# Episode 1484, Total Reward: 10392.10, Epsilon: 0.010
# Episode 1485, Total Reward: 10406.72, Epsilon: 0.010
# Episode 1486, Total Reward: 10381.43, Epsilon: 0.010
# Episode 1487, Total Reward: 10380.36, Epsilon: 0.010
# Episode 1488, Total Reward: 10359.33, Epsilon: 0.010
# Episode 1489, Total Reward: 10385.49, Epsilon: 0.010
# Episode 1490, Total Reward: 10361.31, Epsilon: 0.010
# Episode 1491, Total Reward: 10392.40, Epsilon: 0.010
# Episode 1492, Total Reward: 10400.13, Epsilon: 0.010
# Episode 1493, Total Reward: 10377.93, Epsilon: 0.010
# Episode 1494, Total Reward: 10408.62, Epsilon: 0.010
# Episode 1495, Total Reward: 10398.81, Epsilon: 0.010
# Episode 1496, Total Reward: 10374.40, Epsilon: 0.010
# Episode 1497, Total Reward: 10346.85, Epsilon: 0.010
# Episode 1498, Total Reward: 10362.22, Epsilon: 0.010
# Episode 1499, Total Reward: 10355.14, Epsilon: 0.010
# Episode 1500, Total Reward: 10368.44, Epsilon: 0.010
# Episode 1501, Total Reward: 10408.24, Epsilon: 0.010
# Episode 1502, Total Reward: 10389.48, Epsilon: 0.010
# Episode 1503, Total Reward: 10342.90, Epsilon: 0.010
# Episode 1504, Total Reward: 10413.56, Epsilon: 0.010
# Episode 1505, Total Reward: 10412.89, Epsilon: 0.010
# Episode 1506, Total Reward: 10398.55, Epsilon: 0.010
# Episode 1507, Total Reward: 10314.90, Epsilon: 0.010
# Episode 1508, Total Reward: 10365.91, Epsilon: 0.010
# Episode 1509, Total Reward: 10392.52, Epsilon: 0.010
# Episode 1510, Total Reward: 10333.65, Epsilon: 0.010
# Episode 1511, Total Reward: 10420.25, Epsilon: 0.010
# Episode 1512, Total Reward: 10407.78, Epsilon: 0.010
# Episode 1513, Total Reward: 10366.12, Epsilon: 0.010
# Episode 1514, Total Reward: 10401.84, Epsilon: 0.010
# Episode 1515, Total Reward: 10417.14, Epsilon: 0.010
# Episode 1516, Total Reward: 10361.14, Epsilon: 0.010
# Episode 1517, Total Reward: 10382.12, Epsilon: 0.010
# Episode 1518, Total Reward: 10334.40, Epsilon: 0.010
# Episode 1519, Total Reward: 10398.37, Epsilon: 0.010
# Episode 1520, Total Reward: 10352.29, Epsilon: 0.010
# Episode 1521, Total Reward: 10346.27, Epsilon: 0.010
# Episode 1522, Total Reward: 10387.26, Epsilon: 0.010
# Episode 1523, Total Reward: 10332.88, Epsilon: 0.010
# Episode 1524, Total Reward: 10359.51, Epsilon: 0.010
# Episode 1525, Total Reward: 10416.30, Epsilon: 0.010
# Episode 1526, Total Reward: 10393.44, Epsilon: 0.010
# Episode 1527, Total Reward: 10361.00, Epsilon: 0.010
# Episode 1528, Total Reward: 10355.60, Epsilon: 0.010
# Episode 1529, Total Reward: 10361.32, Epsilon: 0.010
# Episode 1530, Total Reward: 10361.59, Epsilon: 0.010
# Episode 1531, Total Reward: 10374.91, Epsilon: 0.010
# Episode 1532, Total Reward: 10375.58, Epsilon: 0.010
# Episode 1533, Total Reward: 10412.56, Epsilon: 0.010
# Episode 1534, Total Reward: 10347.21, Epsilon: 0.010
# Episode 1535, Total Reward: 10386.34, Epsilon: 0.010
# Episode 1536, Total Reward: 10373.00, Epsilon: 0.010
# Episode 1537, Total Reward: 10374.30, Epsilon: 0.010
# Episode 1538, Total Reward: 10394.37, Epsilon: 0.010
# Episode 1539, Total Reward: 10368.17, Epsilon: 0.010
# Episode 1540, Total Reward: 10370.73, Epsilon: 0.010
# Episode 1541, Total Reward: 10390.90, Epsilon: 0.010
# Episode 1542, Total Reward: 10395.28, Epsilon: 0.010
# Episode 1543, Total Reward: 10382.66, Epsilon: 0.010
# Episode 1544, Total Reward: 10370.29, Epsilon: 0.010
# Episode 1545, Total Reward: 10380.43, Epsilon: 0.010
# Episode 1546, Total Reward: 10392.84, Epsilon: 0.010
# Episode 1547, Total Reward: 10381.52, Epsilon: 0.010
# Episode 1548, Total Reward: 10405.82, Epsilon: 0.010
# Episode 1549, Total Reward: 10348.36, Epsilon: 0.010
# Episode 1550, Total Reward: 10426.54, Epsilon: 0.010
# Episode 1551, Total Reward: 10336.74, Epsilon: 0.010
# Episode 1552, Total Reward: 10380.48, Epsilon: 0.010
# Episode 1553, Total Reward: 10400.62, Epsilon: 0.010
# Episode 1554, Total Reward: 9936.47, Epsilon: 0.010
# Episode 1555, Total Reward: 10327.94, Epsilon: 0.010
# Episode 1556, Total Reward: 10382.31, Epsilon: 0.010
# Episode 1557, Total Reward: 10363.40, Epsilon: 0.010
# Episode 1558, Total Reward: 10394.49, Epsilon: 0.010
# Episode 1559, Total Reward: 10396.42, Epsilon: 0.010
# Episode 1560, Total Reward: 10388.42, Epsilon: 0.010
# Episode 1561, Total Reward: 10344.60, Epsilon: 0.010
# Episode 1562, Total Reward: 10392.61, Epsilon: 0.010
# Episode 1563, Total Reward: 10387.15, Epsilon: 0.010
# Episode 1564, Total Reward: 10357.55, Epsilon: 0.010
# Episode 1565, Total Reward: 10360.61, Epsilon: 0.010
# Episode 1566, Total Reward: 10414.34, Epsilon: 0.010
# Episode 1567, Total Reward: 10426.77, Epsilon: 0.010
# Episode 1568, Total Reward: 10378.93, Epsilon: 0.010
# Episode 1569, Total Reward: 10368.60, Epsilon: 0.010
# Episode 1570, Total Reward: 10411.41, Epsilon: 0.010
# Episode 1571, Total Reward: 10389.78, Epsilon: 0.010
# Episode 1572, Total Reward: 10377.07, Epsilon: 0.010
# Episode 1573, Total Reward: 10382.01, Epsilon: 0.010
# Episode 1574, Total Reward: 9443.65, Epsilon: 0.010
# Episode 1575, Total Reward: 9923.50, Epsilon: 0.010
# Episode 1576, Total Reward: 10389.39, Epsilon: 0.010
# Episode 1577, Total Reward: 10397.89, Epsilon: 0.010
# Episode 1578, Total Reward: 10394.23, Epsilon: 0.010
# Episode 1579, Total Reward: 10387.19, Epsilon: 0.010
# Episode 1580, Total Reward: 10392.31, Epsilon: 0.010
# Episode 1581, Total Reward: 10409.39, Epsilon: 0.010
# Episode 1582, Total Reward: 10365.60, Epsilon: 0.010
# Episode 1583, Total Reward: 10405.72, Epsilon: 0.010
# Episode 1584, Total Reward: 10408.96, Epsilon: 0.010
# Episode 1585, Total Reward: 10401.11, Epsilon: 0.010
# Episode 1586, Total Reward: 10367.79, Epsilon: 0.010
# Episode 1587, Total Reward: 10362.44, Epsilon: 0.010
# Episode 1588, Total Reward: 10374.58, Epsilon: 0.010
# Episode 1589, Total Reward: 10404.11, Epsilon: 0.010
# Episode 1590, Total Reward: 10371.72, Epsilon: 0.010
# Episode 1591, Total Reward: 10423.48, Epsilon: 0.010
# Episode 1592, Total Reward: 10396.54, Epsilon: 0.010
# Episode 1593, Total Reward: 10363.17, Epsilon: 0.010
# Episode 1594, Total Reward: 10384.89, Epsilon: 0.010
# Episode 1595, Total Reward: 10405.29, Epsilon: 0.010
# Episode 1596, Total Reward: 10352.39, Epsilon: 0.010
# Episode 1597, Total Reward: 10376.70, Epsilon: 0.010
# Episode 1598, Total Reward: 10397.45, Epsilon: 0.010
# Episode 1599, Total Reward: 10390.45, Epsilon: 0.010
# Episode 1600, Total Reward: 10394.82, Epsilon: 0.010
# Episode 1601, Total Reward: 10373.36, Epsilon: 0.010
# Episode 1602, Total Reward: 10384.20, Epsilon: 0.010
# Episode 1603, Total Reward: 10364.97, Epsilon: 0.010
# Episode 1604, Total Reward: 10376.87, Epsilon: 0.010
# Episode 1605, Total Reward: 10379.21, Epsilon: 0.010
# Episode 1606, Total Reward: 10400.39, Epsilon: 0.010
# Episode 1607, Total Reward: 10404.07, Epsilon: 0.010
# Episode 1608, Total Reward: 10353.30, Epsilon: 0.010
# Episode 1609, Total Reward: 10429.55, Epsilon: 0.010
# Episode 1610, Total Reward: 10364.81, Epsilon: 0.010
# Episode 1611, Total Reward: 10375.70, Epsilon: 0.010
# Episode 1612, Total Reward: 10351.14, Epsilon: 0.010
# Episode 1613, Total Reward: 10427.14, Epsilon: 0.010
# Episode 1614, Total Reward: 10381.13, Epsilon: 0.010
# Episode 1615, Total Reward: 10364.58, Epsilon: 0.010
# Episode 1616, Total Reward: 10370.54, Epsilon: 0.010
# Episode 1617, Total Reward: 10435.11, Epsilon: 0.010
# Episode 1618, Total Reward: 10390.76, Epsilon: 0.010
# Episode 1619, Total Reward: 10361.04, Epsilon: 0.010
# Episode 1620, Total Reward: 10401.76, Epsilon: 0.010
# Episode 1621, Total Reward: 10407.47, Epsilon: 0.010
# Episode 1622, Total Reward: 10371.90, Epsilon: 0.010
# Episode 1623, Total Reward: 10371.49, Epsilon: 0.010
# Episode 1624, Total Reward: 10417.68, Epsilon: 0.010
# Episode 1625, Total Reward: 10358.93, Epsilon: 0.010
# Episode 1626, Total Reward: 10407.75, Epsilon: 0.010
# Episode 1627, Total Reward: 10372.58, Epsilon: 0.010
# Episode 1628, Total Reward: 10381.27, Epsilon: 0.010
# Episode 1629, Total Reward: 10399.89, Epsilon: 0.010
# Episode 1630, Total Reward: 10412.48, Epsilon: 0.010
# Episode 1631, Total Reward: 10360.11, Epsilon: 0.010
# Episode 1632, Total Reward: 10396.18, Epsilon: 0.010
# Episode 1633, Total Reward: 10402.64, Epsilon: 0.010
# Episode 1634, Total Reward: 10344.25, Epsilon: 0.010
# Episode 1635, Total Reward: 10370.33, Epsilon: 0.010
# Episode 1636, Total Reward: 10379.83, Epsilon: 0.010
# Episode 1637, Total Reward: 10366.80, Epsilon: 0.010
# Episode 1638, Total Reward: 10378.14, Epsilon: 0.010
# Episode 1639, Total Reward: 10405.38, Epsilon: 0.010
# Episode 1640, Total Reward: 10410.50, Epsilon: 0.010
# Episode 1641, Total Reward: 10404.50, Epsilon: 0.010
# Episode 1642, Total Reward: 10359.49, Epsilon: 0.010
# Episode 1643, Total Reward: 10384.86, Epsilon: 0.010
# Episode 1644, Total Reward: 10390.81, Epsilon: 0.010
# Episode 1645, Total Reward: 10372.96, Epsilon: 0.010
# Episode 1646, Total Reward: 10364.09, Epsilon: 0.010
# Episode 1647, Total Reward: 10371.88, Epsilon: 0.010
# Episode 1648, Total Reward: 10381.38, Epsilon: 0.010
# Episode 1649, Total Reward: 10403.68, Epsilon: 0.010
# Episode 1650, Total Reward: 10387.09, Epsilon: 0.010
# Episode 1651, Total Reward: 10401.79, Epsilon: 0.010
# Episode 1652, Total Reward: 10393.45, Epsilon: 0.010
# Episode 1653, Total Reward: 10386.71, Epsilon: 0.010
# Episode 1654, Total Reward: 10394.77, Epsilon: 0.010
# Episode 1655, Total Reward: 10331.19, Epsilon: 0.010
# Episode 1656, Total Reward: 10367.25, Epsilon: 0.010
# Episode 1657, Total Reward: 10331.08, Epsilon: 0.010
# Episode 1658, Total Reward: 10402.96, Epsilon: 0.010
# Episode 1659, Total Reward: 10376.67, Epsilon: 0.010
# Episode 1660, Total Reward: 10373.65, Epsilon: 0.010
# Episode 1661, Total Reward: 10378.16, Epsilon: 0.010
# Episode 1662, Total Reward: 10377.13, Epsilon: 0.010
# Episode 1663, Total Reward: 10405.38, Epsilon: 0.010
# Episode 1664, Total Reward: 10397.50, Epsilon: 0.010
# Episode 1665, Total Reward: 10421.73, Epsilon: 0.010
# Episode 1666, Total Reward: 10416.05, Epsilon: 0.010
# Episode 1667, Total Reward: 10381.37, Epsilon: 0.010
# Episode 1668, Total Reward: 10413.70, Epsilon: 0.010
# Episode 1669, Total Reward: 10352.90, Epsilon: 0.010
# Episode 1670, Total Reward: 10374.43, Epsilon: 0.010
# Episode 1671, Total Reward: 10383.56, Epsilon: 0.010
# Episode 1672, Total Reward: 10413.73, Epsilon: 0.010
# Episode 1673, Total Reward: 10399.39, Epsilon: 0.010
# Episode 1674, Total Reward: 10352.80, Epsilon: 0.010
# Episode 1675, Total Reward: 10379.84, Epsilon: 0.010
# Episode 1676, Total Reward: 10368.33, Epsilon: 0.010
# Episode 1677, Total Reward: 10407.45, Epsilon: 0.010
# Episode 1678, Total Reward: 10391.37, Epsilon: 0.010
# Episode 1679, Total Reward: 10419.65, Epsilon: 0.010
# Episode 1680, Total Reward: 10367.46, Epsilon: 0.010
# Episode 1681, Total Reward: 10384.14, Epsilon: 0.010
# Episode 1682, Total Reward: 10384.41, Epsilon: 0.010
# Episode 1683, Total Reward: 10389.99, Epsilon: 0.010
# Episode 1684, Total Reward: 10339.81, Epsilon: 0.010
# Episode 1685, Total Reward: 10353.42, Epsilon: 0.010
# Episode 1686, Total Reward: 10390.24, Epsilon: 0.010
# Episode 1687, Total Reward: 10308.71, Epsilon: 0.010
# Episode 1688, Total Reward: 10411.53, Epsilon: 0.010
# Episode 1689, Total Reward: 10403.13, Epsilon: 0.010
# Episode 1690, Total Reward: 10412.19, Epsilon: 0.010
# Episode 1691, Total Reward: 10415.37, Epsilon: 0.010
# Episode 1692, Total Reward: 10376.40, Epsilon: 0.010
# Episode 1693, Total Reward: 10405.76, Epsilon: 0.010
# Episode 1694, Total Reward: 10409.89, Epsilon: 0.010
# Episode 1695, Total Reward: 10420.81, Epsilon: 0.010
# Episode 1696, Total Reward: 10409.10, Epsilon: 0.010
# Episode 1697, Total Reward: 10352.50, Epsilon: 0.010
# Episode 1698, Total Reward: 10379.21, Epsilon: 0.010
# Episode 1699, Total Reward: 10384.24, Epsilon: 0.010
# Episode 1700, Total Reward: 10381.06, Epsilon: 0.010
# Episode 1701, Total Reward: 10382.28, Epsilon: 0.010
# Episode 1702, Total Reward: 10392.76, Epsilon: 0.010
# Episode 1703, Total Reward: 10370.32, Epsilon: 0.010
# Episode 1704, Total Reward: 10362.78, Epsilon: 0.010
# Episode 1705, Total Reward: 10395.11, Epsilon: 0.010
# Episode 1706, Total Reward: 10414.95, Epsilon: 0.010
# Episode 1707, Total Reward: 10369.79, Epsilon: 0.010
# Episode 1708, Total Reward: 10361.20, Epsilon: 0.010
# Episode 1709, Total Reward: 10397.71, Epsilon: 0.010
# Episode 1710, Total Reward: 10384.67, Epsilon: 0.010
# Episode 1711, Total Reward: 10423.91, Epsilon: 0.010
# Episode 1712, Total Reward: 10419.81, Epsilon: 0.010
# Episode 1713, Total Reward: 10377.09, Epsilon: 0.010
# Episode 1714, Total Reward: 10397.87, Epsilon: 0.010
# Episode 1715, Total Reward: 10386.64, Epsilon: 0.010
# Episode 1716, Total Reward: 10369.18, Epsilon: 0.010
# Episode 1717, Total Reward: 10382.54, Epsilon: 0.010
# Episode 1718, Total Reward: 10410.94, Epsilon: 0.010
# Episode 1719, Total Reward: 10412.38, Epsilon: 0.010
# Episode 1720, Total Reward: 10404.71, Epsilon: 0.010
# Episode 1721, Total Reward: 10381.25, Epsilon: 0.010
# Episode 1722, Total Reward: 10396.60, Epsilon: 0.010
# Episode 1723, Total Reward: 10369.42, Epsilon: 0.010
# Episode 1724, Total Reward: 10424.66, Epsilon: 0.010
# Episode 1725, Total Reward: 10361.23, Epsilon: 0.010
# Episode 1726, Total Reward: 10380.37, Epsilon: 0.010
# Episode 1727, Total Reward: 10398.99, Epsilon: 0.010
# Episode 1728, Total Reward: 10397.14, Epsilon: 0.010
# Episode 1729, Total Reward: 10364.34, Epsilon: 0.010
# Episode 1730, Total Reward: 10423.43, Epsilon: 0.010
# Episode 1731, Total Reward: 10386.91, Epsilon: 0.010
# Episode 1732, Total Reward: 10382.82, Epsilon: 0.010
# Episode 1733, Total Reward: 10383.91, Epsilon: 0.010
# Episode 1734, Total Reward: 10404.46, Epsilon: 0.010
# Episode 1735, Total Reward: 10368.06, Epsilon: 0.010
# Episode 1736, Total Reward: 9168.19, Epsilon: 0.010
# Episode 1737, Total Reward: 10392.75, Epsilon: 0.010
# Episode 1738, Total Reward: 10388.18, Epsilon: 0.010
# Episode 1739, Total Reward: 10412.54, Epsilon: 0.010
# Episode 1740, Total Reward: 10366.37, Epsilon: 0.010
# Episode 1741, Total Reward: 10395.66, Epsilon: 0.010
# Episode 1742, Total Reward: 10392.72, Epsilon: 0.010
# Episode 1743, Total Reward: 10353.08, Epsilon: 0.010
# Episode 1744, Total Reward: 10378.45, Epsilon: 0.010
# Episode 1745, Total Reward: 9125.91, Epsilon: 0.010
# Episode 1746, Total Reward: 10393.17, Epsilon: 0.010
# Episode 1747, Total Reward: 10418.78, Epsilon: 0.010
# Episode 1748, Total Reward: 10405.04, Epsilon: 0.010
# Episode 1749, Total Reward: 10414.42, Epsilon: 0.010
# Episode 1750, Total Reward: 10355.40, Epsilon: 0.010
# Episode 1751, Total Reward: 10409.70, Epsilon: 0.010
# Episode 1752, Total Reward: 10352.39, Epsilon: 0.010
# Episode 1753, Total Reward: 10410.40, Epsilon: 0.010
# Episode 1754, Total Reward: 10385.06, Epsilon: 0.010
# Episode 1755, Total Reward: 10379.63, Epsilon: 0.010
# Episode 1756, Total Reward: 10328.14, Epsilon: 0.010
# Episode 1757, Total Reward: 9157.90, Epsilon: 0.010
# Episode 1758, Total Reward: 10356.44, Epsilon: 0.010
# Episode 1759, Total Reward: 10386.54, Epsilon: 0.010
# Episode 1760, Total Reward: 10366.61, Epsilon: 0.010
# Episode 1761, Total Reward: 10371.26, Epsilon: 0.010
# Episode 1762, Total Reward: 10384.71, Epsilon: 0.010
# Episode 1763, Total Reward: 10394.36, Epsilon: 0.010
# Episode 1764, Total Reward: 10420.13, Epsilon: 0.010
# Episode 1765, Total Reward: 10407.64, Epsilon: 0.010
# Episode 1766, Total Reward: 10354.01, Epsilon: 0.010
# Episode 1767, Total Reward: 10348.04, Epsilon: 0.010
# Episode 1768, Total Reward: 10407.24, Epsilon: 0.010
# Episode 1769, Total Reward: 10362.60, Epsilon: 0.010
# Episode 1770, Total Reward: 10395.31, Epsilon: 0.010
# Episode 1771, Total Reward: 10396.71, Epsilon: 0.010
# Episode 1772, Total Reward: 10378.19, Epsilon: 0.010
# Episode 1773, Total Reward: 10363.03, Epsilon: 0.010
# Episode 1774, Total Reward: 10372.84, Epsilon: 0.010
# Episode 1775, Total Reward: 10369.63, Epsilon: 0.010
# Episode 1776, Total Reward: 10380.93, Epsilon: 0.010
# Episode 1777, Total Reward: 10397.77, Epsilon: 0.010
# Episode 1778, Total Reward: 10366.09, Epsilon: 0.010
# Episode 1779, Total Reward: 10395.39, Epsilon: 0.010
# Episode 1780, Total Reward: 10411.44, Epsilon: 0.010
# Episode 1781, Total Reward: 10420.91, Epsilon: 0.010
# Episode 1782, Total Reward: 10385.28, Epsilon: 0.010
# Episode 1783, Total Reward: 10372.14, Epsilon: 0.010
# Episode 1784, Total Reward: 10377.04, Epsilon: 0.010
# Episode 1785, Total Reward: 10407.53, Epsilon: 0.010
# Episode 1786, Total Reward: 10395.41, Epsilon: 0.010
# Episode 1787, Total Reward: 10367.65, Epsilon: 0.010
# Episode 1788, Total Reward: 10370.52, Epsilon: 0.010
# Episode 1789, Total Reward: 10400.78, Epsilon: 0.010
# Episode 1790, Total Reward: 10386.17, Epsilon: 0.010
# Episode 1791, Total Reward: 10376.20, Epsilon: 0.010
# Episode 1792, Total Reward: 10373.63, Epsilon: 0.010
# Episode 1793, Total Reward: 10389.99, Epsilon: 0.010
# Episode 1794, Total Reward: 10407.12, Epsilon: 0.010
# Episode 1795, Total Reward: 10361.96, Epsilon: 0.010
# Episode 1796, Total Reward: 10359.79, Epsilon: 0.010
# Episode 1797, Total Reward: 10387.19, Epsilon: 0.010
# Episode 1798, Total Reward: 10395.68, Epsilon: 0.010
# Episode 1799, Total Reward: 10411.61, Epsilon: 0.010
# Episode 1800, Total Reward: 10356.82, Epsilon: 0.010
# Episode 1801, Total Reward: 10388.78, Epsilon: 0.010
# Episode 1802, Total Reward: 10390.31, Epsilon: 0.010
# Episode 1803, Total Reward: 10332.33, Epsilon: 0.010
# Episode 1804, Total Reward: 10378.93, Epsilon: 0.010
# Episode 1805, Total Reward: 10360.93, Epsilon: 0.010
# Episode 1806, Total Reward: 10375.46, Epsilon: 0.010
# Episode 1807, Total Reward: 10353.25, Epsilon: 0.010
# Episode 1808, Total Reward: 10393.90, Epsilon: 0.010
# Episode 1809, Total Reward: 10339.35, Epsilon: 0.010
# Episode 1810, Total Reward: 10373.72, Epsilon: 0.010
# Episode 1811, Total Reward: 10334.23, Epsilon: 0.010
# Episode 1812, Total Reward: 10393.42, Epsilon: 0.010
# Episode 1813, Total Reward: 10425.56, Epsilon: 0.010
# Episode 1814, Total Reward: 10378.70, Epsilon: 0.010
# Episode 1815, Total Reward: 10397.18, Epsilon: 0.010
# Episode 1816, Total Reward: 10347.89, Epsilon: 0.010
# Episode 1817, Total Reward: 10340.34, Epsilon: 0.010
# Episode 1818, Total Reward: 10354.46, Epsilon: 0.010
# Episode 1819, Total Reward: 10405.80, Epsilon: 0.010
# Episode 1820, Total Reward: 10379.97, Epsilon: 0.010
# Episode 1821, Total Reward: 10382.30, Epsilon: 0.010
# Episode 1822, Total Reward: 10335.48, Epsilon: 0.010
# Episode 1823, Total Reward: 10377.70, Epsilon: 0.010
# Episode 1824, Total Reward: 10354.75, Epsilon: 0.010
# Episode 1825, Total Reward: 10366.68, Epsilon: 0.010
# Episode 1826, Total Reward: 10376.61, Epsilon: 0.010
# Episode 1827, Total Reward: 10405.16, Epsilon: 0.010
# Episode 1828, Total Reward: 10363.03, Epsilon: 0.010
# Episode 1829, Total Reward: 10390.89, Epsilon: 0.010
# Episode 1830, Total Reward: 10361.21, Epsilon: 0.010
# Episode 1831, Total Reward: 10391.72, Epsilon: 0.010
# Episode 1832, Total Reward: 10369.42, Epsilon: 0.010
# Episode 1833, Total Reward: 10344.32, Epsilon: 0.010
# Episode 1834, Total Reward: 10394.74, Epsilon: 0.010
# Episode 1835, Total Reward: 10398.81, Epsilon: 0.010
# Episode 1836, Total Reward: 10394.08, Epsilon: 0.010
# Episode 1837, Total Reward: 10365.82, Epsilon: 0.010
# Episode 1838, Total Reward: 10377.74, Epsilon: 0.010
# Episode 1839, Total Reward: 10390.43, Epsilon: 0.010
# Episode 1840, Total Reward: 10379.32, Epsilon: 0.010
# Episode 1841, Total Reward: 10371.90, Epsilon: 0.010
# Episode 1842, Total Reward: 10339.76, Epsilon: 0.010
# Episode 1843, Total Reward: 10408.01, Epsilon: 0.010
# Episode 1844, Total Reward: 10393.55, Epsilon: 0.010
# Episode 1845, Total Reward: 10384.87, Epsilon: 0.010
# Episode 1846, Total Reward: 10412.41, Epsilon: 0.010
# Episode 1847, Total Reward: 10403.73, Epsilon: 0.010
# Episode 1848, Total Reward: 10401.06, Epsilon: 0.010
# Episode 1849, Total Reward: 10381.59, Epsilon: 0.010
# Episode 1850, Total Reward: 10337.40, Epsilon: 0.010
# Episode 1851, Total Reward: 10402.11, Epsilon: 0.010
# Episode 1852, Total Reward: 10382.73, Epsilon: 0.010
# Episode 1853, Total Reward: 10381.58, Epsilon: 0.010
# Episode 1854, Total Reward: 10382.76, Epsilon: 0.010
# Episode 1855, Total Reward: 10395.86, Epsilon: 0.010
# Episode 1856, Total Reward: 10346.16, Epsilon: 0.010
# Episode 1857, Total Reward: 10396.30, Epsilon: 0.010
# Episode 1858, Total Reward: 10377.80, Epsilon: 0.010
# Episode 1859, Total Reward: 10421.52, Epsilon: 0.010
# Episode 1860, Total Reward: 10376.15, Epsilon: 0.010
# Episode 1861, Total Reward: 10371.01, Epsilon: 0.010
# Episode 1862, Total Reward: 10379.76, Epsilon: 0.010
# Episode 1863, Total Reward: 10385.90, Epsilon: 0.010
# Episode 1864, Total Reward: 10392.41, Epsilon: 0.010
# Episode 1865, Total Reward: 10397.66, Epsilon: 0.010
# Episode 1866, Total Reward: 10378.76, Epsilon: 0.010
# Episode 1867, Total Reward: 10390.11, Epsilon: 0.010
# Episode 1868, Total Reward: 10377.77, Epsilon: 0.010
# Episode 1869, Total Reward: 10365.11, Epsilon: 0.010
# Episode 1870, Total Reward: 10354.77, Epsilon: 0.010
# Episode 1871, Total Reward: 10398.07, Epsilon: 0.010
# Episode 1872, Total Reward: 10376.40, Epsilon: 0.010
# Episode 1873, Total Reward: 10387.50, Epsilon: 0.010
# Episode 1874, Total Reward: 10370.01, Epsilon: 0.010
# Episode 1875, Total Reward: 10388.25, Epsilon: 0.010
# Episode 1876, Total Reward: 10370.41, Epsilon: 0.010
# Episode 1877, Total Reward: 10411.55, Epsilon: 0.010
# Episode 1878, Total Reward: 10387.07, Epsilon: 0.010
# Episode 1879, Total Reward: 10373.64, Epsilon: 0.010
# Episode 1880, Total Reward: 10378.82, Epsilon: 0.010
# Episode 1881, Total Reward: 10380.45, Epsilon: 0.010
# Episode 1882, Total Reward: 10370.26, Epsilon: 0.010
# Episode 1883, Total Reward: 10396.62, Epsilon: 0.010
# Episode 1884, Total Reward: 10406.98, Epsilon: 0.010
# Episode 1885, Total Reward: 10358.28, Epsilon: 0.010
# Episode 1886, Total Reward: 10407.11, Epsilon: 0.010
# Episode 1887, Total Reward: 10388.00, Epsilon: 0.010
# Episode 1888, Total Reward: 10406.48, Epsilon: 0.010
# Episode 1889, Total Reward: 10383.72, Epsilon: 0.010
# Episode 1890, Total Reward: 10378.19, Epsilon: 0.010
# Episode 1891, Total Reward: 10405.69, Epsilon: 0.010
# Episode 1892, Total Reward: 10378.24, Epsilon: 0.010
# Episode 1893, Total Reward: 10346.21, Epsilon: 0.010
# Episode 1894, Total Reward: 10393.93, Epsilon: 0.010
# Episode 1895, Total Reward: 10421.01, Epsilon: 0.010
# Episode 1896, Total Reward: 10355.32, Epsilon: 0.010
# Episode 1897, Total Reward: 10394.62, Epsilon: 0.010
# Episode 1898, Total Reward: 10386.57, Epsilon: 0.010
# Episode 1899, Total Reward: 10354.70, Epsilon: 0.010
# Episode 1900, Total Reward: 1044.09, Epsilon: 0.010
# Episode 1901, Total Reward: 9988.83, Epsilon: 0.010
# Episode 1902, Total Reward: 10371.66, Epsilon: 0.010
# Episode 1903, Total Reward: 10351.21, Epsilon: 0.010
# Episode 1904, Total Reward: 10395.24, Epsilon: 0.010
# Episode 1905, Total Reward: 10388.53, Epsilon: 0.010
# ...
# Episode 5715, Total Reward: 10422.89, Epsilon: 0.010
# Episode 5716, Total Reward: 10376.98, Epsilon: 0.010
# Episode 5717, Total Reward: 10374.36, Epsilon: 0.010
# Episode 5718, Total Reward: 10355.08, Epsilon: 0.010
# Episode 5719, Total Reward: 10381.95, Epsilon: 0.010
# Episode 5720, Total Reward: 10406.39, Epsilon: 0.010
# Episode 5721, Total Reward: 10383.01, Epsilon: 0.010
# Episode 5722, Total Reward: 10399.92, Epsilon: 0.010
# Episode 5723, Total Reward: 10322.19, Epsilon: 0.010
# Episode 5724, Total Reward: 10384.16, Epsilon: 0.010
# Episode 5725, Total Reward: 10367.25, Epsilon: 0.010
# Episode 5726, Total Reward: 10380.44, Epsilon: 0.010
# Episode 5727, Total Reward: 10373.05, Epsilon: 0.010
# Episode 5728, Total Reward: 10439.80, Epsilon: 0.010
# Episode 5729, Total Reward: 10352.27, Epsilon: 0.010
# Episode 5730, Total Reward: 10390.48, Epsilon: 0.010
# Episode 5731, Total Reward: 10383.73, Epsilon: 0.010
# Episode 5732, Total Reward: 10350.61, Epsilon: 0.010
# Episode 5733, Total Reward: 10367.72, Epsilon: 0.010
# Episode 5734, Total Reward: 10414.48, Epsilon: 0.010
# Episode 5735, Total Reward: 10390.90, Epsilon: 0.010
# Episode 5736, Total Reward: 10389.73, Epsilon: 0.010
# Episode 5737, Total Reward: 10411.37, Epsilon: 0.010
# Episode 5738, Total Reward: 10383.73, Epsilon: 0.010
# Episode 5739, Total Reward: 10354.06, Epsilon: 0.010
# Episode 5740, Total Reward: 10385.77, Epsilon: 0.010
# Episode 5741, Total Reward: 10390.48, Epsilon: 0.010
# Episode 5742, Total Reward: 10417.99, Epsilon: 0.010
# Episode 5743, Total Reward: 10391.56, Epsilon: 0.010
# Episode 5744, Total Reward: 10419.03, Epsilon: 0.010
# Episode 5745, Total Reward: 10403.69, Epsilon: 0.010
# Episode 5746, Total Reward: 10370.37, Epsilon: 0.010
# Episode 5747, Total Reward: 10363.66, Epsilon: 0.010
# Episode 5748, Total Reward: 10385.24, Epsilon: 0.010
# Episode 5749, Total Reward: 10362.01, Epsilon: 0.010
# Episode 5750, Total Reward: 10387.22, Epsilon: 0.010
# Episode 5751, Total Reward: 10390.33, Epsilon: 0.010
# Episode 5752, Total Reward: 10411.92, Epsilon: 0.010
# Episode 5753, Total Reward: 10388.33, Epsilon: 0.010
# Episode 5754, Total Reward: 10414.64, Epsilon: 0.010
# Episode 5755, Total Reward: 10371.47, Epsilon: 0.010
# Episode 5756, Total Reward: 10420.82, Epsilon: 0.010
# Episode 5757, Total Reward: 10413.98, Epsilon: 0.010
# Episode 5758, Total Reward: 10402.70, Epsilon: 0.010
# Episode 5759, Total Reward: 10388.64, Epsilon: 0.010
# Episode 5760, Total Reward: 10395.97, Epsilon: 0.010
# Episode 5761, Total Reward: 10385.46, Epsilon: 0.010
# Episode 5762, Total Reward: 10419.76, Epsilon: 0.010
# Episode 5763, Total Reward: 10350.40, Epsilon: 0.010
# Episode 5764, Total Reward: 10326.20, Epsilon: 0.010
# Episode 5765, Total Reward: 10346.49, Epsilon: 0.010
# Episode 5766, Total Reward: 10339.56, Epsilon: 0.010
# Episode 5767, Total Reward: 10342.96, Epsilon: 0.010
# Episode 5768, Total Reward: 10415.01, Epsilon: 0.010
# Episode 5769, Total Reward: 10329.18, Epsilon: 0.010
# Episode 5770, Total Reward: 10364.27, Epsilon: 0.010
# Episode 5771, Total Reward: 10387.63, Epsilon: 0.010
# Episode 5772, Total Reward: 10389.35, Epsilon: 0.010
# Episode 5773, Total Reward: 10350.38, Epsilon: 0.010
# Episode 5774, Total Reward: 10405.09, Epsilon: 0.010
# Episode 5775, Total Reward: 10374.69, Epsilon: 0.010
# Episode 5776, Total Reward: 10382.16, Epsilon: 0.010
# Episode 5777, Total Reward: 10388.79, Epsilon: 0.010
# Episode 5778, Total Reward: 10389.67, Epsilon: 0.010
# Episode 5779, Total Reward: 10396.94, Epsilon: 0.010
# Episode 5780, Total Reward: 10393.01, Epsilon: 0.010
# Episode 5781, Total Reward: 10379.44, Epsilon: 0.010
# Episode 5782, Total Reward: 10336.19, Epsilon: 0.010
# Episode 5783, Total Reward: 10398.37, Epsilon: 0.010
# Episode 5784, Total Reward: 10351.28, Epsilon: 0.010
# Episode 5785, Total Reward: 10365.28, Epsilon: 0.010
# Episode 5786, Total Reward: 10408.33, Epsilon: 0.010
# Episode 5787, Total Reward: 10404.76, Epsilon: 0.010
# Episode 5788, Total Reward: 10406.59, Epsilon: 0.010
# Episode 5789, Total Reward: 10396.91, Epsilon: 0.010
# Episode 5790, Total Reward: 10382.39, Epsilon: 0.010
# Episode 5791, Total Reward: 10375.34, Epsilon: 0.010
# Episode 5792, Total Reward: 10387.35, Epsilon: 0.010
# Episode 5793, Total Reward: 10318.72, Epsilon: 0.010
# Episode 5794, Total Reward: 10400.50, Epsilon: 0.010
# Episode 5795, Total Reward: 10416.32, Epsilon: 0.010
# Episode 5796, Total Reward: 10368.28, Epsilon: 0.010
# Episode 5797, Total Reward: 10367.91, Epsilon: 0.010
# Episode 5798, Total Reward: 10416.63, Epsilon: 0.010
# Episode 5799, Total Reward: 10388.44, Epsilon: 0.010
# Episode 5800, Total Reward: 10409.30, Epsilon: 0.010
# Episode 5801, Total Reward: 10384.91, Epsilon: 0.010
# Episode 5802, Total Reward: 10382.70, Epsilon: 0.010
# Episode 5803, Total Reward: 10378.75, Epsilon: 0.010
# Episode 5804, Total Reward: 10366.85, Epsilon: 0.010
# Episode 5805, Total Reward: 10389.99, Epsilon: 0.010
# Episode 5806, Total Reward: 10350.46, Epsilon: 0.010
# Episode 5807, Total Reward: 10402.82, Epsilon: 0.010
# Episode 5808, Total Reward: 10396.45, Epsilon: 0.010
# Episode 5809, Total Reward: 10366.45, Epsilon: 0.010
# Episode 5810, Total Reward: 10341.81, Epsilon: 0.010
# Episode 5811, Total Reward: 10400.11, Epsilon: 0.010
# Episode 5812, Total Reward: 10425.53, Epsilon: 0.010
# Episode 5813, Total Reward: 10384.22, Epsilon: 0.010
# Episode 5814, Total Reward: 10401.81, Epsilon: 0.010
# Episode 5815, Total Reward: 10377.36, Epsilon: 0.010
# Episode 5816, Total Reward: 10375.28, Epsilon: 0.010
# Episode 5817, Total Reward: 10395.00, Epsilon: 0.010
# Episode 5818, Total Reward: 10390.82, Epsilon: 0.010
# Episode 5819, Total Reward: 10414.37, Epsilon: 0.010
# Episode 5820, Total Reward: 10353.83, Epsilon: 0.010
# Episode 5821, Total Reward: 10407.06, Epsilon: 0.010
# Episode 5822, Total Reward: 10388.16, Epsilon: 0.010
# Episode 5823, Total Reward: 10400.79, Epsilon: 0.010
# Episode 5824, Total Reward: 10361.97, Epsilon: 0.010
# Episode 5825, Total Reward: 10365.14, Epsilon: 0.010
# Episode 5826, Total Reward: 10357.92, Epsilon: 0.010
# Episode 5827, Total Reward: 10392.29, Epsilon: 0.010
# Episode 5828, Total Reward: 10402.17, Epsilon: 0.010
# Episode 5829, Total Reward: 10400.75, Epsilon: 0.010
# Episode 5830, Total Reward: 10378.27, Epsilon: 0.010
# Episode 5831, Total Reward: 10405.45, Epsilon: 0.010
# Episode 5832, Total Reward: 10389.79, Epsilon: 0.010
# Episode 5833, Total Reward: 10371.66, Epsilon: 0.010
# Episode 5834, Total Reward: 10317.16, Epsilon: 0.010
# Episode 5835, Total Reward: 10360.90, Epsilon: 0.010
# Episode 5836, Total Reward: 10372.34, Epsilon: 0.010
# Episode 5837, Total Reward: 10351.50, Epsilon: 0.010
# Episode 5838, Total Reward: 10420.63, Epsilon: 0.010
# Episode 5839, Total Reward: 10374.93, Epsilon: 0.010
# Episode 5840, Total Reward: 10375.84, Epsilon: 0.010
# Episode 5841, Total Reward: 10426.31, Epsilon: 0.010
# Episode 5842, Total Reward: 10378.98, Epsilon: 0.010
# Episode 5843, Total Reward: 10393.14, Epsilon: 0.010
# Episode 5844, Total Reward: 10340.63, Epsilon: 0.010
# Episode 5845, Total Reward: 10371.45, Epsilon: 0.010
# Episode 5846, Total Reward: 10385.66, Epsilon: 0.010
# Episode 5847, Total Reward: 10381.92, Epsilon: 0.010
# Episode 5848, Total Reward: 10365.43, Epsilon: 0.010
# Episode 5849, Total Reward: 10389.47, Epsilon: 0.010
# Episode 5850, Total Reward: 10390.50, Epsilon: 0.010
# Episode 5851, Total Reward: 10370.27, Epsilon: 0.010
# Episode 5852, Total Reward: 10376.99, Epsilon: 0.010
# Episode 5853, Total Reward: 10396.45, Epsilon: 0.010
# Episode 5854, Total Reward: 10395.61, Epsilon: 0.010
# Episode 5855, Total Reward: 10397.76, Epsilon: 0.010
# Episode 5856, Total Reward: 10421.98, Epsilon: 0.010
# Episode 5857, Total Reward: 10401.50, Epsilon: 0.010
# Episode 5858, Total Reward: 10388.80, Epsilon: 0.010
# Episode 5859, Total Reward: 10385.16, Epsilon: 0.010
# Episode 5860, Total Reward: 10401.69, Epsilon: 0.010
# Episode 5861, Total Reward: 10406.65, Epsilon: 0.010
# Episode 5862, Total Reward: 10401.87, Epsilon: 0.010
# Episode 5863, Total Reward: 10382.87, Epsilon: 0.010
# Episode 5864, Total Reward: 10371.62, Epsilon: 0.010
# Episode 5865, Total Reward: 10396.30, Epsilon: 0.010
# Episode 5866, Total Reward: 10396.30, Epsilon: 0.010
# Episode 5867, Total Reward: 10371.45, Epsilon: 0.010
# Episode 5868, Total Reward: 10390.67, Epsilon: 0.010
# Episode 5869, Total Reward: 10411.56, Epsilon: 0.010
# Episode 5870, Total Reward: 10422.19, Epsilon: 0.010
# Episode 5871, Total Reward: 10396.28, Epsilon: 0.010
# Episode 5872, Total Reward: 10380.93, Epsilon: 0.010
# Episode 5873, Total Reward: 10408.97, Epsilon: 0.010
# Episode 5874, Total Reward: 10388.23, Epsilon: 0.010
# Episode 5875, Total Reward: 10398.49, Epsilon: 0.010
# Episode 5876, Total Reward: 10383.18, Epsilon: 0.010
# Episode 5877, Total Reward: 10371.94, Epsilon: 0.010
# Episode 5878, Total Reward: 10410.06, Epsilon: 0.010
# Episode 5879, Total Reward: 10384.26, Epsilon: 0.010
# Episode 5880, Total Reward: 10391.82, Epsilon: 0.010
# Episode 5881, Total Reward: 10356.50, Epsilon: 0.010
# Episode 5882, Total Reward: 10381.01, Epsilon: 0.010
# Episode 5883, Total Reward: 10341.68, Epsilon: 0.010
# Episode 5884, Total Reward: 10411.37, Epsilon: 0.010
# Episode 5885, Total Reward: 10384.32, Epsilon: 0.010
# Episode 5886, Total Reward: 10399.11, Epsilon: 0.010
# Episode 5887, Total Reward: 10383.45, Epsilon: 0.010
# Episode 5888, Total Reward: 10402.72, Epsilon: 0.010
# Episode 5889, Total Reward: 10409.86, Epsilon: 0.010
# Episode 5890, Total Reward: 10379.66, Epsilon: 0.010
# Episode 5891, Total Reward: 10357.88, Epsilon: 0.010
# Episode 5892, Total Reward: 10385.98, Epsilon: 0.010
# Episode 5893, Total Reward: 10383.73, Epsilon: 0.010
# Episode 5894, Total Reward: 10361.29, Epsilon: 0.010
# Episode 5895, Total Reward: 10404.02, Epsilon: 0.010
# Episode 5896, Total Reward: 10366.08, Epsilon: 0.010
# Episode 5897, Total Reward: 10409.20, Epsilon: 0.010
# Episode 5898, Total Reward: 10388.42, Epsilon: 0.010
# Episode 5899, Total Reward: 10374.65, Epsilon: 0.010
# Episode 5900, Total Reward: 10391.86, Epsilon: 0.010
# Episode 5901, Total Reward: 10380.21, Epsilon: 0.010
# Episode 5902, Total Reward: 10366.83, Epsilon: 0.010
# Episode 5903, Total Reward: 10373.68, Epsilon: 0.010
# Episode 5904, Total Reward: 10399.23, Epsilon: 0.010
# Episode 5905, Total Reward: 10360.27, Epsilon: 0.010
# Episode 5906, Total Reward: 10361.34, Epsilon: 0.010
# Episode 5907, Total Reward: 10344.47, Epsilon: 0.010
# Episode 5908, Total Reward: 10388.49, Epsilon: 0.010
# Episode 5909, Total Reward: 10385.62, Epsilon: 0.010
# Episode 5910, Total Reward: 10358.76, Epsilon: 0.010
# Episode 5911, Total Reward: 10408.13, Epsilon: 0.010
# Episode 5912, Total Reward: 10332.58, Epsilon: 0.010
# Episode 5913, Total Reward: 10370.31, Epsilon: 0.010
# Episode 5914, Total Reward: 10387.68, Epsilon: 0.010
# Episode 5915, Total Reward: 10346.03, Epsilon: 0.010
# Episode 5916, Total Reward: 10382.22, Epsilon: 0.010
# Episode 5917, Total Reward: 10396.43, Epsilon: 0.010
# Episode 5918, Total Reward: 10400.21, Epsilon: 0.010
# Episode 5919, Total Reward: 10389.43, Epsilon: 0.010
# Episode 5920, Total Reward: 10374.56, Epsilon: 0.010
# Episode 5921, Total Reward: 10336.35, Epsilon: 0.010
# Episode 5922, Total Reward: 10372.83, Epsilon: 0.010
# Episode 5923, Total Reward: 10395.81, Epsilon: 0.010
# Episode 5924, Total Reward: 10388.79, Epsilon: 0.010
# Episode 5925, Total Reward: 10355.48, Epsilon: 0.010
# Episode 5926, Total Reward: 10340.88, Epsilon: 0.010
# Episode 5927, Total Reward: 10357.29, Epsilon: 0.010
# Episode 5928, Total Reward: 10391.70, Epsilon: 0.010
# Episode 5929, Total Reward: 10410.80, Epsilon: 0.010
# Episode 5930, Total Reward: 10411.38, Epsilon: 0.010
# Episode 5931, Total Reward: 10383.21, Epsilon: 0.010
# Episode 5932, Total Reward: 10335.01, Epsilon: 0.010
# Episode 5933, Total Reward: 10402.43, Epsilon: 0.010
# Episode 5934, Total Reward: 10379.36, Epsilon: 0.010
# Episode 5935, Total Reward: 10384.97, Epsilon: 0.010
# Episode 5936, Total Reward: 10366.89, Epsilon: 0.010
# Episode 5937, Total Reward: 10398.67, Epsilon: 0.010
# Episode 5938, Total Reward: 10348.97, Epsilon: 0.010
# Episode 5939, Total Reward: 10374.00, Epsilon: 0.010
# Episode 5940, Total Reward: 10365.34, Epsilon: 0.010
# Episode 5941, Total Reward: 10379.48, Epsilon: 0.010
# Episode 5942, Total Reward: 10398.08, Epsilon: 0.010
# Episode 5943, Total Reward: 10369.57, Epsilon: 0.010
# Episode 5944, Total Reward: 10391.69, Epsilon: 0.010
# Episode 5945, Total Reward: 10383.12, Epsilon: 0.010
# Episode 5946, Total Reward: 10406.57, Epsilon: 0.010
# Episode 5947, Total Reward: 10392.77, Epsilon: 0.010
# Episode 5948, Total Reward: 10363.68, Epsilon: 0.010
# Episode 5949, Total Reward: 10365.31, Epsilon: 0.010
# Episode 5950, Total Reward: 10386.58, Epsilon: 0.010
# Episode 5951, Total Reward: 10370.19, Epsilon: 0.010
# Episode 5952, Total Reward: 10365.81, Epsilon: 0.010
# Episode 5953, Total Reward: 10374.46, Epsilon: 0.010
# Episode 5954, Total Reward: 10425.27, Epsilon: 0.010
# Episode 5955, Total Reward: 10371.81, Epsilon: 0.010
# Episode 5956, Total Reward: 10390.63, Epsilon: 0.010
# Episode 5957, Total Reward: 10338.53, Epsilon: 0.010
# Episode 5958, Total Reward: 10366.66, Epsilon: 0.010
# Episode 5959, Total Reward: 10403.10, Epsilon: 0.010
# Episode 5960, Total Reward: 10398.38, Epsilon: 0.010
# Episode 5961, Total Reward: 10379.61, Epsilon: 0.010
# Episode 5962, Total Reward: 10368.94, Epsilon: 0.010
# Episode 5963, Total Reward: 10384.11, Epsilon: 0.010
# Episode 5964, Total Reward: 10393.67, Epsilon: 0.010
# Episode 5965, Total Reward: 10375.00, Epsilon: 0.010
# Episode 5966, Total Reward: 10376.50, Epsilon: 0.010
# Episode 5967, Total Reward: 10398.40, Epsilon: 0.010
# Episode 5968, Total Reward: 10387.54, Epsilon: 0.010
# Episode 5969, Total Reward: 10420.41, Epsilon: 0.010
# Episode 5970, Total Reward: 10389.61, Epsilon: 0.010
# Episode 5971, Total Reward: 10329.48, Epsilon: 0.010
# Episode 5972, Total Reward: 10407.64, Epsilon: 0.010
# Episode 5973, Total Reward: 10393.59, Epsilon: 0.010
# Episode 5974, Total Reward: 10363.65, Epsilon: 0.010
# Episode 5975, Total Reward: 10358.34, Epsilon: 0.010
# Episode 5976, Total Reward: 10403.87, Epsilon: 0.010
# Episode 5977, Total Reward: 10405.96, Epsilon: 0.010
# Episode 5978, Total Reward: 10397.39, Epsilon: 0.010
# Episode 5979, Total Reward: 10413.32, Epsilon: 0.010
# Episode 5980, Total Reward: 10359.81, Epsilon: 0.010
# Episode 5981, Total Reward: 10344.97, Epsilon: 0.010
# Episode 5982, Total Reward: 10412.89, Epsilon: 0.010
# Episode 5983, Total Reward: 10381.12, Epsilon: 0.010
# Episode 5984, Total Reward: 10352.12, Epsilon: 0.010
# Episode 5985, Total Reward: 10413.62, Epsilon: 0.010
# Episode 5986, Total Reward: 10403.56, Epsilon: 0.010
# Episode 5987, Total Reward: 10353.51, Epsilon: 0.010
# Episode 5988, Total Reward: 10405.02, Epsilon: 0.010
# Episode 5989, Total Reward: 10365.95, Epsilon: 0.010
# Episode 5990, Total Reward: 10365.50, Epsilon: 0.010
# Episode 5991, Total Reward: 10394.62, Epsilon: 0.010
# Episode 5992, Total Reward: 10372.70, Epsilon: 0.010
# Episode 5993, Total Reward: 10406.93, Epsilon: 0.010
# Episode 5994, Total Reward: 10381.48, Epsilon: 0.010
# Episode 5995, Total Reward: 10405.76, Epsilon: 0.010
# Episode 5996, Total Reward: 10390.94, Epsilon: 0.010
# Episode 5997, Total Reward: 10367.95, Epsilon: 0.010
# Episode 5998, Total Reward: 10375.18, Epsilon: 0.010
# Episode 5999, Total Reward: 10383.72, Epsilon: 0.010
# Episode 6000, Total Reward: 10344.54, Epsilon: 0.010
# Evaluating policy using KM matching:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-4e7c31bc33fa> in <cell line: 0>()
#     300     while not done:
#     301         actions, q_matrix = km_match_posthoc(agent, state, top_15_ids)
# --> 302         next_state, rewards, done = env.step(actions)
#     303         state = next_state
#     304         total_reward += sum(rewards)
#
# <ipython-input-13-4e7c31bc33fa> in step(self, actions)
#      72             x, y, _, _ = self.trajectories[vid][self.current_step]
#      73
# ---> 74             action = actions[i]
#      75             if action == 0:
#      76                 delay = self.vehicles[vid].compDelay(cpu_cycles)
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %% [markdown]
# Working(FINAL MODEL)

# %%
import random
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt

# -------- Constants --------
m = 10**6
g = 10**9
W = 10 * m
P_u = 0.1
sigma2 = 10**(-17.4)
I = 1e-10

# -------- RSU and Vehicle --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]  # Only 2 RSUs

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

    def rsu_return_delay(self, d_n):
        rate = W * math.log2(1 + (P_u * 1e-7) / (sigma2 + I))
        return d_n / rate

    def step(self, actions):
        rewards = []
        rsu_remaining = self.rsu.resource_capacity

        for i, vid in enumerate(self.vehicle_ids):
            cpu_cycles = random.uniform(0.5, 1.2) * g
            data_size = random.uniform(0.3, 1.0) * m
            task_deadline = 1.2
            x, y, _, _ = self.trajectories[vid][self.current_step]

            action = actions[i]
            if action == 0:
                delay = self.vehicles[vid].compDelay(cpu_cycles)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 0
            else:
                comp = self.rsu.compDelay(cpu_cycles)
                t_ret = self.rsu_return_delay(data_size)
                delay = comp + t_ret
                stable = any(math.hypot(x - rx, y - ry) <= self.rsu.radius for rx, ry in self.rsu_positions)
                rsuc = 10 if delay <= task_deadline else -10
                roffsuc = 5 if stable else -5
                rsu_remaining -= 1
                self.Salloc[i] = 1

            delay_ratio = delay / max(0.0001, task_deadline)
            rtime = 5 * (1 - min(1, delay_ratio))
            reward = 0.4 * rsuc + 0.4 * rtime + 0.2 * roffsuc
            rewards.append(reward)

            self.Soff[i] = action
            self.Ssche[i] = 1 if delay <= task_deadline else 0

        self.Srest = [max(0, rsu_remaining)]
        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_state = self.Soff + self.Ssche + self.Salloc + self.Srest
        return next_state, rewards, done

# -------- Replay Memory --------
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.idx = 0

    def store(self, state, action, next_state, reward, done):
        data = (state, action, next_state, reward, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(data)
        else:
            self.buffer[self.idx] = data
        self.idx = (self.idx + 1) % self.capacity

    def sample(self, batch_size, device):
        batch = random.sample(self.buffer, batch_size)
        states, actions, next_states, rewards, dones = zip(*batch)
        return (
            torch.tensor(states, dtype=torch.float32).to(device),
            torch.tensor(actions, dtype=torch.int64).to(device),
            torch.tensor(next_states, dtype=torch.float32).to(device),
            torch.tensor(rewards, dtype=torch.float32).to(device),
            torch.tensor(dones, dtype=torch.bool).to(device)
        )

    def __len__(self):
        return len(self.buffer)

# -------- DQN Network --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- DQN Agent --------
class DQNAgent:
    def __init__(self, state_size, action_size, device):
        self.device = device
        self.epsilon = 0.9
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.discount = 0.99
        self.memory = ReplayMemory(10000)
        self.policy_net = DQNNet(state_size, action_size).to(device)
        self.target_net = DQNNet(state_size, action_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=0.0008)

    def learn(self, batch_size):
        if len(self.memory) < batch_size:
            return
        states, actions, next_states, rewards, dones = self.memory.sample(batch_size, self.device)
        q_values = self.policy_net(states).gather(1, actions.view(-1, 1))
        max_next_q = self.target_net(next_states).max(1).values
        targets = rewards + self.discount * max_next_q * (~dones)
        loss = F.mse_loss(q_values.view(-1), targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_target_net(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# -------- Action Selection (ε-greedy) --------
def select_actions_epsilon_greedy(agent, state, vehicle_ids, action_size):
    actions = []
    for _ in vehicle_ids:
        if random.random() < agent.epsilon:
            actions.append(random.randint(0, action_size - 1))
        else:
            s = torch.tensor([state], dtype=torch.float32).to(agent.device)
            with torch.no_grad():
                q_values = agent.policy_net(s).cpu().numpy().flatten()
                actions.append(np.argmax(q_values))
    return actions

# -------- Main --------
if __name__ == '__main__':
    data = np.load("test_predictions_full_300.npz")
    predicted = data['predicted']
    vehicle_ids = data['vehicle_ids']

    df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                      columns=["vehicle_id", "lat", "lon", "vx", "vy"])
    top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
    trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

    vehicles = {vid: Vehicle() for vid in top_15_ids}
    rsu = RSU()
    env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

    state_size = len(env.reset())
    action_size = 3  # 0: local, 1–3: RSUs
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    agent = DQNAgent(state_size, action_size, device)

    episodes = 6000
    reward_log = []

    for ep in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            actions = select_actions_epsilon_greedy(agent, state, top_15_ids, action_size)
            next_state, rewards, done = env.step(actions)

            for i, vid in enumerate(top_15_ids):
                action = actions[i]
                reward = rewards[i]
                agent.memory.store(state, action, next_state, reward, done)

            agent.learn(32)
            state = next_state
            total_reward += sum(rewards)

        agent.update_epsilon()
        agent.update_target_net()
        reward_log.append(total_reward)
        print(f"Episode {ep+1}, Total Reward: {total_reward:.2f}, Epsilon: {agent.epsilon:.3f}")

    torch.save(agent.policy_net.state_dict(), "dqn_multi_vehicle.pth")

    plt.plot(range(1, episodes + 1), reward_log)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("DQN Training: Reward vs Episode")
    plt.grid(True)
    plt.savefig("reward_vs_episode.png")
    plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 1001, Total Reward: 10346.62, Epsilon: 0.010
# Episode 1002, Total Reward: 10307.58, Epsilon: 0.010
# Episode 1003, Total Reward: 10306.97, Epsilon: 0.010
# Episode 1004, Total Reward: 10345.48, Epsilon: 0.010
# Episode 1005, Total Reward: 10299.09, Epsilon: 0.010
# Episode 1006, Total Reward: 10294.03, Epsilon: 0.010
# Episode 1007, Total Reward: 10304.93, Epsilon: 0.010
# Episode 1008, Total Reward: 10320.36, Epsilon: 0.010
# Episode 1009, Total Reward: 10301.86, Epsilon: 0.010
# Episode 1010, Total Reward: 10293.27, Epsilon: 0.010
# Episode 1011, Total Reward: 10294.93, Epsilon: 0.010
# Episode 1012, Total Reward: 10285.12, Epsilon: 0.010
# Episode 1013, Total Reward: 10365.97, Epsilon: 0.010
# Episode 1014, Total Reward: 10330.52, Epsilon: 0.010
# Episode 1015, Total Reward: 10284.43, Epsilon: 0.010
# Episode 1016, Total Reward: 10283.25, Epsilon: 0.010
# Episode 1017, Total Reward: 10314.05, Epsilon: 0.010
# Episode 1018, Total Reward: 10271.86, Epsilon: 0.010
# Episode 1019, Total Reward: 10264.33, Epsilon: 0.010
# Episode 1020, Total Reward: 10329.16, Epsilon: 0.010
# Episode 1021, Total Reward: 10324.54, Epsilon: 0.010
# Episode 1022, Total Reward: 10349.48, Epsilon: 0.010
# Episode 1023, Total Reward: 10348.05, Epsilon: 0.010
# Episode 1024, Total Reward: 10327.89, Epsilon: 0.010
# Episode 1025, Total Reward: 10317.58, Epsilon: 0.010
# Episode 1026, Total Reward: 10291.43, Epsilon: 0.010
# Episode 1027, Total Reward: 10348.61, Epsilon: 0.010
# Episode 1028, Total Reward: 10262.60, Epsilon: 0.010
# Episode 1029, Total Reward: 10309.30, Epsilon: 0.010
# Episode 1030, Total Reward: 10307.97, Epsilon: 0.010
# Episode 1031, Total Reward: 10332.42, Epsilon: 0.010
# Episode 1032, Total Reward: 10308.46, Epsilon: 0.010
# Episode 1033, Total Reward: 10300.62, Epsilon: 0.010
# Episode 1034, Total Reward: 10311.13, Epsilon: 0.010
# Episode 1035, Total Reward: 10335.64, Epsilon: 0.010
# Episode 1036, Total Reward: 10272.02, Epsilon: 0.010
# Episode 1037, Total Reward: 10283.75, Epsilon: 0.010
# Episode 1038, Total Reward: 10288.11, Epsilon: 0.010
# Episode 1039, Total Reward: 10318.74, Epsilon: 0.010
# Episode 1040, Total Reward: 10326.80, Epsilon: 0.010
# Episode 1041, Total Reward: 10288.36, Epsilon: 0.010
# Episode 1042, Total Reward: 10294.45, Epsilon: 0.010
# Episode 1043, Total Reward: 10291.26, Epsilon: 0.010
# Episode 1044, Total Reward: 10312.27, Epsilon: 0.010
# Episode 1045, Total Reward: 10307.48, Epsilon: 0.010
# Episode 1046, Total Reward: 10311.41, Epsilon: 0.010
# Episode 1047, Total Reward: 10274.60, Epsilon: 0.010
# Episode 1048, Total Reward: 10276.29, Epsilon: 0.010
# Episode 1049, Total Reward: 10319.79, Epsilon: 0.010
# Episode 1050, Total Reward: 10281.78, Epsilon: 0.010
# Episode 1051, Total Reward: 10310.99, Epsilon: 0.010
# Episode 1052, Total Reward: 10303.57, Epsilon: 0.010
# Episode 1053, Total Reward: 10313.47, Epsilon: 0.010
# Episode 1054, Total Reward: 10290.89, Epsilon: 0.010
# Episode 1055, Total Reward: 10313.26, Epsilon: 0.010
# Episode 1056, Total Reward: 10293.18, Epsilon: 0.010
# Episode 1057, Total Reward: 10313.10, Epsilon: 0.010
# Episode 1058, Total Reward: 10326.45, Epsilon: 0.010
# Episode 1059, Total Reward: 10284.51, Epsilon: 0.010
# Episode 1060, Total Reward: 10288.48, Epsilon: 0.010
# Episode 1061, Total Reward: 10301.82, Epsilon: 0.010
# Episode 1062, Total Reward: 10339.00, Epsilon: 0.010
# Episode 1063, Total Reward: 10295.96, Epsilon: 0.010
# Episode 1064, Total Reward: 10302.85, Epsilon: 0.010
# Episode 1065, Total Reward: 10286.17, Epsilon: 0.010
# Episode 1066, Total Reward: 10344.14, Epsilon: 0.010
# Episode 1067, Total Reward: 10345.26, Epsilon: 0.010
# Episode 1068, Total Reward: 10277.95, Epsilon: 0.010
# Episode 1069, Total Reward: 10296.89, Epsilon: 0.010
# Episode 1070, Total Reward: 10293.13, Epsilon: 0.010
# Episode 1071, Total Reward: 10306.41, Epsilon: 0.010
# Episode 1072, Total Reward: 10293.78, Epsilon: 0.010
# Episode 1073, Total Reward: 10333.81, Epsilon: 0.010
# Episode 1074, Total Reward: 10270.92, Epsilon: 0.010
# Episode 1075, Total Reward: 10293.41, Epsilon: 0.010
# Episode 1076, Total Reward: 10301.03, Epsilon: 0.010
# Episode 1077, Total Reward: 10325.06, Epsilon: 0.010
# Episode 1078, Total Reward: 10290.18, Epsilon: 0.010
# Episode 1079, Total Reward: 10300.41, Epsilon: 0.010
# Episode 1080, Total Reward: 10297.08, Epsilon: 0.010
# Episode 1081, Total Reward: 10238.60, Epsilon: 0.010
# Episode 1082, Total Reward: 10300.05, Epsilon: 0.010
# Episode 1083, Total Reward: 10326.05, Epsilon: 0.010
# Episode 1084, Total Reward: 10303.54, Epsilon: 0.010
# Episode 1085, Total Reward: 10260.46, Epsilon: 0.010
# Episode 1086, Total Reward: 10316.05, Epsilon: 0.010
# Episode 1087, Total Reward: 10311.32, Epsilon: 0.010
# Episode 1088, Total Reward: 10313.64, Epsilon: 0.010
# Episode 1089, Total Reward: 10326.21, Epsilon: 0.010
# Episode 1090, Total Reward: 9261.18, Epsilon: 0.010
# Episode 1091, Total Reward: 10302.29, Epsilon: 0.010
# Episode 1092, Total Reward: 10311.69, Epsilon: 0.010
# Episode 1093, Total Reward: 9718.02, Epsilon: 0.010
# Episode 1094, Total Reward: 10307.45, Epsilon: 0.010
# Episode 1095, Total Reward: 10317.87, Epsilon: 0.010
# Episode 1096, Total Reward: 10282.57, Epsilon: 0.010
# Episode 1097, Total Reward: 10315.83, Epsilon: 0.010
# Episode 1098, Total Reward: 10319.09, Epsilon: 0.010
# Episode 1099, Total Reward: 10308.10, Epsilon: 0.010
# Episode 1100, Total Reward: 10310.32, Epsilon: 0.010
# Episode 1101, Total Reward: 10324.15, Epsilon: 0.010
# Episode 1102, Total Reward: 10327.03, Epsilon: 0.010
# Episode 1103, Total Reward: 10315.54, Epsilon: 0.010
# Episode 1104, Total Reward: 10298.56, Epsilon: 0.010
# Episode 1105, Total Reward: 10332.16, Epsilon: 0.010
# Episode 1106, Total Reward: 10309.53, Epsilon: 0.010
# Episode 1107, Total Reward: 10309.01, Epsilon: 0.010
# Episode 1108, Total Reward: 10339.14, Epsilon: 0.010
# Episode 1109, Total Reward: 10333.31, Epsilon: 0.010
# Episode 1110, Total Reward: 10226.37, Epsilon: 0.010
# Episode 1111, Total Reward: 10354.28, Epsilon: 0.010
# Episode 1112, Total Reward: 10310.68, Epsilon: 0.010
# Episode 1113, Total Reward: 10313.14, Epsilon: 0.010
# Episode 1114, Total Reward: 10317.71, Epsilon: 0.010
# Episode 1115, Total Reward: 10253.81, Epsilon: 0.010
# Episode 1116, Total Reward: 10281.70, Epsilon: 0.010
# Episode 1117, Total Reward: 10293.03, Epsilon: 0.010
# Episode 1118, Total Reward: 10276.21, Epsilon: 0.010
# Episode 1119, Total Reward: 10260.21, Epsilon: 0.010
# Episode 1120, Total Reward: 10345.07, Epsilon: 0.010
# Episode 1121, Total Reward: 10292.01, Epsilon: 0.010
# Episode 1122, Total Reward: 10338.93, Epsilon: 0.010
# Episode 1123, Total Reward: 10318.04, Epsilon: 0.010
# Episode 1124, Total Reward: 10295.92, Epsilon: 0.010
# Episode 1125, Total Reward: 10303.84, Epsilon: 0.010
# Episode 1126, Total Reward: 10288.57, Epsilon: 0.010
# Episode 1127, Total Reward: 10344.07, Epsilon: 0.010
# Episode 1128, Total Reward: 10293.13, Epsilon: 0.010
# Episode 1129, Total Reward: 10285.18, Epsilon: 0.010
# Episode 1130, Total Reward: 10301.89, Epsilon: 0.010
# Episode 1131, Total Reward: 10366.76, Epsilon: 0.010
# Episode 1132, Total Reward: 10292.98, Epsilon: 0.010
# Episode 1133, Total Reward: 10348.82, Epsilon: 0.010
# Episode 1134, Total Reward: 10278.96, Epsilon: 0.010
# Episode 1135, Total Reward: 10303.30, Epsilon: 0.010
# Episode 1136, Total Reward: 10327.13, Epsilon: 0.010
# Episode 1137, Total Reward: 10309.30, Epsilon: 0.010
# Episode 1138, Total Reward: 10321.44, Epsilon: 0.010
# Episode 1139, Total Reward: 10328.14, Epsilon: 0.010
# Episode 1140, Total Reward: 10263.74, Epsilon: 0.010
# Episode 1141, Total Reward: 10269.97, Epsilon: 0.010
# Episode 1142, Total Reward: 10331.61, Epsilon: 0.010
# Episode 1143, Total Reward: 10338.73, Epsilon: 0.010
# Episode 1144, Total Reward: 10323.29, Epsilon: 0.010
# Episode 1145, Total Reward: 10323.43, Epsilon: 0.010
# Episode 1146, Total Reward: 10303.60, Epsilon: 0.010
# Episode 1147, Total Reward: 10327.71, Epsilon: 0.010
# Episode 1148, Total Reward: 10287.95, Epsilon: 0.010
# Episode 1149, Total Reward: 10327.32, Epsilon: 0.010
# Episode 1150, Total Reward: 10304.66, Epsilon: 0.010
# Episode 1151, Total Reward: 10310.70, Epsilon: 0.010
# Episode 1152, Total Reward: 10327.37, Epsilon: 0.010
# Episode 1153, Total Reward: 10300.91, Epsilon: 0.010
# Episode 1154, Total Reward: 10289.40, Epsilon: 0.010
# Episode 1155, Total Reward: 10305.36, Epsilon: 0.010
# Episode 1156, Total Reward: 10298.51, Epsilon: 0.010
# Episode 1157, Total Reward: 10353.27, Epsilon: 0.010
# Episode 1158, Total Reward: 10296.30, Epsilon: 0.010
# Episode 1159, Total Reward: 10337.11, Epsilon: 0.010
# Episode 1160, Total Reward: 10331.86, Epsilon: 0.010
# Episode 1161, Total Reward: 10315.83, Epsilon: 0.010
# Episode 1162, Total Reward: 10289.53, Epsilon: 0.010
# Episode 1163, Total Reward: 10333.42, Epsilon: 0.010
# Episode 1164, Total Reward: 10294.05, Epsilon: 0.010
# Episode 1165, Total Reward: 10331.53, Epsilon: 0.010
# Episode 1166, Total Reward: 10311.17, Epsilon: 0.010
# Episode 1167, Total Reward: 10283.86, Epsilon: 0.010
# Episode 1168, Total Reward: 10280.74, Epsilon: 0.010
# Episode 1169, Total Reward: 10285.27, Epsilon: 0.010
# Episode 1170, Total Reward: 10303.60, Epsilon: 0.010
# Episode 1171, Total Reward: 10287.69, Epsilon: 0.010
# Episode 1172, Total Reward: 10254.18, Epsilon: 0.010
# Episode 1173, Total Reward: 10297.81, Epsilon: 0.010
# Episode 1174, Total Reward: 10311.69, Epsilon: 0.010
# Episode 1175, Total Reward: 10312.06, Epsilon: 0.010
# Episode 1176, Total Reward: 10267.87, Epsilon: 0.010
# Episode 1177, Total Reward: 10345.81, Epsilon: 0.010
# Episode 1178, Total Reward: 10285.40, Epsilon: 0.010
# Episode 1179, Total Reward: 10306.78, Epsilon: 0.010
# Episode 1180, Total Reward: 10334.28, Epsilon: 0.010
# Episode 1181, Total Reward: 10316.31, Epsilon: 0.010
# Episode 1182, Total Reward: 10326.48, Epsilon: 0.010
# Episode 1183, Total Reward: 10282.50, Epsilon: 0.010
# Episode 1184, Total Reward: 10307.97, Epsilon: 0.010
# Episode 1185, Total Reward: 10330.27, Epsilon: 0.010
# Episode 1186, Total Reward: 10261.33, Epsilon: 0.010
# Episode 1187, Total Reward: 10331.97, Epsilon: 0.010
# Episode 1188, Total Reward: 10235.13, Epsilon: 0.010
# Episode 1189, Total Reward: 10288.55, Epsilon: 0.010
# Episode 1190, Total Reward: 10269.89, Epsilon: 0.010
# Episode 1191, Total Reward: 10325.01, Epsilon: 0.010
# Episode 1192, Total Reward: 10277.40, Epsilon: 0.010
# Episode 1193, Total Reward: 8957.99, Epsilon: 0.010
# Episode 1194, Total Reward: 10302.45, Epsilon: 0.010
# Episode 1195, Total Reward: 9108.59, Epsilon: 0.010
# Episode 1196, Total Reward: 8925.60, Epsilon: 0.010
# Episode 1197, Total Reward: 9346.66, Epsilon: 0.010
# Episode 1198, Total Reward: 10255.32, Epsilon: 0.010
# Episode 1199, Total Reward: 10319.44, Epsilon: 0.010
# Episode 1200, Total Reward: 10269.31, Epsilon: 0.010
# Episode 1201, Total Reward: 10316.76, Epsilon: 0.010
# Episode 1202, Total Reward: 10319.79, Epsilon: 0.010
# Episode 1203, Total Reward: 10271.64, Epsilon: 0.010
# Episode 1204, Total Reward: 10318.37, Epsilon: 0.010
# Episode 1205, Total Reward: 10305.00, Epsilon: 0.010
# Episode 1206, Total Reward: 10295.20, Epsilon: 0.010
# Episode 1207, Total Reward: 10235.19, Epsilon: 0.010
# Episode 1208, Total Reward: 10321.66, Epsilon: 0.010
# Episode 1209, Total Reward: 10285.78, Epsilon: 0.010
# Episode 1210, Total Reward: 10226.50, Epsilon: 0.010
# Episode 1211, Total Reward: 10329.05, Epsilon: 0.010
# Episode 1212, Total Reward: 10303.93, Epsilon: 0.010
# Episode 1213, Total Reward: 10305.73, Epsilon: 0.010
# Episode 1214, Total Reward: 10290.40, Epsilon: 0.010
# Episode 1215, Total Reward: 10305.93, Epsilon: 0.010
# Episode 1216, Total Reward: 10318.31, Epsilon: 0.010
# Episode 1217, Total Reward: 10318.91, Epsilon: 0.010
# Episode 1218, Total Reward: 10281.30, Epsilon: 0.010
# Episode 1219, Total Reward: 10249.80, Epsilon: 0.010
# Episode 1220, Total Reward: 10251.79, Epsilon: 0.010
# Episode 1221, Total Reward: 10301.20, Epsilon: 0.010
# Episode 1222, Total Reward: 10289.00, Epsilon: 0.010
# Episode 1223, Total Reward: 10288.47, Epsilon: 0.010
# Episode 1224, Total Reward: 10265.69, Epsilon: 0.010
# Episode 1225, Total Reward: 10301.31, Epsilon: 0.010
# Episode 1226, Total Reward: 10349.34, Epsilon: 0.010
# Episode 1227, Total Reward: 10294.64, Epsilon: 0.010
# Episode 1228, Total Reward: 10306.01, Epsilon: 0.010
# Episode 1229, Total Reward: 10295.86, Epsilon: 0.010
# Episode 1230, Total Reward: 10296.58, Epsilon: 0.010
# Episode 1231, Total Reward: 10293.31, Epsilon: 0.010
# Episode 1232, Total Reward: 10318.58, Epsilon: 0.010
# Episode 1233, Total Reward: 10343.26, Epsilon: 0.010
# Episode 1234, Total Reward: 10296.23, Epsilon: 0.010
# Episode 1235, Total Reward: 10284.30, Epsilon: 0.010
# Episode 1236, Total Reward: 10312.90, Epsilon: 0.010
# Episode 1237, Total Reward: 10315.95, Epsilon: 0.010
# Episode 1238, Total Reward: 10314.32, Epsilon: 0.010
# Episode 1239, Total Reward: 10315.88, Epsilon: 0.010
# Episode 1240, Total Reward: 10312.87, Epsilon: 0.010
# Episode 1241, Total Reward: 10299.47, Epsilon: 0.010
# Episode 1242, Total Reward: 10293.21, Epsilon: 0.010
# Episode 1243, Total Reward: 10319.92, Epsilon: 0.010
# Episode 1244, Total Reward: 10313.26, Epsilon: 0.010
# Episode 1245, Total Reward: 10311.11, Epsilon: 0.010
# Episode 1246, Total Reward: 10318.90, Epsilon: 0.010
# Episode 1247, Total Reward: 10269.81, Epsilon: 0.010
# Episode 1248, Total Reward: 10297.35, Epsilon: 0.010
# Episode 1249, Total Reward: 10326.66, Epsilon: 0.010
# Episode 1250, Total Reward: 10280.73, Epsilon: 0.010
# Episode 1251, Total Reward: 10354.81, Epsilon: 0.010
# Episode 1252, Total Reward: 10332.69, Epsilon: 0.010
# Episode 1253, Total Reward: 10303.66, Epsilon: 0.010
# Episode 1254, Total Reward: 10319.91, Epsilon: 0.010
# Episode 1255, Total Reward: 10292.54, Epsilon: 0.010
# Episode 1256, Total Reward: 10280.09, Epsilon: 0.010
# Episode 1257, Total Reward: 10339.83, Epsilon: 0.010
# Episode 1258, Total Reward: 10293.43, Epsilon: 0.010
# Episode 1259, Total Reward: 10326.60, Epsilon: 0.010
# Episode 1260, Total Reward: 10312.54, Epsilon: 0.010
# Episode 1261, Total Reward: 10291.96, Epsilon: 0.010
# Episode 1262, Total Reward: 10277.66, Epsilon: 0.010
# Episode 1263, Total Reward: 10302.22, Epsilon: 0.010
# Episode 1264, Total Reward: 10316.34, Epsilon: 0.010
# Episode 1265, Total Reward: 10290.20, Epsilon: 0.010
# Episode 1266, Total Reward: 10273.56, Epsilon: 0.010
# Episode 1267, Total Reward: 10308.63, Epsilon: 0.010
# Episode 1268, Total Reward: 10281.37, Epsilon: 0.010
# Episode 1269, Total Reward: 10306.10, Epsilon: 0.010
# Episode 1270, Total Reward: 10340.84, Epsilon: 0.010
# Episode 1271, Total Reward: 10286.91, Epsilon: 0.010
# Episode 1272, Total Reward: 10272.00, Epsilon: 0.010
# Episode 1273, Total Reward: 10319.69, Epsilon: 0.010
# Episode 1274, Total Reward: 10350.76, Epsilon: 0.010
# Episode 1275, Total Reward: 10284.30, Epsilon: 0.010
# Episode 1276, Total Reward: 10338.87, Epsilon: 0.010
# Episode 1277, Total Reward: 10315.34, Epsilon: 0.010
# Episode 1278, Total Reward: 10305.63, Epsilon: 0.010
# Episode 1279, Total Reward: 10091.90, Epsilon: 0.010
# Episode 1280, Total Reward: 10293.52, Epsilon: 0.010
# Episode 1281, Total Reward: 8358.30, Epsilon: 0.010
# Episode 1282, Total Reward: 7718.46, Epsilon: 0.010
# Episode 1283, Total Reward: 9083.28, Epsilon: 0.010
# Episode 1284, Total Reward: 10333.24, Epsilon: 0.010
# Episode 1285, Total Reward: 10291.69, Epsilon: 0.010
# Episode 1286, Total Reward: 9514.80, Epsilon: 0.010
# Episode 1287, Total Reward: 10317.23, Epsilon: 0.010
# Episode 1288, Total Reward: 10297.41, Epsilon: 0.010
# Episode 1289, Total Reward: 10352.82, Epsilon: 0.010
# Episode 1290, Total Reward: 10324.04, Epsilon: 0.010
# Episode 1291, Total Reward: 10340.11, Epsilon: 0.010
# Episode 1292, Total Reward: 10327.72, Epsilon: 0.010
# Episode 1293, Total Reward: 10294.52, Epsilon: 0.010
# Episode 1294, Total Reward: 10281.01, Epsilon: 0.010
# Episode 1295, Total Reward: 10309.61, Epsilon: 0.010
# Episode 1296, Total Reward: 10322.51, Epsilon: 0.010
# Episode 1297, Total Reward: 10263.69, Epsilon: 0.010
# Episode 1298, Total Reward: 10302.24, Epsilon: 0.010
# Episode 1299, Total Reward: 10299.41, Epsilon: 0.010
# Episode 1300, Total Reward: 10320.43, Epsilon: 0.010
# Episode 1301, Total Reward: 10300.87, Epsilon: 0.010
# Episode 1302, Total Reward: 10308.49, Epsilon: 0.010
# Episode 1303, Total Reward: 10307.10, Epsilon: 0.010
# Episode 1304, Total Reward: 10327.36, Epsilon: 0.010
# Episode 1305, Total Reward: 10287.18, Epsilon: 0.010
# Episode 1306, Total Reward: 10264.59, Epsilon: 0.010
# Episode 1307, Total Reward: 10308.09, Epsilon: 0.010
# Episode 1308, Total Reward: 10307.76, Epsilon: 0.010
# Episode 1309, Total Reward: 10299.44, Epsilon: 0.010
# Episode 1310, Total Reward: 10313.95, Epsilon: 0.010
# Episode 1311, Total Reward: 10296.46, Epsilon: 0.010
# Episode 1312, Total Reward: 10257.90, Epsilon: 0.010
# Episode 1313, Total Reward: 10327.66, Epsilon: 0.010
# Episode 1314, Total Reward: 10343.23, Epsilon: 0.010
# Episode 1315, Total Reward: 10280.59, Epsilon: 0.010
# Episode 1316, Total Reward: 10324.85, Epsilon: 0.010
# Episode 1317, Total Reward: 10316.13, Epsilon: 0.010
# Episode 1318, Total Reward: 10329.17, Epsilon: 0.010
# Episode 1319, Total Reward: 10311.28, Epsilon: 0.010
# Episode 1320, Total Reward: 10272.61, Epsilon: 0.010
# Episode 1321, Total Reward: 10268.48, Epsilon: 0.010
# Episode 1322, Total Reward: 10307.64, Epsilon: 0.010
# Episode 1323, Total Reward: 10305.59, Epsilon: 0.010
# Episode 1324, Total Reward: 10301.04, Epsilon: 0.010
# Episode 1325, Total Reward: 10261.20, Epsilon: 0.010
# Episode 1326, Total Reward: 10324.41, Epsilon: 0.010
# Episode 1327, Total Reward: 10231.15, Epsilon: 0.010
# Episode 1328, Total Reward: 10352.13, Epsilon: 0.010
# Episode 1329, Total Reward: 10340.41, Epsilon: 0.010
# Episode 1330, Total Reward: 10281.01, Epsilon: 0.010
# Episode 1331, Total Reward: 10327.12, Epsilon: 0.010
# Episode 1332, Total Reward: 10316.96, Epsilon: 0.010
# Episode 1333, Total Reward: 10330.81, Epsilon: 0.010
# Episode 1334, Total Reward: 10306.41, Epsilon: 0.010
# Episode 1335, Total Reward: 10321.49, Epsilon: 0.010
# Episode 1336, Total Reward: 10261.67, Epsilon: 0.010
# Episode 1337, Total Reward: 10327.50, Epsilon: 0.010
# Episode 1338, Total Reward: 10345.87, Epsilon: 0.010
# Episode 1339, Total Reward: 10318.57, Epsilon: 0.010
# Episode 1340, Total Reward: 10330.75, Epsilon: 0.010
# Episode 1341, Total Reward: 10321.38, Epsilon: 0.010
# Episode 1342, Total Reward: 10295.64, Epsilon: 0.010
# Episode 1343, Total Reward: 10340.05, Epsilon: 0.010
# Episode 1344, Total Reward: 10289.06, Epsilon: 0.010
# Episode 1345, Total Reward: 10271.85, Epsilon: 0.010
# Episode 1346, Total Reward: 10278.63, Epsilon: 0.010
# Episode 1347, Total Reward: 10301.39, Epsilon: 0.010
# Episode 1348, Total Reward: 10287.94, Epsilon: 0.010
# Episode 1349, Total Reward: 10275.34, Epsilon: 0.010
# Episode 1350, Total Reward: 10269.26, Epsilon: 0.010
# Episode 1351, Total Reward: 10336.41, Epsilon: 0.010
# Episode 1352, Total Reward: 10323.80, Epsilon: 0.010
# Episode 1353, Total Reward: 10301.27, Epsilon: 0.010
# Episode 1354, Total Reward: 10291.17, Epsilon: 0.010
# Episode 1355, Total Reward: 10281.35, Epsilon: 0.010
# Episode 1356, Total Reward: 10323.62, Epsilon: 0.010
# Episode 1357, Total Reward: 10316.72, Epsilon: 0.010
# Episode 1358, Total Reward: 10307.44, Epsilon: 0.010
# Episode 1359, Total Reward: 10339.74, Epsilon: 0.010
# Episode 1360, Total Reward: 10279.32, Epsilon: 0.010
# Episode 1361, Total Reward: 10330.99, Epsilon: 0.010
# Episode 1362, Total Reward: 10253.80, Epsilon: 0.010
# Episode 1363, Total Reward: 10296.58, Epsilon: 0.010
# Episode 1364, Total Reward: 10348.51, Epsilon: 0.010
# Episode 1365, Total Reward: 10315.03, Epsilon: 0.010
# Episode 1366, Total Reward: 10288.69, Epsilon: 0.010
# Episode 1367, Total Reward: 10304.56, Epsilon: 0.010
# Episode 1368, Total Reward: 10319.32, Epsilon: 0.010
# Episode 1369, Total Reward: 10288.21, Epsilon: 0.010
# Episode 1370, Total Reward: 10298.55, Epsilon: 0.010
# Episode 1371, Total Reward: 10329.92, Epsilon: 0.010
# Episode 1372, Total Reward: 10320.26, Epsilon: 0.010
# Episode 1373, Total Reward: 10284.02, Epsilon: 0.010
# Episode 1374, Total Reward: 10297.07, Epsilon: 0.010
# Episode 1375, Total Reward: 10318.52, Epsilon: 0.010
# Episode 1376, Total Reward: 10284.82, Epsilon: 0.010
# Episode 1377, Total Reward: 10289.99, Epsilon: 0.010
# Episode 1378, Total Reward: 10305.80, Epsilon: 0.010
# Episode 1379, Total Reward: 10293.38, Epsilon: 0.010
# Episode 1380, Total Reward: 10296.55, Epsilon: 0.010
# Episode 1381, Total Reward: 10283.04, Epsilon: 0.010
# Episode 1382, Total Reward: 10298.18, Epsilon: 0.010
# Episode 1383, Total Reward: 10331.47, Epsilon: 0.010
# Episode 1384, Total Reward: 10271.31, Epsilon: 0.010
# Episode 1385, Total Reward: 10311.37, Epsilon: 0.010
# Episode 1386, Total Reward: 10305.16, Epsilon: 0.010
# Episode 1387, Total Reward: 10339.15, Epsilon: 0.010
# Episode 1388, Total Reward: 10279.98, Epsilon: 0.010
# Episode 1389, Total Reward: 10314.74, Epsilon: 0.010
# Episode 1390, Total Reward: 10322.69, Epsilon: 0.010
# Episode 1391, Total Reward: 10323.83, Epsilon: 0.010
# Episode 1392, Total Reward: 10328.70, Epsilon: 0.010
# Episode 1393, Total Reward: 10265.67, Epsilon: 0.010
# Episode 1394, Total Reward: 10354.70, Epsilon: 0.010
# Episode 1395, Total Reward: 10293.78, Epsilon: 0.010
# Episode 1396, Total Reward: 10292.69, Epsilon: 0.010
# Episode 1397, Total Reward: 10328.53, Epsilon: 0.010
# Episode 1398, Total Reward: 10312.21, Epsilon: 0.010
# Episode 1399, Total Reward: 10307.37, Epsilon: 0.010
# Episode 1400, Total Reward: 10328.00, Epsilon: 0.010
# Episode 1401, Total Reward: 10286.68, Epsilon: 0.010
# Episode 1402, Total Reward: 10238.36, Epsilon: 0.010
# Episode 1403, Total Reward: 10301.10, Epsilon: 0.010
# Episode 1404, Total Reward: 10258.18, Epsilon: 0.010
# Episode 1405, Total Reward: 10305.82, Epsilon: 0.010
# Episode 1406, Total Reward: 10254.10, Epsilon: 0.010
# Episode 1407, Total Reward: 10339.07, Epsilon: 0.010
# Episode 1408, Total Reward: 10266.44, Epsilon: 0.010
# Episode 1409, Total Reward: 10301.48, Epsilon: 0.010
# Episode 1410, Total Reward: 10273.45, Epsilon: 0.010
# Episode 1411, Total Reward: 10275.47, Epsilon: 0.010
# Episode 1412, Total Reward: 10339.07, Epsilon: 0.010
# Episode 1413, Total Reward: 10288.93, Epsilon: 0.010
# Episode 1414, Total Reward: 10331.25, Epsilon: 0.010
# Episode 1415, Total Reward: 10337.05, Epsilon: 0.010
# Episode 1416, Total Reward: 10299.15, Epsilon: 0.010
# Episode 1417, Total Reward: 10251.47, Epsilon: 0.010
# Episode 1418, Total Reward: 10311.93, Epsilon: 0.010
# Episode 1419, Total Reward: 10334.81, Epsilon: 0.010
# Episode 1420, Total Reward: 10290.00, Epsilon: 0.010
# Episode 1421, Total Reward: 10300.99, Epsilon: 0.010
# Episode 1422, Total Reward: 10309.36, Epsilon: 0.010
# Episode 1423, Total Reward: 10279.44, Epsilon: 0.010
# Episode 1424, Total Reward: 10312.87, Epsilon: 0.010
# Episode 1425, Total Reward: 10296.86, Epsilon: 0.010
# Episode 1426, Total Reward: 10309.57, Epsilon: 0.010
# Episode 1427, Total Reward: 10359.50, Epsilon: 0.010
# Episode 1428, Total Reward: 10308.52, Epsilon: 0.010
# Episode 1429, Total Reward: 10308.87, Epsilon: 0.010
# Episode 1430, Total Reward: 10341.66, Epsilon: 0.010
# Episode 1431, Total Reward: 10344.81, Epsilon: 0.010
# Episode 1432, Total Reward: 10341.63, Epsilon: 0.010
# Episode 1433, Total Reward: 10301.41, Epsilon: 0.010
# Episode 1434, Total Reward: 10315.98, Epsilon: 0.010
# Episode 1435, Total Reward: 10290.59, Epsilon: 0.010
# Episode 1436, Total Reward: 10321.96, Epsilon: 0.010
# Episode 1437, Total Reward: 10319.55, Epsilon: 0.010
# Episode 1438, Total Reward: 10324.81, Epsilon: 0.010
# Episode 1439, Total Reward: 10320.86, Epsilon: 0.010
# Episode 1440, Total Reward: 10325.64, Epsilon: 0.010
# Episode 1441, Total Reward: 10306.11, Epsilon: 0.010
# Episode 1442, Total Reward: 10320.21, Epsilon: 0.010
# Episode 1443, Total Reward: 10335.99, Epsilon: 0.010
# Episode 1444, Total Reward: 10308.42, Epsilon: 0.010
# Episode 1445, Total Reward: 10279.30, Epsilon: 0.010
# Episode 1446, Total Reward: 10310.92, Epsilon: 0.010
# Episode 1447, Total Reward: 10274.20, Epsilon: 0.010
# Episode 1448, Total Reward: 10323.80, Epsilon: 0.010
# Episode 1449, Total Reward: 10334.95, Epsilon: 0.010
# Episode 1450, Total Reward: 10278.50, Epsilon: 0.010
# Episode 1451, Total Reward: 10290.97, Epsilon: 0.010
# Episode 1452, Total Reward: 10337.21, Epsilon: 0.010
# Episode 1453, Total Reward: 10351.12, Epsilon: 0.010
# Episode 1454, Total Reward: 10317.26, Epsilon: 0.010
# Episode 1455, Total Reward: 10276.94, Epsilon: 0.010
# Episode 1456, Total Reward: 10326.15, Epsilon: 0.010
# Episode 1457, Total Reward: 10301.18, Epsilon: 0.010
# Episode 1458, Total Reward: 10318.73, Epsilon: 0.010
# Episode 1459, Total Reward: 10325.29, Epsilon: 0.010
# Episode 1460, Total Reward: 10281.45, Epsilon: 0.010
# Episode 1461, Total Reward: 10322.90, Epsilon: 0.010
# Episode 1462, Total Reward: 10330.82, Epsilon: 0.010
# Episode 1463, Total Reward: 10329.37, Epsilon: 0.010
# Episode 1464, Total Reward: 10348.67, Epsilon: 0.010
# Episode 1465, Total Reward: 10300.42, Epsilon: 0.010
# Episode 1466, Total Reward: 10338.43, Epsilon: 0.010
# Episode 1467, Total Reward: 10270.58, Epsilon: 0.010
# Episode 1468, Total Reward: 10308.89, Epsilon: 0.010
# Episode 1469, Total Reward: 10281.54, Epsilon: 0.010
# Episode 1470, Total Reward: 10323.71, Epsilon: 0.010
# Episode 1471, Total Reward: 10275.38, Epsilon: 0.010
# Episode 1472, Total Reward: 10306.55, Epsilon: 0.010
# Episode 1473, Total Reward: 10317.44, Epsilon: 0.010
# Episode 1474, Total Reward: 10316.57, Epsilon: 0.010
# Episode 1475, Total Reward: 10281.15, Epsilon: 0.010
# Episode 1476, Total Reward: 10289.59, Epsilon: 0.010
# Episode 1477, Total Reward: 10266.20, Epsilon: 0.010
# Episode 1478, Total Reward: 10290.46, Epsilon: 0.010
# Episode 1479, Total Reward: 10323.22, Epsilon: 0.010
# Episode 1480, Total Reward: 10285.44, Epsilon: 0.010
# Episode 1481, Total Reward: 10271.56, Epsilon: 0.010
# Episode 1482, Total Reward: 10261.36, Epsilon: 0.010
# Episode 1483, Total Reward: 10314.93, Epsilon: 0.010
# Episode 1484, Total Reward: 10283.57, Epsilon: 0.010
# Episode 1485, Total Reward: 10289.09, Epsilon: 0.010
# Episode 1486, Total Reward: 10303.70, Epsilon: 0.010
# Episode 1487, Total Reward: 10307.77, Epsilon: 0.010
# Episode 1488, Total Reward: 10294.45, Epsilon: 0.010
# Episode 1489, Total Reward: 10316.19, Epsilon: 0.010
# Episode 1490, Total Reward: 10294.28, Epsilon: 0.010
# Episode 1491, Total Reward: 10323.26, Epsilon: 0.010
# Episode 1492, Total Reward: 10309.39, Epsilon: 0.010
# Episode 1493, Total Reward: 10291.80, Epsilon: 0.010
# Episode 1494, Total Reward: 10329.80, Epsilon: 0.010
# Episode 1495, Total Reward: 10277.53, Epsilon: 0.010
# Episode 1496, Total Reward: 10325.64, Epsilon: 0.010
# Episode 1497, Total Reward: 10333.12, Epsilon: 0.010
# Episode 1498, Total Reward: 10315.57, Epsilon: 0.010
# Episode 1499, Total Reward: 10300.02, Epsilon: 0.010
# Episode 1500, Total Reward: 10323.28, Epsilon: 0.010
# Episode 1501, Total Reward: 10335.68, Epsilon: 0.010
# Episode 1502, Total Reward: 10311.89, Epsilon: 0.010
# Episode 1503, Total Reward: 10326.73, Epsilon: 0.010
# Episode 1504, Total Reward: 10319.73, Epsilon: 0.010
# Episode 1505, Total Reward: 10253.99, Epsilon: 0.010
# Episode 1506, Total Reward: 10335.91, Epsilon: 0.010
# Episode 1507, Total Reward: 10272.66, Epsilon: 0.010
# Episode 1508, Total Reward: 10316.10, Epsilon: 0.010
# Episode 1509, Total Reward: 10334.44, Epsilon: 0.010
# Episode 1510, Total Reward: 10283.63, Epsilon: 0.010
# Episode 1511, Total Reward: 10306.22, Epsilon: 0.010
# Episode 1512, Total Reward: 10327.97, Epsilon: 0.010
# Episode 1513, Total Reward: 10321.71, Epsilon: 0.010
# Episode 1514, Total Reward: 10341.98, Epsilon: 0.010
# Episode 1515, Total Reward: 10318.55, Epsilon: 0.010
# Episode 1516, Total Reward: 10285.95, Epsilon: 0.010
# Episode 1517, Total Reward: 10299.21, Epsilon: 0.010
# Episode 1518, Total Reward: 10310.68, Epsilon: 0.010
# Episode 1519, Total Reward: 10266.91, Epsilon: 0.010
# Episode 1520, Total Reward: 10319.19, Epsilon: 0.010
# Episode 1521, Total Reward: 10321.92, Epsilon: 0.010
# Episode 1522, Total Reward: 10301.63, Epsilon: 0.010
# Episode 1523, Total Reward: 10330.25, Epsilon: 0.010
# Episode 1524, Total Reward: 10241.51, Epsilon: 0.010
# Episode 1525, Total Reward: 10332.84, Epsilon: 0.010
# Episode 1526, Total Reward: 10303.28, Epsilon: 0.010
# Episode 1527, Total Reward: 10329.92, Epsilon: 0.010
# Episode 1528, Total Reward: 10301.71, Epsilon: 0.010
# Episode 1529, Total Reward: 10288.37, Epsilon: 0.010
# Episode 1530, Total Reward: 10314.39, Epsilon: 0.010
# Episode 1531, Total Reward: 10238.91, Epsilon: 0.010
# Episode 1532, Total Reward: 10308.10, Epsilon: 0.010
# Episode 1533, Total Reward: 10296.38, Epsilon: 0.010
# Episode 1534, Total Reward: 10319.74, Epsilon: 0.010
# Episode 1535, Total Reward: 10258.03, Epsilon: 0.010
# Episode 1536, Total Reward: 10284.47, Epsilon: 0.010
# Episode 1537, Total Reward: 10268.37, Epsilon: 0.010
# Episode 1538, Total Reward: 10319.10, Epsilon: 0.010
# Episode 1539, Total Reward: 10297.82, Epsilon: 0.010
# Episode 1540, Total Reward: 10321.00, Epsilon: 0.010
# Episode 1541, Total Reward: 10307.19, Epsilon: 0.010
# Episode 1542, Total Reward: 10301.72, Epsilon: 0.010
# Episode 1543, Total Reward: 10345.00, Epsilon: 0.010
# Episode 1544, Total Reward: 10308.83, Epsilon: 0.010
# Episode 1545, Total Reward: 10282.06, Epsilon: 0.010
# Episode 1546, Total Reward: 10326.93, Epsilon: 0.010
# Episode 1547, Total Reward: 10284.67, Epsilon: 0.010
# Episode 1548, Total Reward: 10322.30, Epsilon: 0.010
# Episode 1549, Total Reward: 10285.70, Epsilon: 0.010
# Episode 1550, Total Reward: 10315.91, Epsilon: 0.010
# Episode 1551, Total Reward: 10286.65, Epsilon: 0.010
# Episode 1552, Total Reward: 10309.02, Epsilon: 0.010
# Episode 1553, Total Reward: 10289.52, Epsilon: 0.010
# Episode 1554, Total Reward: 10328.61, Epsilon: 0.010
# Episode 1555, Total Reward: 10282.52, Epsilon: 0.010
# Episode 1556, Total Reward: 10300.86, Epsilon: 0.010
# Episode 1557, Total Reward: 10279.70, Epsilon: 0.010
# Episode 1558, Total Reward: 10307.30, Epsilon: 0.010
# Episode 1559, Total Reward: 10283.08, Epsilon: 0.010
# Episode 1560, Total Reward: 10330.77, Epsilon: 0.010
# Episode 1561, Total Reward: 10295.12, Epsilon: 0.010
# Episode 1562, Total Reward: 10283.95, Epsilon: 0.010
# Episode 1563, Total Reward: 10337.54, Epsilon: 0.010
# Episode 1564, Total Reward: 10304.73, Epsilon: 0.010
# Episode 1565, Total Reward: 10344.78, Epsilon: 0.010
# Episode 1566, Total Reward: 10293.14, Epsilon: 0.010
# Episode 1567, Total Reward: 10300.11, Epsilon: 0.010
# Episode 1568, Total Reward: 10322.34, Epsilon: 0.010
# Episode 1569, Total Reward: 10310.27, Epsilon: 0.010
# Episode 1570, Total Reward: 10297.14, Epsilon: 0.010
# Episode 1571, Total Reward: 10300.48, Epsilon: 0.010
# Episode 1572, Total Reward: 10320.01, Epsilon: 0.010
# Episode 1573, Total Reward: 10351.62, Epsilon: 0.010
# Episode 1574, Total Reward: 10272.55, Epsilon: 0.010
# Episode 1575, Total Reward: 10295.51, Epsilon: 0.010
# Episode 1576, Total Reward: 10315.96, Epsilon: 0.010
# Episode 1577, Total Reward: 10312.19, Epsilon: 0.010
# Episode 1578, Total Reward: 10326.34, Epsilon: 0.010
# Episode 1579, Total Reward: 10289.09, Epsilon: 0.010
# Episode 1580, Total Reward: 10323.33, Epsilon: 0.010
# Episode 1581, Total Reward: 10314.15, Epsilon: 0.010
# Episode 1582, Total Reward: 10334.83, Epsilon: 0.010
# Episode 1583, Total Reward: 9694.46, Epsilon: 0.010
# Episode 1584, Total Reward: 10301.70, Epsilon: 0.010
# Episode 1585, Total Reward: 10331.67, Epsilon: 0.010
# Episode 1586, Total Reward: 10331.80, Epsilon: 0.010
# Episode 1587, Total Reward: 10341.15, Epsilon: 0.010
# Episode 1588, Total Reward: 10274.89, Epsilon: 0.010
# Episode 1589, Total Reward: 10295.07, Epsilon: 0.010
# Episode 1590, Total Reward: 10304.79, Epsilon: 0.010
# Episode 1591, Total Reward: 10279.00, Epsilon: 0.010
# Episode 1592, Total Reward: 10333.09, Epsilon: 0.010
# Episode 1593, Total Reward: 10287.47, Epsilon: 0.010
# Episode 1594, Total Reward: 10298.14, Epsilon: 0.010
# Episode 1595, Total Reward: 10071.22, Epsilon: 0.010
# Episode 1596, Total Reward: 10328.18, Epsilon: 0.010
# Episode 1597, Total Reward: 9545.35, Epsilon: 0.010
# Episode 1598, Total Reward: 10265.27, Epsilon: 0.010
# Episode 1599, Total Reward: 10267.06, Epsilon: 0.010
# Episode 1600, Total Reward: 10288.72, Epsilon: 0.010
# Episode 1601, Total Reward: 10319.87, Epsilon: 0.010
# Episode 1602, Total Reward: 10301.18, Epsilon: 0.010
# Episode 1603, Total Reward: 10295.96, Epsilon: 0.010
# Episode 1604, Total Reward: 10316.08, Epsilon: 0.010
# Episode 1605, Total Reward: 10229.14, Epsilon: 0.010
# Episode 1606, Total Reward: 10283.23, Epsilon: 0.010
# Episode 1607, Total Reward: 10324.12, Epsilon: 0.010
# Episode 1608, Total Reward: 10294.75, Epsilon: 0.010
# Episode 1609, Total Reward: 10296.39, Epsilon: 0.010
# Episode 1610, Total Reward: 10303.96, Epsilon: 0.010
# Episode 1611, Total Reward: 10273.85, Epsilon: 0.010
# Episode 1612, Total Reward: 10320.10, Epsilon: 0.010
# Episode 1613, Total Reward: 10309.70, Epsilon: 0.010
# Episode 1614, Total Reward: 10283.71, Epsilon: 0.010
# Episode 1615, Total Reward: 10304.79, Epsilon: 0.010
# Episode 1616, Total Reward: 10242.93, Epsilon: 0.010
# Episode 1617, Total Reward: 10316.81, Epsilon: 0.010
# Episode 1618, Total Reward: 10300.53, Epsilon: 0.010
# Episode 1619, Total Reward: 10347.97, Epsilon: 0.010
# Episode 1620, Total Reward: 10317.79, Epsilon: 0.010
# Episode 1621, Total Reward: 10347.42, Epsilon: 0.010
# Episode 1622, Total Reward: 10277.52, Epsilon: 0.010
# Episode 1623, Total Reward: 10306.53, Epsilon: 0.010
# Episode 1624, Total Reward: 10345.76, Epsilon: 0.010
# Episode 1625, Total Reward: 10321.61, Epsilon: 0.010
# Episode 1626, Total Reward: 10335.52, Epsilon: 0.010
# Episode 1627, Total Reward: 10314.74, Epsilon: 0.010
# Episode 1628, Total Reward: 10253.83, Epsilon: 0.010
# Episode 1629, Total Reward: 10269.81, Epsilon: 0.010
# Episode 1630, Total Reward: 10267.19, Epsilon: 0.010
# Episode 1631, Total Reward: 10337.62, Epsilon: 0.010
# Episode 1632, Total Reward: 10316.57, Epsilon: 0.010
# Episode 1633, Total Reward: 10252.71, Epsilon: 0.010
# Episode 1634, Total Reward: 10293.01, Epsilon: 0.010
# Episode 1635, Total Reward: 10324.15, Epsilon: 0.010
# Episode 1636, Total Reward: 10310.74, Epsilon: 0.010
# Episode 1637, Total Reward: 10296.78, Epsilon: 0.010
# Episode 1638, Total Reward: 10295.90, Epsilon: 0.010
# Episode 1639, Total Reward: 10283.75, Epsilon: 0.010
# Episode 1640, Total Reward: 10277.56, Epsilon: 0.010
# Episode 1641, Total Reward: 10344.38, Epsilon: 0.010
# Episode 1642, Total Reward: 10295.86, Epsilon: 0.010
# Episode 1643, Total Reward: 10299.65, Epsilon: 0.010
# Episode 1644, Total Reward: 10301.55, Epsilon: 0.010
# Episode 1645, Total Reward: 10317.68, Epsilon: 0.010
# Episode 1646, Total Reward: 10270.73, Epsilon: 0.010
# Episode 1647, Total Reward: 10248.49, Epsilon: 0.010
# Episode 1648, Total Reward: 10301.35, Epsilon: 0.010
# Episode 1649, Total Reward: 10354.60, Epsilon: 0.010
# Episode 1650, Total Reward: 10299.80, Epsilon: 0.010
# Episode 1651, Total Reward: 10287.88, Epsilon: 0.010
# Episode 1652, Total Reward: 10341.18, Epsilon: 0.010
# Episode 1653, Total Reward: 10261.46, Epsilon: 0.010
# Episode 1654, Total Reward: 10287.03, Epsilon: 0.010
# Episode 1655, Total Reward: 10303.67, Epsilon: 0.010
# Episode 1656, Total Reward: 10293.51, Epsilon: 0.010
# Episode 1657, Total Reward: 10323.67, Epsilon: 0.010
# Episode 1658, Total Reward: 10293.33, Epsilon: 0.010
# Episode 1659, Total Reward: 10281.84, Epsilon: 0.010
# Episode 1660, Total Reward: 10310.73, Epsilon: 0.010
# Episode 1661, Total Reward: 10309.79, Epsilon: 0.010
# Episode 1662, Total Reward: 10290.69, Epsilon: 0.010
# Episode 1663, Total Reward: 10326.38, Epsilon: 0.010
# Episode 1664, Total Reward: 10337.79, Epsilon: 0.010
# Episode 1665, Total Reward: 10334.24, Epsilon: 0.010
# Episode 1666, Total Reward: 10314.45, Epsilon: 0.010
# Episode 1667, Total Reward: 10320.51, Epsilon: 0.010
# Episode 1668, Total Reward: 10306.49, Epsilon: 0.010
# Episode 1669, Total Reward: 10284.38, Epsilon: 0.010
# Episode 1670, Total Reward: 10311.12, Epsilon: 0.010
# Episode 1671, Total Reward: 10299.96, Epsilon: 0.010
# Episode 1672, Total Reward: 10329.82, Epsilon: 0.010
# Episode 1673, Total Reward: 10339.75, Epsilon: 0.010
# Episode 1674, Total Reward: 10317.24, Epsilon: 0.010
# Episode 1675, Total Reward: 10269.68, Epsilon: 0.010
# Episode 1676, Total Reward: 10324.86, Epsilon: 0.010
# Episode 1677, Total Reward: 10301.18, Epsilon: 0.010
# Episode 1678, Total Reward: 10318.20, Epsilon: 0.010
# Episode 1679, Total Reward: 10290.96, Epsilon: 0.010
# Episode 1680, Total Reward: 10342.26, Epsilon: 0.010
# Episode 1681, Total Reward: 10287.22, Epsilon: 0.010
# Episode 1682, Total Reward: 10290.45, Epsilon: 0.010
# Episode 1683, Total Reward: 10344.87, Epsilon: 0.010
# Episode 1684, Total Reward: 10278.27, Epsilon: 0.010
# Episode 1685, Total Reward: 10284.56, Epsilon: 0.010
# Episode 1686, Total Reward: 10324.02, Epsilon: 0.010
# Episode 1687, Total Reward: 10337.16, Epsilon: 0.010
# Episode 1688, Total Reward: 10310.93, Epsilon: 0.010
# Episode 1689, Total Reward: 10313.89, Epsilon: 0.010
# Episode 1690, Total Reward: 10315.93, Epsilon: 0.010
# Episode 1691, Total Reward: 10340.13, Epsilon: 0.010
# Episode 1692, Total Reward: 10328.10, Epsilon: 0.010
# Episode 1693, Total Reward: 10300.86, Epsilon: 0.010
# Episode 1694, Total Reward: 10291.00, Epsilon: 0.010
# Episode 1695, Total Reward: 10303.58, Epsilon: 0.010
# Episode 1696, Total Reward: 10332.19, Epsilon: 0.010
# Episode 1697, Total Reward: 10310.43, Epsilon: 0.010
# Episode 1698, Total Reward: 10353.02, Epsilon: 0.010
# Episode 1699, Total Reward: 10316.19, Epsilon: 0.010
# Episode 1700, Total Reward: 10297.56, Epsilon: 0.010
# Episode 1701, Total Reward: 10329.91, Epsilon: 0.010
# Episode 1702, Total Reward: 10289.41, Epsilon: 0.010
# Episode 1703, Total Reward: 10311.55, Epsilon: 0.010
# Episode 1704, Total Reward: 10300.86, Epsilon: 0.010
# Episode 1705, Total Reward: 10298.63, Epsilon: 0.010
# Episode 1706, Total Reward: 10326.84, Epsilon: 0.010
# Episode 1707, Total Reward: 10263.14, Epsilon: 0.010
# Episode 1708, Total Reward: 10263.08, Epsilon: 0.010
# Episode 1709, Total Reward: 10309.66, Epsilon: 0.010
# Episode 1710, Total Reward: 10275.73, Epsilon: 0.010
# Episode 1711, Total Reward: 10278.98, Epsilon: 0.010
# Episode 1712, Total Reward: 10301.34, Epsilon: 0.010
# Episode 1713, Total Reward: 10293.69, Epsilon: 0.010
# Episode 1714, Total Reward: 10295.23, Epsilon: 0.010
# Episode 1715, Total Reward: 10315.79, Epsilon: 0.010
# Episode 1716, Total Reward: 10327.65, Epsilon: 0.010
# Episode 1717, Total Reward: 10333.75, Epsilon: 0.010
# Episode 1718, Total Reward: 10312.93, Epsilon: 0.010
# Episode 1719, Total Reward: 10310.73, Epsilon: 0.010
# Episode 1720, Total Reward: 10322.40, Epsilon: 0.010
# Episode 1721, Total Reward: 10360.13, Epsilon: 0.010
# Episode 1722, Total Reward: 10259.31, Epsilon: 0.010
# Episode 1723, Total Reward: 10287.16, Epsilon: 0.010
# Episode 1724, Total Reward: 10300.90, Epsilon: 0.010
# Episode 1725, Total Reward: 10327.48, Epsilon: 0.010
# Episode 1726, Total Reward: 10294.71, Epsilon: 0.010
# Episode 1727, Total Reward: 10332.58, Epsilon: 0.010
# Episode 1728, Total Reward: 10311.78, Epsilon: 0.010
# Episode 1729, Total Reward: 10330.16, Epsilon: 0.010
# Episode 1730, Total Reward: 10307.19, Epsilon: 0.010
# Episode 1731, Total Reward: 10269.81, Epsilon: 0.010
# Episode 1732, Total Reward: 10344.08, Epsilon: 0.010
# Episode 1733, Total Reward: 10300.68, Epsilon: 0.010
# Episode 1734, Total Reward: 10326.45, Epsilon: 0.010
# Episode 1735, Total Reward: 10271.65, Epsilon: 0.010
# Episode 1736, Total Reward: 7602.35, Epsilon: 0.010
# Episode 1737, Total Reward: 10273.61, Epsilon: 0.010
# Episode 1738, Total Reward: 10283.03, Epsilon: 0.010
# Episode 1739, Total Reward: 8944.87, Epsilon: 0.010
# Episode 1740, Total Reward: 10298.58, Epsilon: 0.010
# Episode 1741, Total Reward: 10335.23, Epsilon: 0.010
# Episode 1742, Total Reward: 10299.75, Epsilon: 0.010
# Episode 1743, Total Reward: 10302.41, Epsilon: 0.010
# Episode 1744, Total Reward: 10310.64, Epsilon: 0.010
# Episode 1745, Total Reward: 10294.66, Epsilon: 0.010
# Episode 1746, Total Reward: 10335.83, Epsilon: 0.010
# Episode 1747, Total Reward: 10361.24, Epsilon: 0.010
# Episode 1748, Total Reward: 10337.19, Epsilon: 0.010
# Episode 1749, Total Reward: 10277.25, Epsilon: 0.010
# Episode 1750, Total Reward: 10311.00, Epsilon: 0.010
# Episode 1751, Total Reward: 10308.52, Epsilon: 0.010
# Episode 1752, Total Reward: 10304.79, Epsilon: 0.010
# Episode 1753, Total Reward: 10316.85, Epsilon: 0.010
# Episode 1754, Total Reward: 10337.54, Epsilon: 0.010
# Episode 1755, Total Reward: 10341.18, Epsilon: 0.010
# Episode 1756, Total Reward: 10261.45, Epsilon: 0.010
# Episode 1757, Total Reward: 10292.45, Epsilon: 0.010
# Episode 1758, Total Reward: 10358.55, Epsilon: 0.010
# Episode 1759, Total Reward: 10313.18, Epsilon: 0.010
# Episode 1760, Total Reward: 10336.96, Epsilon: 0.010
# Episode 1761, Total Reward: 10312.33, Epsilon: 0.010
# Episode 1762, Total Reward: 10246.70, Epsilon: 0.010
# Episode 1763, Total Reward: 10292.60, Epsilon: 0.010
# Episode 1764, Total Reward: 10273.84, Epsilon: 0.010
# Episode 1765, Total Reward: 10339.35, Epsilon: 0.010
# Episode 1766, Total Reward: 10321.01, Epsilon: 0.010
# Episode 1767, Total Reward: 10315.21, Epsilon: 0.010
# Episode 1768, Total Reward: 10316.48, Epsilon: 0.010
# Episode 1769, Total Reward: 10285.40, Epsilon: 0.010
# Episode 1770, Total Reward: 10272.87, Epsilon: 0.010
# Episode 1771, Total Reward: 10298.59, Epsilon: 0.010
# Episode 1772, Total Reward: 10174.45, Epsilon: 0.010
# Episode 1773, Total Reward: 10015.69, Epsilon: 0.010
# Episode 1774, Total Reward: 10253.85, Epsilon: 0.010
# Episode 1775, Total Reward: 10336.43, Epsilon: 0.010
# Episode 1776, Total Reward: 10307.75, Epsilon: 0.010
# Episode 1777, Total Reward: 10301.68, Epsilon: 0.010
# Episode 1778, Total Reward: 10282.67, Epsilon: 0.010
# Episode 1779, Total Reward: 10282.71, Epsilon: 0.010
# Episode 1780, Total Reward: 10327.17, Epsilon: 0.010
# Episode 1781, Total Reward: 10287.94, Epsilon: 0.010
# Episode 1782, Total Reward: 10310.36, Epsilon: 0.010
# Episode 1783, Total Reward: 10303.84, Epsilon: 0.010
# Episode 1784, Total Reward: 10304.24, Epsilon: 0.010
# Episode 1785, Total Reward: 10308.81, Epsilon: 0.010
# Episode 1786, Total Reward: 10291.30, Epsilon: 0.010
# Episode 1787, Total Reward: 10312.76, Epsilon: 0.010
# Episode 1788, Total Reward: 10293.61, Epsilon: 0.010
# Episode 1789, Total Reward: 10317.56, Epsilon: 0.010
# Episode 1790, Total Reward: 10309.41, Epsilon: 0.010
# Episode 1791, Total Reward: 10320.40, Epsilon: 0.010
# Episode 1792, Total Reward: 10345.00, Epsilon: 0.010
# Episode 1793, Total Reward: 10314.01, Epsilon: 0.010
# Episode 1794, Total Reward: 10234.82, Epsilon: 0.010
# Episode 1795, Total Reward: 10284.87, Epsilon: 0.010
# Episode 1796, Total Reward: 10329.37, Epsilon: 0.010
# Episode 1797, Total Reward: 10292.94, Epsilon: 0.010
# Episode 1798, Total Reward: 10286.53, Epsilon: 0.010
# Episode 1799, Total Reward: 10264.08, Epsilon: 0.010
# Episode 1800, Total Reward: 10281.04, Epsilon: 0.010
# Episode 1801, Total Reward: 10315.29, Epsilon: 0.010
# Episode 1802, Total Reward: 10321.28, Epsilon: 0.010
# Episode 1803, Total Reward: 10331.43, Epsilon: 0.010
# Episode 1804, Total Reward: 10348.53, Epsilon: 0.010
# Episode 1805, Total Reward: 10281.70, Epsilon: 0.010
# Episode 1806, Total Reward: 10299.00, Epsilon: 0.010
# Episode 1807, Total Reward: 10302.90, Epsilon: 0.010
# Episode 1808, Total Reward: 10332.85, Epsilon: 0.010
# Episode 1809, Total Reward: 10279.88, Epsilon: 0.010
# Episode 1810, Total Reward: 10302.97, Epsilon: 0.010
# Episode 1811, Total Reward: 10315.03, Epsilon: 0.010
# Episode 1812, Total Reward: 10321.72, Epsilon: 0.010
# Episode 1813, Total Reward: 10304.61, Epsilon: 0.010
# Episode 1814, Total Reward: 10275.21, Epsilon: 0.010
# Episode 1815, Total Reward: 10292.26, Epsilon: 0.010
# Episode 1816, Total Reward: 10302.93, Epsilon: 0.010
# Episode 1817, Total Reward: 10351.20, Epsilon: 0.010
# Episode 1818, Total Reward: 10301.62, Epsilon: 0.010
# Episode 1819, Total Reward: 10300.72, Epsilon: 0.010
# Episode 1820, Total Reward: 10318.73, Epsilon: 0.010
# Episode 1821, Total Reward: 10301.33, Epsilon: 0.010
# Episode 1822, Total Reward: 10304.83, Epsilon: 0.010
# Episode 1823, Total Reward: 10253.42, Epsilon: 0.010
# Episode 1824, Total Reward: 10289.41, Epsilon: 0.010
# Episode 1825, Total Reward: 10341.12, Epsilon: 0.010
# Episode 1826, Total Reward: 10309.17, Epsilon: 0.010
# Episode 1827, Total Reward: 10308.48, Epsilon: 0.010
# Episode 1828, Total Reward: 10339.91, Epsilon: 0.010
# Episode 1829, Total Reward: 10327.22, Epsilon: 0.010
# Episode 1830, Total Reward: 10327.12, Epsilon: 0.010
# Episode 1831, Total Reward: 10281.99, Epsilon: 0.010
# Episode 1832, Total Reward: 10315.49, Epsilon: 0.010
# Episode 1833, Total Reward: 10281.00, Epsilon: 0.010
# Episode 1834, Total Reward: 10316.79, Epsilon: 0.010
# Episode 1835, Total Reward: 10268.78, Epsilon: 0.010
# Episode 1836, Total Reward: 10260.52, Epsilon: 0.010
# Episode 1837, Total Reward: 10335.67, Epsilon: 0.010
# Episode 1838, Total Reward: 10291.78, Epsilon: 0.010
# Episode 1839, Total Reward: 10299.08, Epsilon: 0.010
# Episode 1840, Total Reward: 10306.85, Epsilon: 0.010
# Episode 1841, Total Reward: 10330.20, Epsilon: 0.010
# Episode 1842, Total Reward: 10291.84, Epsilon: 0.010
# Episode 1843, Total Reward: 10314.98, Epsilon: 0.010
# Episode 1844, Total Reward: 10303.57, Epsilon: 0.010
# Episode 1845, Total Reward: 10300.34, Epsilon: 0.010
# Episode 1846, Total Reward: 10333.06, Epsilon: 0.010
# Episode 1847, Total Reward: 10266.57, Epsilon: 0.010
# Episode 1848, Total Reward: 10350.73, Epsilon: 0.010
# Episode 1849, Total Reward: 10271.84, Epsilon: 0.010
# Episode 1850, Total Reward: 10287.96, Epsilon: 0.010
# Episode 1851, Total Reward: 10343.62, Epsilon: 0.010
# Episode 1852, Total Reward: 10304.90, Epsilon: 0.010
# Episode 1853, Total Reward: 10302.94, Epsilon: 0.010
# Episode 1854, Total Reward: 10329.71, Epsilon: 0.010
# Episode 1855, Total Reward: 10321.07, Epsilon: 0.010
# Episode 1856, Total Reward: 10330.60, Epsilon: 0.010
# Episode 1857, Total Reward: 10331.24, Epsilon: 0.010
# Episode 1858, Total Reward: 10293.01, Epsilon: 0.010
# Episode 1859, Total Reward: 10289.56, Epsilon: 0.010
# Episode 1860, Total Reward: 10336.14, Epsilon: 0.010
# Episode 1861, Total Reward: 10299.88, Epsilon: 0.010
# Episode 1862, Total Reward: 10321.03, Epsilon: 0.010
# Episode 1863, Total Reward: 10301.94, Epsilon: 0.010
# Episode 1864, Total Reward: 10286.90, Epsilon: 0.010
# Episode 1865, Total Reward: 10320.77, Epsilon: 0.010
# Episode 1866, Total Reward: 10320.52, Epsilon: 0.010
# Episode 1867, Total Reward: 10312.54, Epsilon: 0.010
# Episode 1868, Total Reward: 10309.16, Epsilon: 0.010
# Episode 1869, Total Reward: 10334.40, Epsilon: 0.010
# Episode 1870, Total Reward: 10355.54, Epsilon: 0.010
# Episode 1871, Total Reward: 10336.79, Epsilon: 0.010
# Episode 1872, Total Reward: 10299.42, Epsilon: 0.010
# Episode 1873, Total Reward: 10304.63, Epsilon: 0.010
# Episode 1874, Total Reward: 10332.84, Epsilon: 0.010
# Episode 1875, Total Reward: 10307.13, Epsilon: 0.010
# Episode 1876, Total Reward: 10289.20, Epsilon: 0.010
# Episode 1877, Total Reward: 10287.85, Epsilon: 0.010
# Episode 1878, Total Reward: 10337.35, Epsilon: 0.010
# Episode 1879, Total Reward: 10266.82, Epsilon: 0.010
# Episode 1880, Total Reward: 10330.92, Epsilon: 0.010
# Episode 1881, Total Reward: 10301.49, Epsilon: 0.010
# Episode 1882, Total Reward: 10256.63, Epsilon: 0.010
# Episode 1883, Total Reward: 10292.03, Epsilon: 0.010
# Episode 1884, Total Reward: 10284.16, Epsilon: 0.010
# Episode 1885, Total Reward: 10308.90, Epsilon: 0.010
# Episode 1886, Total Reward: 10307.87, Epsilon: 0.010
# Episode 1887, Total Reward: 10352.66, Epsilon: 0.010
# Episode 1888, Total Reward: 10241.26, Epsilon: 0.010
# Episode 1889, Total Reward: 10337.30, Epsilon: 0.010
# Episode 1890, Total Reward: 10310.01, Epsilon: 0.010
# Episode 1891, Total Reward: 10313.31, Epsilon: 0.010
# Episode 1892, Total Reward: 10280.54, Epsilon: 0.010
# Episode 1893, Total Reward: 10268.82, Epsilon: 0.010
# Episode 1894, Total Reward: 10294.52, Epsilon: 0.010
# Episode 1895, Total Reward: 10313.94, Epsilon: 0.010
# Episode 1896, Total Reward: 10317.44, Epsilon: 0.010
# Episode 1897, Total Reward: 10326.41, Epsilon: 0.010
# Episode 1898, Total Reward: 10268.12, Epsilon: 0.010
# Episode 1899, Total Reward: 10301.64, Epsilon: 0.010
# Episode 1900, Total Reward: 10276.35, Epsilon: 0.010
# Episode 1901, Total Reward: 10322.36, Epsilon: 0.010
# Episode 1902, Total Reward: 10333.04, Epsilon: 0.010
# Episode 1903, Total Reward: 10301.24, Epsilon: 0.010
# Episode 1904, Total Reward: 10307.71, Epsilon: 0.010
# ...
# Episode 5700, Total Reward: 10250.14, Epsilon: 0.010
# Episode 5701, Total Reward: 10297.94, Epsilon: 0.010
# Episode 5702, Total Reward: 10279.80, Epsilon: 0.010
# Episode 5703, Total Reward: 10317.09, Epsilon: 0.010
# Episode 5704, Total Reward: 10315.25, Epsilon: 0.010
# Episode 5705, Total Reward: 10262.97, Epsilon: 0.010
# Episode 5706, Total Reward: 10243.92, Epsilon: 0.010
# Episode 5707, Total Reward: 10298.91, Epsilon: 0.010
# Episode 5708, Total Reward: 10297.39, Epsilon: 0.010
# Episode 5709, Total Reward: 10317.50, Epsilon: 0.010
# Episode 5710, Total Reward: 10314.45, Epsilon: 0.010
# Episode 5711, Total Reward: 10292.91, Epsilon: 0.010
# Episode 5712, Total Reward: 10277.80, Epsilon: 0.010
# Episode 5713, Total Reward: 10319.03, Epsilon: 0.010
# Episode 5714, Total Reward: 10311.54, Epsilon: 0.010
# Episode 5715, Total Reward: 10310.53, Epsilon: 0.010
# Episode 5716, Total Reward: 10273.35, Epsilon: 0.010
# Episode 5717, Total Reward: 10317.86, Epsilon: 0.010
# Episode 5718, Total Reward: 10295.91, Epsilon: 0.010
# Episode 5719, Total Reward: 10292.88, Epsilon: 0.010
# Episode 5720, Total Reward: 10330.47, Epsilon: 0.010
# Episode 5721, Total Reward: 10270.02, Epsilon: 0.010
# Episode 5722, Total Reward: 10254.58, Epsilon: 0.010
# Episode 5723, Total Reward: 10297.44, Epsilon: 0.010
# Episode 5724, Total Reward: 10291.16, Epsilon: 0.010
# Episode 5725, Total Reward: 10350.71, Epsilon: 0.010
# Episode 5726, Total Reward: 10279.73, Epsilon: 0.010
# Episode 5727, Total Reward: 10187.55, Epsilon: 0.010
# Episode 5728, Total Reward: 10341.98, Epsilon: 0.010
# Episode 5729, Total Reward: 10355.27, Epsilon: 0.010
# Episode 5730, Total Reward: 10292.95, Epsilon: 0.010
# Episode 5731, Total Reward: 10323.71, Epsilon: 0.010
# Episode 5732, Total Reward: 10281.60, Epsilon: 0.010
# Episode 5733, Total Reward: 10320.44, Epsilon: 0.010
# Episode 5734, Total Reward: 10276.92, Epsilon: 0.010
# Episode 5735, Total Reward: 10286.39, Epsilon: 0.010
# Episode 5736, Total Reward: 10278.35, Epsilon: 0.010
# Episode 5737, Total Reward: 10324.79, Epsilon: 0.010
# Episode 5738, Total Reward: 10347.60, Epsilon: 0.010
# Episode 5739, Total Reward: 10311.86, Epsilon: 0.010
# Episode 5740, Total Reward: 10317.22, Epsilon: 0.010
# Episode 5741, Total Reward: 10261.37, Epsilon: 0.010
# Episode 5742, Total Reward: 10301.67, Epsilon: 0.010
# Episode 5743, Total Reward: 10333.56, Epsilon: 0.010
# Episode 5744, Total Reward: 10287.90, Epsilon: 0.010
# Episode 5745, Total Reward: 10316.19, Epsilon: 0.010
# Episode 5746, Total Reward: 10356.24, Epsilon: 0.010
# Episode 5747, Total Reward: 10290.01, Epsilon: 0.010
# Episode 5748, Total Reward: 10325.32, Epsilon: 0.010
# Episode 5749, Total Reward: 10299.62, Epsilon: 0.010
# Episode 5750, Total Reward: 10290.91, Epsilon: 0.010
# Episode 5751, Total Reward: 10321.70, Epsilon: 0.010
# Episode 5752, Total Reward: 10292.48, Epsilon: 0.010
# Episode 5753, Total Reward: 10284.42, Epsilon: 0.010
# Episode 5754, Total Reward: 10338.21, Epsilon: 0.010
# Episode 5755, Total Reward: 10322.19, Epsilon: 0.010
# Episode 5756, Total Reward: 10332.61, Epsilon: 0.010
# Episode 5757, Total Reward: 10272.63, Epsilon: 0.010
# Episode 5758, Total Reward: 10263.30, Epsilon: 0.010
# Episode 5759, Total Reward: 10352.56, Epsilon: 0.010
# Episode 5760, Total Reward: 10287.49, Epsilon: 0.010
# Episode 5761, Total Reward: 10273.71, Epsilon: 0.010
# Episode 5762, Total Reward: 10329.14, Epsilon: 0.010
# Episode 5763, Total Reward: 10344.81, Epsilon: 0.010
# Episode 5764, Total Reward: 10328.20, Epsilon: 0.010
# Episode 5765, Total Reward: 10291.31, Epsilon: 0.010
# Episode 5766, Total Reward: 10313.49, Epsilon: 0.010
# Episode 5767, Total Reward: 10346.68, Epsilon: 0.010
# Episode 5768, Total Reward: 10300.33, Epsilon: 0.010
# Episode 5769, Total Reward: 10289.57, Epsilon: 0.010
# Episode 5770, Total Reward: 10301.60, Epsilon: 0.010
# Episode 5771, Total Reward: 10320.62, Epsilon: 0.010
# Episode 5772, Total Reward: 10291.94, Epsilon: 0.010
# Episode 5773, Total Reward: 10298.01, Epsilon: 0.010
# Episode 5774, Total Reward: 10326.85, Epsilon: 0.010
# Episode 5775, Total Reward: 10282.82, Epsilon: 0.010
# Episode 5776, Total Reward: 10319.13, Epsilon: 0.010
# Episode 5777, Total Reward: 10299.69, Epsilon: 0.010
# Episode 5778, Total Reward: 10302.17, Epsilon: 0.010
# Episode 5779, Total Reward: 10315.94, Epsilon: 0.010
# Episode 5780, Total Reward: 10346.51, Epsilon: 0.010
# Episode 5781, Total Reward: 10286.08, Epsilon: 0.010
# Episode 5782, Total Reward: 10314.82, Epsilon: 0.010
# Episode 5783, Total Reward: 10351.52, Epsilon: 0.010
# Episode 5784, Total Reward: 10357.50, Epsilon: 0.010
# Episode 5785, Total Reward: 10294.74, Epsilon: 0.010
# Episode 5786, Total Reward: 10314.35, Epsilon: 0.010
# Episode 5787, Total Reward: 10308.23, Epsilon: 0.010
# Episode 5788, Total Reward: 10323.04, Epsilon: 0.010
# Episode 5789, Total Reward: 10281.96, Epsilon: 0.010
# Episode 5790, Total Reward: 10308.41, Epsilon: 0.010
# Episode 5791, Total Reward: 10339.84, Epsilon: 0.010
# Episode 5792, Total Reward: 10261.25, Epsilon: 0.010
# Episode 5793, Total Reward: 10312.97, Epsilon: 0.010
# Episode 5794, Total Reward: 10280.39, Epsilon: 0.010
# Episode 5795, Total Reward: 10304.85, Epsilon: 0.010
# Episode 5796, Total Reward: 10306.01, Epsilon: 0.010
# Episode 5797, Total Reward: 10282.22, Epsilon: 0.010
# Episode 5798, Total Reward: 10334.25, Epsilon: 0.010
# Episode 5799, Total Reward: 10288.66, Epsilon: 0.010
# Episode 5800, Total Reward: 10289.88, Epsilon: 0.010
# Episode 5801, Total Reward: 10315.93, Epsilon: 0.010
# Episode 5802, Total Reward: 10335.61, Epsilon: 0.010
# Episode 5803, Total Reward: 10283.12, Epsilon: 0.010
# Episode 5804, Total Reward: 10339.39, Epsilon: 0.010
# Episode 5805, Total Reward: 10332.63, Epsilon: 0.010
# Episode 5806, Total Reward: 10307.65, Epsilon: 0.010
# Episode 5807, Total Reward: 10337.81, Epsilon: 0.010
# Episode 5808, Total Reward: 10316.62, Epsilon: 0.010
# Episode 5809, Total Reward: 10354.72, Epsilon: 0.010
# Episode 5810, Total Reward: 10340.75, Epsilon: 0.010
# Episode 5811, Total Reward: 10368.66, Epsilon: 0.010
# Episode 5812, Total Reward: 10298.64, Epsilon: 0.010
# Episode 5813, Total Reward: 10296.48, Epsilon: 0.010
# Episode 5814, Total Reward: 10317.73, Epsilon: 0.010
# Episode 5815, Total Reward: 10290.38, Epsilon: 0.010
# Episode 5816, Total Reward: 10330.01, Epsilon: 0.010
# Episode 5817, Total Reward: 10315.56, Epsilon: 0.010
# Episode 5818, Total Reward: 10291.57, Epsilon: 0.010
# Episode 5819, Total Reward: 10317.79, Epsilon: 0.010
# Episode 5820, Total Reward: 10323.56, Epsilon: 0.010
# Episode 5821, Total Reward: 10339.77, Epsilon: 0.010
# Episode 5822, Total Reward: 10328.73, Epsilon: 0.010
# Episode 5823, Total Reward: 10305.36, Epsilon: 0.010
# Episode 5824, Total Reward: 10300.88, Epsilon: 0.010
# Episode 5825, Total Reward: 10296.35, Epsilon: 0.010
# Episode 5826, Total Reward: 10348.96, Epsilon: 0.010
# Episode 5827, Total Reward: 10273.67, Epsilon: 0.010
# Episode 5828, Total Reward: 10308.85, Epsilon: 0.010
# Episode 5829, Total Reward: 10342.93, Epsilon: 0.010
# Episode 5830, Total Reward: 10311.14, Epsilon: 0.010
# Episode 5831, Total Reward: 10282.57, Epsilon: 0.010
# Episode 5832, Total Reward: 10310.83, Epsilon: 0.010
# Episode 5833, Total Reward: 10319.16, Epsilon: 0.010
# Episode 5834, Total Reward: 10276.48, Epsilon: 0.010
# Episode 5835, Total Reward: 10328.18, Epsilon: 0.010
# Episode 5836, Total Reward: 10338.45, Epsilon: 0.010
# Episode 5837, Total Reward: 10324.97, Epsilon: 0.010
# Episode 5838, Total Reward: 10353.40, Epsilon: 0.010
# Episode 5839, Total Reward: 10321.66, Epsilon: 0.010
# Episode 5840, Total Reward: 10293.66, Epsilon: 0.010
# Episode 5841, Total Reward: 10281.87, Epsilon: 0.010
# Episode 5842, Total Reward: 10299.17, Epsilon: 0.010
# Episode 5843, Total Reward: 10227.19, Epsilon: 0.010
# Episode 5844, Total Reward: 10299.20, Epsilon: 0.010
# Episode 5845, Total Reward: 10311.74, Epsilon: 0.010
# Episode 5846, Total Reward: 10356.99, Epsilon: 0.010
# Episode 5847, Total Reward: 10310.88, Epsilon: 0.010
# Episode 5848, Total Reward: 10309.77, Epsilon: 0.010
# Episode 5849, Total Reward: 10322.82, Epsilon: 0.010
# Episode 5850, Total Reward: 10290.20, Epsilon: 0.010
# Episode 5851, Total Reward: 10319.81, Epsilon: 0.010
# Episode 5852, Total Reward: 10315.04, Epsilon: 0.010
# Episode 5853, Total Reward: 10333.56, Epsilon: 0.010
# Episode 5854, Total Reward: 10312.78, Epsilon: 0.010
# Episode 5855, Total Reward: 10306.60, Epsilon: 0.010
# Episode 5856, Total Reward: 10327.71, Epsilon: 0.010
# Episode 5857, Total Reward: 10265.28, Epsilon: 0.010
# Episode 5858, Total Reward: 10292.04, Epsilon: 0.010
# Episode 5859, Total Reward: 10284.89, Epsilon: 0.010
# Episode 5860, Total Reward: 10342.37, Epsilon: 0.010
# Episode 5861, Total Reward: 10281.03, Epsilon: 0.010
# Episode 5862, Total Reward: 10317.35, Epsilon: 0.010
# Episode 5863, Total Reward: 10306.84, Epsilon: 0.010
# Episode 5864, Total Reward: 10295.23, Epsilon: 0.010
# Episode 5865, Total Reward: 10323.07, Epsilon: 0.010
# Episode 5866, Total Reward: 10335.94, Epsilon: 0.010
# Episode 5867, Total Reward: 10292.66, Epsilon: 0.010
# Episode 5868, Total Reward: 10281.18, Epsilon: 0.010
# Episode 5869, Total Reward: 10330.88, Epsilon: 0.010
# Episode 5870, Total Reward: 10280.92, Epsilon: 0.010
# Episode 5871, Total Reward: 10299.76, Epsilon: 0.010
# Episode 5872, Total Reward: 10258.69, Epsilon: 0.010
# Episode 5873, Total Reward: 10288.43, Epsilon: 0.010
# Episode 5874, Total Reward: 10282.07, Epsilon: 0.010
# Episode 5875, Total Reward: 10303.72, Epsilon: 0.010
# Episode 5876, Total Reward: 10322.16, Epsilon: 0.010
# Episode 5877, Total Reward: 10339.64, Epsilon: 0.010
# Episode 5878, Total Reward: 10342.78, Epsilon: 0.010
# Episode 5879, Total Reward: 10258.34, Epsilon: 0.010
# Episode 5880, Total Reward: 10320.91, Epsilon: 0.010
# Episode 5881, Total Reward: 10297.54, Epsilon: 0.010
# Episode 5882, Total Reward: 10325.93, Epsilon: 0.010
# Episode 5883, Total Reward: 10311.21, Epsilon: 0.010
# Episode 5884, Total Reward: 10264.56, Epsilon: 0.010
# Episode 5885, Total Reward: 10329.88, Epsilon: 0.010
# Episode 5886, Total Reward: 10317.99, Epsilon: 0.010
# Episode 5887, Total Reward: 10316.06, Epsilon: 0.010
# Episode 5888, Total Reward: 10297.80, Epsilon: 0.010
# Episode 5889, Total Reward: 10310.59, Epsilon: 0.010
# Episode 5890, Total Reward: 10318.95, Epsilon: 0.010
# Episode 5891, Total Reward: 10326.14, Epsilon: 0.010
# Episode 5892, Total Reward: 10307.08, Epsilon: 0.010
# Episode 5893, Total Reward: 10269.06, Epsilon: 0.010
# Episode 5894, Total Reward: 10289.68, Epsilon: 0.010
# Episode 5895, Total Reward: 10330.58, Epsilon: 0.010
# Episode 5896, Total Reward: 10301.55, Epsilon: 0.010
# Episode 5897, Total Reward: 10293.81, Epsilon: 0.010
# Episode 5898, Total Reward: 10314.21, Epsilon: 0.010
# Episode 5899, Total Reward: 10275.10, Epsilon: 0.010
# Episode 5900, Total Reward: 10330.04, Epsilon: 0.010
# Episode 5901, Total Reward: 10320.88, Epsilon: 0.010
# Episode 5902, Total Reward: 10344.04, Epsilon: 0.010
# Episode 5903, Total Reward: 10352.80, Epsilon: 0.010
# Episode 5904, Total Reward: 10312.86, Epsilon: 0.010
# Episode 5905, Total Reward: 10307.03, Epsilon: 0.010
# Episode 5906, Total Reward: 10324.72, Epsilon: 0.010
# Episode 5907, Total Reward: 10347.49, Epsilon: 0.010
# Episode 5908, Total Reward: 10309.34, Epsilon: 0.010
# Episode 5909, Total Reward: 10280.32, Epsilon: 0.010
# Episode 5910, Total Reward: 10258.98, Epsilon: 0.010
# Episode 5911, Total Reward: 10290.21, Epsilon: 0.010
# Episode 5912, Total Reward: 10307.01, Epsilon: 0.010
# Episode 5913, Total Reward: 10290.54, Epsilon: 0.010
# Episode 5914, Total Reward: 10298.09, Epsilon: 0.010
# Episode 5915, Total Reward: 10313.26, Epsilon: 0.010
# Episode 5916, Total Reward: 10294.60, Epsilon: 0.010
# Episode 5917, Total Reward: 10288.47, Epsilon: 0.010
# Episode 5918, Total Reward: 10300.43, Epsilon: 0.010
# Episode 5919, Total Reward: 10314.84, Epsilon: 0.010
# Episode 5920, Total Reward: 10287.88, Epsilon: 0.010
# Episode 5921, Total Reward: 10321.88, Epsilon: 0.010
# Episode 5922, Total Reward: 10331.57, Epsilon: 0.010
# Episode 5923, Total Reward: 10306.66, Epsilon: 0.010
# Episode 5924, Total Reward: 10341.06, Epsilon: 0.010
# Episode 5925, Total Reward: 10335.11, Epsilon: 0.010
# Episode 5926, Total Reward: 10288.95, Epsilon: 0.010
# Episode 5927, Total Reward: 10329.51, Epsilon: 0.010
# Episode 5928, Total Reward: 10307.48, Epsilon: 0.010
# Episode 5929, Total Reward: 10288.10, Epsilon: 0.010
# Episode 5930, Total Reward: 10290.58, Epsilon: 0.010
# Episode 5931, Total Reward: 10284.88, Epsilon: 0.010
# Episode 5932, Total Reward: 10235.86, Epsilon: 0.010
# Episode 5933, Total Reward: 10332.48, Epsilon: 0.010
# Episode 5934, Total Reward: 10296.18, Epsilon: 0.010
# Episode 5935, Total Reward: 10311.52, Epsilon: 0.010
# Episode 5936, Total Reward: 10281.70, Epsilon: 0.010
# Episode 5937, Total Reward: 10270.99, Epsilon: 0.010
# Episode 5938, Total Reward: 10321.76, Epsilon: 0.010
# Episode 5939, Total Reward: 10288.64, Epsilon: 0.010
# Episode 5940, Total Reward: 10319.89, Epsilon: 0.010
# Episode 5941, Total Reward: 10298.99, Epsilon: 0.010
# Episode 5942, Total Reward: 10316.65, Epsilon: 0.010
# Episode 5943, Total Reward: 10312.56, Epsilon: 0.010
# Episode 5944, Total Reward: 10278.73, Epsilon: 0.010
# Episode 5945, Total Reward: 10319.00, Epsilon: 0.010
# Episode 5946, Total Reward: 10314.70, Epsilon: 0.010
# Episode 5947, Total Reward: 10298.03, Epsilon: 0.010
# Episode 5948, Total Reward: 10325.59, Epsilon: 0.010
# Episode 5949, Total Reward: 10300.23, Epsilon: 0.010
# Episode 5950, Total Reward: 10280.22, Epsilon: 0.010
# Episode 5951, Total Reward: 10305.18, Epsilon: 0.010
# Episode 5952, Total Reward: 10239.83, Epsilon: 0.010
# Episode 5953, Total Reward: 10258.50, Epsilon: 0.010
# Episode 5954, Total Reward: 10273.31, Epsilon: 0.010
# Episode 5955, Total Reward: 10309.84, Epsilon: 0.010
# Episode 5956, Total Reward: 10310.01, Epsilon: 0.010
# Episode 5957, Total Reward: 10309.14, Epsilon: 0.010
# Episode 5958, Total Reward: 10309.49, Epsilon: 0.010
# Episode 5959, Total Reward: 10309.66, Epsilon: 0.010
# Episode 5960, Total Reward: 10282.11, Epsilon: 0.010
# Episode 5961, Total Reward: 10302.16, Epsilon: 0.010
# Episode 5962, Total Reward: 10289.51, Epsilon: 0.010
# Episode 5963, Total Reward: 10339.50, Epsilon: 0.010
# Episode 5964, Total Reward: 10291.63, Epsilon: 0.010
# Episode 5965, Total Reward: 10326.66, Epsilon: 0.010
# Episode 5966, Total Reward: 10292.18, Epsilon: 0.010
# Episode 5967, Total Reward: 10287.25, Epsilon: 0.010
# Episode 5968, Total Reward: 10305.73, Epsilon: 0.010
# Episode 5969, Total Reward: 10313.19, Epsilon: 0.010
# Episode 5970, Total Reward: 10297.97, Epsilon: 0.010
# Episode 5971, Total Reward: 10288.96, Epsilon: 0.010
# Episode 5972, Total Reward: 10294.90, Epsilon: 0.010
# Episode 5973, Total Reward: 10336.75, Epsilon: 0.010
# Episode 5974, Total Reward: 10296.96, Epsilon: 0.010
# Episode 5975, Total Reward: 10323.43, Epsilon: 0.010
# Episode 5976, Total Reward: 10298.84, Epsilon: 0.010
# Episode 5977, Total Reward: 10301.32, Epsilon: 0.010
# Episode 5978, Total Reward: 10257.55, Epsilon: 0.010
# Episode 5979, Total Reward: 10269.27, Epsilon: 0.010
# Episode 5980, Total Reward: 10303.08, Epsilon: 0.010
# Episode 5981, Total Reward: 10292.79, Epsilon: 0.010
# Episode 5982, Total Reward: 10298.41, Epsilon: 0.010
# Episode 5983, Total Reward: 10252.44, Epsilon: 0.010
# Episode 5984, Total Reward: 10296.73, Epsilon: 0.010
# Episode 5985, Total Reward: 10269.13, Epsilon: 0.010
# Episode 5986, Total Reward: 10253.07, Epsilon: 0.010
# Episode 5987, Total Reward: 10309.27, Epsilon: 0.010
# Episode 5988, Total Reward: 10310.75, Epsilon: 0.010
# Episode 5989, Total Reward: 10328.88, Epsilon: 0.010
# Episode 5990, Total Reward: 10297.85, Epsilon: 0.010
# Episode 5991, Total Reward: 10333.92, Epsilon: 0.010
# Episode 5992, Total Reward: 10318.48, Epsilon: 0.010
# Episode 5993, Total Reward: 10299.81, Epsilon: 0.010
# Episode 5994, Total Reward: 10281.52, Epsilon: 0.010
# Episode 5995, Total Reward: 10310.50, Epsilon: 0.010
# Episode 5996, Total Reward: 10298.06, Epsilon: 0.010
# Episode 5997, Total Reward: 10357.11, Epsilon: 0.010
# Episode 5998, Total Reward: 10327.57, Epsilon: 0.010
# Episode 5999, Total Reward: 10295.51, Epsilon: 0.010
# Episode 6000, Total Reward: 10285.22, Epsilon: 0.010

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
from scipy.optimize import linear_sum_assignment

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment (no reward needed for KM) --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]  # only 2 RSUs

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQNNet Definition --------
import torch.nn as nn

class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data and Rebuild Env --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained DQN --------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
state_size = len(env.reset())
action_size = 3

policy_net = DQNNet(state_size, action_size).to(device)
policy_net.load_state_dict(torch.load("dqn_multi_vehicle.pth", map_location=device))
policy_net.eval()

# -------- KM Matching on Initial State --------
def run_dqn_hungarian(policy_net, state, vehicle_ids, action_size):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    cost_matrix = -q_matrix
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    print("Hungarian Assignment (Vehicle → Action):")
    for v_idx, a_idx in zip(row_ind, col_ind):
        print(f"Vehicle {vehicle_ids[v_idx]} → Action {a_idx} (Q: {q_matrix[v_idx, a_idx]:.2f})")

    total_q = q_matrix[row_ind, col_ind].sum()
    print(f"Total Q-value: {total_q:.2f}")
    return col_ind, q_matrix

# Run KM matching
state = env.reset()
actions, q_matrix = run_dqn_hungarian(policy_net, state, top_15_ids, action_size)
# Out:
# Hungarian Assignment (Vehicle → Action):
# Vehicle 35 → Action 0 (Q: 381.90)
# Vehicle 24 → Action 1 (Q: 386.66)
# Vehicle 3 → Action 2 (Q: 387.87)
# Total Q-value: 1156.43

# %%
def detect_rsu_range_per__vehicle(tv_x, tv_y, tv_velocity, eta, R, t_link, t_com, rsu1_pos=(500, 0), rsu2_pos=(1450, 0)):
    """
    Detect RSU range for a single vehicle using predicted trajectory and the algorithm from the paper.

    Parameters:
        tv_x, tv_y (float): Current position
        tv_velocity (float): Estimated constant velocity
        eta, R, t_link, t_com: Stability parameters
        rsu1_pos, rsu2_pos: RSU coordinates (default for 2 RSUs)

    Returns:
        rsu_set: List of RSU indices (1 or 2) if covered, else [-1]
    """
    def calc_dist(x1, y1, x2, y2):
        return np.sqrt((x1 - x2)**2 + (y1 - y2)**2)

    # Slot t and t+1 center positions
    d_r1_t = calc_dist(tv_x, tv_y, *rsu1_pos)
    d_r1_tp1 = calc_dist(tv_x + tv_velocity, tv_y, *rsu1_pos)
    d_r2_t = calc_dist(tv_x, tv_y, *rsu2_pos)
    d_r2_tp1 = calc_dist(tv_x + tv_velocity, tv_y, *rsu2_pos)

    rsu_t = set()
    rsu_tp1 = set()

    # Time slot t
    if ((eta + 2 * R) - d_r2_t) / tv_velocity <= t_link + t_com:
        rsu_t.add(2)
        if (R - d_r1_t) / tv_velocity <= t_link + t_com:
            if R >= d_r1_t >= eta:
                rsu_t.add(1)

    if (R - d_r1_t) / tv_velocity <= t_link + t_com and not (R >= d_r1_t >= eta):
        rsu_t.add(1)

    # Time slot t+1
    if ((eta + 2 * R) - d_r2_tp1) / tv_velocity <= t_link + t_com:
        rsu_tp1.add(2)
        if (R - d_r1_tp1) / tv_velocity <= t_link + t_com:
            if R >= d_r1_tp1 >= eta:
                rsu_tp1.update([1, 2])
            else:
                rsu_tp1.add(1)
    elif (R - d_r1_tp1) / tv_velocity <= t_link + t_com:
        rsu_tp1.add(1)

    # Final decision
    if rsu_t and rsu_tp1:
        intersect = rsu_t.intersection(rsu_tp1)
        return list(intersect) if intersect else [-1]
    return [-1]

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
import torch.nn as nn
import matplotlib.pyplot as plt
import networkx as nx
from scipy.optimize import linear_sum_assignment

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQN Model --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data and Setup --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained Model --------
device = torch.device("cpu")
state_size = len(env.reset())
action_size = 3
policy_net = DQNNet(state_size, action_size).to(device)
policy_net.eval()

def detect_rsu_range_per_vehicle(tv_x, tv_y, tv_velocity, eta, R, t_link, t_com):

    return [-1]
def generate_random_mask(num_vehicles, action_size, min_links=1, max_links=3):
    mask = np.zeros((num_vehicles, action_size), dtype=int)
    for i in range(num_vehicles):
        k = random.randint(min_links, min(max_links, action_size))
        selected = random.sample(range(action_size), k)
        mask[i, selected] = 1
    return mask

def run_dqn_hungarian(policy_net, state, vehicle_ids, action_size, availability_mask):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(next(policy_net.parameters()).device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    cost_matrix = -np.where(availability_mask == 1, q_matrix, 1e6)  # Large cost for disallowed assignments
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    print("Hungarian Assignment (all assignments valid):")
    for v_idx, a_idx in zip(row_ind, col_ind):
        print(f"Vehicle {vehicle_ids[v_idx]} → Action {a_idx} (Q: {q_matrix[v_idx, a_idx]:.2f})")

    total_q = q_matrix[row_ind, col_ind].sum()
    print(f"Total Q-value: {total_q:.2f}")
    return col_ind, q_matrix, availability_mask

# -------- Plot Function --------
def plot_bipartite_graph(q_matrix, actions, vehicle_ids, availability_mask, filename=None):
    B = nx.Graph()
    left_nodes = [f'V{vid}' for vid in vehicle_ids]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    for i, v in enumerate(left_nodes):
        for j, a in enumerate(right_nodes):
            if availability_mask[i][j]:
                weight = q_matrix[i][j]
                B.add_edge(v, a, weight=round(weight, 2))

    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    for i, j in enumerate(actions):
        v = f'V{vehicle_ids[i]}'
        a = f'A{j}'
        if B.has_node(v) and B.has_node(a):
            B.add_edge(v, a)
            nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with Random Constraints (KM Assignment)")
    plt.axis('off')
    if filename:
        plt.savefig(filename)
    plt.show()

# -------- Apply Random Mask and Run --------
state = env.reset()
availability_mask = generate_random_mask(len(top_15_ids), action_size, min_links=1, max_links=2)
actions, q_matrix, mask_used = run_dqn_hungarian(policy_net, state, top_15_ids, action_size, availability_mask)
plot_bipartite_graph(q_matrix, actions, top_15_ids, mask_used)
# Out:
# Hungarian Assignment (all assignments valid):
# Vehicle 35 → Action 0 (Q: 0.57)
# Vehicle 24 → Action 2 (Q: 3.58)
# Vehicle 12 → Action 1 (Q: -0.96)
# Total Q-value: 3.19

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
import matplotlib.pyplot as plt
import networkx as nx
from scipy.optimize import linear_sum_assignment
import torch.nn as nn

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQN Model --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained Model --------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
state_size = len(env.reset())
action_size = 3
policy_net = DQNNet(state_size, action_size).to(device)
policy_net.load_state_dict(torch.load("dqn_multi_vehicle.pth", map_location=device))
policy_net.eval()

# -------- Generate Random Mask --------
def generate_random_mask(num_vehicles, action_size, min_links=1, max_links=3):
    mask = np.zeros((num_vehicles, action_size), dtype=int)
    for i in range(num_vehicles):
        k = random.randint(min_links, min(max_links, action_size))
        selected = random.sample(range(action_size), k)
        mask[i, selected] = 1
    return mask

# -------- Hungarian Assignment --------
def run_dqn_hungarian(policy_net, state, vehicle_ids, action_size):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    cost_matrix = -q_matrix
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    print("Hungarian Assignment (Vehicle → Action):")
    for v_idx, a_idx in zip(row_ind, col_ind):
        print(f"Vehicle {vehicle_ids[v_idx]} → Action {a_idx} (Q: {q_matrix[v_idx, a_idx]:.2f})")

    total_q = q_matrix[row_ind, col_ind].sum()
    print(f"Total Q-value: {total_q:.2f}")
    return col_ind, q_matrix

# -------- Plot Bipartite Graph --------
def plot_bipartite_graph(q_matrix, actions, vehicle_ids, availability_mask=None, filename=None):
    B = nx.Graph()
    left_nodes = [f'V{vid}' for vid in vehicle_ids]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    for i, v in enumerate(left_nodes):
        for j, a in enumerate(right_nodes):
            if availability_mask is None or availability_mask[i][j]:
                weight = q_matrix[i][j]
                B.add_edge(v, a, weight=round(weight, 2))

    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    for i, j in enumerate(actions):
        v = f'V{vehicle_ids[i]}'
        a = f'A{j}'
        if B.has_edge(v, a):
            nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with KM Matching ")
    plt.axis('off')
    if filename:
        plt.savefig(filename)
    plt.show()

# -------- Run Everything --------
state = env.reset()
availability_mask = generate_random_mask(len(top_15_ids), action_size, min_links=1, max_links=2)
actions, q_matrix = run_dqn_hungarian(policy_net, state, top_15_ids, action_size)
plot_bipartite_graph(q_matrix, actions, top_15_ids, availability_mask)
# Out:
# Hungarian Assignment (Vehicle → Action):
# Vehicle 35 → Action 0 (Q: 381.90)
# Vehicle 24 → Action 1 (Q: 386.66)
# Vehicle 3 → Action 2 (Q: 387.87)
# Total Q-value: 1156.43

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
import matplotlib.pyplot as plt
import networkx as nx
from scipy.optimize import linear_sum_assignment
import torch.nn as nn

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQN Model --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained Model --------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
state_size = len(env.reset())
action_size = 3
policy_net = DQNNet(state_size, action_size).to(device)
policy_net.load_state_dict(torch.load("dqn_multi_vehicle.pth", map_location=device))
policy_net.eval()

# -------- Generate Random Mask --------
def generate_random_mask(num_vehicles, action_size, min_links=1, max_links=3):
    mask = np.zeros((num_vehicles, action_size), dtype=int)
    for i in range(num_vehicles):
        k = random.randint(min_links, min(max_links, action_size))
        selected = random.sample(range(action_size), k)
        mask[i, selected] = 1
    return mask

# -------- Hungarian Assignment (Fixed) --------
def run_dqn_hungarian(policy_net, state, vehicle_ids, action_size):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    cost_matrix = -q_matrix
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    print("Hungarian Assignment (Vehicle → Action):")
    for v_idx, a_idx in zip(row_ind, col_ind):
        print(f"Vehicle {vehicle_ids[v_idx]} → Action {a_idx} (Q: {q_matrix[v_idx, a_idx]:.2f})")

    total_q = q_matrix[row_ind, col_ind].sum()
    print(f"Total Q-value: {total_q:.2f}")
    return row_ind, col_ind, q_matrix

# -------- Plot Bipartite Graph --------
def plot_bipartite_graph(q_matrix, col_ind, vehicle_ids, availability_mask=None, row_ind=None, filename=None):
    B = nx.Graph()
    left_nodes = [f'V{vid}' for vid in vehicle_ids]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    for i, v in enumerate(left_nodes):
        for j, a in enumerate(right_nodes):
            if availability_mask is None or availability_mask[i][j]:
                weight = q_matrix[i][j]
                B.add_edge(v, a, weight=round(weight, 2))

    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    if row_ind is not None:
        for i, j in zip(row_ind, col_ind):
            v = f'V{vehicle_ids[i]}'
            a = f'A{j}'
            if B.has_edge(v, a):
                nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with KM Matching")
    plt.axis('off')
    if filename:
        plt.savefig(filename)
    plt.show()

# -------- Run Everything --------
state = env.reset()
availability_mask = generate_random_mask(len(top_15_ids), action_size, min_links=1, max_links=2)
row_ind, col_ind, q_matrix = run_dqn_hungarian(policy_net, state, top_15_ids, action_size)
plot_bipartite_graph(q_matrix, col_ind, top_15_ids, availability_mask, row_ind)
# Out:
# Hungarian Assignment (Vehicle → Action):
# Vehicle 35 → Action 0 (Q: 381.90)
# Vehicle 24 → Action 1 (Q: 386.66)
# Vehicle 3 → Action 2 (Q: 387.87)
# Total Q-value: 1156.43

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
import matplotlib.pyplot as plt
import networkx as nx
from scipy.optimize import linear_sum_assignment
import torch.nn as nn

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQN Model --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained Model --------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
state_size = len(env.reset())
action_size = 3
policy_net = DQNNet(state_size, action_size).to(device)
policy_net.load_state_dict(torch.load("dqn_multi_vehicle.pth", map_location=device))
policy_net.eval()

# -------- Generate  Mask --------
def generate_random_mask(num_vehicles, action_size, min_links=1, max_links=3):
    mask = np.zeros((num_vehicles, action_size), dtype=int)
    for i in range(num_vehicles):
        k = random.randint(min_links, min(max_links, action_size))
        selected = random.sample(range(action_size), k)
        mask[i, selected] = 1
    return mask

# -------- Hungarian Assignment --------
def run_dqn_hungarian(policy_net, state, vehicle_ids, action_size):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    cost_matrix = -q_matrix
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    print("Hungarian Assignment (Vehicle → Action):")
    for v_idx, a_idx in zip(row_ind, col_ind):
        print(f"Vehicle {vehicle_ids[v_idx]} → Action {a_idx} (Q: {q_matrix[v_idx, a_idx]:.2f})")

    total_q = q_matrix[row_ind, col_ind].sum()
    print(f"Total Q-value: {total_q:.2f}")
    return row_ind, col_ind, q_matrix

# -------- Plot Bipartite Graph (with shuffled Vx) --------
def plot_bipartite_graph(q_matrix, col_ind, vehicle_ids, availability_mask=None, row_ind=None, filename=None):
    B = nx.Graph()




    shuffled_indices = list(range(len(vehicle_ids)))
    random.shuffle(shuffled_indices)
    shuffled_vehicle_ids = [vehicle_ids[i] for i in shuffled_indices]

    left_nodes = [f'V{vid}' for vid in shuffled_vehicle_ids]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    # Add weighted edges with respect to shuffled index
    for i_shuffled, vid in zip(shuffled_indices, vehicle_ids):
        v = f'V{vid}'
        for j, a in enumerate(right_nodes):
            if availability_mask is None or availability_mask[i_shuffled][j]:
                weight = q_matrix[i_shuffled][j]
                B.add_edge(v, a, weight=round(weight, 2))

    # Define layout
    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))   # shuffled Vx
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))  # fixed Ax

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    # Draw only KM-assigned edges
    if row_ind is not None:
        for i_orig, j in zip(row_ind, col_ind):
            v = f'V{vehicle_ids[i_orig]}'
            a = f'A{j}'
            if B.has_edge(v, a):
                nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with KM Matching")
    plt.axis('off')
    if filename:
        plt.savefig(filename)
    plt.show()

# -------- Run Everything --------
state = env.reset()
availability_mask = generate_random_mask(len(top_15_ids), action_size, min_links=1, max_links=2)
row_ind, col_ind, q_matrix = run_dqn_hungarian(policy_net, state, top_15_ids, action_size)
plot_bipartite_graph(q_matrix, col_ind, top_15_ids, availability_mask, row_ind)
# Out:
# Hungarian Assignment (Vehicle → Action):
# Vehicle 35 → Action 0 (Q: 381.90)
# Vehicle 24 → Action 1 (Q: 386.66)
# Vehicle 3 → Action 2 (Q: 387.87)
# Total Q-value: 1156.43

# %% [markdown]
# Greedy

# %%
import torch
import numpy as np
import pandas as pd
import math
import random
import torch.nn as nn
import matplotlib.pyplot as plt
import networkx as nx
from scipy.optimize import linear_sum_assignment

# -------- Constants --------
m = 10**6
g = 10**9

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

# -------- Environment --------
class MultiVehicleEnvironment:
    def __init__(self, vehicles, rsu, trajectories_dict):
        self.vehicles = vehicles
        self.rsu = rsu
        self.trajectories = trajectories_dict
        self.vehicle_ids = list(trajectories_dict.keys())
        self.num_vehicles = len(self.vehicle_ids)
        self.max_steps = min(len(traj) for traj in trajectories_dict.values())
        self.current_step = 0
        self.rsu_positions = [(500, 0), (1450, 0)]

    def reset(self):
        self.current_step = 0
        self.Soff = [0] * self.num_vehicles
        self.Ssche = [0] * self.num_vehicles
        self.Salloc = [0] * self.num_vehicles
        self.Srest = [self.rsu.resource_capacity]
        return self.Soff + self.Ssche + self.Salloc + self.Srest

# -------- DQN Model --------
class DQNNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQNNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_size)
        )

    def forward(self, x):
        return self.fc(x)

# -------- Load Data and Setup --------
data = np.load("test_predictions_full_300.npz")
predicted = data['predicted']
vehicle_ids = data['vehicle_ids']

df = pd.DataFrame(np.hstack([vehicle_ids.reshape(-1, 1), predicted]),
                  columns=["vehicle_id", "lat", "lon", "vx", "vy"])
top_15_ids = df['vehicle_id'].value_counts().head(15).index.astype(int).tolist()
trajectories = {vid: df[df['vehicle_id'] == vid][["lat", "lon", "vx", "vy"]].values for vid in top_15_ids}

vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
env = MultiVehicleEnvironment(vehicles, rsu, trajectories)

# -------- Load Trained Model --------
device = torch.device("cpu")
state_size = len(env.reset())
action_size = 3
policy_net = DQNNet(state_size, action_size).to(device)
policy_net.eval()

# -------- Greedy Matching (Worse than KM) --------
def run_dqn_greedy_worse(policy_net, state, vehicle_ids, action_size):
    q_matrix = []
    for _ in vehicle_ids:
        s = torch.tensor([state], dtype=torch.float32).to(next(policy_net.parameters()).device)
        with torch.no_grad():
            q_values = policy_net(s).cpu().numpy().flatten()
        q_matrix.append(q_values)

    q_matrix = np.array(q_matrix)
    actions = [-1] * len(vehicle_ids)
    used_actions = set()

    for i in range(len(vehicle_ids)):

        valid_q = [(j, q_matrix[i][j]) for j in range(action_size) if j not in used_actions]
        if valid_q:
            worst_action = min(valid_q, key=lambda x: x[1])[0]
            actions[i] = worst_action
            used_actions.add(worst_action)

    total_q = sum(q_matrix[i][a] for i, a in enumerate(actions) if a != -1)
    print("Greedy (Suboptimal) Assignment:")
    for i, a in enumerate(actions):
        print(f"Vehicle {vehicle_ids[i]} → Action {a} (Q: {q_matrix[i, a]:.2f})" if a != -1 else f"Vehicle {vehicle_ids[i]} → No assignment")
    print(f"Total Q-value: {total_q:.2f}")
    return actions, q_matrix

# -------- RSU Range Detection Stub --------
def detect_rsu_range_per_vehicle_stub(tv_x, tv_y, tv_velocity, eta, R, t_link, t_com):
    return [-1]

# -------- Plot Function --------
def plot_bipartite_graph(q_matrix, actions, vehicle_ids, filename=None):
    B = nx.Graph()
    left_nodes = [f'V{vid}' for vid in vehicle_ids]
    right_nodes = [f'A{j}' for j in range(q_matrix.shape[1])]

    B.add_nodes_from(left_nodes, bipartite=0)
    B.add_nodes_from(right_nodes, bipartite=1)

    for i, v in enumerate(left_nodes):
        for j, a in enumerate(right_nodes):
            weight = q_matrix[i][j]
            B.add_edge(v, a, weight=round(weight, 2))

    pos = {}
    pos.update((n, (0, i)) for i, n in enumerate(left_nodes))
    pos.update((n, (1, i)) for i, n in enumerate(right_nodes))

    plt.figure(figsize=(12, 6))
    edge_labels = nx.get_edge_attributes(B, 'weight')
    nx.draw(B, pos, with_labels=True, node_color='lightblue', edge_color='gray')
    nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

    for i, j in enumerate(actions):
        v = f'V{vehicle_ids[i]}'
        a = f'A{j}'
        if j != -1 and B.has_node(v) and B.has_node(a):
            B.add_edge(v, a)
            nx.draw_networkx_edges(B, pos, edgelist=[(v, a)], width=2, edge_color='red')

    plt.title("Bipartite Graph with Suboptimal Greedy Assignment")
    plt.axis('off')
    if filename:
        plt.savefig(filename)
    plt.show()

# -------- Run Greedy Worse --------
state = env.reset()
actions, q_matrix = run_dqn_greedy_worse(policy_net, state, top_15_ids, action_size)
plot_bipartite_graph(q_matrix, actions, top_15_ids)

# -------- Example call to RSU detection stub --------
example_rsu_result = detect_rsu_range_per_vehicle_stub(tv_x=1000, tv_y=0, tv_velocity=25, eta=450, R=500, t_link=0.02, t_com=0.01)
print("Example RSU range detected:", example_rsu_result)
# Out:
# Greedy (Suboptimal) Assignment:
# Vehicle 35 → Action 0 (Q: -1.16)
# Vehicle 24 → Action 1 (Q: 0.54)
# Vehicle 3 → Action 2 (Q: 3.46)
# Vehicle 12 → No assignment
# Vehicle 2 → No assignment
# Vehicle 17 → No assignment
# Vehicle 8 → No assignment
# Vehicle 1 → No assignment
# Vehicle 36 → No assignment
# Vehicle 6 → No assignment
# Vehicle 0 → No assignment
# Vehicle 20 → No assignment
# Vehicle 33 → No assignment
# Vehicle 5 → No assignment
# Vehicle 28 → No assignment
# Total Q-value: 2.84
# Example RSU range detected: [-1]

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# -------- Constants --------
m = 10**6
g = 10**9
W = 10 * m
P_u = 0.1
sigma2 = 10**(-17.4)
I = 1e-10

# -------- RSU and Vehicle Classes --------
class RSU:
    def __init__(self):
        self.radius = 500
        self.freq = random.uniform(1.6 * g, 2.4 * g)
        self.resource_capacity = 100

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

class Vehicle:
    def __init__(self):
        self.freq = 0.3 * g

    def compDelay(self, cpu_cycles):
        return cpu_cycles / self.freq

# -------- Setup --------
top_15_ids = list(range(15))
trajectories = {
    vid: np.array([[random.uniform(0, 2000), 0, random.uniform(10, 30), 0]])
    for vid in top_15_ids
}
vehicles = {vid: Vehicle() for vid in top_15_ids}
rsu = RSU()
rsu_positions = [(500, 0), (1450, 0)]

# -------- Episode
episodes = np.arange(0, 6000, 500)
latency_log_pdqkm = []
osr_log_pdqkm = []
tcv_log_pdqkm = []



# -------- Plotting (Only PDQKM) --------
def rsu_return_delay(data_size):
    rate = W * math.log2(1 + (P_u * 1e-7) / (sigma2 + I))
    return data_size / rate

for ep in episodes:
    delays = []
    successes = 0

    for vid in top_15_ids:
        cpu_cycles = random.uniform(0.5, 1.2) * g
        data_size = random.uniform(0.3, 1.0) * m
        task_deadline = 1.2
        x, y, _, _ = trajectories[vid][0]
        action = random.randint(0, 2)  # 0: local, 1/2: RSU

        if action == 0:
            delay = vehicles[vid].compDelay(cpu_cycles)
        else:
            comp = rsu.compDelay(cpu_cycles)
            t_ret = rsu_return_delay(data_size)
            delay = comp + t_ret

        delays.append(delay)
        if delay <= task_deadline:
            successes += 1

    avg_latency = np.mean(delays)
    osr = successes / len(top_15_ids)
    tcv = (0.5 * (1 / avg_latency)) + (0.5 * osr)

    latency_log_pdqkm.append(avg_latency)
    osr_log_pdqkm.append(osr)
    tcv_log_pdqkm.append(tcv)


fig, axs = plt.subplots(1, 3, figsize=(16, 4))

axs[0].plot(episodes, latency_log_pdqkm, marker='^', color='blue', label='PDQKM')
axs[0].set_title('(a) Total system latency')
axs[0].set_xlabel('Episodes')
axs[0].set_ylabel('System latency (s)')
axs[0].grid(True)
axs[0].legend()

axs[1].plot(episodes, osr_log_pdqkm, marker='^', color='blue', label='PDQKM')
axs[1].set_title('(b) Offloading success rate')
axs[1].set_xlabel('Episodes')
axs[1].set_ylabel('Success rate')
axs[1].grid(True)
axs[1].legend()

axs[2].plot(episodes, tcv_log_pdqkm, marker='^', color='blue', label='PDQKM')
axs[2].set_title('(c) Task computing value')
axs[2].set_xlabel('Episodes')
axs[2].set_ylabel('TCV')
axs[2].grid(True)
axs[2].legend()

plt.tight_layout()
plt.show()
